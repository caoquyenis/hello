# %% [markdown]
# # Part I. ETL Pipeline for Pre-Processing the Files

# %%
# Import Python packages 
import pandas as pd
import cassandra
import re
import os
import glob
import numpy as np
import json
import csv

# %% [markdown]
# ## PLEASE RUN THE FOLLOWING CODE FOR PRE-PROCESSING THE FILES

# %% [markdown]
# #### Import Python packages

# %% [markdown]
# # Import Python packages
# import pandas as pd
# import cassandra
# import re
# import os
# import glob
# import numpy as np
# import json
# import csv

# %% [markdown]
# #### Creating list of filepaths to process original event csv data files

# %%
# checking your current working directory
print(os.getcwd())

# Get your current folder and subfolder event data
filepath = os.getcwd() + '/event_data'

# Create a for loop to create a list of files and collect each filepath
for root, dirs, files in os.walk(filepath):
    
# join the file path and roots with the subdirectories using glob
    file_path_list = glob.glob(os.path.join(root,'*'))
    #print(file_path_list)
# Out:
# /Users/genie/hello/Project1B

# %% [markdown]
# #### Processing the files to create the data file csv that will be used for Apache Casssandra tables

# %%
# initiating an empty list of rows that will be generated from each file
full_data_rows_list = [] 
    
# for every filepath in the file path list 
for f in file_path_list:

# reading csv file 
    with open(f, 'r', encoding = 'utf8', newline='') as csvfile: 
        # creating a csv reader object 
        csvreader = csv.reader(csvfile) 
        next(csvreader)
        
 # extracting each data row one by one and append it        
        for line in csvreader:
            #print(line)
            full_data_rows_list.append(line) 
            
# uncomment the code below if you would like to get total number of rows 
#print(len(full_data_rows_list))
# uncomment the code below if you would like to check to see what the list of event data rows will look like
#print(full_data_rows_list)

# creating a smaller event data csv file called event_datafile_full csv that will be used to insert data into the \
# Apache Cassandra tables
csv.register_dialect('myDialect', quoting=csv.QUOTE_ALL, skipinitialspace=True)

with open('event_datafile_new.csv', 'w', encoding = 'utf8', newline='') as f:
    writer = csv.writer(f, dialect='myDialect')
    writer.writerow(['artist','firstName','gender','itemInSession','lastName','length',\
                'level','location','sessionId','song','userId'])
    for row in full_data_rows_list:
        if (row[0] == ''):
            continue
        writer.writerow((row[0], row[2], row[3], row[4], row[5], row[6], row[7], row[8], row[12], row[13], row[16]))

# %%
# check the number of rows in your csv file
with open('event_datafile_new.csv', 'r', encoding = 'utf8') as f:
    print(sum(1 for line in f))
# Out:
# 6821

# %% [markdown]
# # Part II. Complete the Apache Cassandra coding portion of your project.
#
# ## Now you are ready to work with the CSV file titled <font color=red>event_datafile_new.csv</font>, located within the Workspace directory.  The event_datafile_new.csv contains the following columns:
# - artist
# - firstName of user
# - gender of user
# - item number in session
# - last name of user
# - length of the song
# - level (paid or free song)
# - location of the user
# - sessionId
# - song title
# - userId
#
# The image below is a screenshot of what the denormalized data should appear like in the <font color=red>**event_datafile_new.csv**</font> after the code above is run:<br>
#
# <img src="images/image_event_datafile_new.jpg">

# %% [markdown]
# ## Begin writing your Apache Cassandra code in the cells below

# %% [markdown]
# #### Creating a Cluster

# %%
# This should make a connection to a Cassandra instance your local machine 
# (127.0.0.1)

from cassandra.cluster import Cluster
cluster = Cluster()

# To establish connection and begin executing queries, need a session
session = cluster.connect()
# Out:
# /var/folders/48/9b_1nhmd64d2hbpc2ycpg1gc0000gn/T/ipykernel_24021/593601484.py:4: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.9 it will stop working
#   from cassandra.cluster import Cluster

# %% [markdown]
# #### Create Keyspace

# %%
# TO-DO: Create a Keyspace 
try:
    session.execute (
        """CREATE KEYSPACE IF NOT EXISTS udacity
        WITH REPLICATION = {
            'class' : 'SimpleStrategy', 'replication_factor' : 1
        }
        """
    )
except Exception as e:
    print(e)

# %% [markdown]
# #### Set Keyspace

# %%
# TO-DO: Set KEYSPACE to the keyspace specified above
try:
    session.set_keyspace ('udacity')
except Exception as e:
    print(e)

# %% [markdown]
# ## Create queries to ask the following three questions of the data
#
# ### 1. Give me the artist, song title and song's length in the music app history that was heard during  sessionId = 338, and itemInSession  = 4
#
#
# ### 2. Give me only the following: name of artist, song (sorted by itemInSession) and user (first and last name) for userid = 10, sessionid = 182
#
#
# ### 3. Give me every user name (first and last) in my music app history who listened to the song 'All Hands Against His Own'

# %% [markdown]
# ### Now we need to create tables to run the following queries. Remember, with Apache Cassandra you model the database tables on the queries you want to run.

# %%
## Drop table after restart test to prevent duplicate data
query = "drop TABLE IF EXISTS music_by_sessionid_iteminsession "
session.execute(query)

# %%
## TO-DO: Query 1:  Give me the artist, song title and song's length in the music app history that was heard during \
## sessionId = 338, and itemInSession = 4
query = "CREATE TABLE IF NOT EXISTS music_by_sessionid_iteminsession "
query = query + """(
sessionId int, itemInsession int, artist text, song text, length float, 
PRIMARY KEY(sessionId, itemInSession))
"""
try:
    session.execute(query)
except Exception as e:
    print(e)

# %%
## TO-DO: Assign the INSERT statements into the `query` variable
# Insert data into table for query 1
file = 'event_datafile_new.csv'
with open(file, encoding = 'utf8') as f:
    csvreader = csv.reader(f)
    next(csvreader)
    for line in csvreader:
        query = "INSERT INTO music_by_sessionid_iteminsession (sessionId, itemInSession, artist, song, length)"
        query = query + "VALUES (%s, %s, %s, %s, %s)"
        ## Test output value from the file csv
        print((line[0], line[1], line[2], line[3], line[4],float(line[5]),line[6],line[7],line[8],line[9],line[10]))
        ## TO-DO: Assign which column element should be assigned for each column in the INSERT statement.
        session.execute(query, (int(line[8]), int(line[3]), line[0], line[9], float(line[5])))
# Out:
# ('Harmonia', 'Ryan', 'M', '0', 'Smith', 655.77751, 'free', 'San Jose-Sunnyvale-Santa Clara, CA', '583', 'Sehr kosmisch', '26')
# ('The Prodigy', 'Ryan', 'M', '1', 'Smith', 260.07465, 'free', 'San Jose-Sunnyvale-Santa Clara, CA', '583', 'The Big Gundown', '26')
# ('Train', 'Ryan', 'M', '2', 'Smith', 205.45261, 'free', 'San Jose-Sunnyvale-Santa Clara, CA', '583', 'Marry Me', '26')
# ('Sony Wonder', 'Samuel', 'M', '0', 'Gonzalez', 218.06975, 'free', 'Houston-The Woodlands-Sugar Land, TX', '597', 'Blackbird', '61')
# ('Van Halen', 'Tegan', 'F', '2', 'Levine', 289.38404, 'paid', 'Portland-South Portland, ME', '602', 'Best Of Both Worlds (Remastered Album Version)', '80')
# ('Magic Sam', 'Tegan', 'F', '3', 'Levine', 132.04853, 'paid', 'Portland-South Portland, ME', '602', 'Call Me If You Need Me', '80')
# ('Edward Sharpe & The Magnetic Zeros', 'Tegan', 'F', '4', 'Levine', 306.31138, 'paid', 'Portland-South Portland, ME', '602', 'Home', '80')
# ('Usher featuring will.i.am', 'Tegan', 'F', '5', 'Levine', 395.72853, 'paid', 'Portland-South Portland, ME', '602', 'OMG', '80')
# ('Helen Reddy', 'Tegan', 'F', '7', 'Levine', 176.50893, 'paid', 'Portland-South Portland, ME', '602', 'Candle On The Water', '80')
# ('Taylor Swift', 'Tegan', 'F', '8', 'Levine', 201.06404, 'paid', 'Portland-South Portland, ME', '602', 'Our Song', '80')
# ('Sean Paul', 'Tegan', 'F', '9', 'Levine', 245.34159, 'paid', 'Portland-South Portland, ME', '602', 'Baby Boy [feat. Beyonce]', '80')
# ('Soundgarden', 'Lily', 'F', '0', 'Koch', 272.19546, 'paid', 'Chicago-Naperville-Elgin, IL-IN-WI', '582', 'Black Hole Sun', '15')
# ('The Killers', 'Tegan', 'F', '10', 'Levine', 360.75057, 'paid', 'Portland-South Portland, ME', '602', 'Human', '80')
# ('Amy Winehouse', 'Lily', 'F', '1', 'Koch', 165.11955, 'paid', 'Chicago-Naperville-Elgin, IL-IN-WI', '582', 'Addicted', '15')
# ('Steve Anderson', 'Lily', 'F', '2', 'Koch', 265.06404, 'paid', 'Chicago-Naperville-Elgin, IL-IN-WI', '582', 'Air', '15')
# ('Rob Zombie', 'Lily', 'F', '3', 'Koch', 220.13342, 'paid', 'Chicago-Naperville-Elgin, IL-IN-WI', '582', 'Superbeast', '15')
# ('Deadmau5 & Kaskade', 'Lily', 'F', '4', 'Koch', 595.56526, 'paid', 'Chicago-Naperville-Elgin, IL-IN-WI', '582', 'I Remember', '15')
# ('Shania Twain', 'Ryan', 'M', '0', 'Smith', 213.7073, 'free', 'San Jose-Sunnyvale-Santa Clara, CA', '607', "Don't Be Stupid (You Know I Love You)", '26')
# ('Los Campesinos', 'Ryan', 'M', '1', 'Smith', 138.10893, 'free', 'San Jose-Sunnyvale-Santa Clara, CA', '607', 'We throw parties_ you throw knives', '26')
# ('Ill Nino', 'Chloe', 'F', '1', 'Cuevas', 188.9171, 'paid', 'San Francisco-Oakland-Hayward, CA', '606', 'How Can I Live (Spanish version) (Album Version)', '49')
# ('Mia X', 'Chloe', 'F', '2', 'Cuevas', 236.09424, 'paid', 'San Francisco-Oakland-Hayward, CA', '606', 'Thugs Like Me', '49')
# ('Rage Against The Machine', 'Chloe', 'F', '3', 'Cuevas', 314.40934, 'paid', 'San Francisco-Oakland-Hayward, CA', '606', 'Killing In The Name', '49')
# ('Asia 2001', 'Chloe', 'F', '4', 'Cuevas', 150.30812, 'paid', 'San Francisco-Oakland-Hayward, CA', '606', 'Epilogue', '49')
# ('Muse', 'Chloe', 'F', '5', 'Cuevas', 228.93669, 'paid', 'San Francisco-Oakland-Hayward, CA', '606', 'Endlessly', '49')
# ('Rise Against', 'Chloe', 'F', '6', 'Cuevas', 221.17832, 'paid', 'San Francisco-Oakland-Hayward, CA', '606', 'Torches', '49')
# ('Modest Mouse', 'Mohammad', 'M', '3', 'Rodriguez', 259.47383, 'free', 'Sacramento--Roseville--Arden-Arcade, CA', '591', 'The Good Times Are Killing Me', '88')
# ('Marc Anthony', 'Chloe', 'F', '7', 'Cuevas', 314.43546, 'paid', 'San Francisco-Oakland-Hayward, CA', '606', 'Te Conozco Bien', '49')
# ('Regina Spektor', 'Chloe', 'F', '8', 'Cuevas', 191.08526, 'paid', 'San Francisco-Oakland-Hayward, CA', '606', 'The Calculation (Album Version)', '49')
# ('Nina Sky', 'Tegan', 'F', '0', 'Levine', 101.92934, 'paid', 'Portland-South Portland, ME', '611', 'Goodbye (Interlude)', '80')
# ('Five Iron Frenzy', 'Avery', 'F', '0', 'Watkins', 236.09424, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Canada', '30')
# ('Kudai', 'Avery', 'F', '2', 'Watkins', 256.62649, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Ven', '30')
# ('Pulp', 'Avery', 'F', '3', 'Watkins', 260.8322, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Do You Remember The First Time?', '30')
# ("SinÃ\x83Â©ad O'Connor", 'Avery', 'F', '4', 'Watkins', 282.51383, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'I Want Your (Hands On Me)', '30')
# ('Paul Brown', 'Tegan', 'F', '3', 'Levine', 232.54159, 'paid', 'Portland-South Portland, ME', '611', 'Chill Out', '80')
# ('Lasgo', 'Avery', 'F', '5', 'Watkins', 220.13342, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Something (Radio Edit)', '30')
# ('Patty Loveless', 'Tegan', 'F', '4', 'Levine', 188.13342, 'paid', 'Portland-South Portland, ME', '611', "What's A Broken Heart", '80')
# ('Eddie Vedder', 'Avery', 'F', '6', 'Watkins', 236.30322, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Society', '30')
# ('Rogue Wave', 'Tegan', 'F', '5', 'Levine', 234.13506, 'paid', 'Portland-South Portland, ME', '611', 'Christians In Black', '80')
# ('Muse', 'Avery', 'F', '7', 'Watkins', 304.84853, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Uprising', '30')
# ('Amanda Blank', 'Tegan', 'F', '6', 'Levine', 175.09832, 'paid', 'Portland-South Portland, ME', '611', 'Might Like You Better', '80')
# ('The Smiths', 'Avery', 'F', '8', 'Watkins', 162.24608, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Sheila Take A Bow', '30')
# ("Old 97's", 'Tegan', 'F', '7', 'Levine', 231.28771, 'paid', 'Portland-South Portland, ME', '611', 'Victoria (LP Version)', '80')
# ('Selena', 'Avery', 'F', '9', 'Watkins', 316.42077, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Dreaming Of You', '30')
# ('Fat Joe', 'Tegan', 'F', '8', 'Levine', 267.10159, 'paid', 'Portland-South Portland, ME', '611', "What's Luv? (Featuring Ja-Rule & Ashanti) (Explicit Album Version)", '80')
# ('Stars', 'Avery', 'F', '10', 'Watkins', 193.33179, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Soft Revolution', '30')
# ('James Blunt', 'Tegan', 'F', '9', 'Levine', 298.4224, 'paid', 'Portland-South Portland, ME', '611', 'Same Mistake  (Album Version)', '80')
# ('Mayday Parade', 'Avery', 'F', '11', 'Watkins', 203.28444, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Bruised And Scarred (Album Version)', '30')
# ('Die Mooskirchner', 'Tegan', 'F', '10', 'Levine', 169.29914, 'paid', 'Portland-South Portland, ME', '611', "Frisch und g'sund", '80')
# ('Gorillaz', 'Avery', 'F', '12', 'Watkins', 211.77424, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Rockit', '30')
# ('Toby Keith', 'Tegan', 'F', '12', 'Levine', 208.48281, 'paid', 'Portland-South Portland, ME', '611', "Should've Been A Cowboy", '80')
# ('Modest Mouse', 'Avery', 'F', '13', 'Watkins', 284.18567, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Little Motel', '30')
# ('Future Rock', 'Tegan', 'F', '13', 'Levine', 239.90812, 'paid', 'Portland-South Portland, ME', '611', 'Gears', '80')
# ('Noel Pointer', 'Avery', 'F', '14', 'Watkins', 259.7873, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Superwoman (Where Were You When I Needed You) (Digitally Remastered)', '30')
# ('Callenish Circle', 'Tegan', 'F', '14', 'Levine', 226.11546, 'paid', 'Portland-South Portland, ME', '611', 'Forgotten', '80')
# ('Foo Fighters', 'Rylan', 'M', '0', 'George', 250.14812, 'paid', 'Birmingham-Hoover, AL', '575', 'Everlong', '16')
# ('Portishead', 'Avery', 'F', '15', 'Watkins', 238.73261, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Hunter', '30')
# ('Taylor Swift', 'Tegan', 'F', '15', 'Levine', 245.36771, 'paid', 'Portland-South Portland, ME', '611', 'The Way I Loved You', '80')
# ('J-Live', 'Rylan', 'M', '1', 'George', 256.93995, 'paid', 'Birmingham-Hoover, AL', '575', 'Longevity', '16')
# ('The White Stripes', 'Avery', 'F', '16', 'Watkins', 110.47138, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Fell In Love With A Girl', '30')
# ('Dwight Yoakam', 'Tegan', 'F', '16', 'Levine', 239.3073, 'paid', 'Portland-South Portland, ME', '611', "You're The One", '80')
# ('The Black Keys', 'Avery', 'F', '17', 'Watkins', 238.99383, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Lies', '30')
# ('Five', 'Rylan', 'M', '2', 'George', 207.62077, 'paid', 'Birmingham-Hoover, AL', '575', "Got The Feelin'", '16')
# ('Ra', 'Tegan', 'F', '17', 'Levine', 319.9473, 'paid', 'Portland-South Portland, ME', '611', 'Do You Call My Name', '80')
# ('Coolio feat. L.V.', 'Rylan', 'M', '4', 'George', 241.57995, 'paid', 'Birmingham-Hoover, AL', '575', "Gangsta's Paradise (LP Version)", '16')
# ('Paramore', 'Avery', 'F', '18', 'Watkins', 211.51302, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Misery Business (Album Version)', '30')
# ('Leggo Beast', 'Avery', 'F', '19', 'Watkins', 321.93261, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Itchy Feet', '30')
# ('Nneka', 'Rylan', 'M', '5', 'George', 226.79465, 'paid', 'Birmingham-Hoover, AL', '575', 'Gypsy', '16')
# ("Diam's", 'Tegan', 'F', '18', 'Levine', 250.72281, 'paid', 'Portland-South Portland, ME', '611', 'Dans Ma Bulle (Edit Radio - Live 2006)', '80')
# ('Haley Bonar', 'Rylan', 'M', '6', 'George', 149.26322, 'paid', 'Birmingham-Hoover, AL', '575', 'Give It Up', '16')
# ('Mansun', 'Tegan', 'F', '19', 'Levine', 140.53832, 'paid', 'Portland-South Portland, ME', '611', 'Love Remains (Home Demo)', '80')
# ('3 Doors Down', 'Avery', 'F', '20', 'Watkins', 237.13914, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Here Without You', '30')
# ('The Corrs', 'Rylan', 'M', '7', 'George', 168.07138, 'paid', 'Birmingham-Hoover, AL', '575', 'Toss The Feathers (Instrumental) ( LP Version )', '16')
# ('Big Tymers', 'Tegan', 'F', '20', 'Levine', 197.79873, 'paid', 'Portland-South Portland, ME', '611', 'Big', '80')
# ('Thursday', 'Avery', 'F', '21', 'Watkins', 215.37914, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'I Am The Killer (Album Version)', '30')
# ('Motion City Soundtrack', 'Rylan', 'M', '8', 'George', 111.49016, 'paid', 'Birmingham-Hoover, AL', '575', "Don't Call It A Comeback (Album Version)", '16')
# ('Usher', 'Tegan', 'F', '21', 'Levine', 224.10404, 'paid', 'Portland-South Portland, ME', '611', "Hey Daddy (Daddy's Home)", '80')
# ('Juanes', 'Rylan', 'M', '10', 'George', 233.40363, 'paid', 'Birmingham-Hoover, AL', '575', 'No Siento Penas', '16')
# ('The Wombats', 'Avery', 'F', '22', 'Watkins', 164.70159, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Kill The Director [Radio Edit]', '30')
# ('Katy Perry', 'Tegan', 'F', '22', 'Levine', 179.40853, 'paid', 'Portland-South Portland, ME', '611', 'I Kissed A Girl', '80')
# ('As I Lay Dying', 'Rylan', 'M', '11', 'George', 231.78404, 'paid', 'Birmingham-Hoover, AL', '575', 'The Darkest Nights', '16')
# ('BjÃ\x83Â¶rk', 'Avery', 'F', '23', 'Watkins', 348.57751, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Undo', '30')
# ('The Bobby Fuller Four', 'Tegan', 'F', '23', 'Levine', 138.60526, 'paid', 'Portland-South Portland, ME', '611', 'I Fought The Law (LP Version)', '80')
# ('Charly GarcÃ\x83Â\xada', 'Rylan', 'M', '12', 'George', 330.89261, 'paid', 'Birmingham-Hoover, AL', '575', 'Influencia', '16')
# ('New Bomb Turks', 'Tegan', 'F', '24', 'Levine', 60.55138, 'paid', 'Portland-South Portland, ME', '611', 'Too Much', '80')
# ('The Black Keys', 'Tegan', 'F', '25', 'Levine', 196.91057, 'paid', 'Portland-South Portland, ME', '611', 'All Hands Against His Own', '80')
# ('PeterLicht', 'Avery', 'F', '24', 'Watkins', 305.97179, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Blaues Blau', '30')
# ('John Mayer', 'Tegan', 'F', '26', 'Levine', 359.23546, 'paid', 'Portland-South Portland, ME', '611', 'Friends_ Lovers Or Nothing', '80')
# ('Stone Temple Pilots', 'Rylan', 'M', '13', 'George', 255.32036, 'paid', 'Birmingham-Hoover, AL', '575', 'A Song For Sleeping (LP Version)', '16')
# ('Bad Lieutenant', 'Avery', 'F', '25', 'Watkins', 266.84036, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Head Into Tomorrow', '30')
# ('Lily Allen', 'Rylan', 'M', '14', 'George', 192.49587, 'paid', 'Birmingham-Hoover, AL', '575', 'Smile Version Revisited (Mark Ronson Remix) (Explicit)', '16')
# ('Neil Halstead', 'Tegan', 'F', '27', 'Levine', 294.29506, 'paid', 'Portland-South Portland, ME', '611', 'A Gentle Heart', '80')
# ('Juanes', 'Avery', 'F', '26', 'Watkins', 222.37995, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Un DÃ\x83Â\xada Normal', '30')
# ('Distance', 'Rylan', 'M', '15', 'George', 300.87791, 'paid', 'Birmingham-Hoover, AL', '575', 'Ska', '16')
# ('Slipknot', 'Avery', 'F', '27', 'Watkins', 253.98812, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'The Heretic Anthem (Album Version)', '30')
# ('Franz Ferdinand', 'Tegan', 'F', '28', 'Levine', 137.56036, 'paid', 'Portland-South Portland, ME', '611', 'Tell Her Tonight', '80')
# ('Jedi Mind Tricks', 'Rylan', 'M', '16', 'George', 232.88118, 'paid', 'Birmingham-Hoover, AL', '575', 'Suicide', '16')
# ('Miles Davis', 'Tegan', 'F', '29', 'Levine', 285.20444, 'paid', 'Portland-South Portland, ME', '611', 'Stella By Starlight', '80')
# ('B.o.B', 'Avery', 'F', '28', 'Watkins', 269.63546, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', "Nothin' On You [feat. Bruno Mars] (Album Version)", '30')
# ('The Avett Brothers', 'Rylan', 'M', '17', 'George', 300.85179, 'paid', 'Birmingham-Hoover, AL', '575', 'I And Love And You', '16')
# ('Joshua Bell / Paul Coker', 'Tegan', 'F', '30', 'Levine', 275.93098, 'paid', 'Portland-South Portland, ME', '611', 'Caprice viennois op.2', '80')
# ('Bad Brains', 'Avery', 'F', '29', 'Watkins', 32.31302, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', "Joshua's Song (1991 Digital Remaster)", '30')
# ('Shakira ft. Wyclef Jean', 'Avery', 'F', '30', 'Watkins', 215.90159, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', "Hips Don't Lie", '30')
# ('Band Of Horses', 'Rylan', 'M', '18', 'George', 321.14893, 'paid', 'Birmingham-Hoover, AL', '575', 'The Funeral (Album Version)', '16')
# ('Alesana', 'Tegan', 'F', '31', 'Levine', 185.33832, 'paid', 'Portland-South Portland, ME', '611', 'Ambrosia', '80')
# ('Samy Deluxe', 'Avery', 'F', '31', 'Watkins', 236.77342, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Einfach Ich', '30')
# ('Corona', 'Tegan', 'F', '32', 'Levine', 408.60689, 'paid', 'Portland-South Portland, ME', '611', 'Higher Messiah', '80')
# ('The Presets', 'Avery', 'F', '32', 'Watkins', 267.54567, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'If I Know You', '30')
# ('Pixies', 'Avery', 'F', '33', 'Watkins', 98.92526, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'In Heaven', '30')
# ('Existone', 'Tegan', 'F', '33', 'Levine', 652.30322, 'paid', 'Portland-South Portland, ME', '611', 'Wounded Soul', '80')
# ('John Mayer', 'Avery', 'F', '34', 'Watkins', 258.16771, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Bold As Love', '30')
# ('Zakir Hussain', 'Avery', 'F', '35', 'Watkins', 722.442, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'The Great ndian Desert', '30')
# ('Jag Panzer', 'Tegan', 'F', '34', 'Levine', 200.38485, 'paid', 'Portland-South Portland, ME', '611', 'Face Of Fear', '80')
# ('Two Door Cinema Club', 'Tegan', 'F', '35', 'Levine', 189.67465, 'paid', 'Portland-South Portland, ME', '611', 'What You Know', '80')
# ('Little Anthony & The Imperials', 'Tegan', 'F', '36', 'Levine', 127.42485, 'paid', 'Portland-South Portland, ME', '611', 'Hurt', '80')
# ('AndrÃ\x83Â©s Cepeda', 'Avery', 'F', '36', 'Watkins', 211.80036, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Me Lleva Tiempo', '30')
# ('Herb Alpert And The Tijuana Brass', 'Tegan', 'F', '37', 'Levine', 132.80608, 'paid', 'Portland-South Portland, ME', '611', "So What's New", '80')
# ('Ozma', 'Avery', 'F', '37', 'Watkins', 144.53506, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Flight Of Yuri Gagarin', '30')
# ('Ozric Tentacles', 'Tegan', 'F', '38', 'Levine', 461.21751, 'paid', 'Portland-South Portland, ME', '611', 'Mooncalf', '80')
# ('Evanescence', 'Avery', 'F', '38', 'Watkins', 263.78404, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'My Immortal (Album Version)', '30')
# ('Weezer', 'Avery', 'F', '39', 'Watkins', 232.85506, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Velouria', '30')
# ('Flying Lotus', 'Jahiem', 'M', '0', 'Miles', 115.33016, 'free', 'San Antonio-New Braunfels, TX', '369', 'Bad Actors', '43')
# ('Ben Folds', 'Tegan', 'F', '39', 'Levine', 250.87955, 'paid', 'Portland-South Portland, ME', '611', "Bitches Ain't Shit", '80')
# ('matchbox twenty', 'Avery', 'F', '40', 'Watkins', 229.14567, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Unwell (Album Version)', '30')
# ('Deftones', 'Tegan', 'F', '40', 'Levine', 189.75302, 'paid', 'Portland-South Portland, ME', '611', 'Feiticeira (LP Version)', '80')
# ('Silverchair', 'Avery', 'F', '41', 'Watkins', 319.13751, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Without You (Album Version)', '30')
# ('Muse', 'Tegan', 'F', '41', 'Levine', 258.06322, 'paid', 'Portland-South Portland, ME', '611', 'Map Of The Problematique', '80')
# ('Zen CafÃ\x83Â©', 'Avery', 'F', '42', 'Watkins', 259.02975, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Kotona kaikuu', '30')
# ('Mariah Carey / Twista', 'Tegan', 'F', '42', 'Levine', 194.7424, 'paid', 'Portland-South Portland, ME', '611', 'One And Only', '80')
# ('Strike Anywhere', 'Avery', 'F', '43', 'Watkins', 120.00608, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Gunpowder', '30')
# ('Tri Sestry', 'Avery', 'F', '44', 'Watkins', 97.72363, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Had Stupid', '30')
# ('Don Williams', 'Avery', 'F', '45', 'Watkins', 191.03302, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', "If Hollywood Don't Need You", '30')
# ('The Nerves', 'Avery', 'F', '46', 'Watkins', 92.86485, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Are You Famous?', '30')
# ('Ulf Wakenius', 'Avery', 'F', '47', 'Watkins', 324.15302, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Good Morning Susie Soho', '30')
# ('The Kooks', 'Avery', 'F', '48', 'Watkins', 168.72444, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'She Moves In Her Own Way', '30')
# ('New Radicals', 'Avery', 'F', '49', 'Watkins', 300.82567, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'You Get What You Give', '30')
# ('Wolfmother', 'Avery', 'F', '50', 'Watkins', 333.7922, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Where Eagles Have Been', '30')
# ('The Shins', 'Avery', 'F', '51', 'Watkins', 225.61914, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Spilt Needles (Album)', '30')
# ('Nickel Creek', 'Avery', 'F', '52', 'Watkins', 248.58077, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Reasons Why', '30')
# ('Pigeon John', 'Avery', 'F', '53', 'Watkins', 180.00934, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Crazy', '30')
# ('Eels', 'Avery', 'F', '54', 'Watkins', 211.48689, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Love Of The Loveless', '30')
# ('Harmonia', 'Avery', 'F', '55', 'Watkins', 655.77751, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Sehr kosmisch', '30')
# ('Marina And The Diamonds', 'Avery', 'F', '56', 'Watkins', 182.59546, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Oh No! (album version)', '30')
# ('Eminem', 'Avery', 'F', '57', 'Watkins', 284.86485, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'The Real Slim Shady', '30')
# ('Hassisen Kone', 'Avery', 'F', '58', 'Watkins', 162.61179, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'REIPPAINA KÃ\x83Â\x84YMME REKKAIN ALLE', '30')
# ('Dwight Yoakam', 'Avery', 'F', '59', 'Watkins', 239.3073, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', "You're The One", '30')
# ('Sunlounger', 'Avery', 'F', '60', 'Watkins', 594.15465, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'White Sand', '30')
# ("Youssou N'Dour", 'Avery', 'F', '61', 'Watkins', 238.39302, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Tan bi (Heat_ Breeze_ Tenderness) / Chaleur_ brise_ tendress', '30')
# ('The Decemberists', 'Avery', 'F', '62', 'Watkins', 209.08363, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Red Right Ankle', '30')
# ('The Ruts', 'Avery', 'F', '63', 'Watkins', 185.75628, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Savage Circle', '30')
# ('Adrian Legg', 'Avery', 'F', '64', 'Watkins', 122.77506, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'The One-Eyed Turk', '30')
# ('Bedrock', 'Avery', 'F', '66', 'Watkins', 664.0322, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Set In Stone', '30')
# ('Prince & The Revolution', 'Kate', 'F', '0', 'Harrell', 280.00608, 'paid', 'Lansing-East Lansing, MI', '605', "Let's Go Crazy (LP Version)", '97')
# ('The Zombies', 'Kate', 'F', '1', 'Harrell', 157.33506, 'paid', 'Lansing-East Lansing, MI', '605', "She's Coming Home", '97')
# ('Portishead', 'Kate', 'F', '2', 'Harrell', 238.0273, 'paid', 'Lansing-East Lansing, MI', '605', 'Numb', '97')
# ('Jack Johnson', 'Avery', 'F', '67', 'Watkins', 212.68853, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Breakdown', '30')
# ('Justice', 'Kate', 'F', '3', 'Harrell', 205.50485, 'paid', 'Lansing-East Lansing, MI', '605', 'Let There Be Lite (Album Version)', '97')
# ('Snow Patrol', 'Avery', 'F', '68', 'Watkins', 223.18975, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Set Down Your Glass', '30')
# ('Lemon Jelly', 'Kate', 'F', '4', 'Harrell', 238.47138, 'paid', 'Lansing-East Lansing, MI', '605', 'Nice Weather For Ducks', '97')
# ('The Lucksmiths', 'Avery', 'F', '69', 'Watkins', 153.70404, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Tale Of Two Cities', '30')
# ('Ben Kweller', 'Kate', 'F', '5', 'Harrell', 188.60363, 'paid', 'Lansing-East Lansing, MI', '605', 'Magic', '97')
# ('Fedde le Grand Pres. Flamingo', 'Avery', 'F', '70', 'Watkins', 396.32934, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Take No Shhh (Original Mix)', '30')
# ('Rodrigo y Gabriela', 'Kate', 'F', '6', 'Harrell', 233.40363, 'paid', 'Lansing-East Lansing, MI', '605', 'VIKING MAN', '97')
# ('Black Eyed Peas', 'Kate', 'F', '7', 'Harrell', 289.12281, 'paid', 'Lansing-East Lansing, MI', '605', 'I Gotta Feeling', '97')
# ('Five Iron Frenzy', 'Avery', 'F', '71', 'Watkins', 236.09424, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Canada', '30')
# ('Creedence Clearwater Revival', 'Ava', 'F', '0', 'Robinson', 164.57098, 'free', 'New Haven-Milford, CT', '598', 'Down On The Corner', '50')
# ('Kings Of Leon', 'Ava', 'F', '1', 'Robinson', 186.69669, 'free', 'New Haven-Milford, CT', '598', 'Camaro', '50')
# ('Fireflight', 'Avery', 'F', '72', 'Watkins', 201.16853, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Unbreakable', '30')
# ('Steppenwolf', 'Kate', 'F', '8', 'Harrell', 208.14322, 'paid', 'Lansing-East Lansing, MI', '605', 'Born To Be Wild', '97')
# ('New Found Glory', 'Ava', 'F', '2', 'Robinson', 222.69342, 'free', 'New Haven-Milford, CT', '598', 'the king of wishful thinking', '50')
# ('The Pussycat Dolls', 'Avery', 'F', '73', 'Watkins', 221.1522, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Elevator', '30')
# ('Eric Clapton', 'Kate', 'F', '9', 'Harrell', 208.48281, 'paid', 'Lansing-East Lansing, MI', '605', 'Willie And The Hand Jive', '97')
# ('Josh Groban', 'Devin', 'M', '1', 'Larson', 260.70159, 'free', 'Tampa-St. Petersburg-Clearwater, FL', '531', 'Little Drummer Boy [featuring guitarist Andy McKee] (Album Version)', '60')
# ('The Dresden Dolls', 'Avery', 'F', '74', 'Watkins', 286.40608, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Coin-Operated Boy', '30')
# ('Pixies', 'Kate', 'F', '10', 'Harrell', 229.3024, 'paid', 'Lansing-East Lansing, MI', '605', 'Where Is My Mind?', '97')
# ('Creedence Clearwater Revival', 'Devin', 'M', '2', 'Larson', 271.882, 'free', 'Tampa-St. Petersburg-Clearwater, FL', '531', 'I Put A Spell On You', '60')
# ('The Smiths', 'Kate', 'F', '11', 'Harrell', 123.01016, 'paid', 'Lansing-East Lansing, MI', '605', 'Girlfriend In A Coma', '97')
# ('Danger Doom', 'Avery', 'F', '75', 'Watkins', 187.27138, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'No Names (Black Debbie) (Album Version)', '30')
# ('Taylor Swift', 'Kate', 'F', '12', 'Harrell', 233.89995, 'paid', 'Lansing-East Lansing, MI', '605', 'Love Story', '97')
# ('Vilma Palma e Vampiros', 'Avery', 'F', '76', 'Watkins', 281.99138, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'La pachanga', '30')
# ('Busta Rhymes feat. Pharrell', 'Kate', 'F', '13', 'Harrell', 220.47302, 'paid', 'Lansing-East Lansing, MI', '605', 'Light Your Ass On Fire', '97')
# ('Little People', 'Avery', 'F', '77', 'Watkins', 230.1122, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Above The Clouds', '30')
# ('Dwight Yoakam', 'Kate', 'F', '14', 'Harrell', 239.3073, 'paid', 'Lansing-East Lansing, MI', '605', "You're The One", '97')
# ('Amy Winehouse', 'Avery', 'F', '78', 'Watkins', 164.85832, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'He Can Only Hold Her', '30')
# ('Ernie K-Doe', 'Kate', 'F', '15', 'Harrell', 160.96608, 'paid', 'Lansing-East Lansing, MI', '605', 'Te-Ta-Te-Ta-Ta (2002 Digital Remaster)', '97')
# ('Alesana', 'Avery', 'F', '79', 'Watkins', 242.49424, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Congratulations_ I Hate You', '30')
# ('Dwight Yoakam', 'Kate', 'F', '16', 'Harrell', 239.3073, 'paid', 'Lansing-East Lansing, MI', '605', "You're The One", '97')
# ('Gazpacho', 'Avery', 'F', '80', 'Watkins', 253.51791, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Premonicion', '30')
# ('Black Lips', 'Kate', 'F', '17', 'Harrell', 162.76853, 'paid', 'Lansing-East Lansing, MI', '605', 'Lock and Key', '97')
# ('Kanye West', 'Kate', 'F', '18', 'Harrell', 311.84934, 'paid', 'Lansing-East Lansing, MI', '605', 'Stronger', '97')
# ('Arcade Fire', 'Avery', 'F', '81', 'Watkins', 136.69832, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Neon Bible', '30')
# ('Barry Tuckwell/Academy of St Martin-in-the-Fields/Sir Neville Marriner', 'Avery', 'F', '82', 'Watkins', 277.15873, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)', '30')
# ('Fanfarlo', 'Kate', 'F', '19', 'Harrell', 270.78485, 'paid', 'Lansing-East Lansing, MI', '605', "I'm a Pilot", '97')
# ('Crystal Castles', 'Avery', 'F', '83', 'Watkins', 251.08853, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Empathy', '30')
# ('Zeca Baleiro', 'Kate', 'F', '20', 'Harrell', 452.8322, 'paid', 'Lansing-East Lansing, MI', '605', 'Brigitte Bardot', '97')
# ('Angus & Julia Stone', 'Avery', 'F', '86', 'Watkins', 236.95628, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Just A Boy', '30')
# ('Julian Casablancas', 'Avery', 'F', '87', 'Watkins', 302.47138, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', '4 Chords of the Apocalypse', '30')
# ('Fat Joe', 'Kate', 'F', '21', 'Harrell', 241.34485, 'paid', 'Lansing-East Lansing, MI', '605', 'Safe 2 Say [The Incredible] (Album Version - Amended)', '97')
# ("Usher Featuring Lil' Jon & Ludacris", 'Avery', 'F', '88', 'Watkins', 250.38322, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Yeah!', '30')
# ('Pat Benatar', 'Kate', 'F', '22', 'Harrell', 290.37669, 'paid', 'Lansing-East Lansing, MI', '605', "Don't Walk Away", '97')
# ('Fergie', 'Avery', 'F', '89', 'Watkins', 248.39791, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Losing My Ground', '30')
# ('Muse', 'Kate', 'F', '23', 'Harrell', 209.50159, 'paid', 'Lansing-East Lansing, MI', '605', 'Supermassive Black Hole (Twilight Soundtrack Version)', '97')
# ('Two Door Cinema Club', 'Avery', 'F', '90', 'Watkins', 168.09751, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Undercover Martyn', '30')
# ('Spineshank', 'Kate', 'F', '24', 'Harrell', 167.26159, 'paid', 'Lansing-East Lansing, MI', '605', 'Intake (Album Version)', '97')
# ('Whitney Houston Duet With Mariah Carey', 'Avery', 'F', '91', 'Watkins', 273.34485, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'When You Believe', '30')
# ('Death Cab for Cutie', 'Kate', 'F', '25', 'Harrell', 488.64608, 'paid', 'Lansing-East Lansing, MI', '605', 'Transatlanticism', '97')
# ('Noir DÃ\x83Â©sir', 'Avery', 'F', '92', 'Watkins', 374.77832, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Ces Gens LÃ\x83Â\xa0', '30')
# ('Paramore', 'Kate', 'F', '26', 'Harrell', 243.51302, 'paid', 'Lansing-East Lansing, MI', '605', 'Emergency (Album Version)', '97')
# ('My Chemical Romance', 'Avery', 'F', '93', 'Watkins', 188.05506, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Cemetery Drive (Album Version)', '30')
# ('Vincent Vincent And The Villains', 'Kate', 'F', '27', 'Harrell', 154.64444, 'paid', 'Lansing-East Lansing, MI', '605', 'On My Own', '97')
# ('Phoenix', 'Avery', 'F', '94', 'Watkins', 229.79873, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Run Run Run', '30')
# ('Beastie Boys', 'Kate', 'F', '28', 'Harrell', 193.54077, 'paid', 'Lansing-East Lansing, MI', '605', 'Skills To Pay The Bills', '97')
# ('Natasha Bedingfield', 'Lily', 'F', '0', 'Burns', 216.65914, 'free', 'New York-Newark-Jersey City, NY-NJ-PA', '554', 'These Words', '32')
# ('Calle 13', 'Avery', 'F', '95', 'Watkins', 239.3073, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'AtrÃ\x83Â©vete te te', '30')
# ('Sondre Lerche', 'Kate', 'F', '29', 'Harrell', 215.71873, 'paid', 'Lansing-East Lansing, MI', '605', 'Modern Nature', '97')
# ('Cecilia', 'Lily', 'F', '1', 'Burns', 157.77914, 'free', 'New York-Newark-Jersey City, NY-NJ-PA', '554', 'Ultimo Baile', '32')
# ('Air', 'Avery', 'F', '96', 'Watkins', 258.58567, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Mayfair Song', '30')
# ('Five Iron Frenzy', 'Kate', 'F', '30', 'Harrell', 236.09424, 'paid', 'Lansing-East Lansing, MI', '605', 'Canada', '97')
# ('Kings Of Convenience', 'Lily', 'F', '2', 'Burns', 245.02812, 'free', 'New York-Newark-Jersey City, NY-NJ-PA', '554', 'Riot On An Empty Street', '32')
# ('Rhonda Vincent', 'Avery', 'F', '97', 'Watkins', 142.78485, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', "You're In My Heart", '30')
# ('Soulwax', 'Kate', 'F', '31', 'Harrell', 277.002, 'paid', 'Lansing-East Lansing, MI', '605', 'E Talking', '97')
# ('Red', 'Lily', 'F', '3', 'Burns', 227.52608, 'free', 'New York-Newark-Jersey City, NY-NJ-PA', '554', 'Mystery of You', '32')
# ('Sugababes', 'Avery', 'F', '98', 'Watkins', 275.93098, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Overload', '30')
# ('Eminem / Dr. Dre', 'Lily', 'F', '4', 'Burns', 309.83791, 'free', 'New York-Newark-Jersey City, NY-NJ-PA', '554', 'Say What You Say', '32')
# ('Michael Jackson', 'Kate', 'F', '32', 'Harrell', 278.282, 'paid', 'Lansing-East Lansing, MI', '605', 'Scream', '97')
# ('Dominique A', 'Avery', 'F', '99', 'Watkins', 153.20771, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Le Courage Des Oiseaux', '30')
# ('Linkin Park', 'Kate', 'F', '33', 'Harrell', 259.86567, 'paid', 'Lansing-East Lansing, MI', '605', 'My December', '97')
# ('Five Iron Frenzy', 'Avery', 'F', '100', 'Watkins', 236.09424, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Canada', '30')
# ('Dear Nora', 'Avery', 'F', '101', 'Watkins', 59.66322, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Give Me Some Of Yr Love', '30')
# ('The Police', 'Kate', 'F', '34', 'Harrell', 290.24608, 'paid', 'Lansing-East Lansing, MI', '605', 'Message In A Bottle', '97')
# ('Cocoon', 'Avery', 'F', '102', 'Watkins', 159.97342, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Microwave', '30')
# ('Coldplay', 'Celeste', 'F', '0', 'Williams', 349.93587, 'free', 'Klamath Falls, OR', '485', 'A Rush Of Blood To The Head', '53')
# ('Peter And Gordon', 'Maia', 'F', '0', 'Burke', 161.14893, 'free', 'Houston-The Woodlands-Sugar Land, TX', '526', 'A World Without Love', '51')
# ('Gotye', 'Avery', 'F', '103', 'Watkins', 360.33261, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Coming Back', '30')
# ('Maps', 'Kate', 'F', '35', 'Harrell', 255.9473, 'paid', 'Lansing-East Lansing, MI', '605', 'To The Sky', '97')
# ('Joshua Radin', 'Maia', 'F', '1', 'Burke', 169.32526, 'free', 'Houston-The Woodlands-Sugar Land, TX', '526', "I'd Rather Be With You", '51')
# ("D'Angelo", 'Chloe', 'F', '3', 'Cuevas', 344.94649, 'paid', 'San Francisco-Oakland-Hayward, CA', '621', 'When We Get By', '49')
# ('Blockhead', 'Celeste', 'F', '1', 'Williams', 289.56689, 'free', 'Klamath Falls, OR', '485', 'The Music Scene', '53')
# ('Nine Inch Nails', 'Ayla', 'F', '0', 'Johnson', 300.64281, 'free', 'Santa Rosa, CA', '588', 'Terrible Lie', '63')
# ('La Roux', 'Maia', 'F', '2', 'Burke', 208.03873, 'free', 'Houston-The Woodlands-Sugar Land, TX', '526', 'Colourless Colour', '51')
# ('Lil Wayne / Shanell', 'Kate', 'F', '36', 'Harrell', 216.81587, 'paid', 'Lansing-East Lansing, MI', '605', 'American Star', '97')
# ('RÃ\x83Â¶yksopp', 'Avery', 'F', '104', 'Watkins', 300.14649, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'What Else Is There?', '30')
# ("Jack's Mannequin", 'Chloe', 'F', '4', 'Cuevas', 172.90404, 'paid', 'San Francisco-Oakland-Hayward, CA', '621', 'Spinning (Album Version)', '49')
# ('FM Static', 'Kate', 'F', '37', 'Harrell', 170.81424, 'paid', 'Lansing-East Lansing, MI', '605', 'Definitely Maybe', '97')
# ('Joy Division', 'Avery', 'F', '105', 'Watkins', 209.03138, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Disorder [2007 Re-mastered Album Version]', '30')
# ('N.E.R.D.', 'Chloe', 'F', '5', 'Cuevas', 259.23873, 'paid', 'San Francisco-Oakland-Hayward, CA', '621', 'Rock Star', '49')
# ('Mickie Krause', 'Kate', 'F', '38', 'Harrell', 204.17261, 'paid', 'Lansing-East Lansing, MI', '605', 'Orange TrÃ\x83Â¤gt Nur Die MÃ\x83Â¼llabfuhr (Go West)', '97')
# ('Steadman', 'Avery', 'F', '106', 'Watkins', 234.1873, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Wave Goodbye (Real/Rhapsody Version)', '30')
# ('The Like', 'Kate', 'F', '39', 'Harrell', 245.68118, 'paid', 'Lansing-East Lansing, MI', '605', 'We Are Lost', '97')
# ('Future Rock', 'Chloe', 'F', '6', 'Cuevas', 239.90812, 'paid', 'San Francisco-Oakland-Hayward, CA', '621', 'Gears', '49')
# ('The All-American Rejects', 'Harper', 'M', '1', 'Barrett', 213.08036, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Gives You Hell', '42')
# ('Bruce Springsteen', 'Avery', 'F', '107', 'Watkins', 270.54975, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Born To Run', '30')
# ('OneRepublic', 'Kate', 'F', '40', 'Harrell', 230.63465, 'paid', 'Lansing-East Lansing, MI', '605', 'Say (All I Need)', '97')
# ('Owl City', 'Chloe', 'F', '7', 'Cuevas', 133.74649, 'paid', 'San Francisco-Oakland-Hayward, CA', '621', 'Meteor Shower', '49')
# ('Justin Nozuka', 'Harper', 'M', '2', 'Barrett', 215.64036, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', "I'm In Peace", '42')
# ('Marina And The Diamonds', 'Chloe', 'F', '8', 'Cuevas', 262.97424, 'paid', 'San Francisco-Oakland-Hayward, CA', '621', 'I Am Not a Robot', '49')
# ('The Serendipity Singers', 'Avery', 'F', '108', 'Watkins', 163.21261, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', "Don't Let The Rain Come Down (Crooked Little Man)", '30')
# ('Haujobb', 'Kate', 'F', '41', 'Harrell', 225.12281, 'paid', 'Lansing-East Lansing, MI', '605', 'Maternal Instinct', '97')
# ('Cyndi Lauper', 'Harper', 'M', '3', 'Barrett', 156.96934, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'My Baby Just Cares For Me', '42')
# ('Usher featuring will.i.am', 'Avery', 'F', '109', 'Watkins', 395.72853, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'OMG', '30')
# ('Depeche Mode', 'Chloe', 'F', '9', 'Cuevas', 397.42649, 'paid', 'San Francisco-Oakland-Hayward, CA', '621', 'Everything Counts (Live) (Single Version)', '49')
# ('Red Hot Chili Peppers', 'Harper', 'M', '4', 'Barrett', 240.32608, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Especially In Michigan (Album Version)', '42')
# ('3 Doors Down', 'Kate', 'F', '42', 'Harrell', 233.74322, 'paid', 'Lansing-East Lansing, MI', '605', 'Kryptonite', '97')
# ('The Newbeats', 'Harper', 'M', '5', 'Barrett', 109.24363, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Bread And Butter', '42')
# ('Kings Of Leon', 'Kate', 'F', '43', 'Harrell', 260.38812, 'paid', 'Lansing-East Lansing, MI', '605', 'Dusty', '97')
# ('Los Lobos', 'Avery', 'F', '110', 'Watkins', 174.18404, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'La Bamba', '30')
# ('Drake / Kanye West / Lil Wayne / Eminem', 'Harper', 'M', '7', 'Barrett', 357.66812, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Forever', '42')
# ('Ginuwine', 'Chloe', 'F', '10', 'Cuevas', 244.27057, 'paid', 'San Francisco-Oakland-Hayward, CA', '621', "I'm In Love", '49')
# ('Descendents', 'Avery', 'F', '111', 'Watkins', 89.23383, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', "I'm Not A Loser", '30')
# ('Jennifer Love Hewitt', 'Kate', 'F', '44', 'Harrell', 222.17098, 'paid', 'Lansing-East Lansing, MI', '605', 'BareNaked', '97')
# ('The Cinematic Orchestra', 'Chloe', 'F', '11', 'Cuevas', 613.74649, 'paid', 'San Francisco-Oakland-Hayward, CA', '621', 'Burn Out', '49')
# ('La Fuga', 'Harper', 'M', '8', 'Barrett', 217.70404, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Baja por diversion (directo 05)', '42')
# ('Killswitch Engage', 'Kate', 'F', '45', 'Harrell', 259.89179, 'paid', 'Lansing-East Lansing, MI', '605', 'Hope Is... (Album Version)', '97')
# ('Kid Cudi Vs Crookers', 'Harper', 'M', '9', 'Barrett', 162.97751, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', "Day 'N' Nite", '42')
# ('Beirut', 'Kate', 'F', '46', 'Harrell', 213.68118, 'paid', 'Lansing-East Lansing, MI', '605', 'La Llorona', '97')
# ('Fall Out Boy', 'Harper', 'M', '10', 'Barrett', 181.36771, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Dance_ Dance', '42')
# ("Christina Aguilera / Lil' Kim / Mya / Pink", 'Kate', 'F', '47', 'Harrell', 264.93342, 'paid', 'Lansing-East Lansing, MI', '605', 'Lady Marmalade', '97')
# ('Harold Budd', 'Harper', 'M', '11', 'Barrett', 392.85506, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Algebra Of Darkness (Album Version)', '42')
# ('Eric Burdon & War', 'Kate', 'F', '48', 'Harrell', 281.93914, 'paid', 'Lansing-East Lansing, MI', '605', 'Jimbo (Album Version)', '97')
# ('Cass McCombs', 'Harper', 'M', '12', 'Barrett', 234.13506, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Deseret', '42')
# ('The Black Keys', 'Kate', 'F', '49', 'Harrell', 139.51955, 'paid', 'Lansing-East Lansing, MI', '605', "I'll Be Your Man", '97')
# ('Leona Naess', 'Harper', 'M', '13', 'Barrett', 223.03302, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Christmas', '42')
# ('Alliance Ethnik', 'Kate', 'F', '50', 'Harrell', 252.21179, 'paid', 'Lansing-East Lansing, MI', '605', 'ReprÃ\x83Â©sente', '97')
# ('Nando Reis', 'Harper', 'M', '14', 'Barrett', 254.6673, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'A Letra "A', '42')
# ('Kris Allen', 'Kate', 'F', '55', 'Harrell', 212.50567, 'paid', 'Lansing-East Lansing, MI', '605', "Live Like We're Dying", '97')
# ('Muse', 'Kate', 'F', '56', 'Harrell', 224.44363, 'paid', 'Lansing-East Lansing, MI', '605', 'Muscle Museum (Soulwax Remix)', '97')
# ('Goldfrapp', 'Harper', 'M', '15', 'Barrett', 228.0224, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Lovely Head', '42')
# ('Slash', 'Kate', 'F', '57', 'Harrell', 189.23057, 'paid', 'Lansing-East Lansing, MI', '605', 'Doctor Alibi (featuring Lemmy Kilmister)', '97')
# ('D.R.I.', 'Harper', 'M', '16', 'Barrett', 66.61179, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Stupid_ Stupid War (Dealing With It)', '42')
# ('Beastie Boys', 'Harper', 'M', '17', 'Barrett', 211.722, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Unite (2009 Digital Remaster)', '42')
# ('Cat Power', 'Kate', 'F', '58', 'Harrell', 218.3571, 'paid', 'Lansing-East Lansing, MI', '605', 'Hate', '97')
# ('Kings Of Leon', 'Harper', 'M', '18', 'Barrett', 201.79546, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Revelry', '42')
# ('Hot Water Music', 'Kate', 'F', '59', 'Harrell', 201.40363, 'paid', 'Lansing-East Lansing, MI', '605', 'Translocation', '97')
# ('Miranda Lambert', 'Harper', 'M', '19', 'Barrett', 251.61098, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Me And Charlie Talking', '42')
# ('Brandy duet with Monica', 'Kate', 'F', '60', 'Harrell', 294.79138, 'paid', 'Lansing-East Lansing, MI', '605', 'The Boy Is Mine (Duet With Monica) (LP Version)', '97')
# ('The Heavy', 'Harper', 'M', '20', 'Barrett', 197.35465, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'How You Like Me Now?', '42')
# ('Streetlight Manifesto', 'Kate', 'F', '61', 'Harrell', 327.91465, 'paid', 'Lansing-East Lansing, MI', '605', 'Point/Counterpoint (Album Version)', '97')
# ('Blitzen Trapper', 'Harper', 'M', '21', 'Barrett', 171.15383, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Murder Babe (Album)', '42')
# ('Megan McCauley', 'Harper', 'M', '22', 'Barrett', 228.57098, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Die For You', '42')
# ('Jack Johnson', 'Kate', 'F', '62', 'Harrell', 207.64689, 'paid', 'Lansing-East Lansing, MI', '605', 'Better Together', '97')
# ('Passion Pit', 'Harper', 'M', '23', 'Barrett', 243.69587, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Eyes As Candles', '42')
# ('Strunz & Farah', 'Aleena', 'F', '0', 'Kirby', 315.32363, 'paid', 'Waterloo-Cedar Falls, IA', '619', 'Zagros', '44')
# ('Minus The Bear', 'Kate', 'F', '63', 'Harrell', 230.45179, 'paid', 'Lansing-East Lansing, MI', '605', 'Part 2', '97')
# ('Van Halen', 'Harper', 'M', '24', 'Barrett', 102.5824, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Eruption (Album Version)', '42')
# ('Pavement', 'Kate', 'F', '64', 'Harrell', 149.83791, 'paid', 'Lansing-East Lansing, MI', '605', 'Heaven Is A Truck', '97')
# ('Alliance Ethnik', 'Harper', 'M', '25', 'Barrett', 195.94404, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'SinceritÃ\x83Â© Et Jalousie', '42')
# ('Pieces Of A Dream', 'Aleena', 'F', '1', 'Kirby', 311.562, 'paid', 'Waterloo-Cedar Falls, IA', '619', 'Keep It Smooth', '44')
# ('Creedence Clearwater Revival', 'Kate', 'F', '65', 'Harrell', 315.42812, 'paid', 'Lansing-East Lansing, MI', '605', 'Born On The Bayou', '97')
# ('Anouk', 'Harper', 'M', '26', 'Barrett', 268.5122, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', "It's So Hard", '42')
# ('Jaco Pastorius Big Band', 'Aleena', 'F', '2', 'Kirby', 69.3024, 'paid', 'Waterloo-Cedar Falls, IA', '619', 'Amerika (Album Version)', '44')
# ('Avril Lavigne', 'Aleena', 'F', '3', 'Kirby', 222.9024, 'paid', 'Waterloo-Cedar Falls, IA', '619', "I'm With You", '44')
# ('Gonzalo Rubalcaba', 'Kate', 'F', '66', 'Harrell', 525.47873, 'paid', 'Lansing-East Lansing, MI', '605', 'Circuito III', '97')
# ('BjÃ\x83Â¶rk', 'Harper', 'M', '27', 'Barrett', 348.57751, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Undo', '42')
# ('Ska-P', 'Aleena', 'F', '4', 'Kirby', 298.13506, 'paid', 'Waterloo-Cedar Falls, IA', '619', 'Casposos', '44')
# ('The Strokes', 'Harper', 'M', '28', 'Barrett', 155.34975, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Is This It', '42')
# ('Jesse Belvin', 'Aleena', 'F', '5', 'Kirby', 184.63302, 'paid', 'Waterloo-Cedar Falls, IA', '619', 'Goodnight My Love', '44')
# ('Alliance Ethnik', 'Harper', 'M', '29', 'Barrett', 265.76934, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Creil City', '42')
# ('The Gerbils', 'Kate', 'F', '67', 'Harrell', 27.01016, 'paid', 'Lansing-East Lansing, MI', '605', '(iii)', '97')
# ('KJ-52', 'Kate', 'F', '68', 'Harrell', 275.77424, 'paid', 'Lansing-East Lansing, MI', '605', 'Life After Death', '97')
# ('Mariah Carey', 'Aleena', 'F', '7', 'Kirby', 242.96444, 'paid', 'Waterloo-Cedar Falls, IA', '619', 'All I Want For Christmas Is You', '44')
# ('Glen Hansard & Marketa Irglova', 'Harper', 'M', '30', 'Barrett', 282.67057, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'The Moon (Album version)', '42')
# ('Dion & The Belmonts', 'Kate', 'F', '69', 'Harrell', 152.31955, 'paid', 'Lansing-East Lansing, MI', '605', 'A Teenager In Love', '97')
# ('Jack Johnson', 'Kynnedi', 'F', '0', 'Sanchez', 236.93016, 'free', 'Cedar Rapids, IA', '600', 'Bubble Toes', '89')
# ('Beastie Boys', 'Aleena', 'F', '8', 'Kirby', 172.22485, 'paid', 'Waterloo-Cedar Falls, IA', '619', 'The Maestro', '44')
# ('Lesley Gore', 'Kate', 'F', '70', 'Harrell', 134.37342, 'paid', 'Lansing-East Lansing, MI', '605', "It's My Party", '97')
# ('Dr. Dre / Snoop Dogg', 'Harper', 'M', '31', 'Barrett', 161.51465, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'The Next Episode', '42')
# ('Pearl Jam', 'Aleena', 'F', '9', 'Kirby', 67.44771, 'paid', 'Waterloo-Cedar Falls, IA', '619', 'Encore Break', '44')
# ('Cake', 'Kynnedi', 'F', '1', 'Sanchez', 179.09506, 'free', 'Cedar Rapids, IA', '600', 'Commissioning A Symphony In C', '89')
# ('Phoenix', 'Kate', 'F', '71', 'Harrell', 278.07302, 'paid', 'Lansing-East Lansing, MI', '605', 'Rome', '97')
# ('Alesana', 'Aleena', 'F', '10', 'Kirby', 285.51791, 'paid', 'Waterloo-Cedar Falls, IA', '619', 'Seduction (album)', '44')
# ('The Kooks', 'Harper', 'M', '32', 'Barrett', 168.72444, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'She Moves In Her Own Way', '42')
# ('Dakis', 'Harper', 'M', '33', 'Barrett', 162.48118, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'La Petite Marie (2005 Digital Remaster)', '42')
# ('Limp Bizkit', 'Kate', 'F', '72', 'Harrell', 214.5171, 'paid', 'Lansing-East Lansing, MI', '605', "Rollin' (Air Raid Vehicle)", '97')
# ('JET', 'Aleena', 'F', '11', 'Kirby', 261.3024, 'paid', 'Waterloo-Cedar Falls, IA', '619', 'Move On (Album Version)', '44')
# ('Mickie Krause', 'Harper', 'M', '34', 'Barrett', 204.17261, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Orange TrÃ\x83Â¤gt Nur Die MÃ\x83Â¼llabfuhr (Go West)', '42')
# ('Hot Chip', 'Kate', 'F', '73', 'Harrell', 314.69669, 'paid', 'Lansing-East Lansing, MI', '605', 'My Piano (DJ-Kicks)', '97')
# ('Yung Berg', 'Aleena', 'F', '12', 'Kirby', 230.63465, 'paid', 'Waterloo-Cedar Falls, IA', '619', "Do That There (featuring Dude 'N Nem)", '44')
# ('Kings Of Leon', 'Harper', 'M', '35', 'Barrett', 237.53098, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Closer', '42')
# ('Johan', 'Aleena', 'F', '13', 'Kirby', 190.27546, 'paid', 'Waterloo-Cedar Falls, IA', '619', 'Life On Mars', '44')
# ('Crystal Castles', 'Kate', 'F', '74', 'Harrell', 138.91873, 'paid', 'Lansing-East Lansing, MI', '605', 'Love And Caring', '97')
# ('Thirteen Senses', 'Harper', 'M', '36', 'Barrett', 286.45832, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Lead Us', '42')
# ('Eisbrecher', 'Kate', 'F', '76', 'Harrell', 241.89342, 'paid', 'Lansing-East Lansing, MI', '605', 'Adrenalin', '97')
# ('Buckcherry', 'Aleena', 'F', '14', 'Kirby', 201.79546, 'paid', 'Waterloo-Cedar Falls, IA', '619', 'Crazy Bitch (Album Version)', '44')
# ('Band Of Horses', 'Harper', 'M', '37', 'Barrett', 187.0624, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'The General Specific (Album)', '42')
# ('Darkseed', 'Kate', 'F', '77', 'Harrell', 250.33098, 'paid', 'Lansing-East Lansing, MI', '605', 'Speak Silence', '97')
# ('Caetano Veloso', 'Aleena', 'F', '15', 'Kirby', 223.97342, 'paid', 'Waterloo-Cedar Falls, IA', '619', 'O Samba E O Tango', '44')
# ('Maria Arredondo', 'Harper', 'M', '38', 'Barrett', 243.74812, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Burning', '42')
# ('Boyzone', 'Aleena', 'F', '16', 'Kirby', 219.81995, 'paid', 'Waterloo-Cedar Falls, IA', '619', 'All That I Need', '44')
# ('Coldplay', 'Kate', 'F', '78', 'Harrell', 273.47546, 'paid', 'Lansing-East Lansing, MI', '605', 'Trouble', '97')
# ('matchbox twenty', 'Harper', 'M', '39', 'Barrett', 229.14567, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Unwell (Album Version)', '42')
# ('Sussie 4', 'Aleena', 'F', '17', 'Kirby', 331.33669, 'paid', 'Waterloo-Cedar Falls, IA', '619', 'On Time', '44')
# ('Klaxons', 'Kate', 'F', '79', 'Harrell', 166.79138, 'paid', 'Lansing-East Lansing, MI', '605', 'Golden Skans', '97')
# ('Prince', 'Harper', 'M', '40', 'Barrett', 340.71465, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Hot Thing ( LP Version )', '42')
# ('Dwight Yoakam', 'Kate', 'F', '80', 'Harrell', 239.3073, 'paid', 'Lansing-East Lansing, MI', '605', "You're The One", '97')
# ...
# ('Five Iron Frenzy', 'Rylan', 'M', '2', 'George', 236.09424, 'paid', 'Birmingham-Hoover, AL', '1076', 'Canada', '16')
# ('12 Stones', 'Jayden', 'M', '5', 'Fox', 184.0322, 'free', 'New Orleans-Metairie, LA', '1060', 'Anthem For The Underdog', '101')
# ('Kings Of Leon', 'Kinsley', 'F', '21', 'Young', 201.79546, 'paid', 'Red Bluff, CA', '977', 'Revelry', '85')
# ('Brooklyn Bounce', 'Rylan', 'M', '3', 'George', 359.13098, 'paid', 'Birmingham-Hoover, AL', '1076', 'Get Ready To Bounce Recall 08', '16')
# ('Dashboard Confessional', 'Kinsley', 'F', '22', 'Young', 147.30404, 'paid', 'Red Bluff, CA', '977', 'The Good Fight', '85')
# ('Lonnie Johnson', 'Kinsley', 'F', '23', 'Young', 194.55955, 'paid', 'Red Bluff, CA', '977', 'Low Land Moan', '85')
# ('Leggo Beast', 'Mohammad', 'M', '2', 'Rodriguez', 376.58077, 'paid', 'Sacramento--Roseville--Arden-Arcade, CA', '1097', 'In', '88')
# ('The Pussycat Dolls', 'Rylan', 'M', '4', 'George', 190.95465, 'paid', 'Birmingham-Hoover, AL', '1076', 'Sway', '16')
# ('Stereophonics', 'Kinsley', 'F', '24', 'Young', 290.53342, 'paid', 'Red Bluff, CA', '977', 'I Miss You Now', '85')
# ('The Beautiful South', 'Rylan', 'M', '5', 'George', 236.5122, 'paid', 'Birmingham-Hoover, AL', '1076', 'Masculine Eclipse', '16')
# ('The Acacia Strain', 'Mohammad', 'M', '3', 'Rodriguez', 194.21995, 'paid', 'Sacramento--Roseville--Arden-Arcade, CA', '1097', 'As If Set Afire', '88')
# ('ATB', 'Kinsley', 'F', '25', 'Young', 251.48036, 'paid', 'Red Bluff, CA', '977', 'Underwater World', '85')
# ('The Robert Cray Band', 'Rylan', 'M', '6', 'George', 309.52444, 'paid', 'Birmingham-Hoover, AL', '1076', 'Our Last Time', '16')
# ('Enigma', 'Mohammad', 'M', '4', 'Rodriguez', 242.78159, 'paid', 'Sacramento--Roseville--Arden-Arcade, CA', '1097', 'T.N.T. For The Brain (112 Bpm) (Radio Edit)', '88')
# ('Amon Amarth', 'Kinsley', 'F', '26', 'Young', 268.2771, 'paid', 'Red Bluff, CA', '977', 'Tattered Banners And Bloody Flags', '85')
# ('We Are Scientists', 'Rylan', 'M', '7', 'George', 198.89587, 'paid', 'Birmingham-Hoover, AL', '1076', 'The Great Escape (Album Version) (Explicit)', '16')
# ('Roberto Murolo', 'Matthew', 'M', '0', 'Jones', 188.02893, 'paid', 'Janesville-Beloit, WI', '1100', 'Lacreme napulitane', '36')
# ('Ashlee Simpson', 'Mohammad', 'M', '5', 'Rodriguez', 214.43873, 'paid', 'Sacramento--Roseville--Arden-Arcade, CA', '1097', 'Autobiography', '88')
# ('Metallica', 'Kinsley', 'F', '27', 'Young', 152.60689, 'paid', 'Red Bluff, CA', '977', 'The Ecstasy Of Gold', '85')
# ('3 Doors Down', 'Rylan', 'M', '8', 'George', 233.74322, 'paid', 'Birmingham-Hoover, AL', '1076', 'Kryptonite', '16')
# ('Hazell Dean', 'Matthew', 'M', '1', 'Jones', 367.98649, 'paid', 'Janesville-Beloit, WI', '1100', 'No Fool (For Love)', '36')
# ('Apocalyptica', 'Kinsley', 'F', '28', 'Young', 262.5824, 'paid', 'Red Bluff, CA', '977', 'Pray', '85')
# ('Jack Johnson', 'Rylan', 'M', '9', 'George', 236.93016, 'paid', 'Birmingham-Hoover, AL', '1076', 'Bubble Toes', '16')
# ('Cage The Elephant', 'Kinsley', 'F', '29', 'Young', 196.38812, 'paid', 'Red Bluff, CA', '977', 'Lotus', '85')
# ('Taylor Swift', 'Matthew', 'M', '2', 'Jones', 230.47791, 'paid', 'Janesville-Beloit, WI', '1100', 'You Belong With Me', '36')
# ('Soul For Real', 'Rylan', 'M', '10', 'George', 271.25506, 'paid', 'Birmingham-Hoover, AL', '1076', 'Candy Rain', '16')
# ('The Prodigy', 'Kinsley', 'F', '30', 'Young', 225.09669, 'paid', 'Red Bluff, CA', '977', 'Firestarter', '85')
# ('Amy Winehouse', 'Matthew', 'M', '3', 'Jones', 165.11955, 'paid', 'Janesville-Beloit, WI', '1100', 'Addicted', '36')
# ('Iron Maiden', 'Rylan', 'M', '11', 'George', 275.19955, 'paid', 'Birmingham-Hoover, AL', '1076', 'The Evil That Men Do (1998 Digital Remaster)', '16')
# ('David Crowder*Band', 'Kinsley', 'F', '31', 'Young', 276.74077, 'paid', 'Red Bluff, CA', '977', 'All Around Me', '85')
# ('The Cinematic Orchestra', 'Rylan', 'M', '12', 'George', 622.2624, 'paid', 'Birmingham-Hoover, AL', '1076', 'Everyday', '16')
# ('Three 6 Mafia vs. TiÃ\x83Â«sto with Sean Kingston and Flo Rida', 'Kinsley', 'F', '32', 'Young', 241.05751, 'paid', 'Red Bluff, CA', '977', 'Feel It', '85')
# ('Sugababes', 'Kinsley', 'F', '33', 'Young', 275.93098, 'paid', 'Red Bluff, CA', '977', 'Overload', '85')
# ('Gyptian', 'Rylan', 'M', '13', 'George', 233.09016, 'paid', 'Birmingham-Hoover, AL', '1076', 'Hold You', '16')
# ('Zion / Akon', 'Rylan', 'M', '14', 'George', 233.19465, 'paid', 'Birmingham-Hoover, AL', '1076', 'The Way She Moves', '16')
# ('Transvision Vamp', 'Rylan', 'M', '15', 'George', 209.91955, 'paid', 'Birmingham-Hoover, AL', '1076', 'I Want Your Love', '16')
# ('Ry Cooder', 'Chloe', 'F', '37', 'Cuevas', 201.56036, 'paid', 'San Francisco-Oakland-Hayward, CA', '1096', 'Corrido de Boxeo', '49')
# ('The Pussycat Dolls', 'Rylan', 'M', '16', 'George', 245.18485, 'paid', 'Birmingham-Hoover, AL', '1076', 'When I Grow Up', '16')
# ('Coldplay', 'Chloe', 'F', '38', 'Cuevas', 268.30322, 'paid', 'San Francisco-Oakland-Hayward, CA', '1096', 'Yellow', '49')
# ('Forever The Sickest Kids', 'Rylan', 'M', '17', 'George', 169.482, 'paid', 'Birmingham-Hoover, AL', '1076', 'She Likes (Bittersweet Love)', '16')
# ('Lil Wayne / Blaque / Mannie Fresh', 'Chloe', 'F', '39', 'Cuevas', 255.34649, 'paid', 'San Francisco-Oakland-Hayward, CA', '1096', 'Believe That', '49')
# ('Dragonforce', 'Rylan', 'M', '18', 'George', 441.02485, 'paid', 'Birmingham-Hoover, AL', '1076', 'Through The Fire And Flames (Album Version)', '16')
# ('Jason Mraz & Colbie Caillat', 'Chloe', 'F', '40', 'Cuevas', 189.6224, 'paid', 'San Francisco-Oakland-Hayward, CA', '1096', 'Lucky (Album Version)', '49')
# ('Pixies', 'Chloe', 'F', '41', 'Cuevas', 181.13261, 'paid', 'San Francisco-Oakland-Hayward, CA', '1096', 'Is She Weird', '49')
# ('Eminem', 'Rylan', 'M', '19', 'George', 251.55873, 'paid', 'Birmingham-Hoover, AL', '1076', 'Without Me', '16')
# ('Buju Banton', 'Chloe', 'F', '42', 'Cuevas', 232.48934, 'paid', 'San Francisco-Oakland-Hayward, CA', '1096', 'Cry No More', '49')
# ('Cage The Elephant', 'Rylan', 'M', '20', 'George', 196.38812, 'paid', 'Birmingham-Hoover, AL', '1076', 'Lotus', '16')
# ('Barry Tuckwell/Academy of St Martin-in-the-Fields/Sir Neville Marriner', 'Chloe', 'F', '43', 'Cuevas', 277.15873, 'paid', 'San Francisco-Oakland-Hayward, CA', '1096', 'Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)', '49')
# ('Ste Strausz', 'Rylan', 'M', '21', 'George', 285.36118, 'paid', 'Birmingham-Hoover, AL', '1076', 'Le Million', '16')
# ('Coldplay', 'Chloe', 'F', '44', 'Cuevas', 228.62322, 'paid', 'San Francisco-Oakland-Hayward, CA', '1096', 'Only Superstition', '49')
# ('Joe Christmas', 'Chloe', 'F', '0', 'Roth', 185.7824, 'free', 'Indianapolis-Carmel-Anderson, IN', '1059', 'Bedroom Suite', '78')
# ('Bright Eyes', 'Rylan', 'M', '22', 'George', 313.23383, 'paid', 'Birmingham-Hoover, AL', '1076', 'A New Arrangement', '16')
# ('Paramore', 'Chloe', 'F', '1', 'Roth', 267.65016, 'free', 'Indianapolis-Carmel-Anderson, IN', '1059', 'The Only Exception (Album Version)', '78')
# ('J. Karjalainen & Mustat Lasit', 'Chloe', 'F', '45', 'Cuevas', 336.74404, 'paid', 'San Francisco-Oakland-Hayward, CA', '1096', 'Sinisten tÃ\x83Â¤htien alla', '49')
# ('Philip Glass', 'Rylan', 'M', '23', 'George', 368.40444, 'paid', 'Birmingham-Hoover, AL', '1076', 'Knee 2', '16')
# ('Alliance Ethnik', 'Chloe', 'F', '46', 'Cuevas', 195.94404, 'paid', 'San Francisco-Oakland-Hayward, CA', '1096', 'SinceritÃ\x83Â© Et Jalousie', '49')
# ('Mew', 'Rylan', 'M', '24', 'George', 167.75791, 'paid', 'Birmingham-Hoover, AL', '1076', 'Her Voice Is Beyond Her Years', '16')
# ('Ive Mendes', 'Rylan', 'M', '25', 'George', 238.94159, 'paid', 'Birmingham-Hoover, AL', '1076', 'If You Leave Me Now', '16')
# ('Alliance Ethnik', 'Bronson', 'M', '1', 'Harris', 195.94404, 'free', 'Eugene, OR', '1026', 'SinceritÃ\x83Â© Et Jalousie', '33')
# ('the bird and the bee', 'Rylan', 'M', '26', 'George', 193.802, 'paid', 'Birmingham-Hoover, AL', '1076', 'Diamond Dave', '16')
# ('Common / Sadat X', 'Bronson', 'M', '2', 'Harris', 256.20853, 'free', 'Eugene, OR', '1026', '1999', '33')
# ('Alanis Morissette', 'Rylan', 'M', '27', 'George', 245.15873, 'paid', 'Birmingham-Hoover, AL', '1076', 'King Of Pain (Live/Unplugged Version)', '16')
# ('Skillet', 'Bronson', 'M', '7', 'Harris', 233.32526, 'free', 'Eugene, OR', '1026', 'Rebirthing (Album Version)', '33')
# ('James Galway;Julian Lee', 'Rylan', 'M', '28', 'George', 218.67057, 'paid', 'Birmingham-Hoover, AL', '1076', 'Beauty and the Beast', '16')
# ('Drop Dead_ Gorgeous', 'Rylan', 'M', '29', 'George', 156.70812, 'paid', 'Birmingham-Hoover, AL', '1076', 'Dressed For Friend Requests (Album Version)', '16')
# ('Dwight Yoakam', 'Rylan', 'M', '30', 'George', 239.3073, 'paid', 'Birmingham-Hoover, AL', '1076', "You're The One", '16')
# ('Trouble', 'Rylan', 'M', '31', 'George', 205.11302, 'paid', 'Birmingham-Hoover, AL', '1076', "Tuesday's Child", '16')
# ('OneRepublic', 'Rylan', 'M', '33', 'George', 237.97506, 'paid', 'Birmingham-Hoover, AL', '1076', 'All The Right Moves', '16')
# ('Switchblade Symphony', 'Rylan', 'M', '34', 'George', 259.5522, 'paid', 'Birmingham-Hoover, AL', '1076', 'Wicked', '16')
# ('Sharooz', 'Rylan', 'M', '35', 'George', 234.05669, 'paid', 'Birmingham-Hoover, AL', '1076', 'My Distressor 40Khz ReRub Mix', '16')
# ('Explosions In The Sky', 'Rylan', 'M', '36', 'George', 522.9971, 'paid', 'Birmingham-Hoover, AL', '1076', 'Six Days At The Bottom Of The Ocean', '16')
# ('Emmylou Harris', 'Chloe', 'F', '1', 'Cuevas', 194.63791, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'Little Bird', '49')
# ('Jack Johnson', 'Chloe', 'F', '2', 'Cuevas', 153.67791, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'The Horizon Has Been Defeated', '49')
# ('Radiohead', 'Rylan', 'M', '37', 'George', 249.93914, 'paid', 'Birmingham-Hoover, AL', '1076', 'Everything In Its Right Place', '16')
# ('Andrew Bird', 'Chloe', 'F', '3', 'Cuevas', 215.87546, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'Heretics', '49')
# ('Metallica', 'Rylan', 'M', '38', 'George', 380.21179, 'paid', 'Birmingham-Hoover, AL', '1076', 'Sabbra Cadabra', '16')
# ('Lonnie Gordon', 'Chloe', 'F', '4', 'Cuevas', 181.21098, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'Catch You Baby (Steve Pitron & Max Sanna Radio Edit)', '49')
# ('Dropkick Murphys', 'Chloe', 'F', '5', 'Cuevas', 167.73179, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'Shattered', '49')
# ('Eric B. & Rakim', 'Rylan', 'M', '39', 'George', 240.32608, 'paid', 'Birmingham-Hoover, AL', '1076', 'As The Rhyme Goes On', '16')
# ('Dierks Bentley', 'Chloe', 'F', '6', 'Cuevas', 223.242, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'Settle For A Slowdown', '49')
# ('Regina Spektor', 'Rylan', 'M', '40', 'George', 290.14159, 'paid', 'Birmingham-Hoover, AL', '1076', 'Daniel Cowman', '16')
# ('Angelspit', 'Chloe', 'F', '7', 'Cuevas', 241.94567, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'Make You Sin', '49')
# ('Young Gunz / Beanie Sigel', 'Chloe', 'F', '8', 'Cuevas', 292.44036, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'Roc U', '49')
# ('DJ Dizzy', 'Rylan', 'M', '41', 'George', 221.1522, 'paid', 'Birmingham-Hoover, AL', '1076', 'Sexy Bitch', '16')
# ('Base Ball Bear', 'Rylan', 'M', '42', 'George', 255.60771, 'paid', 'Birmingham-Hoover, AL', '1076', 'Sayonara-Nostalgia', '16')
# ('Morcheeba', 'Chloe', 'F', '9', 'Cuevas', 101.95546, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'In The Hands Of The Gods (Featuring Biz Markie)', '49')
# ('Bitter:Sweet', 'Chloe', 'F', '10', 'Cuevas', 194.16771, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', "Don't Forget To Breathe", '49')
# ('Basshunter Feat. DJ Mental Theo\x19s Bazzheadz', 'Rylan', 'M', '43', 'George', 152.65914, 'paid', 'Birmingham-Hoover, AL', '1076', "Now You're Gone", '16')
# ('BjÃ\x83Â¶rk', 'Chloe', 'F', '11', 'Cuevas', 348.57751, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'Undo', '49')
# ('Rihanna', 'Rylan', 'M', '44', 'George', 239.75138, 'paid', 'Birmingham-Hoover, AL', '1076', 'G4L', '16')
# ('Evanescence', 'Rylan', 'M', '45', 'George', 220.3424, 'paid', 'Birmingham-Hoover, AL', '1076', 'Hello', '16')
# ('Mr. Vegas', 'Chloe', 'F', '12', 'Cuevas', 240.69179, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'Tamale', '49')
# ('Mischa Daniels', 'Rylan', 'M', '46', 'George', 419.81342, 'paid', 'Birmingham-Hoover, AL', '1076', 'Another Place', '16')
# ('The Menzingers', 'Chloe', 'F', '13', 'Cuevas', 276.00934, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'Straight To Hell', '49')
# ('Justin Timberlake', 'Chloe', 'F', '14', 'Cuevas', 288.93995, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'Cry Me A River', '49')
# ('Vilma Palma e Vampiros', 'Rylan', 'M', '47', 'George', 338.18077, 'paid', 'Birmingham-Hoover, AL', '1076', 'Un Camino Hasta Vos', '16')
# ('CCCP - Fedeli Alla Linea', 'Chloe', 'F', '15', 'Cuevas', 329.66485, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'Sura (2008 Digital Remaster)', '49')
# ('Kid Cudi / MGMT / Ratatat', 'Rylan', 'M', '48', 'George', 295.67955, 'paid', 'Birmingham-Hoover, AL', '1076', 'Pursuit Of Happiness (nightmare)', '16')
# ('Drake / Kanye West / Lil Wayne / Eminem', 'Chloe', 'F', '16', 'Cuevas', 357.66812, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'Forever', '49')
# ('A Day To Remember', 'Rylan', 'M', '49', 'George', 247.64036, 'paid', 'Birmingham-Hoover, AL', '1076', 'Homesick [Acoustic]', '16')
# ('T.I.', 'Jayden', 'M', '0', 'Bell', 299.75465, 'free', 'Dallas-Fort Worth-Arlington, TX', '1085', 'Dead And Gone [feat. Justin Timberlake] (Explicit Album Version)', '91')
# ('The Offspring', 'Rylan', 'M', '50', 'George', 163.3171, 'paid', 'Birmingham-Hoover, AL', '1076', "It'll Be a Long Time (Album Version)", '16')
# ('Jorge Gonzalez', 'Chloe', 'F', '17', 'Cuevas', 272.14322, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'Esta Es Para Hacerte FÃ\x83Â©liz', '49')
# ('Sneaker Pimps', 'Jayden', 'M', '1', 'Bell', 260.91057, 'free', 'Dallas-Fort Worth-Arlington, TX', '1085', 'Spin Spin Sugar', '91')
# ('Escape The Fate', 'Rylan', 'M', '51', 'George', 266.73587, 'paid', 'Birmingham-Hoover, AL', '1076', 'This War Is Ours (The Guillotine II)', '16')
# ('Juanes', 'Chloe', 'F', '18', 'Cuevas', 243.27791, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'La Vida Es Un Ratico', '49')
# ('The Replacements', 'Rylan', 'M', '52', 'George', 170.57914, 'paid', 'Birmingham-Hoover, AL', '1076', 'Never Mind', '16')
# ('Sarah McLachlan', 'Chloe', 'F', '19', 'Cuevas', 278.90893, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'Possession', '49')
# ('Sonny Boy Williamson', 'Rylan', 'M', '53', 'George', 152.24118, 'paid', 'Birmingham-Hoover, AL', '1076', "Don't Start Me Talkin'", '16')
# ('Soul II Soul Featuring Caron Wheeler', 'Rylan', 'M', '54', 'George', 225.2273, 'paid', 'Birmingham-Hoover, AL', '1076', 'Back To Life (However Do You Want Me) (2003 Digital Remaster) (Feat. Caron Wheeler)', '16')
# ('Florence + The Machine', 'Chloe', 'F', '20', 'Cuevas', 219.66322, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'Dog Days Are Over (Radio Edit)', '49')
# ('Pantera', 'Rylan', 'M', '55', 'George', 286.69342, 'paid', 'Birmingham-Hoover, AL', '1076', 'Heresy  (LP Version)', '16')
# ('Cold', 'Chloe', 'F', '21', 'Cuevas', 177.76281, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'Remedy', '49')
# ('Norther', 'Chloe', 'F', '22', 'Cuevas', 246.54322, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'Frozen Angel', '49')
# ('Foo Fighters', 'Rylan', 'M', '57', 'George', 271.38567, 'paid', 'Birmingham-Hoover, AL', '1076', 'The Pretender', '16')
# ('Timbiriche', 'Rylan', 'M', '58', 'George', 202.60526, 'paid', 'Birmingham-Hoover, AL', '1076', 'Besos De Ceniza', '16')
# ('A Perfect Circle', 'Rylan', 'M', '59', 'George', 206.05342, 'paid', 'Birmingham-Hoover, AL', '1076', 'Rose', '16')
# ('Anberlin', 'Rylan', 'M', '60', 'George', 348.682, 'paid', 'Birmingham-Hoover, AL', '1076', 'The Haunting', '16')
# ('Deas Vail', 'Elijah', 'M', '0', 'Davis', 237.68771, 'free', 'Detroit-Warren-Dearborn, MI', '985', 'Anything You Say (Unreleased Version)', '5')

# %% [markdown]
# #### Do a SELECT to verify that the data have been inserted into each table

# %%
## TO-DO: Add in the SELECT statement to verify the data was entered into the table
## Confirm query 1 output
query = """
SELECT artist, song, length 
FROM music_by_sessionid_iteminsession
WHERE sessionId = 338
AND itemInSession = 4
"""
query = session.execute(query)
print(query)
for row in query:
    print(row)
# Out:
# <cassandra.cluster.ResultSet object at 0x7fa1c18bb940>
# Row(artist='Faithless', song='Music Matters (Mark Knight Dub)', length=495.30731201171875)

# %% [markdown]
# ### COPY AND REPEAT THE ABOVE THREE CELLS FOR EACH OF THE THREE QUESTIONS

# %%
## Drop table after restart test to prevent duplicate data
query = "drop TABLE IF EXISTS music_by_artist_song_user "
session.execute(query)

# %%
## TO-DO: Query 2:  Give me only the following: name of artist, song (sorted by itemInSession) and user (first and last name)
## for userid = 10, sessionid = 182
query = "CREATE TABLE IF NOT EXISTS music_by_artist_song_user "
query = query + """(
userId int, sessionId int, itemInSession int, artist text, song text, firstName text, lastName text, 
PRIMARY KEY((userId, sessionId), itemInSession))
WITH CLUSTERING ORDER BY (itemInSession ASC)
"""
try:
    session.execute(query)
except Exception as e:
    print(e)

# %%
## TO-DO: Assign the INSERT statements into the `query` variable
# Insert data into table for query 2
file = 'event_datafile_new.csv'
with open(file, encoding = 'utf8') as f:
    csvreader = csv.reader(f)
    next(csvreader)
    for line in csvreader:
        query = "INSERT INTO music_by_artist_song_user (userId, sessionId, itemInSession, artist, song, firstName, lastName)"
        query = query + "VALUES (%s, %s, %s, %s, %s, %s, %s)"
        ## Test output value from the file csv
        print((int(line[10]), int(line[8]), line[3], line[0], line[9], line[1],line[4]))
        ## TO-DO: Assign which column element should be assigned for each column in the INSERT statement.
        session.execute(query, (int(line[10]), int(line[8]), int(line[3]), line[0], line[9], line[1], line[4]))
# Out:
# (26, 583, '0', 'Harmonia', 'Sehr kosmisch', 'Ryan', 'Smith')
# (26, 583, '1', 'The Prodigy', 'The Big Gundown', 'Ryan', 'Smith')
# (26, 583, '2', 'Train', 'Marry Me', 'Ryan', 'Smith')
# (61, 597, '0', 'Sony Wonder', 'Blackbird', 'Samuel', 'Gonzalez')
# (80, 602, '2', 'Van Halen', 'Best Of Both Worlds (Remastered Album Version)', 'Tegan', 'Levine')
# (80, 602, '3', 'Magic Sam', 'Call Me If You Need Me', 'Tegan', 'Levine')
# (80, 602, '4', 'Edward Sharpe & The Magnetic Zeros', 'Home', 'Tegan', 'Levine')
# (80, 602, '5', 'Usher featuring will.i.am', 'OMG', 'Tegan', 'Levine')
# (80, 602, '7', 'Helen Reddy', 'Candle On The Water', 'Tegan', 'Levine')
# (80, 602, '8', 'Taylor Swift', 'Our Song', 'Tegan', 'Levine')
# (80, 602, '9', 'Sean Paul', 'Baby Boy [feat. Beyonce]', 'Tegan', 'Levine')
# (15, 582, '0', 'Soundgarden', 'Black Hole Sun', 'Lily', 'Koch')
# (80, 602, '10', 'The Killers', 'Human', 'Tegan', 'Levine')
# (15, 582, '1', 'Amy Winehouse', 'Addicted', 'Lily', 'Koch')
# (15, 582, '2', 'Steve Anderson', 'Air', 'Lily', 'Koch')
# (15, 582, '3', 'Rob Zombie', 'Superbeast', 'Lily', 'Koch')
# (15, 582, '4', 'Deadmau5 & Kaskade', 'I Remember', 'Lily', 'Koch')
# (26, 607, '0', 'Shania Twain', "Don't Be Stupid (You Know I Love You)", 'Ryan', 'Smith')
# (26, 607, '1', 'Los Campesinos', 'We throw parties_ you throw knives', 'Ryan', 'Smith')
# (49, 606, '1', 'Ill Nino', 'How Can I Live (Spanish version) (Album Version)', 'Chloe', 'Cuevas')
# (49, 606, '2', 'Mia X', 'Thugs Like Me', 'Chloe', 'Cuevas')
# (49, 606, '3', 'Rage Against The Machine', 'Killing In The Name', 'Chloe', 'Cuevas')
# (49, 606, '4', 'Asia 2001', 'Epilogue', 'Chloe', 'Cuevas')
# (49, 606, '5', 'Muse', 'Endlessly', 'Chloe', 'Cuevas')
# (49, 606, '6', 'Rise Against', 'Torches', 'Chloe', 'Cuevas')
# (88, 591, '3', 'Modest Mouse', 'The Good Times Are Killing Me', 'Mohammad', 'Rodriguez')
# (49, 606, '7', 'Marc Anthony', 'Te Conozco Bien', 'Chloe', 'Cuevas')
# (49, 606, '8', 'Regina Spektor', 'The Calculation (Album Version)', 'Chloe', 'Cuevas')
# (80, 611, '0', 'Nina Sky', 'Goodbye (Interlude)', 'Tegan', 'Levine')
# (30, 324, '0', 'Five Iron Frenzy', 'Canada', 'Avery', 'Watkins')
# (30, 324, '2', 'Kudai', 'Ven', 'Avery', 'Watkins')
# (30, 324, '3', 'Pulp', 'Do You Remember The First Time?', 'Avery', 'Watkins')
# (30, 324, '4', "SinÃ\x83Â©ad O'Connor", 'I Want Your (Hands On Me)', 'Avery', 'Watkins')
# (80, 611, '3', 'Paul Brown', 'Chill Out', 'Tegan', 'Levine')
# (30, 324, '5', 'Lasgo', 'Something (Radio Edit)', 'Avery', 'Watkins')
# (80, 611, '4', 'Patty Loveless', "What's A Broken Heart", 'Tegan', 'Levine')
# (30, 324, '6', 'Eddie Vedder', 'Society', 'Avery', 'Watkins')
# (80, 611, '5', 'Rogue Wave', 'Christians In Black', 'Tegan', 'Levine')
# (30, 324, '7', 'Muse', 'Uprising', 'Avery', 'Watkins')
# (80, 611, '6', 'Amanda Blank', 'Might Like You Better', 'Tegan', 'Levine')
# (30, 324, '8', 'The Smiths', 'Sheila Take A Bow', 'Avery', 'Watkins')
# (80, 611, '7', "Old 97's", 'Victoria (LP Version)', 'Tegan', 'Levine')
# (30, 324, '9', 'Selena', 'Dreaming Of You', 'Avery', 'Watkins')
# (80, 611, '8', 'Fat Joe', "What's Luv? (Featuring Ja-Rule & Ashanti) (Explicit Album Version)", 'Tegan', 'Levine')
# (30, 324, '10', 'Stars', 'Soft Revolution', 'Avery', 'Watkins')
# (80, 611, '9', 'James Blunt', 'Same Mistake  (Album Version)', 'Tegan', 'Levine')
# (30, 324, '11', 'Mayday Parade', 'Bruised And Scarred (Album Version)', 'Avery', 'Watkins')
# (80, 611, '10', 'Die Mooskirchner', "Frisch und g'sund", 'Tegan', 'Levine')
# (30, 324, '12', 'Gorillaz', 'Rockit', 'Avery', 'Watkins')
# (80, 611, '12', 'Toby Keith', "Should've Been A Cowboy", 'Tegan', 'Levine')
# (30, 324, '13', 'Modest Mouse', 'Little Motel', 'Avery', 'Watkins')
# (80, 611, '13', 'Future Rock', 'Gears', 'Tegan', 'Levine')
# (30, 324, '14', 'Noel Pointer', 'Superwoman (Where Were You When I Needed You) (Digitally Remastered)', 'Avery', 'Watkins')
# (80, 611, '14', 'Callenish Circle', 'Forgotten', 'Tegan', 'Levine')
# (16, 575, '0', 'Foo Fighters', 'Everlong', 'Rylan', 'George')
# (30, 324, '15', 'Portishead', 'Hunter', 'Avery', 'Watkins')
# (80, 611, '15', 'Taylor Swift', 'The Way I Loved You', 'Tegan', 'Levine')
# (16, 575, '1', 'J-Live', 'Longevity', 'Rylan', 'George')
# (30, 324, '16', 'The White Stripes', 'Fell In Love With A Girl', 'Avery', 'Watkins')
# (80, 611, '16', 'Dwight Yoakam', "You're The One", 'Tegan', 'Levine')
# (30, 324, '17', 'The Black Keys', 'Lies', 'Avery', 'Watkins')
# (16, 575, '2', 'Five', "Got The Feelin'", 'Rylan', 'George')
# (80, 611, '17', 'Ra', 'Do You Call My Name', 'Tegan', 'Levine')
# (16, 575, '4', 'Coolio feat. L.V.', "Gangsta's Paradise (LP Version)", 'Rylan', 'George')
# (30, 324, '18', 'Paramore', 'Misery Business (Album Version)', 'Avery', 'Watkins')
# (30, 324, '19', 'Leggo Beast', 'Itchy Feet', 'Avery', 'Watkins')
# (16, 575, '5', 'Nneka', 'Gypsy', 'Rylan', 'George')
# (80, 611, '18', "Diam's", 'Dans Ma Bulle (Edit Radio - Live 2006)', 'Tegan', 'Levine')
# (16, 575, '6', 'Haley Bonar', 'Give It Up', 'Rylan', 'George')
# (80, 611, '19', 'Mansun', 'Love Remains (Home Demo)', 'Tegan', 'Levine')
# (30, 324, '20', '3 Doors Down', 'Here Without You', 'Avery', 'Watkins')
# (16, 575, '7', 'The Corrs', 'Toss The Feathers (Instrumental) ( LP Version )', 'Rylan', 'George')
# (80, 611, '20', 'Big Tymers', 'Big', 'Tegan', 'Levine')
# (30, 324, '21', 'Thursday', 'I Am The Killer (Album Version)', 'Avery', 'Watkins')
# (16, 575, '8', 'Motion City Soundtrack', "Don't Call It A Comeback (Album Version)", 'Rylan', 'George')
# (80, 611, '21', 'Usher', "Hey Daddy (Daddy's Home)", 'Tegan', 'Levine')
# (16, 575, '10', 'Juanes', 'No Siento Penas', 'Rylan', 'George')
# (30, 324, '22', 'The Wombats', 'Kill The Director [Radio Edit]', 'Avery', 'Watkins')
# (80, 611, '22', 'Katy Perry', 'I Kissed A Girl', 'Tegan', 'Levine')
# (16, 575, '11', 'As I Lay Dying', 'The Darkest Nights', 'Rylan', 'George')
# (30, 324, '23', 'BjÃ\x83Â¶rk', 'Undo', 'Avery', 'Watkins')
# (80, 611, '23', 'The Bobby Fuller Four', 'I Fought The Law (LP Version)', 'Tegan', 'Levine')
# (16, 575, '12', 'Charly GarcÃ\x83Â\xada', 'Influencia', 'Rylan', 'George')
# (80, 611, '24', 'New Bomb Turks', 'Too Much', 'Tegan', 'Levine')
# (80, 611, '25', 'The Black Keys', 'All Hands Against His Own', 'Tegan', 'Levine')
# (30, 324, '24', 'PeterLicht', 'Blaues Blau', 'Avery', 'Watkins')
# (80, 611, '26', 'John Mayer', 'Friends_ Lovers Or Nothing', 'Tegan', 'Levine')
# (16, 575, '13', 'Stone Temple Pilots', 'A Song For Sleeping (LP Version)', 'Rylan', 'George')
# (30, 324, '25', 'Bad Lieutenant', 'Head Into Tomorrow', 'Avery', 'Watkins')
# (16, 575, '14', 'Lily Allen', 'Smile Version Revisited (Mark Ronson Remix) (Explicit)', 'Rylan', 'George')
# (80, 611, '27', 'Neil Halstead', 'A Gentle Heart', 'Tegan', 'Levine')
# (30, 324, '26', 'Juanes', 'Un DÃ\x83Â\xada Normal', 'Avery', 'Watkins')
# (16, 575, '15', 'Distance', 'Ska', 'Rylan', 'George')
# (30, 324, '27', 'Slipknot', 'The Heretic Anthem (Album Version)', 'Avery', 'Watkins')
# (80, 611, '28', 'Franz Ferdinand', 'Tell Her Tonight', 'Tegan', 'Levine')
# (16, 575, '16', 'Jedi Mind Tricks', 'Suicide', 'Rylan', 'George')
# (80, 611, '29', 'Miles Davis', 'Stella By Starlight', 'Tegan', 'Levine')
# (30, 324, '28', 'B.o.B', "Nothin' On You [feat. Bruno Mars] (Album Version)", 'Avery', 'Watkins')
# (16, 575, '17', 'The Avett Brothers', 'I And Love And You', 'Rylan', 'George')
# (80, 611, '30', 'Joshua Bell / Paul Coker', 'Caprice viennois op.2', 'Tegan', 'Levine')
# (30, 324, '29', 'Bad Brains', "Joshua's Song (1991 Digital Remaster)", 'Avery', 'Watkins')
# (30, 324, '30', 'Shakira ft. Wyclef Jean', "Hips Don't Lie", 'Avery', 'Watkins')
# (16, 575, '18', 'Band Of Horses', 'The Funeral (Album Version)', 'Rylan', 'George')
# (80, 611, '31', 'Alesana', 'Ambrosia', 'Tegan', 'Levine')
# (30, 324, '31', 'Samy Deluxe', 'Einfach Ich', 'Avery', 'Watkins')
# (80, 611, '32', 'Corona', 'Higher Messiah', 'Tegan', 'Levine')
# (30, 324, '32', 'The Presets', 'If I Know You', 'Avery', 'Watkins')
# (30, 324, '33', 'Pixies', 'In Heaven', 'Avery', 'Watkins')
# (80, 611, '33', 'Existone', 'Wounded Soul', 'Tegan', 'Levine')
# (30, 324, '34', 'John Mayer', 'Bold As Love', 'Avery', 'Watkins')
# (30, 324, '35', 'Zakir Hussain', 'The Great ndian Desert', 'Avery', 'Watkins')
# (80, 611, '34', 'Jag Panzer', 'Face Of Fear', 'Tegan', 'Levine')
# (80, 611, '35', 'Two Door Cinema Club', 'What You Know', 'Tegan', 'Levine')
# (80, 611, '36', 'Little Anthony & The Imperials', 'Hurt', 'Tegan', 'Levine')
# (30, 324, '36', 'AndrÃ\x83Â©s Cepeda', 'Me Lleva Tiempo', 'Avery', 'Watkins')
# (80, 611, '37', 'Herb Alpert And The Tijuana Brass', "So What's New", 'Tegan', 'Levine')
# (30, 324, '37', 'Ozma', 'Flight Of Yuri Gagarin', 'Avery', 'Watkins')
# (80, 611, '38', 'Ozric Tentacles', 'Mooncalf', 'Tegan', 'Levine')
# (30, 324, '38', 'Evanescence', 'My Immortal (Album Version)', 'Avery', 'Watkins')
# (30, 324, '39', 'Weezer', 'Velouria', 'Avery', 'Watkins')
# (43, 369, '0', 'Flying Lotus', 'Bad Actors', 'Jahiem', 'Miles')
# (80, 611, '39', 'Ben Folds', "Bitches Ain't Shit", 'Tegan', 'Levine')
# (30, 324, '40', 'matchbox twenty', 'Unwell (Album Version)', 'Avery', 'Watkins')
# (80, 611, '40', 'Deftones', 'Feiticeira (LP Version)', 'Tegan', 'Levine')
# (30, 324, '41', 'Silverchair', 'Without You (Album Version)', 'Avery', 'Watkins')
# (80, 611, '41', 'Muse', 'Map Of The Problematique', 'Tegan', 'Levine')
# (30, 324, '42', 'Zen CafÃ\x83Â©', 'Kotona kaikuu', 'Avery', 'Watkins')
# (80, 611, '42', 'Mariah Carey / Twista', 'One And Only', 'Tegan', 'Levine')
# (30, 324, '43', 'Strike Anywhere', 'Gunpowder', 'Avery', 'Watkins')
# (30, 324, '44', 'Tri Sestry', 'Had Stupid', 'Avery', 'Watkins')
# (30, 324, '45', 'Don Williams', "If Hollywood Don't Need You", 'Avery', 'Watkins')
# (30, 324, '46', 'The Nerves', 'Are You Famous?', 'Avery', 'Watkins')
# (30, 324, '47', 'Ulf Wakenius', 'Good Morning Susie Soho', 'Avery', 'Watkins')
# (30, 324, '48', 'The Kooks', 'She Moves In Her Own Way', 'Avery', 'Watkins')
# (30, 324, '49', 'New Radicals', 'You Get What You Give', 'Avery', 'Watkins')
# (30, 324, '50', 'Wolfmother', 'Where Eagles Have Been', 'Avery', 'Watkins')
# (30, 324, '51', 'The Shins', 'Spilt Needles (Album)', 'Avery', 'Watkins')
# (30, 324, '52', 'Nickel Creek', 'Reasons Why', 'Avery', 'Watkins')
# (30, 324, '53', 'Pigeon John', 'Crazy', 'Avery', 'Watkins')
# (30, 324, '54', 'Eels', 'Love Of The Loveless', 'Avery', 'Watkins')
# (30, 324, '55', 'Harmonia', 'Sehr kosmisch', 'Avery', 'Watkins')
# (30, 324, '56', 'Marina And The Diamonds', 'Oh No! (album version)', 'Avery', 'Watkins')
# (30, 324, '57', 'Eminem', 'The Real Slim Shady', 'Avery', 'Watkins')
# (30, 324, '58', 'Hassisen Kone', 'REIPPAINA KÃ\x83Â\x84YMME REKKAIN ALLE', 'Avery', 'Watkins')
# (30, 324, '59', 'Dwight Yoakam', "You're The One", 'Avery', 'Watkins')
# (30, 324, '60', 'Sunlounger', 'White Sand', 'Avery', 'Watkins')
# (30, 324, '61', "Youssou N'Dour", 'Tan bi (Heat_ Breeze_ Tenderness) / Chaleur_ brise_ tendress', 'Avery', 'Watkins')
# (30, 324, '62', 'The Decemberists', 'Red Right Ankle', 'Avery', 'Watkins')
# (30, 324, '63', 'The Ruts', 'Savage Circle', 'Avery', 'Watkins')
# (30, 324, '64', 'Adrian Legg', 'The One-Eyed Turk', 'Avery', 'Watkins')
# (30, 324, '66', 'Bedrock', 'Set In Stone', 'Avery', 'Watkins')
# (97, 605, '0', 'Prince & The Revolution', "Let's Go Crazy (LP Version)", 'Kate', 'Harrell')
# (97, 605, '1', 'The Zombies', "She's Coming Home", 'Kate', 'Harrell')
# (97, 605, '2', 'Portishead', 'Numb', 'Kate', 'Harrell')
# (30, 324, '67', 'Jack Johnson', 'Breakdown', 'Avery', 'Watkins')
# (97, 605, '3', 'Justice', 'Let There Be Lite (Album Version)', 'Kate', 'Harrell')
# (30, 324, '68', 'Snow Patrol', 'Set Down Your Glass', 'Avery', 'Watkins')
# (97, 605, '4', 'Lemon Jelly', 'Nice Weather For Ducks', 'Kate', 'Harrell')
# (30, 324, '69', 'The Lucksmiths', 'Tale Of Two Cities', 'Avery', 'Watkins')
# (97, 605, '5', 'Ben Kweller', 'Magic', 'Kate', 'Harrell')
# (30, 324, '70', 'Fedde le Grand Pres. Flamingo', 'Take No Shhh (Original Mix)', 'Avery', 'Watkins')
# (97, 605, '6', 'Rodrigo y Gabriela', 'VIKING MAN', 'Kate', 'Harrell')
# (97, 605, '7', 'Black Eyed Peas', 'I Gotta Feeling', 'Kate', 'Harrell')
# (30, 324, '71', 'Five Iron Frenzy', 'Canada', 'Avery', 'Watkins')
# (50, 598, '0', 'Creedence Clearwater Revival', 'Down On The Corner', 'Ava', 'Robinson')
# (50, 598, '1', 'Kings Of Leon', 'Camaro', 'Ava', 'Robinson')
# (30, 324, '72', 'Fireflight', 'Unbreakable', 'Avery', 'Watkins')
# (97, 605, '8', 'Steppenwolf', 'Born To Be Wild', 'Kate', 'Harrell')
# (50, 598, '2', 'New Found Glory', 'the king of wishful thinking', 'Ava', 'Robinson')
# (30, 324, '73', 'The Pussycat Dolls', 'Elevator', 'Avery', 'Watkins')
# (97, 605, '9', 'Eric Clapton', 'Willie And The Hand Jive', 'Kate', 'Harrell')
# (60, 531, '1', 'Josh Groban', 'Little Drummer Boy [featuring guitarist Andy McKee] (Album Version)', 'Devin', 'Larson')
# (30, 324, '74', 'The Dresden Dolls', 'Coin-Operated Boy', 'Avery', 'Watkins')
# (97, 605, '10', 'Pixies', 'Where Is My Mind?', 'Kate', 'Harrell')
# (60, 531, '2', 'Creedence Clearwater Revival', 'I Put A Spell On You', 'Devin', 'Larson')
# (97, 605, '11', 'The Smiths', 'Girlfriend In A Coma', 'Kate', 'Harrell')
# (30, 324, '75', 'Danger Doom', 'No Names (Black Debbie) (Album Version)', 'Avery', 'Watkins')
# (97, 605, '12', 'Taylor Swift', 'Love Story', 'Kate', 'Harrell')
# (30, 324, '76', 'Vilma Palma e Vampiros', 'La pachanga', 'Avery', 'Watkins')
# (97, 605, '13', 'Busta Rhymes feat. Pharrell', 'Light Your Ass On Fire', 'Kate', 'Harrell')
# (30, 324, '77', 'Little People', 'Above The Clouds', 'Avery', 'Watkins')
# (97, 605, '14', 'Dwight Yoakam', "You're The One", 'Kate', 'Harrell')
# (30, 324, '78', 'Amy Winehouse', 'He Can Only Hold Her', 'Avery', 'Watkins')
# (97, 605, '15', 'Ernie K-Doe', 'Te-Ta-Te-Ta-Ta (2002 Digital Remaster)', 'Kate', 'Harrell')
# (30, 324, '79', 'Alesana', 'Congratulations_ I Hate You', 'Avery', 'Watkins')
# (97, 605, '16', 'Dwight Yoakam', "You're The One", 'Kate', 'Harrell')
# (30, 324, '80', 'Gazpacho', 'Premonicion', 'Avery', 'Watkins')
# (97, 605, '17', 'Black Lips', 'Lock and Key', 'Kate', 'Harrell')
# (97, 605, '18', 'Kanye West', 'Stronger', 'Kate', 'Harrell')
# (30, 324, '81', 'Arcade Fire', 'Neon Bible', 'Avery', 'Watkins')
# (30, 324, '82', 'Barry Tuckwell/Academy of St Martin-in-the-Fields/Sir Neville Marriner', 'Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)', 'Avery', 'Watkins')
# (97, 605, '19', 'Fanfarlo', "I'm a Pilot", 'Kate', 'Harrell')
# (30, 324, '83', 'Crystal Castles', 'Empathy', 'Avery', 'Watkins')
# (97, 605, '20', 'Zeca Baleiro', 'Brigitte Bardot', 'Kate', 'Harrell')
# (30, 324, '86', 'Angus & Julia Stone', 'Just A Boy', 'Avery', 'Watkins')
# (30, 324, '87', 'Julian Casablancas', '4 Chords of the Apocalypse', 'Avery', 'Watkins')
# (97, 605, '21', 'Fat Joe', 'Safe 2 Say [The Incredible] (Album Version - Amended)', 'Kate', 'Harrell')
# (30, 324, '88', "Usher Featuring Lil' Jon & Ludacris", 'Yeah!', 'Avery', 'Watkins')
# (97, 605, '22', 'Pat Benatar', "Don't Walk Away", 'Kate', 'Harrell')
# (30, 324, '89', 'Fergie', 'Losing My Ground', 'Avery', 'Watkins')
# (97, 605, '23', 'Muse', 'Supermassive Black Hole (Twilight Soundtrack Version)', 'Kate', 'Harrell')
# (30, 324, '90', 'Two Door Cinema Club', 'Undercover Martyn', 'Avery', 'Watkins')
# (97, 605, '24', 'Spineshank', 'Intake (Album Version)', 'Kate', 'Harrell')
# (30, 324, '91', 'Whitney Houston Duet With Mariah Carey', 'When You Believe', 'Avery', 'Watkins')
# (97, 605, '25', 'Death Cab for Cutie', 'Transatlanticism', 'Kate', 'Harrell')
# (30, 324, '92', 'Noir DÃ\x83Â©sir', 'Ces Gens LÃ\x83Â\xa0', 'Avery', 'Watkins')
# (97, 605, '26', 'Paramore', 'Emergency (Album Version)', 'Kate', 'Harrell')
# (30, 324, '93', 'My Chemical Romance', 'Cemetery Drive (Album Version)', 'Avery', 'Watkins')
# (97, 605, '27', 'Vincent Vincent And The Villains', 'On My Own', 'Kate', 'Harrell')
# (30, 324, '94', 'Phoenix', 'Run Run Run', 'Avery', 'Watkins')
# (97, 605, '28', 'Beastie Boys', 'Skills To Pay The Bills', 'Kate', 'Harrell')
# (32, 554, '0', 'Natasha Bedingfield', 'These Words', 'Lily', 'Burns')
# (30, 324, '95', 'Calle 13', 'AtrÃ\x83Â©vete te te', 'Avery', 'Watkins')
# (97, 605, '29', 'Sondre Lerche', 'Modern Nature', 'Kate', 'Harrell')
# (32, 554, '1', 'Cecilia', 'Ultimo Baile', 'Lily', 'Burns')
# (30, 324, '96', 'Air', 'Mayfair Song', 'Avery', 'Watkins')
# (97, 605, '30', 'Five Iron Frenzy', 'Canada', 'Kate', 'Harrell')
# (32, 554, '2', 'Kings Of Convenience', 'Riot On An Empty Street', 'Lily', 'Burns')
# (30, 324, '97', 'Rhonda Vincent', "You're In My Heart", 'Avery', 'Watkins')
# (97, 605, '31', 'Soulwax', 'E Talking', 'Kate', 'Harrell')
# (32, 554, '3', 'Red', 'Mystery of You', 'Lily', 'Burns')
# (30, 324, '98', 'Sugababes', 'Overload', 'Avery', 'Watkins')
# (32, 554, '4', 'Eminem / Dr. Dre', 'Say What You Say', 'Lily', 'Burns')
# (97, 605, '32', 'Michael Jackson', 'Scream', 'Kate', 'Harrell')
# (30, 324, '99', 'Dominique A', 'Le Courage Des Oiseaux', 'Avery', 'Watkins')
# (97, 605, '33', 'Linkin Park', 'My December', 'Kate', 'Harrell')
# (30, 324, '100', 'Five Iron Frenzy', 'Canada', 'Avery', 'Watkins')
# (30, 324, '101', 'Dear Nora', 'Give Me Some Of Yr Love', 'Avery', 'Watkins')
# (97, 605, '34', 'The Police', 'Message In A Bottle', 'Kate', 'Harrell')
# (30, 324, '102', 'Cocoon', 'Microwave', 'Avery', 'Watkins')
# (53, 485, '0', 'Coldplay', 'A Rush Of Blood To The Head', 'Celeste', 'Williams')
# (51, 526, '0', 'Peter And Gordon', 'A World Without Love', 'Maia', 'Burke')
# (30, 324, '103', 'Gotye', 'Coming Back', 'Avery', 'Watkins')
# (97, 605, '35', 'Maps', 'To The Sky', 'Kate', 'Harrell')
# (51, 526, '1', 'Joshua Radin', "I'd Rather Be With You", 'Maia', 'Burke')
# (49, 621, '3', "D'Angelo", 'When We Get By', 'Chloe', 'Cuevas')
# (53, 485, '1', 'Blockhead', 'The Music Scene', 'Celeste', 'Williams')
# (63, 588, '0', 'Nine Inch Nails', 'Terrible Lie', 'Ayla', 'Johnson')
# (51, 526, '2', 'La Roux', 'Colourless Colour', 'Maia', 'Burke')
# (97, 605, '36', 'Lil Wayne / Shanell', 'American Star', 'Kate', 'Harrell')
# (30, 324, '104', 'RÃ\x83Â¶yksopp', 'What Else Is There?', 'Avery', 'Watkins')
# (49, 621, '4', "Jack's Mannequin", 'Spinning (Album Version)', 'Chloe', 'Cuevas')
# (97, 605, '37', 'FM Static', 'Definitely Maybe', 'Kate', 'Harrell')
# (30, 324, '105', 'Joy Division', 'Disorder [2007 Re-mastered Album Version]', 'Avery', 'Watkins')
# (49, 621, '5', 'N.E.R.D.', 'Rock Star', 'Chloe', 'Cuevas')
# (97, 605, '38', 'Mickie Krause', 'Orange TrÃ\x83Â¤gt Nur Die MÃ\x83Â¼llabfuhr (Go West)', 'Kate', 'Harrell')
# (30, 324, '106', 'Steadman', 'Wave Goodbye (Real/Rhapsody Version)', 'Avery', 'Watkins')
# (97, 605, '39', 'The Like', 'We Are Lost', 'Kate', 'Harrell')
# (49, 621, '6', 'Future Rock', 'Gears', 'Chloe', 'Cuevas')
# (42, 404, '1', 'The All-American Rejects', 'Gives You Hell', 'Harper', 'Barrett')
# (30, 324, '107', 'Bruce Springsteen', 'Born To Run', 'Avery', 'Watkins')
# (97, 605, '40', 'OneRepublic', 'Say (All I Need)', 'Kate', 'Harrell')
# (49, 621, '7', 'Owl City', 'Meteor Shower', 'Chloe', 'Cuevas')
# (42, 404, '2', 'Justin Nozuka', "I'm In Peace", 'Harper', 'Barrett')
# (49, 621, '8', 'Marina And The Diamonds', 'I Am Not a Robot', 'Chloe', 'Cuevas')
# (30, 324, '108', 'The Serendipity Singers', "Don't Let The Rain Come Down (Crooked Little Man)", 'Avery', 'Watkins')
# (97, 605, '41', 'Haujobb', 'Maternal Instinct', 'Kate', 'Harrell')
# (42, 404, '3', 'Cyndi Lauper', 'My Baby Just Cares For Me', 'Harper', 'Barrett')
# (30, 324, '109', 'Usher featuring will.i.am', 'OMG', 'Avery', 'Watkins')
# (49, 621, '9', 'Depeche Mode', 'Everything Counts (Live) (Single Version)', 'Chloe', 'Cuevas')
# (42, 404, '4', 'Red Hot Chili Peppers', 'Especially In Michigan (Album Version)', 'Harper', 'Barrett')
# (97, 605, '42', '3 Doors Down', 'Kryptonite', 'Kate', 'Harrell')
# (42, 404, '5', 'The Newbeats', 'Bread And Butter', 'Harper', 'Barrett')
# (97, 605, '43', 'Kings Of Leon', 'Dusty', 'Kate', 'Harrell')
# (30, 324, '110', 'Los Lobos', 'La Bamba', 'Avery', 'Watkins')
# (42, 404, '7', 'Drake / Kanye West / Lil Wayne / Eminem', 'Forever', 'Harper', 'Barrett')
# (49, 621, '10', 'Ginuwine', "I'm In Love", 'Chloe', 'Cuevas')
# (30, 324, '111', 'Descendents', "I'm Not A Loser", 'Avery', 'Watkins')
# (97, 605, '44', 'Jennifer Love Hewitt', 'BareNaked', 'Kate', 'Harrell')
# (49, 621, '11', 'The Cinematic Orchestra', 'Burn Out', 'Chloe', 'Cuevas')
# (42, 404, '8', 'La Fuga', 'Baja por diversion (directo 05)', 'Harper', 'Barrett')
# (97, 605, '45', 'Killswitch Engage', 'Hope Is... (Album Version)', 'Kate', 'Harrell')
# (42, 404, '9', 'Kid Cudi Vs Crookers', "Day 'N' Nite", 'Harper', 'Barrett')
# (97, 605, '46', 'Beirut', 'La Llorona', 'Kate', 'Harrell')
# (42, 404, '10', 'Fall Out Boy', 'Dance_ Dance', 'Harper', 'Barrett')
# (97, 605, '47', "Christina Aguilera / Lil' Kim / Mya / Pink", 'Lady Marmalade', 'Kate', 'Harrell')
# (42, 404, '11', 'Harold Budd', 'Algebra Of Darkness (Album Version)', 'Harper', 'Barrett')
# (97, 605, '48', 'Eric Burdon & War', 'Jimbo (Album Version)', 'Kate', 'Harrell')
# (42, 404, '12', 'Cass McCombs', 'Deseret', 'Harper', 'Barrett')
# (97, 605, '49', 'The Black Keys', "I'll Be Your Man", 'Kate', 'Harrell')
# (42, 404, '13', 'Leona Naess', 'Christmas', 'Harper', 'Barrett')
# (97, 605, '50', 'Alliance Ethnik', 'ReprÃ\x83Â©sente', 'Kate', 'Harrell')
# (42, 404, '14', 'Nando Reis', 'A Letra "A', 'Harper', 'Barrett')
# (97, 605, '55', 'Kris Allen', "Live Like We're Dying", 'Kate', 'Harrell')
# (97, 605, '56', 'Muse', 'Muscle Museum (Soulwax Remix)', 'Kate', 'Harrell')
# (42, 404, '15', 'Goldfrapp', 'Lovely Head', 'Harper', 'Barrett')
# (97, 605, '57', 'Slash', 'Doctor Alibi (featuring Lemmy Kilmister)', 'Kate', 'Harrell')
# (42, 404, '16', 'D.R.I.', 'Stupid_ Stupid War (Dealing With It)', 'Harper', 'Barrett')
# (42, 404, '17', 'Beastie Boys', 'Unite (2009 Digital Remaster)', 'Harper', 'Barrett')
# (97, 605, '58', 'Cat Power', 'Hate', 'Kate', 'Harrell')
# (42, 404, '18', 'Kings Of Leon', 'Revelry', 'Harper', 'Barrett')
# (97, 605, '59', 'Hot Water Music', 'Translocation', 'Kate', 'Harrell')
# (42, 404, '19', 'Miranda Lambert', 'Me And Charlie Talking', 'Harper', 'Barrett')
# (97, 605, '60', 'Brandy duet with Monica', 'The Boy Is Mine (Duet With Monica) (LP Version)', 'Kate', 'Harrell')
# (42, 404, '20', 'The Heavy', 'How You Like Me Now?', 'Harper', 'Barrett')
# (97, 605, '61', 'Streetlight Manifesto', 'Point/Counterpoint (Album Version)', 'Kate', 'Harrell')
# (42, 404, '21', 'Blitzen Trapper', 'Murder Babe (Album)', 'Harper', 'Barrett')
# (42, 404, '22', 'Megan McCauley', 'Die For You', 'Harper', 'Barrett')
# (97, 605, '62', 'Jack Johnson', 'Better Together', 'Kate', 'Harrell')
# (42, 404, '23', 'Passion Pit', 'Eyes As Candles', 'Harper', 'Barrett')
# (44, 619, '0', 'Strunz & Farah', 'Zagros', 'Aleena', 'Kirby')
# (97, 605, '63', 'Minus The Bear', 'Part 2', 'Kate', 'Harrell')
# (42, 404, '24', 'Van Halen', 'Eruption (Album Version)', 'Harper', 'Barrett')
# (97, 605, '64', 'Pavement', 'Heaven Is A Truck', 'Kate', 'Harrell')
# (42, 404, '25', 'Alliance Ethnik', 'SinceritÃ\x83Â© Et Jalousie', 'Harper', 'Barrett')
# (44, 619, '1', 'Pieces Of A Dream', 'Keep It Smooth', 'Aleena', 'Kirby')
# (97, 605, '65', 'Creedence Clearwater Revival', 'Born On The Bayou', 'Kate', 'Harrell')
# (42, 404, '26', 'Anouk', "It's So Hard", 'Harper', 'Barrett')
# (44, 619, '2', 'Jaco Pastorius Big Band', 'Amerika (Album Version)', 'Aleena', 'Kirby')
# (44, 619, '3', 'Avril Lavigne', "I'm With You", 'Aleena', 'Kirby')
# (97, 605, '66', 'Gonzalo Rubalcaba', 'Circuito III', 'Kate', 'Harrell')
# (42, 404, '27', 'BjÃ\x83Â¶rk', 'Undo', 'Harper', 'Barrett')
# (44, 619, '4', 'Ska-P', 'Casposos', 'Aleena', 'Kirby')
# (42, 404, '28', 'The Strokes', 'Is This It', 'Harper', 'Barrett')
# (44, 619, '5', 'Jesse Belvin', 'Goodnight My Love', 'Aleena', 'Kirby')
# (42, 404, '29', 'Alliance Ethnik', 'Creil City', 'Harper', 'Barrett')
# (97, 605, '67', 'The Gerbils', '(iii)', 'Kate', 'Harrell')
# (97, 605, '68', 'KJ-52', 'Life After Death', 'Kate', 'Harrell')
# (44, 619, '7', 'Mariah Carey', 'All I Want For Christmas Is You', 'Aleena', 'Kirby')
# (42, 404, '30', 'Glen Hansard & Marketa Irglova', 'The Moon (Album version)', 'Harper', 'Barrett')
# (97, 605, '69', 'Dion & The Belmonts', 'A Teenager In Love', 'Kate', 'Harrell')
# (89, 600, '0', 'Jack Johnson', 'Bubble Toes', 'Kynnedi', 'Sanchez')
# (44, 619, '8', 'Beastie Boys', 'The Maestro', 'Aleena', 'Kirby')
# (97, 605, '70', 'Lesley Gore', "It's My Party", 'Kate', 'Harrell')
# (42, 404, '31', 'Dr. Dre / Snoop Dogg', 'The Next Episode', 'Harper', 'Barrett')
# (44, 619, '9', 'Pearl Jam', 'Encore Break', 'Aleena', 'Kirby')
# (89, 600, '1', 'Cake', 'Commissioning A Symphony In C', 'Kynnedi', 'Sanchez')
# (97, 605, '71', 'Phoenix', 'Rome', 'Kate', 'Harrell')
# (44, 619, '10', 'Alesana', 'Seduction (album)', 'Aleena', 'Kirby')
# (42, 404, '32', 'The Kooks', 'She Moves In Her Own Way', 'Harper', 'Barrett')
# (42, 404, '33', 'Dakis', 'La Petite Marie (2005 Digital Remaster)', 'Harper', 'Barrett')
# (97, 605, '72', 'Limp Bizkit', "Rollin' (Air Raid Vehicle)", 'Kate', 'Harrell')
# (44, 619, '11', 'JET', 'Move On (Album Version)', 'Aleena', 'Kirby')
# (42, 404, '34', 'Mickie Krause', 'Orange TrÃ\x83Â¤gt Nur Die MÃ\x83Â¼llabfuhr (Go West)', 'Harper', 'Barrett')
# (97, 605, '73', 'Hot Chip', 'My Piano (DJ-Kicks)', 'Kate', 'Harrell')
# (44, 619, '12', 'Yung Berg', "Do That There (featuring Dude 'N Nem)", 'Aleena', 'Kirby')
# (42, 404, '35', 'Kings Of Leon', 'Closer', 'Harper', 'Barrett')
# (44, 619, '13', 'Johan', 'Life On Mars', 'Aleena', 'Kirby')
# (97, 605, '74', 'Crystal Castles', 'Love And Caring', 'Kate', 'Harrell')
# (42, 404, '36', 'Thirteen Senses', 'Lead Us', 'Harper', 'Barrett')
# (97, 605, '76', 'Eisbrecher', 'Adrenalin', 'Kate', 'Harrell')
# (44, 619, '14', 'Buckcherry', 'Crazy Bitch (Album Version)', 'Aleena', 'Kirby')
# (42, 404, '37', 'Band Of Horses', 'The General Specific (Album)', 'Harper', 'Barrett')
# (97, 605, '77', 'Darkseed', 'Speak Silence', 'Kate', 'Harrell')
# (44, 619, '15', 'Caetano Veloso', 'O Samba E O Tango', 'Aleena', 'Kirby')
# (42, 404, '38', 'Maria Arredondo', 'Burning', 'Harper', 'Barrett')
# (44, 619, '16', 'Boyzone', 'All That I Need', 'Aleena', 'Kirby')
# (97, 605, '78', 'Coldplay', 'Trouble', 'Kate', 'Harrell')
# (42, 404, '39', 'matchbox twenty', 'Unwell (Album Version)', 'Harper', 'Barrett')
# (44, 619, '17', 'Sussie 4', 'On Time', 'Aleena', 'Kirby')
# (97, 605, '79', 'Klaxons', 'Golden Skans', 'Kate', 'Harrell')
# (42, 404, '40', 'Prince', 'Hot Thing ( LP Version )', 'Harper', 'Barrett')
# (97, 605, '80', 'Dwight Yoakam', "You're The One", 'Kate', 'Harrell')
# (44, 619, '18', 'Damian Marley / Capleton / Drag-On / Stephen Marley', 'It Was Written', 'Aleena', 'Kirby')
# (97, 605, '81', 'Markus KrunegÃ\x83Â¥rd', 'Genom tunna tyger', 'Kate', 'Harrell')
# (42, 404, '41', 'Kamera', 'I Was Made', 'Harper', 'Barrett')
# (97, 605, '82', 'Rainer Weichhold vs. Dandi & Ugo', 'Infinite Template', 'Kate', 'Harrell')
# (44, 619, '19', 'Sondre Lerche', 'Face The Blood', 'Aleena', 'Kirby')
# (42, 404, '42', 'John Mayer', 'Slow Dancing In A Burning Room', 'Harper', 'Barrett')
# (44, 619, '20', 'Mystikal', 'Alright', 'Aleena', 'Kirby')
# (42, 404, '43', 'Luis Fonsi', 'Aunque Estes Con El', 'Harper', 'Barrett')
# (44, 619, '21', 'Angelic Upstarts', 'Two Million Voices', 'Aleena', 'Kirby')
# (97, 605, '83', 'Tonic', 'Count On Me (Somebody)', 'Kate', 'Harrell')
# (44, 619, '22', 'Enya', 'Exile', 'Aleena', 'Kirby')
# (42, 404, '44', 'Lily Allen', "Everyone's At It", 'Harper', 'Barrett')
# (97, 605, '84', 'Lissi Dancefloor Disaster', "I'M Gonna Keep On Driving My Car", 'Kate', 'Harrell')
# (44, 619, '23', 'M.I.A.', 'Paper Planes', 'Aleena', 'Kirby')
# (97, 605, '85', 'India.Arie', 'Interested', 'Kate', 'Harrell')
# (42, 404, '46', 'AFI', 'This Celluloid Dream', 'Harper', 'Barrett')
# (44, 619, '24', '3 Doors Down', "She Don't Want The World", 'Aleena', 'Kirby')
# (97, 605, '86', 'Linkin Park', 'Points Of Authority (Album Version)', 'Kate', 'Harrell')
# (42, 404, '47', 'Leatherface and Hot Water Music', 'Gang Party (Leatherface)', 'Harper', 'Barrett')
# (44, 619, '25', 'Agnes', 'Release Me', 'Aleena', 'Kirby')
# (97, 605, '87', 'Weezer', 'Island In The Sun', 'Kate', 'Harrell')
# (42, 404, '48', 'Scandinavian Music Group', 'Kun Puut Tekee SeittiÃ\x83Â¤', 'Harper', 'Barrett')
# (44, 619, '26', 'Caparezza', 'Fuori Dal Tunnel (Album Version)', 'Aleena', 'Kirby')
# (97, 605, '89', 'Billy Idol', 'Flesh For Fantasy', 'Kate', 'Harrell')
# (44, 619, '27', 'Charttraxx Karaoke', 'Fireflies', 'Aleena', 'Kirby')
# (97, 605, '90', 'Michael BublÃ\x83Â©', "Can't Help Falling In Love (Album Version) (Studio)", 'Kate', 'Harrell')
# (42, 404, '49', 'Amos Lee', 'Baby I Want You', 'Harper', 'Barrett')
# (44, 619, '28', 'The Notorious B.I.G.', 'Big Poppa', 'Aleena', 'Kirby')
# (44, 619, '29', 'The Spinanes', 'Azure (Album)', 'Aleena', 'Kirby')
# (44, 619, '30', 'Coldplay', 'Brothers & Sisters', 'Aleena', 'Kirby')
# (44, 619, '31', 'Evanescence', 'Good Enough', 'Aleena', 'Kirby')
# (44, 619, '32', 'L-Kan', 'Cuentos chinos', 'Aleena', 'Kirby')
# (44, 619, '33', 'Peter Mulvey', 'Hidden Love', 'Aleena', 'Kirby')
# (44, 619, '34', 'Beverley Craven', 'Promise Me', 'Aleena', 'Kirby')
# (44, 619, '35', 'The Lonely Island / Julian Casablancas', 'Boombox', 'Aleena', 'Kirby')
# (44, 619, '36', 'Three Days Grace', 'Just Like You', 'Aleena', 'Kirby')
# (44, 619, '37', 'The Ethiopians', 'Woman Capture Man', 'Aleena', 'Kirby')
# (44, 619, '38', 'Fozzy', 'Watch Me Shine (Album)', 'Aleena', 'Kirby')
# (44, 619, '39', 'Silversun Pickups', 'Booksmart Devil', 'Aleena', 'Kirby')
# (44, 619, '40', 'Lionel Richie', 'Lady', 'Aleena', 'Kirby')
# (49, 630, '2', 'Margaret Cho', 'Gay Porn', 'Chloe', 'Cuevas')
# (44, 619, '41', 'A Day To Remember', 'Heart Less', 'Aleena', 'Kirby')
# (49, 630, '3', 'Armored Saint', 'Human Vulture', 'Chloe', 'Cuevas')
# (44, 619, '42', 'The Dropkick Murphys', 'The State Of Massachusetts', 'Aleena', 'Kirby')
# (44, 619, '43', 'Fall Out Boy', 'Beat It', 'Aleena', 'Kirby')
# (49, 630, '4', 'Beck', 'Girl Dreams', 'Chloe', 'Cuevas')
# (49, 630, '5', 'Beastie Boys', 'Intergalactic', 'Chloe', 'Cuevas')
# (44, 619, '44', 'Fall Out Boy', 'Thnks fr th Mmrs', 'Aleena', 'Kirby')
# (49, 630, '6', 'keller williams', '221', 'Chloe', 'Cuevas')
# (44, 619, '45', 'Al Gromer Khan', 'A Hundred Moons', 'Aleena', 'Kirby')
# (49, 630, '7', 'Benny Benassi Presents The Biz', 'Love Is Gonna Save Us ', 'Chloe', 'Cuevas')
# (44, 619, '46', 'Symphony X', 'Evolution (the Grand Design)', 'Aleena', 'Kirby')
# (49, 630, '8', 'Kajagoogoo', 'Big Apple (Metro Mix)', 'Chloe', 'Cuevas')
# (44, 619, '47', 'Jamiroquai', 'Virtual Insanity', 'Aleena', 'Kirby')
# (49, 630, '9', 'Justin Bieber', 'Somebody To Love', 'Chloe', 'Cuevas')
# (44, 619, '48', 'Bruce Willis', 'Save The Last Dance For Me', 'Aleena', 'Kirby')
# (49, 630, '10', 'The Killers', 'Read My Mind', 'Chloe', 'Cuevas')
# (44, 619, '49', 'Sharleen Spiteri', 'Cat People (Putting Out Fire)', 'Aleena', 'Kirby')
# (49, 630, '11', 'Alliance Ethnik', 'ReprÃ\x83Â©sente', 'Chloe', 'Cuevas')
# (44, 619, '50', 'The Cardigans', 'Lovefool', 'Aleena', 'Kirby')
# (44, 619, '51', 'Black Kids', "I'm Not Gonna Teach Your Boyfriend How To Dance With You", 'Aleena', 'Kirby')
# (49, 630, '12', 'Parachute', 'She Is Love', 'Chloe', 'Cuevas')
# (49, 630, '13', 'Mudcrutch', 'The Wrong Thing To Do (Album Version)', 'Chloe', 'Cuevas')
# (44, 619, '52', 'Simon Harris', 'Sample Track 2', 'Aleena', 'Kirby')
# (49, 630, '14', 'Sufjan Stevens', 'Movement III - Linear Tableau with Intersecting Surprise', 'Chloe', 'Cuevas')
# (44, 619, '53', 'Charlie Patton', 'Green River Blues', 'Aleena', 'Kirby')
# (44, 619, '54', 'Basshunter', 'Walk On Water', 'Aleena', 'Kirby')
# (49, 630, '15', 'Lindisfarne', 'Fog On The Tyne (Live)', 'Chloe', 'Cuevas')
# (44, 619, '55', 'Kanye West', 'Jesus Walks', 'Aleena', 'Kirby')
# (49, 630, '16', 'Ariane Moffatt', 'Retourne Chez Elle', 'Chloe', 'Cuevas')
# (44, 619, '56', 'Linkin Park', 'Runaway (Album Version)', 'Aleena', 'Kirby')
# (44, 619, '57', 'The Beach Boys', "You've Got To Hide Your Love Away (Digitally Remastered 01)", 'Aleena', 'Kirby')
# (49, 630, '17', 'No Doubt', "Don't Speak", 'Chloe', 'Cuevas')
# (44, 619, '58', 'Queens Of The Stone Age', 'God Is On The Radio', 'Aleena', 'Kirby')
# (49, 630, '18', 'LMFAO / Lil Jon', 'Shots', 'Chloe', 'Cuevas')
# (49, 630, '19', 'The Suicide Machines', 'High Anxiety', 'Chloe', 'Cuevas')
# (44, 619, '59', 'Kate Nash', 'Mariella', 'Aleena', 'Kirby')
# (49, 630, '20', 'The Saturdays', 'If This Is Love', 'Chloe', 'Cuevas')
# (44, 619, '60', 'Frou Frou', 'Holding Out For A Hero', 'Aleena', 'Kirby')
# (49, 630, '21', 'Flaw', 'Get Up Again', 'Chloe', 'Cuevas')
# (49, 630, '22', 'Liz Callaway', 'Journey To The Past  (LP Version)', 'Chloe', 'Cuevas')
# (44, 619, '61', 'Les MisÃ\x83Â©rables - Original London Cast', 'Finale', 'Aleena', 'Kirby')
# (49, 630, '23', "Lady GaGa / Colby O'Donis", 'Just Dance', 'Chloe', 'Cuevas')
# (44, 619, '62', 'Cozy Powell', 'Dance With The Devil', 'Aleena', 'Kirby')
# (49, 630, '24', 'Animal Collective', 'Bluish', 'Chloe', 'Cuevas')
# (44, 619, '63', 'Blink-182', 'A New Hope', 'Aleena', 'Kirby')
# (35, 482, '0', 'Charisma', 'Loon Garden', 'Molly', 'Taylor')
# (49, 630, '25', 'Dido', 'Thank You', 'Chloe', 'Cuevas')
# (44, 619, '64', "Screamin' Jay Hawkins", 'The Whammy', 'Aleena', 'Kirby')
# (44, 619, '65', 'Silverchair', 'All Across The World', 'Aleena', 'Kirby')
# (49, 630, '26', 'Emery', 'The Ponytail Parades', 'Chloe', 'Cuevas')
# (44, 619, '66', 'Hockey', 'Song Away', 'Aleena', 'Kirby')
# (76, 561, '1', 'Flight Of The Conchords', 'Hurt Feelings', 'Jayden', 'Duffy')
# (49, 630, '27', 'Mike Posner', 'Cooler Than Me', 'Chloe', 'Cuevas')
# (44, 619, '67', 'Juana Molina', 'Medlong', 'Aleena', 'Kirby')
# (76, 561, '2', 'Nancy Sinatra', 'So Long_ Babe (2006 Digital Remaster)', 'Jayden', 'Duffy')
# (49, 630, '28', 'Joy Division', 'I Remember Nothing [2007 Re-mastered Album Version]', 'Chloe', 'Cuevas')
# (44, 619, '68', 'Elvis Presley', 'Suspicious Minds', 'Aleena', 'Kirby')
# (49, 630, '30', 'Kings Of Leon', 'Revelry', 'Chloe', 'Cuevas')
# (44, 619, '69', "Kanye West / Consequence / Cam'Ron", 'Gone', 'Aleena', 'Kirby')
# (49, 630, '31', 'Johnny Winter', "It's My Own Fault", 'Chloe', 'Cuevas')
# (44, 619, '70', 'Greg Brown', "I Believe I'll Go Back Home", 'Aleena', 'Kirby')
# (44, 619, '71', 'Wim Mertens', 'Naviamente', 'Aleena', 'Kirby')
# (49, 630, '32', 'Ra Ra Riot', 'Can You Tell', 'Chloe', 'Cuevas')
# (44, 619, '72', 'Foo Fighters', 'What If I Do?', 'Aleena', 'Kirby')
# (44, 619, '73', 'Vanessa Williams', 'Colors Of The Wind', 'Aleena', 'Kirby')
# (44, 619, '74', 'Gyllene Tider', '(Hon Vill Ha) Puls', 'Aleena', 'Kirby')
# (49, 630, '34', 'Ska Cubano', 'Cumbia En Do Menor', 'Chloe', 'Cuevas')
# (44, 619, '75', 'Train', 'Marry Me', 'Aleena', 'Kirby')
# (44, 619, '76', 'Camera Obscura', 'Teenager', 'Aleena', 'Kirby')
# (49, 630, '35', 'Liah', 'Tudo Que Eu Sempre Quis', 'Chloe', 'Cuevas')
# (44, 619, '77', 'Rise Against', 'Audience Of One', 'Aleena', 'Kirby')
# (44, 619, '78', 'Rise Against', 'My Life Inside Your Heart', 'Aleena', 'Kirby')
# (44, 619, '79', 'Sly Fox', "Let's Go All The Way (Short Blix Mix)", 'Aleena', 'Kirby')
# (44, 619, '80', 'Heart', 'Crazy On You', 'Aleena', 'Kirby')
# (44, 619, '81', 'Ugly Kid Joe', 'Cats In The Cradle', 'Aleena', 'Kirby')
# (44, 637, '0', 'Traveling Wilburys', 'You Took My Breath Away (2007 Remastered LP Version)', 'Aleena', 'Kirby')
# (44, 637, '1', 'Michael BublÃ\x83Â©', 'A Foggy Day (In London Town) (Album Version)', 'Aleena', 'Kirby')
# (44, 637, '2', 'S Club 7', 'Have You Ever', 'Aleena', 'Kirby')
# (44, 637, '3', 'Hevia', 'Fandangu Los Llobos', 'Aleena', 'Kirby')
# (44, 637, '4', 'Billy Talent', 'Voices Of Violence (Album Version)', 'Aleena', 'Kirby')
# (44, 637, '5', 'Phoenix', 'Courtesy Laughs', 'Aleena', 'Kirby')
# (44, 637, '6', 'Kanye West', "We Don't Care", 'Aleena', 'Kirby')
# (44, 637, '7', 'Damero feat. Nevis Peak', 'Gestern_Morgen', 'Aleena', 'Kirby')
# (44, 637, '8', 'Shakira', 'Que Me Quedes Tu', 'Aleena', 'Kirby')
# (44, 637, '9', 'Big Kuntry King', 'Da Baddest [Feat. Trey Songz] (Explicit Album Version)', 'Aleena', 'Kirby')
# (15, 818, '38', 'Dee Dee Bridgewater', 'La Vie En Rose', 'Lily', 'Koch')
# (15, 818, '39', "Tim O'brien", 'Think About Last Night', 'Lily', 'Koch')
# (15, 818, '40', 'Nirvana', 'Love Buzz', 'Lily', 'Koch')
# (15, 818, '41', 'Weezer', 'Only In Dreams', 'Lily', 'Koch')
# (15, 818, '42', 'Nightwish', 'She Is My Sin', 'Lily', 'Koch')
# (15, 818, '43', 'California Swag District', 'Teach Me How To Dougie', 'Lily', 'Koch')
# (15, 818, '44', 'Miike Snow', 'Silvia', 'Lily', 'Koch')
# (15, 818, '45', 'Katy Perry', 'I Kissed A Girl', 'Lily', 'Koch')
# (15, 818, '46', 'Sikth', 'Peep Show', 'Lily', 'Koch')
# (15, 818, '47', 'Lily Allen', 'Not Fair', 'Lily', 'Koch')
# (15, 818, '48', 'The Presidents of the United States of America', 'Lump', 'Lily', 'Koch')
# (15, 818, '49', 'Wordsworth', 'Right Now (Produced by Ayatollah)', 'Lily', 'Koch')
# (15, 818, '50', 'Rihanna', 'Take A Bow', 'Lily', 'Koch')
# (15, 818, '51', 'Tomas Bodin', 'Back To The African Garden', 'Lily', 'Koch')
# (15, 818, '52', 'Black Eyed Peas', 'My Humps', 'Lily', 'Koch')
# (15, 818, '53', 'Carolina Liar', "Show Me What I'm Looking For (Album Version)", 'Lily', 'Koch')
# (15, 818, '54', 'Kansas', 'Dust in The Wind', 'Lily', 'Koch')
# (15, 818, '55', 'Onar', 'Xehasmeni Melodia', 'Lily', 'Koch')
# (15, 818, '56', 'Live', "Lakini's Juice", 'Lily', 'Koch')
# (15, 818, '57', 'Abstract Rude', 'Nuff Fire', 'Lily', 'Koch')
# (15, 818, '58', 'Johnny Horton', 'Mean Mean Son Of A Gun', 'Lily', 'Koch')
# (15, 818, '59', "The Men They Couldn't Hang", 'Ironmasters', 'Lily', 'Koch')
# (15, 818, '60', 'Rilo Kiley', 'The Absence Of God (Album Version)', 'Lily', 'Koch')
# (15, 818, '61', 'Shwayze', 'Lost My Mind', 'Lily', 'Koch')
# (15, 818, '62', 'Bram Vermeulen', 'Mamma', 'Lily', 'Koch')
# (15, 818, '63', 'Death Cab for Cutie', 'I Will Follow You into the Dark (Album Version)', 'Lily', 'Koch')
# (15, 818, '64', 'Dwight Yoakam', "You're The One", 'Lily', 'Koch')
# (15, 818, '65', 'Jadakiss / Ghostface Killah / Raekwon', 'Cartel Gathering', 'Lily', 'Koch')
# (15, 818, '66', 'Rosana', 'Si tu no estas', 'Lily', 'Koch')
# (15, 818, '67', 'The Killers', 'The Ballad of Michael Valentine', 'Lily', 'Koch')
# (15, 818, '68', 'Alliance Ethnik', 'SinceritÃ\x83Â© Et Jalousie', 'Lily', 'Koch')
# (15, 818, '69', 'Enya', 'China Roses', 'Lily', 'Koch')
# (15, 818, '70', 'Aya RL', 'Jazz', 'Lily', 'Koch')
# (26, 820, '0', 'Clor', 'Love + Pain', 'Ryan', 'Smith')
# (26, 820, '1', 'Alejandro Fernandez', 'Solitario Y Solo', 'Ryan', 'Smith')
# (26, 820, '2', 'Yonder Mountain String Band', 'Midwest Gospel Radio', 'Ryan', 'Smith')
# (50, 824, '0', "K'Naan", "Wavin'  Flag", 'Ava', 'Robinson')
# (97, 828, '0', 'Cradle Of Filth', 'Her Ghost In The Fog', 'Kate', 'Harrell')
# (97, 828, '1', 'Amanda Marshall', 'Let It Rain', 'Kate', 'Harrell')
# (97, 828, '2', 'Rammstein', 'Sonne', 'Kate', 'Harrell')
# (97, 828, '3', 'Cat Stevens', 'If You Want To Sing Out_ Sing Out', 'Kate', 'Harrell')
# (97, 828, '4', 'Emma Shapplin', 'Spente Le Stelle', 'Kate', 'Harrell')
# (97, 828, '5', 'Modest Mouse', 'Float On', 'Kate', 'Harrell')
# (97, 828, '6', 'Flaco Jimenez', 'En El Cielo No Hay Cerveza (In Heaven There Is No Beer)', 'Kate', 'Harrell')
# (97, 828, '7', 'Modest Mouse', 'Float On', 'Kate', 'Harrell')
# (97, 828, '8', 'Cedric Gervais feat. Second Sun', 'Pills (Radio Edit) (Radio Edit)', 'Kate', 'Harrell')
# (97, 828, '9', 'Sheena Easton', 'Strut (1993 Digital Remaster)', 'Kate', 'Harrell')
# (97, 828, '10', 'Everything But The Girl', "My Baby Don't Love Me", 'Kate', 'Harrell')
# (97, 828, '11', 'Florence + The Machine', 'Dog Days Are Over (Radio Edit)', 'Kate', 'Harrell')
# (97, 828, '12', 'BoDeans', 'Naked (Live)', 'Kate', 'Harrell')
# (97, 828, '13', 'OneRepublic', 'Apologize', 'Kate', 'Harrell')
# (97, 828, '14', 'Miley Cyrus', 'Full Circle', 'Kate', 'Harrell')
# (97, 828, '15', 'Coldplay', "Don't Panic", 'Kate', 'Harrell')
# (97, 828, '16', 'Atreyu', "You Were The King_ Now You're Unconscious (Album Version)", 'Kate', 'Harrell')
# (97, 828, '17', 'Bruce Springsteen', 'Born To Run', 'Kate', 'Harrell')
# (97, 828, '18', 'BjÃ\x83Â¶rk', 'Undo', 'Kate', 'Harrell')
# (97, 828, '19', 'Big Shug', "It Just Don't Stop", 'Kate', 'Harrell')
# (97, 828, '20', 'The Wallflowers', 'Be Your Own Girl', 'Kate', 'Harrell')
# (97, 828, '21', 'Chris Brown', "Ain't No Way (You Won't Love Me)", 'Kate', 'Harrell')
# (97, 828, '22', 'Charly GarcÃ\x83Â\xada', 'Filosofia Barata Y Zapatos De Goma', 'Kate', 'Harrell')
# (97, 828, '23', 'N.W.A ft. Eazy-E', 'Boyz-N-The-Hood', 'Kate', 'Harrell')
# (97, 828, '24', 'The Mighty Mighty Bosstones', '1/2/2008', 'Kate', 'Harrell')
# (97, 828, '25', 'Beastie Boys', 'Unite (2009 Digital Remaster)', 'Kate', 'Harrell')
# (97, 828, '26', 'Yuksek', 'Take A Ride', 'Kate', 'Harrell')
# (97, 828, '27', 'Fernando Ubiergo', 'Cuando Agosto Era 21', 'Kate', 'Harrell')
# (97, 828, '28', 'Phoenix', 'Napoleon Says', 'Kate', 'Harrell')
# (101, 790, '0', 'Radney Foster', 'Sweet And Wild', 'Jayden', 'Fox')
# (101, 790, '1', 'Neneh Cherry', 'Manchild', 'Jayden', 'Fox')
# (63, 785, '0', 'Hooligans', 'Szex & KV', 'Ayla', 'Johnson')
# (32, 786, '0', 'Kid Cudi / MGMT / Ratatat', 'Pursuit Of Happiness (nightmare)', 'Lily', 'Burns')
# (23, 351, '0', 'Foals', 'Blue Blood', 'Morris', 'Gilmore')
# (23, 351, '1', "'N Sync/Phil Collins", "Trashin' The Camp (Phil And 'N Sync Version)", 'Morris', 'Gilmore')
# (101, 838, '0', 'Kristian Stanfill', 'I Need You', 'Jayden', 'Fox')
# (101, 838, '1', 'Enrique Iglesias', 'Tired Of Being Sorry', 'Jayden', 'Fox')
# (101, 838, '2', 'Michael Cretu', 'The Invisible Man', 'Jayden', 'Fox')
# (101, 838, '3', 'Tommy Emmanuel', 'Windy & Warm', 'Jayden', 'Fox')
# (83, 772, '0', 'Cherise', 'No Good 4 You', 'Stefany', 'White')
# (76, 662, '0', 'Anna Waronker', 'Nothing Personal', 'Jayden', 'Duffy')
# (6, 763, '0', 'King ChangÃ\x83Â³', 'ConfesiÃ\x83Â³n', 'Cecilia', 'Owens')
# (6, 763, '1', 'Gang Of Four', 'I Found That Essence Rare', 'Cecilia', 'Owens')
# (6, 763, '2', 'Line Renaud', 'Le Soir', 'Cecilia', 'Owens')
# (80, 823, '2', 'the bird and the bee', 'Last Day Of Our Love', 'Tegan', 'Levine')
# (42, 275, '1', 'Muse', 'Supermassive Black Hole (Twilight Soundtrack Version)', 'Harper', 'Barrett')
# (42, 275, '2', 'Beastie Boys', 'Lighten Up', 'Harper', 'Barrett')
# (42, 275, '3', 'Shakira', 'Pienso En Ti', 'Harper', 'Barrett')
# (42, 275, '4', 'Selena', 'Amor Prohibido', 'Harper', 'Barrett')
# (42, 275, '5', 'Kid Cudi Vs Crookers', "Day 'N' Nite", 'Harper', 'Barrett')
# (42, 275, '6', 'Rise Against', 'Black Masks & Gasoline', 'Harper', 'Barrett')
# (42, 275, '7', 'Fall Out Boy', "I'm Like A Lawyer With The Way I'm Always Trying To Get You Off (Me & You)", 'Harper', 'Barrett')
# (42, 275, '8', 'Jack Johnson', 'Staple It Together', 'Harper', 'Barrett')
# (42, 275, '9', 'Twista feat. Kayne West & Jamie Foxx', 'Slow Jamz (Feat. Kanye West & Jamie Foxx) (Edited Album Version)', 'Harper', 'Barrett')
# (42, 275, '10', 'Train', 'Hey_ Soul Sister', 'Harper', 'Barrett')
# (42, 275, '11', 'Rihanna', 'Rehab', 'Harper', 'Barrett')
# (42, 275, '12', 'Man Man', 'Van Helsing Boombox', 'Harper', 'Barrett')
# (42, 275, '13', 'Ween', 'The Stallion', 'Harper', 'Barrett')
# (42, 275, '14', 'Charttraxx Karaoke', 'Fireflies', 'Harper', 'Barrett')
# (42, 275, '15', 'Digitalism', 'I Want I Want', 'Harper', 'Barrett')
# (42, 275, '16', 'Dispatch', 'Railway', 'Harper', 'Barrett')
# (42, 275, '17', 'Postal Service', 'Clark Gable (Album)', 'Harper', 'Barrett')
# (42, 275, '18', 'Patricia Barber', 'Phaeton', 'Harper', 'Barrett')
# (42, 275, '19', 'Enur', 'Ucci Ucci feat. Nicki Minaj & The Chopper City Boyz', 'Harper', 'Barrett')
# (42, 275, '20', 'Hybrid', 'Choke', 'Harper', 'Barrett')
# (42, 275, '21', 'Riverside', 'Stuck Between', 'Harper', 'Barrett')
# (42, 275, '22', 'Enigma', 'Smell Of Desire.', 'Harper', 'Barrett')
# (42, 275, '23', 'Arcade Fire', 'Headlights Look Like Diamonds', 'Harper', 'Barrett')
# (42, 275, '25', 'Spoon', 'Out Go The Lights', 'Harper', 'Barrett')
# (42, 275, '26', 'The Wannadies', 'You & Me Song', 'Harper', 'Barrett')
# (42, 275, '27', 'Tricky', 'Girls (Album version)', 'Harper', 'Barrett')
# (42, 275, '28', 'Tony Rice', 'Wayfaring Stranger', 'Harper', 'Barrett')
# (42, 275, '29', 'Rasheeda', 'Sweep The Flo (Featuring Diamond)', 'Harper', 'Barrett')
# (42, 275, '30', 'George Younce', 'This Old House w/ When The Saints Medley', 'Harper', 'Barrett')
# (42, 275, '31', 'Alex Gopher', 'Brain Leech', 'Harper', 'Barrett')
# (42, 275, '32', 'Aphex Twin', 'Didgeridoo', 'Harper', 'Barrett')
# (42, 275, '33', 'Emmanuel Moire', 'LÃ\x83Â\xa0 OÃ\x83Â¹ Je Pars', 'Harper', 'Barrett')
# (42, 275, '34', 'Josh Turner', "I Wouldn't Be A Man", 'Harper', 'Barrett')
# (49, 336, '0', 'Carlos Y JosÃ\x83Â©', 'Soy AlbaÃ\x83Â±il', 'Chloe', 'Cuevas')
# (6, 288, '0', 'Motionless in White', 'Ghost In The Mirror', 'Cecilia', 'Owens')
# (24, 395, '0', 'Feist', 'My Moon My Man', 'Layla', 'Griffin')
# (80, 398, '0', 'Postal Service', 'We Will Become Silhouettes (Album)', 'Tegan', 'Levine')
# (80, 398, '1', 'Stevie Ray Vaughan And Double Trouble', 'Life Without You', 'Tegan', 'Levine')
# (64, 166, '0', 'AFI', 'Miseria Cantare--The Beginning', 'Hannah', 'Calhoun')
# (95, 276, '3', 'Lonnie Gordon', 'Catch You Baby (Steve Pitron & Max Sanna Radio Edit)', 'Sara', 'Johnson')
# (95, 276, '4', 'Harry Connick_ Jr.', 'My Blue Heaven', 'Sara', 'Johnson')
# (95, 276, '5', 'Andres Calamaro', 'Crucificame', 'Sara', 'Johnson')
# (95, 276, '6', 'Tub Ring', 'Invalid', 'Sara', 'Johnson')
# (47, 142, '0', 'Brian Poole & The Tremeloes', 'I Can Dance', 'Kimber', 'Norris')
# (47, 142, '1', 'War', 'The World Is A Ghetto', 'Kimber', 'Norris')
# (80, 409, '0', "Kanye West / Consequence / Cam'Ron", 'Gone', 'Tegan', 'Levine')
# (80, 409, '1', 'David Banner', 'Play', 'Tegan', 'Levine')
# (60, 271, '0', 'Kreator', 'Second awakening', 'Devin', 'Larson')
# (80, 409, '2', 'Cipher', 'Protoculture (Sankofa)', 'Tegan', 'Levine')
# (80, 409, '3', 'Daft Punk', 'Emotion', 'Tegan', 'Levine')
# (67, 66, '0', 'Taylor Swift', 'Love Story', 'Colm', 'Santana')
# (80, 409, '4', 'The Police', 'Message In A Bottle', 'Tegan', 'Levine')
# (80, 409, '5', 'JayMay', "You'd Rather Run", 'Tegan', 'Levine')
# (55, 331, '1', 'Amy Adams', 'Happy Working Song', 'Martin', 'Johnson')
# (80, 409, '6', 'Shinedown', 'Second Chance (Album Version)', 'Tegan', 'Levine')
# (55, 331, '2', 'Amy Winehouse', 'Some Unholy War', 'Martin', 'Johnson')
# (80, 409, '7', 'T.I. & DJ Drama', 'Ride Wit Me', 'Tegan', 'Levine')
# (15, 362, '0', 'Gang Starr', 'Soliloquy Of Chaos (Explicit)', 'Lily', 'Koch')
# (80, 409, '8', 'Benny Benassi', "Who's Your Daddy? ", 'Tegan', 'Levine')
# (15, 362, '2', 'Paramore', 'When It Rains (Album Version)', 'Lily', 'Koch')
# (80, 409, '9', 'Metallica', 'Mama Said', 'Tegan', 'Levine')
# (15, 362, '3', 'A-Ha', 'Forever Not Yours (Album Version  - NY Mix II)', 'Lily', 'Koch')
# (80, 409, '10', 'Easy Star All-Stars', 'Lovely Rita (feat. Bunny Rugs and U Roy)', 'Tegan', 'Levine')
# (15, 362, '4', 'Alter Bridge', 'Down To My Last', 'Lily', 'Koch')
# (80, 409, '11', 'O Terco', 'Mudanca De Tempo', 'Tegan', 'Levine')
# (15, 362, '5', 'Nightwish', 'Walking In The Air', 'Lily', 'Koch')
# (80, 409, '12', 'Augustana', 'Mayfield', 'Tegan', 'Levine')
# (15, 362, '6', 'Anita Ward', 'Ring My Bell', 'Lily', 'Koch')
# (80, 409, '13', 'Gaz Nevada', 'I C Love Affair', 'Tegan', 'Levine')
# (15, 362, '7', "Flamin' Groovies", 'Slow Death', 'Lily', 'Koch')
# (80, 409, '14', 'isis', 'Carry', 'Tegan', 'Levine')
# (15, 362, '11', 'Five Iron Frenzy', 'Canada', 'Lily', 'Koch')
# (15, 362, '12', 'Frankie HI-NRG MC', 'Pace E Guerra', 'Lily', 'Koch')
# (80, 416, '0', 'Alliance Ethnik', 'ReprÃ\x83Â©sente', 'Tegan', 'Levine')
# (80, 416, '1', 'Pavement', 'Mercy:The Laundromat', 'Tegan', 'Levine')
# (80, 416, '2', '4 Skins', 'Clockwork Skinhead', 'Tegan', 'Levine')
# (80, 416, '3', 'Thrice', 'Wood And Wire', 'Tegan', 'Levine')
# (101, 408, '0', 'Van Halen', 'Best Of Both Worlds (Remastered Album Version)', 'Jayden', 'Fox')
# (14, 340, '0', 'Barry Tuckwell/Academy of St Martin-in-the-Fields/Sir Neville Marriner', 'Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)', 'Theodore', 'Harris')
# (99, 227, '0', 'Hot Chip', 'My Brother Is Watching Me', 'Ann', 'Banks')
# (80, 416, '4', 'Lasgo', 'Over You', 'Tegan', 'Levine')
# (101, 408, '1', 'Peter Sellers', 'She Loves You', 'Jayden', 'Fox')
# (32, 363, '0', 'Alphaville', 'Big In Japan (Original)', 'Lily', 'Burns')
# (80, 416, '5', 'Eneida Marta', 'Mindjer dÃ\x83Â´ce mel', 'Tegan', 'Levine')
# (99, 227, '1', 'Astral Projection', 'Flying Into a Star', 'Ann', 'Banks')
# (80, 416, '6', 'Gare du Nord', 'Marvin & Miles', 'Tegan', 'Levine')
# ...
# (36, 998, '1', 'Alex Ubago', 'Sin Miedo a Nada (con Amaia Montero)', 'Matthew', 'Jones')
# (36, 998, '2', 'The Twilight Singers', 'Bonnie Brae', 'Matthew', 'Jones')
# (36, 998, '3', 'Chikita Violenta', 'War', 'Matthew', 'Jones')
# (36, 998, '4', 'Cat Stevens', 'Sad Lisa', 'Matthew', 'Jones')
# (36, 998, '5', 'Kenny Garrett', 'The House That Nat Built (Album Version)', 'Matthew', 'Jones')
# (36, 998, '6', 'You Me At Six', 'Jealous Minds Think Alike', 'Matthew', 'Jones')
# (36, 998, '7', 'Nellie Lutcher', "My Mother's Eyes", 'Matthew', 'Jones')
# (36, 998, '8', 'Kid Cudi / Kanye West / Common', 'Make Her Say', 'Matthew', 'Jones')
# (36, 998, '9', 'Tiro De Gracia', 'Viaje Sin Rumbo (2004 Digital Remaster)', 'Matthew', 'Jones')
# (36, 998, '10', 'polarkreis 18', 'Dreamdancer', 'Matthew', 'Jones')
# (36, 998, '11', '+ / - {Plus/Minus}', 'The Queen of Nothing', 'Matthew', 'Jones')
# (92, 1092, '0', 'Dr Feelgood', 'Riot In Cell Block Number Nine', 'Ryann', 'Smith')
# (36, 998, '12', 'Harmonia', 'Sehr kosmisch', 'Matthew', 'Jones')
# (92, 1092, '1', 'Chimaira', 'Everything You Love (Album Version)', 'Ryann', 'Smith')
# (92, 1092, '2', 'Joshua Radin', "Someone Else's Life", 'Ryann', 'Smith')
# (92, 1092, '3', 'Bajaga & Instruktori', 'Godine prolaze', 'Ryann', 'Smith')
# (36, 998, '13', 'The Virgins', 'Private Affair (Amended Album Version)', 'Matthew', 'Jones')
# (36, 998, '14', "SA Rawls / Still Flyin' / Still Flyin'", 'Ginko Biloba', 'Matthew', 'Jones')
# (36, 998, '15', 'Grown Ups', 'Three Day Weekend', 'Matthew', 'Jones')
# (36, 998, '16', 'Nancy Ajram', 'Meen Dah Elly Nseik', 'Matthew', 'Jones')
# (36, 998, '17', 'The Donkeys', 'Boot On The Seat', 'Matthew', 'Jones')
# (36, 998, '18', 'Datarock', 'FaFaFa (Radio Edit)', 'Matthew', 'Jones')
# (36, 998, '19', 'Daft Punk', 'Human After All', 'Matthew', 'Jones')
# (36, 998, '21', 'Justin Bieber', 'Somebody To Love', 'Matthew', 'Jones')
# (36, 998, '22', 'Beach House', 'Real Love', 'Matthew', 'Jones')
# (36, 998, '23', 'The Walkmen', 'Subterranean Homesick Blues (Album Version)', 'Matthew', 'Jones')
# (36, 998, '24', 'Busted / Charlie Simpson / Mattie Jay / James Bourne', "Can't Break Thru", 'Matthew', 'Jones')
# (12, 1078, '0', 'BeyoncÃ\x83Â©', 'Get Me Bodied', 'Austin', 'Rosales')
# (49, 1096, '1', 'Sick Puppies', 'Maybe', 'Chloe', 'Cuevas')
# (49, 1096, '2', 'U2', 'Walk To The Water', 'Chloe', 'Cuevas')
# (49, 1096, '3', 'Ron Carter', "I CAN'T GET STARTED", 'Chloe', 'Cuevas')
# (49, 1096, '4', 'Duran Duran', 'Breath After Breath', 'Chloe', 'Cuevas')
# (49, 1096, '5', 'Tears For Fears', 'Head Over Heels', 'Chloe', 'Cuevas')
# (49, 1096, '6', 'Foo Fighters', 'Lonely As You', 'Chloe', 'Cuevas')
# (61, 1064, '1', 'Yellowcard', 'One Year_ Six Months', 'Samuel', 'Gonzalez')
# (49, 1096, '7', 'Big Tymers', 'Against The Wall', 'Chloe', 'Cuevas')
# (49, 1096, '9', 'Enigma', 'Knocking On Forbidden Doors', 'Chloe', 'Cuevas')
# (49, 1096, '10', 'Dennis Ferrer', 'Hey Hey', 'Chloe', 'Cuevas')
# (49, 1096, '11', 'Justin Bieber', 'Somebody To Love', 'Chloe', 'Cuevas')
# (49, 1096, '12', 'Markus KrunegÃ\x83Â¥rd', 'Genom tunna tyger', 'Chloe', 'Cuevas')
# (49, 1096, '13', 'Linkin Park', 'The Little Things Give You Away [Live At Milton Keynes]', 'Chloe', 'Cuevas')
# (43, 618, '0', 'Jamie Cullum', 'Devil May Care', 'Jahiem', 'Miles')
# (49, 1096, '15', 'Every Avenue', "Tell Me I'm A Wreck", 'Chloe', 'Cuevas')
# (49, 1096, '16', 'Jack Johnson', 'Constellations', 'Chloe', 'Cuevas')
# (49, 1096, '17', 'Shakira', 'Vuelve', 'Chloe', 'Cuevas')
# (49, 1096, '18', 'The Maine', 'Give Me Anything', 'Chloe', 'Cuevas')
# (49, 1096, '19', 'Cannibal Corpse', 'Worm Infested', 'Chloe', 'Cuevas')
# (85, 977, '3', 'Arcade Fire', 'Headlights Look Like Diamonds', 'Kinsley', 'Young')
# (49, 1096, '20', 'Black Eyed Peas', 'Hands Up', 'Chloe', 'Cuevas')
# (85, 977, '4', 'Radney Foster', 'Sweet And Wild', 'Kinsley', 'Young')
# (49, 1096, '21', 'Metric', 'Satellite Mind', 'Chloe', 'Cuevas')
# (49, 1096, '22', 'Dwight Yoakam', "You're The One", 'Chloe', 'Cuevas')
# (85, 977, '5', 'Jason Mraz', 'Did You Get My Message? (Live From Montalvo)', 'Kinsley', 'Young')
# (49, 1096, '23', 'Kutt Calhoun', 'N A Whitemanzeyez', 'Chloe', 'Cuevas')
# (85, 977, '6', 'Radiohead', 'Karma Police', 'Kinsley', 'Young')
# (50, 1050, '0', 'Molotov', 'Puto', 'Ava', 'Robinson')
# (50, 1050, '1', 'The Strokes', 'Killing Lies', 'Ava', 'Robinson')
# (26, 1090, '0', 'Rufus Wainwright', 'Hallelujah', 'Ryan', 'Smith')
# (85, 977, '7', 'Deadmau5', "Ghosts 'n' Stuff (Original Instrumental Mix)", 'Kinsley', 'Young')
# (49, 1096, '24', 'John Farnham', "You're The Voice", 'Chloe', 'Cuevas')
# (50, 1050, '2', 'Infant Sorrow', 'Inside Of You', 'Ava', 'Robinson')
# (26, 1090, '1', 'Betty Wright', 'Clean Up Woman (Single/LP Version)', 'Ryan', 'Smith')
# (49, 1096, '25', 'Guus Meeuwis', 'Tranen Gelachen', 'Chloe', 'Cuevas')
# (85, 977, '8', 'Muse', 'The Small Print', 'Kinsley', 'Young')
# (49, 1096, '26', 'Estrella Morente', 'A QuÃ\x83Â© Niegas El Delirio (MalagueÃ\x83Â±a) (Live)', 'Chloe', 'Cuevas')
# (85, 977, '9', 'Dr. Alban', "It's My Life (Radio Edit)", 'Kinsley', 'Young')
# (49, 1096, '27', 'Radiohead', 'Sit Down. Stand Up', 'Chloe', 'Cuevas')
# (85, 977, '10', 'Mondo Marcio', 'Purple Weed', 'Kinsley', 'Young')
# (49, 1096, '28', 'Mae', "Someone Else's Arms", 'Chloe', 'Cuevas')
# (85, 977, '11', 'Meat Loaf / Jennifer Hudson', "The Future Ain't What It Used To Be", 'Kinsley', 'Young')
# (49, 1096, '29', 'Vampire Weekend', 'A-Punk (Album)', 'Chloe', 'Cuevas')
# (49, 1096, '30', 'MGMT', 'Time To Pretend', 'Chloe', 'Cuevas')
# (85, 977, '12', 'Federico Aubele', 'Luna y Sol', 'Kinsley', 'Young')
# (49, 1096, '31', 'Jesse Rose', 'Touch My Horn', 'Chloe', 'Cuevas')
# (85, 977, '13', 'Orion', 'Eternity', 'Kinsley', 'Young')
# (49, 1096, '32', 'Circa Survive', 'Dyed in the Wool (Album Version)', 'Chloe', 'Cuevas')
# (101, 1060, '0', 'Wretch 32_ Vis', 'Wretchrospective (feat. Vis)', 'Jayden', 'Fox')
# (85, 977, '18', 'Simian Mobile Disco', 'Simple', 'Kinsley', 'Young')
# (101, 1060, '1', 'ErdmÃ\x83Â¶bel', 'Riecht wie Teen Spirit (Smells Like Teen Spirit)', 'Jayden', 'Fox')
# (49, 1096, '33', 'Eisbrecher', 'Adrenalin', 'Chloe', 'Cuevas')
# (16, 1076, '0', 'Ryan Bingham', 'Bread & Water', 'Rylan', 'George')
# (85, 977, '19', 'Ashanti', 'VooDoo', 'Kinsley', 'Young')
# (49, 1096, '34', 'Barry Tuckwell/Academy of St Martin-in-the-Fields/Sir Neville Marriner', 'Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)', 'Chloe', 'Cuevas')
# (101, 1060, '2', 'Clint Eastwood', "Frankie's Office", 'Jayden', 'Fox')
# (101, 1060, '3', 'Charttraxx Karaoke', 'Fireflies', 'Jayden', 'Fox')
# (16, 1076, '1', 'Jason Mraz', 'Summer Breeze', 'Rylan', 'George')
# (85, 977, '20', "The B-52's", 'Love Shack', 'Kinsley', 'Young')
# (101, 1060, '4', 'Aventura', 'Alexandra', 'Jayden', 'Fox')
# (16, 1076, '2', 'Five Iron Frenzy', 'Canada', 'Rylan', 'George')
# (101, 1060, '5', '12 Stones', 'Anthem For The Underdog', 'Jayden', 'Fox')
# (85, 977, '21', 'Kings Of Leon', 'Revelry', 'Kinsley', 'Young')
# (16, 1076, '3', 'Brooklyn Bounce', 'Get Ready To Bounce Recall 08', 'Rylan', 'George')
# (85, 977, '22', 'Dashboard Confessional', 'The Good Fight', 'Kinsley', 'Young')
# (85, 977, '23', 'Lonnie Johnson', 'Low Land Moan', 'Kinsley', 'Young')
# (88, 1097, '2', 'Leggo Beast', 'In', 'Mohammad', 'Rodriguez')
# (16, 1076, '4', 'The Pussycat Dolls', 'Sway', 'Rylan', 'George')
# (85, 977, '24', 'Stereophonics', 'I Miss You Now', 'Kinsley', 'Young')
# (16, 1076, '5', 'The Beautiful South', 'Masculine Eclipse', 'Rylan', 'George')
# (88, 1097, '3', 'The Acacia Strain', 'As If Set Afire', 'Mohammad', 'Rodriguez')
# (85, 977, '25', 'ATB', 'Underwater World', 'Kinsley', 'Young')
# (16, 1076, '6', 'The Robert Cray Band', 'Our Last Time', 'Rylan', 'George')
# (88, 1097, '4', 'Enigma', 'T.N.T. For The Brain (112 Bpm) (Radio Edit)', 'Mohammad', 'Rodriguez')
# (85, 977, '26', 'Amon Amarth', 'Tattered Banners And Bloody Flags', 'Kinsley', 'Young')
# (16, 1076, '7', 'We Are Scientists', 'The Great Escape (Album Version) (Explicit)', 'Rylan', 'George')
# (36, 1100, '0', 'Roberto Murolo', 'Lacreme napulitane', 'Matthew', 'Jones')
# (88, 1097, '5', 'Ashlee Simpson', 'Autobiography', 'Mohammad', 'Rodriguez')
# (85, 977, '27', 'Metallica', 'The Ecstasy Of Gold', 'Kinsley', 'Young')
# (16, 1076, '8', '3 Doors Down', 'Kryptonite', 'Rylan', 'George')
# (36, 1100, '1', 'Hazell Dean', 'No Fool (For Love)', 'Matthew', 'Jones')
# (85, 977, '28', 'Apocalyptica', 'Pray', 'Kinsley', 'Young')
# (16, 1076, '9', 'Jack Johnson', 'Bubble Toes', 'Rylan', 'George')
# (85, 977, '29', 'Cage The Elephant', 'Lotus', 'Kinsley', 'Young')
# (36, 1100, '2', 'Taylor Swift', 'You Belong With Me', 'Matthew', 'Jones')
# (16, 1076, '10', 'Soul For Real', 'Candy Rain', 'Rylan', 'George')
# (85, 977, '30', 'The Prodigy', 'Firestarter', 'Kinsley', 'Young')
# (36, 1100, '3', 'Amy Winehouse', 'Addicted', 'Matthew', 'Jones')
# (16, 1076, '11', 'Iron Maiden', 'The Evil That Men Do (1998 Digital Remaster)', 'Rylan', 'George')
# (85, 977, '31', 'David Crowder*Band', 'All Around Me', 'Kinsley', 'Young')
# (16, 1076, '12', 'The Cinematic Orchestra', 'Everyday', 'Rylan', 'George')
# (85, 977, '32', 'Three 6 Mafia vs. TiÃ\x83Â«sto with Sean Kingston and Flo Rida', 'Feel It', 'Kinsley', 'Young')
# (85, 977, '33', 'Sugababes', 'Overload', 'Kinsley', 'Young')
# (16, 1076, '13', 'Gyptian', 'Hold You', 'Rylan', 'George')
# (16, 1076, '14', 'Zion / Akon', 'The Way She Moves', 'Rylan', 'George')
# (16, 1076, '15', 'Transvision Vamp', 'I Want Your Love', 'Rylan', 'George')
# (49, 1096, '37', 'Ry Cooder', 'Corrido de Boxeo', 'Chloe', 'Cuevas')
# (16, 1076, '16', 'The Pussycat Dolls', 'When I Grow Up', 'Rylan', 'George')
# (49, 1096, '38', 'Coldplay', 'Yellow', 'Chloe', 'Cuevas')
# (16, 1076, '17', 'Forever The Sickest Kids', 'She Likes (Bittersweet Love)', 'Rylan', 'George')
# (49, 1096, '39', 'Lil Wayne / Blaque / Mannie Fresh', 'Believe That', 'Chloe', 'Cuevas')
# (16, 1076, '18', 'Dragonforce', 'Through The Fire And Flames (Album Version)', 'Rylan', 'George')
# (49, 1096, '40', 'Jason Mraz & Colbie Caillat', 'Lucky (Album Version)', 'Chloe', 'Cuevas')
# (49, 1096, '41', 'Pixies', 'Is She Weird', 'Chloe', 'Cuevas')
# (16, 1076, '19', 'Eminem', 'Without Me', 'Rylan', 'George')
# (49, 1096, '42', 'Buju Banton', 'Cry No More', 'Chloe', 'Cuevas')
# (16, 1076, '20', 'Cage The Elephant', 'Lotus', 'Rylan', 'George')
# (49, 1096, '43', 'Barry Tuckwell/Academy of St Martin-in-the-Fields/Sir Neville Marriner', 'Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)', 'Chloe', 'Cuevas')
# (16, 1076, '21', 'Ste Strausz', 'Le Million', 'Rylan', 'George')
# (49, 1096, '44', 'Coldplay', 'Only Superstition', 'Chloe', 'Cuevas')
# (78, 1059, '0', 'Joe Christmas', 'Bedroom Suite', 'Chloe', 'Roth')
# (16, 1076, '22', 'Bright Eyes', 'A New Arrangement', 'Rylan', 'George')
# (78, 1059, '1', 'Paramore', 'The Only Exception (Album Version)', 'Chloe', 'Roth')
# (49, 1096, '45', 'J. Karjalainen & Mustat Lasit', 'Sinisten tÃ\x83Â¤htien alla', 'Chloe', 'Cuevas')
# (16, 1076, '23', 'Philip Glass', 'Knee 2', 'Rylan', 'George')
# (49, 1096, '46', 'Alliance Ethnik', 'SinceritÃ\x83Â© Et Jalousie', 'Chloe', 'Cuevas')
# (16, 1076, '24', 'Mew', 'Her Voice Is Beyond Her Years', 'Rylan', 'George')
# (16, 1076, '25', 'Ive Mendes', 'If You Leave Me Now', 'Rylan', 'George')
# (33, 1026, '1', 'Alliance Ethnik', 'SinceritÃ\x83Â© Et Jalousie', 'Bronson', 'Harris')
# (16, 1076, '26', 'the bird and the bee', 'Diamond Dave', 'Rylan', 'George')
# (33, 1026, '2', 'Common / Sadat X', '1999', 'Bronson', 'Harris')
# (16, 1076, '27', 'Alanis Morissette', 'King Of Pain (Live/Unplugged Version)', 'Rylan', 'George')
# (33, 1026, '7', 'Skillet', 'Rebirthing (Album Version)', 'Bronson', 'Harris')
# (16, 1076, '28', 'James Galway;Julian Lee', 'Beauty and the Beast', 'Rylan', 'George')
# (16, 1076, '29', 'Drop Dead_ Gorgeous', 'Dressed For Friend Requests (Album Version)', 'Rylan', 'George')
# (16, 1076, '30', 'Dwight Yoakam', "You're The One", 'Rylan', 'George')
# (16, 1076, '31', 'Trouble', "Tuesday's Child", 'Rylan', 'George')
# (16, 1076, '33', 'OneRepublic', 'All The Right Moves', 'Rylan', 'George')
# (16, 1076, '34', 'Switchblade Symphony', 'Wicked', 'Rylan', 'George')
# (16, 1076, '35', 'Sharooz', 'My Distressor 40Khz ReRub Mix', 'Rylan', 'George')
# (16, 1076, '36', 'Explosions In The Sky', 'Six Days At The Bottom Of The Ocean', 'Rylan', 'George')
# (49, 1114, '1', 'Emmylou Harris', 'Little Bird', 'Chloe', 'Cuevas')
# (49, 1114, '2', 'Jack Johnson', 'The Horizon Has Been Defeated', 'Chloe', 'Cuevas')
# (16, 1076, '37', 'Radiohead', 'Everything In Its Right Place', 'Rylan', 'George')
# (49, 1114, '3', 'Andrew Bird', 'Heretics', 'Chloe', 'Cuevas')
# (16, 1076, '38', 'Metallica', 'Sabbra Cadabra', 'Rylan', 'George')
# (49, 1114, '4', 'Lonnie Gordon', 'Catch You Baby (Steve Pitron & Max Sanna Radio Edit)', 'Chloe', 'Cuevas')
# (49, 1114, '5', 'Dropkick Murphys', 'Shattered', 'Chloe', 'Cuevas')
# (16, 1076, '39', 'Eric B. & Rakim', 'As The Rhyme Goes On', 'Rylan', 'George')
# (49, 1114, '6', 'Dierks Bentley', 'Settle For A Slowdown', 'Chloe', 'Cuevas')
# (16, 1076, '40', 'Regina Spektor', 'Daniel Cowman', 'Rylan', 'George')
# (49, 1114, '7', 'Angelspit', 'Make You Sin', 'Chloe', 'Cuevas')
# (49, 1114, '8', 'Young Gunz / Beanie Sigel', 'Roc U', 'Chloe', 'Cuevas')
# (16, 1076, '41', 'DJ Dizzy', 'Sexy Bitch', 'Rylan', 'George')
# (16, 1076, '42', 'Base Ball Bear', 'Sayonara-Nostalgia', 'Rylan', 'George')
# (49, 1114, '9', 'Morcheeba', 'In The Hands Of The Gods (Featuring Biz Markie)', 'Chloe', 'Cuevas')
# (49, 1114, '10', 'Bitter:Sweet', "Don't Forget To Breathe", 'Chloe', 'Cuevas')
# (16, 1076, '43', 'Basshunter Feat. DJ Mental Theo\x19s Bazzheadz', "Now You're Gone", 'Rylan', 'George')
# (49, 1114, '11', 'BjÃ\x83Â¶rk', 'Undo', 'Chloe', 'Cuevas')
# (16, 1076, '44', 'Rihanna', 'G4L', 'Rylan', 'George')
# (16, 1076, '45', 'Evanescence', 'Hello', 'Rylan', 'George')
# (49, 1114, '12', 'Mr. Vegas', 'Tamale', 'Chloe', 'Cuevas')
# (16, 1076, '46', 'Mischa Daniels', 'Another Place', 'Rylan', 'George')
# (49, 1114, '13', 'The Menzingers', 'Straight To Hell', 'Chloe', 'Cuevas')
# (49, 1114, '14', 'Justin Timberlake', 'Cry Me A River', 'Chloe', 'Cuevas')
# (16, 1076, '47', 'Vilma Palma e Vampiros', 'Un Camino Hasta Vos', 'Rylan', 'George')
# (49, 1114, '15', 'CCCP - Fedeli Alla Linea', 'Sura (2008 Digital Remaster)', 'Chloe', 'Cuevas')
# (16, 1076, '48', 'Kid Cudi / MGMT / Ratatat', 'Pursuit Of Happiness (nightmare)', 'Rylan', 'George')
# (49, 1114, '16', 'Drake / Kanye West / Lil Wayne / Eminem', 'Forever', 'Chloe', 'Cuevas')
# (16, 1076, '49', 'A Day To Remember', 'Homesick [Acoustic]', 'Rylan', 'George')
# (91, 1085, '0', 'T.I.', 'Dead And Gone [feat. Justin Timberlake] (Explicit Album Version)', 'Jayden', 'Bell')
# (16, 1076, '50', 'The Offspring', "It'll Be a Long Time (Album Version)", 'Rylan', 'George')
# (49, 1114, '17', 'Jorge Gonzalez', 'Esta Es Para Hacerte FÃ\x83Â©liz', 'Chloe', 'Cuevas')
# (91, 1085, '1', 'Sneaker Pimps', 'Spin Spin Sugar', 'Jayden', 'Bell')
# (16, 1076, '51', 'Escape The Fate', 'This War Is Ours (The Guillotine II)', 'Rylan', 'George')
# (49, 1114, '18', 'Juanes', 'La Vida Es Un Ratico', 'Chloe', 'Cuevas')
# (16, 1076, '52', 'The Replacements', 'Never Mind', 'Rylan', 'George')
# (49, 1114, '19', 'Sarah McLachlan', 'Possession', 'Chloe', 'Cuevas')
# (16, 1076, '53', 'Sonny Boy Williamson', "Don't Start Me Talkin'", 'Rylan', 'George')
# (16, 1076, '54', 'Soul II Soul Featuring Caron Wheeler', 'Back To Life (However Do You Want Me) (2003 Digital Remaster) (Feat. Caron Wheeler)', 'Rylan', 'George')
# (49, 1114, '20', 'Florence + The Machine', 'Dog Days Are Over (Radio Edit)', 'Chloe', 'Cuevas')
# (16, 1076, '55', 'Pantera', 'Heresy  (LP Version)', 'Rylan', 'George')
# (49, 1114, '21', 'Cold', 'Remedy', 'Chloe', 'Cuevas')
# (49, 1114, '22', 'Norther', 'Frozen Angel', 'Chloe', 'Cuevas')
# (16, 1076, '57', 'Foo Fighters', 'The Pretender', 'Rylan', 'George')
# (16, 1076, '58', 'Timbiriche', 'Besos De Ceniza', 'Rylan', 'George')
# (16, 1076, '59', 'A Perfect Circle', 'Rose', 'Rylan', 'George')
# (16, 1076, '60', 'Anberlin', 'The Haunting', 'Rylan', 'George')
# (5, 985, '0', 'Deas Vail', 'Anything You Say (Unreleased Version)', 'Elijah', 'Davis')

# %%
## TO-DO: Add in the SELECT statement to verify the data was entered into the table
## Confirm query 2 output
## Ascending by itemInSession
query = """
SELECT artist, song, firstName, lastName 
FROM music_by_artist_song_user
WHERE userId = 10
AND sessionId = 182
"""
query = session.execute(query)
print(query)
for row in query:
    print(row)
# Out:
# <cassandra.cluster.ResultSet object at 0x7fa1c072eee0>
# Row(artist='Down To The Bone', song="Keep On Keepin' On", firstname='Sylvie', lastname='Cruz')
# Row(artist='Three Drives', song='Greece 2000', firstname='Sylvie', lastname='Cruz')
# Row(artist='Sebastien Tellier', song='Kilometer', firstname='Sylvie', lastname='Cruz')
# Row(artist='Lonnie Gordon', song='Catch You Baby (Steve Pitron & Max Sanna Radio Edit)', firstname='Sylvie', lastname='Cruz')

# %%
## Drop table after restart test to prevent duplicate data
query = "drop TABLE IF EXISTS user_by_song "
session.execute(query)

# %%
## TO-DO: Query 3: Give me every user name (first and last) in my music app history
## who listened to the song 'All Hands Against His Own'
query = "CREATE TABLE IF NOT EXISTS user_by_song "
query = query + """(
song text, userId int, firstName text, lastName text, 
PRIMARY KEY(song, userId))
"""
try:
    session.execute(query)
except Exception as e:
    print(e)

# %%
## TO-DO: Assign the INSERT statements into the `query` variable
# Insert data into table for query 3
file = 'event_datafile_new.csv'
with open(file, encoding = 'utf8') as f:
    csvreader = csv.reader(f)
    next(csvreader)
    for line in csvreader:
        query = "INSERT INTO user_by_song (song, userId, firstName, lastName)"
        query = query + "VALUES (%s, %s, %s, %s)"
        print((line[9], line[4], line[1], int(line[10])))
        ## TO-DO: Assign which column element should be assigned for each column in the INSERT statement.
        session.execute(query, (line[9], int(line[10]), line[4], line[1]))
# Out:
# ('Sehr kosmisch', 'Smith', 'Ryan', 26)
# ('The Big Gundown', 'Smith', 'Ryan', 26)
# ('Marry Me', 'Smith', 'Ryan', 26)
# ('Blackbird', 'Gonzalez', 'Samuel', 61)
# ('Best Of Both Worlds (Remastered Album Version)', 'Levine', 'Tegan', 80)
# ('Call Me If You Need Me', 'Levine', 'Tegan', 80)
# ('Home', 'Levine', 'Tegan', 80)
# ('OMG', 'Levine', 'Tegan', 80)
# ('Candle On The Water', 'Levine', 'Tegan', 80)
# ('Our Song', 'Levine', 'Tegan', 80)
# ('Baby Boy [feat. Beyonce]', 'Levine', 'Tegan', 80)
# ('Black Hole Sun', 'Koch', 'Lily', 15)
# ('Human', 'Levine', 'Tegan', 80)
# ('Addicted', 'Koch', 'Lily', 15)
# ('Air', 'Koch', 'Lily', 15)
# ('Superbeast', 'Koch', 'Lily', 15)
# ('I Remember', 'Koch', 'Lily', 15)
# ("Don't Be Stupid (You Know I Love You)", 'Smith', 'Ryan', 26)
# ('We throw parties_ you throw knives', 'Smith', 'Ryan', 26)
# ('How Can I Live (Spanish version) (Album Version)', 'Cuevas', 'Chloe', 49)
# ('Thugs Like Me', 'Cuevas', 'Chloe', 49)
# ('Killing In The Name', 'Cuevas', 'Chloe', 49)
# ('Epilogue', 'Cuevas', 'Chloe', 49)
# ('Endlessly', 'Cuevas', 'Chloe', 49)
# ('Torches', 'Cuevas', 'Chloe', 49)
# ('The Good Times Are Killing Me', 'Rodriguez', 'Mohammad', 88)
# ('Te Conozco Bien', 'Cuevas', 'Chloe', 49)
# ('The Calculation (Album Version)', 'Cuevas', 'Chloe', 49)
# ('Goodbye (Interlude)', 'Levine', 'Tegan', 80)
# ('Canada', 'Watkins', 'Avery', 30)
# ('Ven', 'Watkins', 'Avery', 30)
# ('Do You Remember The First Time?', 'Watkins', 'Avery', 30)
# ('I Want Your (Hands On Me)', 'Watkins', 'Avery', 30)
# ('Chill Out', 'Levine', 'Tegan', 80)
# ('Something (Radio Edit)', 'Watkins', 'Avery', 30)
# ("What's A Broken Heart", 'Levine', 'Tegan', 80)
# ('Society', 'Watkins', 'Avery', 30)
# ('Christians In Black', 'Levine', 'Tegan', 80)
# ('Uprising', 'Watkins', 'Avery', 30)
# ('Might Like You Better', 'Levine', 'Tegan', 80)
# ('Sheila Take A Bow', 'Watkins', 'Avery', 30)
# ('Victoria (LP Version)', 'Levine', 'Tegan', 80)
# ('Dreaming Of You', 'Watkins', 'Avery', 30)
# ("What's Luv? (Featuring Ja-Rule & Ashanti) (Explicit Album Version)", 'Levine', 'Tegan', 80)
# ('Soft Revolution', 'Watkins', 'Avery', 30)
# ('Same Mistake  (Album Version)', 'Levine', 'Tegan', 80)
# ('Bruised And Scarred (Album Version)', 'Watkins', 'Avery', 30)
# ("Frisch und g'sund", 'Levine', 'Tegan', 80)
# ('Rockit', 'Watkins', 'Avery', 30)
# ("Should've Been A Cowboy", 'Levine', 'Tegan', 80)
# ('Little Motel', 'Watkins', 'Avery', 30)
# ('Gears', 'Levine', 'Tegan', 80)
# ('Superwoman (Where Were You When I Needed You) (Digitally Remastered)', 'Watkins', 'Avery', 30)
# ('Forgotten', 'Levine', 'Tegan', 80)
# ('Everlong', 'George', 'Rylan', 16)
# ('Hunter', 'Watkins', 'Avery', 30)
# ('The Way I Loved You', 'Levine', 'Tegan', 80)
# ('Longevity', 'George', 'Rylan', 16)
# ('Fell In Love With A Girl', 'Watkins', 'Avery', 30)
# ("You're The One", 'Levine', 'Tegan', 80)
# ('Lies', 'Watkins', 'Avery', 30)
# ("Got The Feelin'", 'George', 'Rylan', 16)
# ('Do You Call My Name', 'Levine', 'Tegan', 80)
# ("Gangsta's Paradise (LP Version)", 'George', 'Rylan', 16)
# ('Misery Business (Album Version)', 'Watkins', 'Avery', 30)
# ('Itchy Feet', 'Watkins', 'Avery', 30)
# ('Gypsy', 'George', 'Rylan', 16)
# ('Dans Ma Bulle (Edit Radio - Live 2006)', 'Levine', 'Tegan', 80)
# ('Give It Up', 'George', 'Rylan', 16)
# ('Love Remains (Home Demo)', 'Levine', 'Tegan', 80)
# ('Here Without You', 'Watkins', 'Avery', 30)
# ('Toss The Feathers (Instrumental) ( LP Version )', 'George', 'Rylan', 16)
# ('Big', 'Levine', 'Tegan', 80)
# ('I Am The Killer (Album Version)', 'Watkins', 'Avery', 30)
# ("Don't Call It A Comeback (Album Version)", 'George', 'Rylan', 16)
# ("Hey Daddy (Daddy's Home)", 'Levine', 'Tegan', 80)
# ('No Siento Penas', 'George', 'Rylan', 16)
# ('Kill The Director [Radio Edit]', 'Watkins', 'Avery', 30)
# ('I Kissed A Girl', 'Levine', 'Tegan', 80)
# ('The Darkest Nights', 'George', 'Rylan', 16)
# ('Undo', 'Watkins', 'Avery', 30)
# ('I Fought The Law (LP Version)', 'Levine', 'Tegan', 80)
# ('Influencia', 'George', 'Rylan', 16)
# ('Too Much', 'Levine', 'Tegan', 80)
# ('All Hands Against His Own', 'Levine', 'Tegan', 80)
# ('Blaues Blau', 'Watkins', 'Avery', 30)
# ('Friends_ Lovers Or Nothing', 'Levine', 'Tegan', 80)
# ('A Song For Sleeping (LP Version)', 'George', 'Rylan', 16)
# ('Head Into Tomorrow', 'Watkins', 'Avery', 30)
# ('Smile Version Revisited (Mark Ronson Remix) (Explicit)', 'George', 'Rylan', 16)
# ('A Gentle Heart', 'Levine', 'Tegan', 80)
# ('Un DÃ\x83Â\xada Normal', 'Watkins', 'Avery', 30)
# ('Ska', 'George', 'Rylan', 16)
# ('The Heretic Anthem (Album Version)', 'Watkins', 'Avery', 30)
# ('Tell Her Tonight', 'Levine', 'Tegan', 80)
# ('Suicide', 'George', 'Rylan', 16)
# ('Stella By Starlight', 'Levine', 'Tegan', 80)
# ("Nothin' On You [feat. Bruno Mars] (Album Version)", 'Watkins', 'Avery', 30)
# ('I And Love And You', 'George', 'Rylan', 16)
# ('Caprice viennois op.2', 'Levine', 'Tegan', 80)
# ("Joshua's Song (1991 Digital Remaster)", 'Watkins', 'Avery', 30)
# ("Hips Don't Lie", 'Watkins', 'Avery', 30)
# ('The Funeral (Album Version)', 'George', 'Rylan', 16)
# ('Ambrosia', 'Levine', 'Tegan', 80)
# ('Einfach Ich', 'Watkins', 'Avery', 30)
# ('Higher Messiah', 'Levine', 'Tegan', 80)
# ('If I Know You', 'Watkins', 'Avery', 30)
# ('In Heaven', 'Watkins', 'Avery', 30)
# ('Wounded Soul', 'Levine', 'Tegan', 80)
# ('Bold As Love', 'Watkins', 'Avery', 30)
# ('The Great ndian Desert', 'Watkins', 'Avery', 30)
# ('Face Of Fear', 'Levine', 'Tegan', 80)
# ('What You Know', 'Levine', 'Tegan', 80)
# ('Hurt', 'Levine', 'Tegan', 80)
# ('Me Lleva Tiempo', 'Watkins', 'Avery', 30)
# ("So What's New", 'Levine', 'Tegan', 80)
# ('Flight Of Yuri Gagarin', 'Watkins', 'Avery', 30)
# ('Mooncalf', 'Levine', 'Tegan', 80)
# ('My Immortal (Album Version)', 'Watkins', 'Avery', 30)
# ('Velouria', 'Watkins', 'Avery', 30)
# ('Bad Actors', 'Miles', 'Jahiem', 43)
# ("Bitches Ain't Shit", 'Levine', 'Tegan', 80)
# ('Unwell (Album Version)', 'Watkins', 'Avery', 30)
# ('Feiticeira (LP Version)', 'Levine', 'Tegan', 80)
# ('Without You (Album Version)', 'Watkins', 'Avery', 30)
# ('Map Of The Problematique', 'Levine', 'Tegan', 80)
# ('Kotona kaikuu', 'Watkins', 'Avery', 30)
# ('One And Only', 'Levine', 'Tegan', 80)
# ('Gunpowder', 'Watkins', 'Avery', 30)
# ('Had Stupid', 'Watkins', 'Avery', 30)
# ("If Hollywood Don't Need You", 'Watkins', 'Avery', 30)
# ('Are You Famous?', 'Watkins', 'Avery', 30)
# ('Good Morning Susie Soho', 'Watkins', 'Avery', 30)
# ('She Moves In Her Own Way', 'Watkins', 'Avery', 30)
# ('You Get What You Give', 'Watkins', 'Avery', 30)
# ('Where Eagles Have Been', 'Watkins', 'Avery', 30)
# ('Spilt Needles (Album)', 'Watkins', 'Avery', 30)
# ('Reasons Why', 'Watkins', 'Avery', 30)
# ('Crazy', 'Watkins', 'Avery', 30)
# ('Love Of The Loveless', 'Watkins', 'Avery', 30)
# ('Sehr kosmisch', 'Watkins', 'Avery', 30)
# ('Oh No! (album version)', 'Watkins', 'Avery', 30)
# ('The Real Slim Shady', 'Watkins', 'Avery', 30)
# ('REIPPAINA KÃ\x83Â\x84YMME REKKAIN ALLE', 'Watkins', 'Avery', 30)
# ("You're The One", 'Watkins', 'Avery', 30)
# ('White Sand', 'Watkins', 'Avery', 30)
# ('Tan bi (Heat_ Breeze_ Tenderness) / Chaleur_ brise_ tendress', 'Watkins', 'Avery', 30)
# ('Red Right Ankle', 'Watkins', 'Avery', 30)
# ('Savage Circle', 'Watkins', 'Avery', 30)
# ('The One-Eyed Turk', 'Watkins', 'Avery', 30)
# ('Set In Stone', 'Watkins', 'Avery', 30)
# ("Let's Go Crazy (LP Version)", 'Harrell', 'Kate', 97)
# ("She's Coming Home", 'Harrell', 'Kate', 97)
# ('Numb', 'Harrell', 'Kate', 97)
# ('Breakdown', 'Watkins', 'Avery', 30)
# ('Let There Be Lite (Album Version)', 'Harrell', 'Kate', 97)
# ('Set Down Your Glass', 'Watkins', 'Avery', 30)
# ('Nice Weather For Ducks', 'Harrell', 'Kate', 97)
# ('Tale Of Two Cities', 'Watkins', 'Avery', 30)
# ('Magic', 'Harrell', 'Kate', 97)
# ('Take No Shhh (Original Mix)', 'Watkins', 'Avery', 30)
# ('VIKING MAN', 'Harrell', 'Kate', 97)
# ('I Gotta Feeling', 'Harrell', 'Kate', 97)
# ('Canada', 'Watkins', 'Avery', 30)
# ('Down On The Corner', 'Robinson', 'Ava', 50)
# ('Camaro', 'Robinson', 'Ava', 50)
# ('Unbreakable', 'Watkins', 'Avery', 30)
# ('Born To Be Wild', 'Harrell', 'Kate', 97)
# ('the king of wishful thinking', 'Robinson', 'Ava', 50)
# ('Elevator', 'Watkins', 'Avery', 30)
# ('Willie And The Hand Jive', 'Harrell', 'Kate', 97)
# ('Little Drummer Boy [featuring guitarist Andy McKee] (Album Version)', 'Larson', 'Devin', 60)
# ('Coin-Operated Boy', 'Watkins', 'Avery', 30)
# ('Where Is My Mind?', 'Harrell', 'Kate', 97)
# ('I Put A Spell On You', 'Larson', 'Devin', 60)
# ('Girlfriend In A Coma', 'Harrell', 'Kate', 97)
# ('No Names (Black Debbie) (Album Version)', 'Watkins', 'Avery', 30)
# ('Love Story', 'Harrell', 'Kate', 97)
# ('La pachanga', 'Watkins', 'Avery', 30)
# ('Light Your Ass On Fire', 'Harrell', 'Kate', 97)
# ('Above The Clouds', 'Watkins', 'Avery', 30)
# ("You're The One", 'Harrell', 'Kate', 97)
# ('He Can Only Hold Her', 'Watkins', 'Avery', 30)
# ('Te-Ta-Te-Ta-Ta (2002 Digital Remaster)', 'Harrell', 'Kate', 97)
# ('Congratulations_ I Hate You', 'Watkins', 'Avery', 30)
# ("You're The One", 'Harrell', 'Kate', 97)
# ('Premonicion', 'Watkins', 'Avery', 30)
# ('Lock and Key', 'Harrell', 'Kate', 97)
# ('Stronger', 'Harrell', 'Kate', 97)
# ('Neon Bible', 'Watkins', 'Avery', 30)
# ('Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)', 'Watkins', 'Avery', 30)
# ("I'm a Pilot", 'Harrell', 'Kate', 97)
# ('Empathy', 'Watkins', 'Avery', 30)
# ('Brigitte Bardot', 'Harrell', 'Kate', 97)
# ('Just A Boy', 'Watkins', 'Avery', 30)
# ('4 Chords of the Apocalypse', 'Watkins', 'Avery', 30)
# ('Safe 2 Say [The Incredible] (Album Version - Amended)', 'Harrell', 'Kate', 97)
# ('Yeah!', 'Watkins', 'Avery', 30)
# ("Don't Walk Away", 'Harrell', 'Kate', 97)
# ('Losing My Ground', 'Watkins', 'Avery', 30)
# ('Supermassive Black Hole (Twilight Soundtrack Version)', 'Harrell', 'Kate', 97)
# ('Undercover Martyn', 'Watkins', 'Avery', 30)
# ('Intake (Album Version)', 'Harrell', 'Kate', 97)
# ('When You Believe', 'Watkins', 'Avery', 30)
# ('Transatlanticism', 'Harrell', 'Kate', 97)
# ('Ces Gens LÃ\x83Â\xa0', 'Watkins', 'Avery', 30)
# ('Emergency (Album Version)', 'Harrell', 'Kate', 97)
# ('Cemetery Drive (Album Version)', 'Watkins', 'Avery', 30)
# ('On My Own', 'Harrell', 'Kate', 97)
# ('Run Run Run', 'Watkins', 'Avery', 30)
# ('Skills To Pay The Bills', 'Harrell', 'Kate', 97)
# ('These Words', 'Burns', 'Lily', 32)
# ('AtrÃ\x83Â©vete te te', 'Watkins', 'Avery', 30)
# ('Modern Nature', 'Harrell', 'Kate', 97)
# ('Ultimo Baile', 'Burns', 'Lily', 32)
# ('Mayfair Song', 'Watkins', 'Avery', 30)
# ('Canada', 'Harrell', 'Kate', 97)
# ('Riot On An Empty Street', 'Burns', 'Lily', 32)
# ("You're In My Heart", 'Watkins', 'Avery', 30)
# ('E Talking', 'Harrell', 'Kate', 97)
# ('Mystery of You', 'Burns', 'Lily', 32)
# ('Overload', 'Watkins', 'Avery', 30)
# ('Say What You Say', 'Burns', 'Lily', 32)
# ('Scream', 'Harrell', 'Kate', 97)
# ('Le Courage Des Oiseaux', 'Watkins', 'Avery', 30)
# ('My December', 'Harrell', 'Kate', 97)
# ('Canada', 'Watkins', 'Avery', 30)
# ('Give Me Some Of Yr Love', 'Watkins', 'Avery', 30)
# ('Message In A Bottle', 'Harrell', 'Kate', 97)
# ('Microwave', 'Watkins', 'Avery', 30)
# ('A Rush Of Blood To The Head', 'Williams', 'Celeste', 53)
# ('A World Without Love', 'Burke', 'Maia', 51)
# ('Coming Back', 'Watkins', 'Avery', 30)
# ('To The Sky', 'Harrell', 'Kate', 97)
# ("I'd Rather Be With You", 'Burke', 'Maia', 51)
# ('When We Get By', 'Cuevas', 'Chloe', 49)
# ('The Music Scene', 'Williams', 'Celeste', 53)
# ('Terrible Lie', 'Johnson', 'Ayla', 63)
# ('Colourless Colour', 'Burke', 'Maia', 51)
# ('American Star', 'Harrell', 'Kate', 97)
# ('What Else Is There?', 'Watkins', 'Avery', 30)
# ('Spinning (Album Version)', 'Cuevas', 'Chloe', 49)
# ('Definitely Maybe', 'Harrell', 'Kate', 97)
# ('Disorder [2007 Re-mastered Album Version]', 'Watkins', 'Avery', 30)
# ('Rock Star', 'Cuevas', 'Chloe', 49)
# ('Orange TrÃ\x83Â¤gt Nur Die MÃ\x83Â¼llabfuhr (Go West)', 'Harrell', 'Kate', 97)
# ('Wave Goodbye (Real/Rhapsody Version)', 'Watkins', 'Avery', 30)
# ('We Are Lost', 'Harrell', 'Kate', 97)
# ('Gears', 'Cuevas', 'Chloe', 49)
# ('Gives You Hell', 'Barrett', 'Harper', 42)
# ('Born To Run', 'Watkins', 'Avery', 30)
# ('Say (All I Need)', 'Harrell', 'Kate', 97)
# ('Meteor Shower', 'Cuevas', 'Chloe', 49)
# ("I'm In Peace", 'Barrett', 'Harper', 42)
# ('I Am Not a Robot', 'Cuevas', 'Chloe', 49)
# ("Don't Let The Rain Come Down (Crooked Little Man)", 'Watkins', 'Avery', 30)
# ('Maternal Instinct', 'Harrell', 'Kate', 97)
# ('My Baby Just Cares For Me', 'Barrett', 'Harper', 42)
# ('OMG', 'Watkins', 'Avery', 30)
# ('Everything Counts (Live) (Single Version)', 'Cuevas', 'Chloe', 49)
# ('Especially In Michigan (Album Version)', 'Barrett', 'Harper', 42)
# ('Kryptonite', 'Harrell', 'Kate', 97)
# ('Bread And Butter', 'Barrett', 'Harper', 42)
# ('Dusty', 'Harrell', 'Kate', 97)
# ('La Bamba', 'Watkins', 'Avery', 30)
# ('Forever', 'Barrett', 'Harper', 42)
# ("I'm In Love", 'Cuevas', 'Chloe', 49)
# ("I'm Not A Loser", 'Watkins', 'Avery', 30)
# ('BareNaked', 'Harrell', 'Kate', 97)
# ('Burn Out', 'Cuevas', 'Chloe', 49)
# ('Baja por diversion (directo 05)', 'Barrett', 'Harper', 42)
# ('Hope Is... (Album Version)', 'Harrell', 'Kate', 97)
# ("Day 'N' Nite", 'Barrett', 'Harper', 42)
# ('La Llorona', 'Harrell', 'Kate', 97)
# ('Dance_ Dance', 'Barrett', 'Harper', 42)
# ('Lady Marmalade', 'Harrell', 'Kate', 97)
# ('Algebra Of Darkness (Album Version)', 'Barrett', 'Harper', 42)
# ('Jimbo (Album Version)', 'Harrell', 'Kate', 97)
# ('Deseret', 'Barrett', 'Harper', 42)
# ("I'll Be Your Man", 'Harrell', 'Kate', 97)
# ('Christmas', 'Barrett', 'Harper', 42)
# ('ReprÃ\x83Â©sente', 'Harrell', 'Kate', 97)
# ('A Letra "A', 'Barrett', 'Harper', 42)
# ("Live Like We're Dying", 'Harrell', 'Kate', 97)
# ('Muscle Museum (Soulwax Remix)', 'Harrell', 'Kate', 97)
# ('Lovely Head', 'Barrett', 'Harper', 42)
# ('Doctor Alibi (featuring Lemmy Kilmister)', 'Harrell', 'Kate', 97)
# ('Stupid_ Stupid War (Dealing With It)', 'Barrett', 'Harper', 42)
# ('Unite (2009 Digital Remaster)', 'Barrett', 'Harper', 42)
# ('Hate', 'Harrell', 'Kate', 97)
# ('Revelry', 'Barrett', 'Harper', 42)
# ('Translocation', 'Harrell', 'Kate', 97)
# ('Me And Charlie Talking', 'Barrett', 'Harper', 42)
# ('The Boy Is Mine (Duet With Monica) (LP Version)', 'Harrell', 'Kate', 97)
# ('How You Like Me Now?', 'Barrett', 'Harper', 42)
# ('Point/Counterpoint (Album Version)', 'Harrell', 'Kate', 97)
# ('Murder Babe (Album)', 'Barrett', 'Harper', 42)
# ('Die For You', 'Barrett', 'Harper', 42)
# ('Better Together', 'Harrell', 'Kate', 97)
# ('Eyes As Candles', 'Barrett', 'Harper', 42)
# ('Zagros', 'Kirby', 'Aleena', 44)
# ('Part 2', 'Harrell', 'Kate', 97)
# ('Eruption (Album Version)', 'Barrett', 'Harper', 42)
# ('Heaven Is A Truck', 'Harrell', 'Kate', 97)
# ('SinceritÃ\x83Â© Et Jalousie', 'Barrett', 'Harper', 42)
# ('Keep It Smooth', 'Kirby', 'Aleena', 44)
# ('Born On The Bayou', 'Harrell', 'Kate', 97)
# ("It's So Hard", 'Barrett', 'Harper', 42)
# ('Amerika (Album Version)', 'Kirby', 'Aleena', 44)
# ("I'm With You", 'Kirby', 'Aleena', 44)
# ('Circuito III', 'Harrell', 'Kate', 97)
# ('Undo', 'Barrett', 'Harper', 42)
# ('Casposos', 'Kirby', 'Aleena', 44)
# ('Is This It', 'Barrett', 'Harper', 42)
# ('Goodnight My Love', 'Kirby', 'Aleena', 44)
# ('Creil City', 'Barrett', 'Harper', 42)
# ('(iii)', 'Harrell', 'Kate', 97)
# ('Life After Death', 'Harrell', 'Kate', 97)
# ('All I Want For Christmas Is You', 'Kirby', 'Aleena', 44)
# ('The Moon (Album version)', 'Barrett', 'Harper', 42)
# ('A Teenager In Love', 'Harrell', 'Kate', 97)
# ('Bubble Toes', 'Sanchez', 'Kynnedi', 89)
# ('The Maestro', 'Kirby', 'Aleena', 44)
# ("It's My Party", 'Harrell', 'Kate', 97)
# ('The Next Episode', 'Barrett', 'Harper', 42)
# ('Encore Break', 'Kirby', 'Aleena', 44)
# ('Commissioning A Symphony In C', 'Sanchez', 'Kynnedi', 89)
# ('Rome', 'Harrell', 'Kate', 97)
# ('Seduction (album)', 'Kirby', 'Aleena', 44)
# ('She Moves In Her Own Way', 'Barrett', 'Harper', 42)
# ('La Petite Marie (2005 Digital Remaster)', 'Barrett', 'Harper', 42)
# ("Rollin' (Air Raid Vehicle)", 'Harrell', 'Kate', 97)
# ('Move On (Album Version)', 'Kirby', 'Aleena', 44)
# ('Orange TrÃ\x83Â¤gt Nur Die MÃ\x83Â¼llabfuhr (Go West)', 'Barrett', 'Harper', 42)
# ('My Piano (DJ-Kicks)', 'Harrell', 'Kate', 97)
# ("Do That There (featuring Dude 'N Nem)", 'Kirby', 'Aleena', 44)
# ('Closer', 'Barrett', 'Harper', 42)
# ('Life On Mars', 'Kirby', 'Aleena', 44)
# ('Love And Caring', 'Harrell', 'Kate', 97)
# ('Lead Us', 'Barrett', 'Harper', 42)
# ('Adrenalin', 'Harrell', 'Kate', 97)
# ('Crazy Bitch (Album Version)', 'Kirby', 'Aleena', 44)
# ('The General Specific (Album)', 'Barrett', 'Harper', 42)
# ('Speak Silence', 'Harrell', 'Kate', 97)
# ('O Samba E O Tango', 'Kirby', 'Aleena', 44)
# ('Burning', 'Barrett', 'Harper', 42)
# ('All That I Need', 'Kirby', 'Aleena', 44)
# ('Trouble', 'Harrell', 'Kate', 97)
# ('Unwell (Album Version)', 'Barrett', 'Harper', 42)
# ('On Time', 'Kirby', 'Aleena', 44)
# ('Golden Skans', 'Harrell', 'Kate', 97)
# ('Hot Thing ( LP Version )', 'Barrett', 'Harper', 42)
# ("You're The One", 'Harrell', 'Kate', 97)
# ('It Was Written', 'Kirby', 'Aleena', 44)
# ('Genom tunna tyger', 'Harrell', 'Kate', 97)
# ('I Was Made', 'Barrett', 'Harper', 42)
# ('Infinite Template', 'Harrell', 'Kate', 97)
# ('Face The Blood', 'Kirby', 'Aleena', 44)
# ('Slow Dancing In A Burning Room', 'Barrett', 'Harper', 42)
# ('Alright', 'Kirby', 'Aleena', 44)
# ('Aunque Estes Con El', 'Barrett', 'Harper', 42)
# ('Two Million Voices', 'Kirby', 'Aleena', 44)
# ('Count On Me (Somebody)', 'Harrell', 'Kate', 97)
# ('Exile', 'Kirby', 'Aleena', 44)
# ("Everyone's At It", 'Barrett', 'Harper', 42)
# ("I'M Gonna Keep On Driving My Car", 'Harrell', 'Kate', 97)
# ('Paper Planes', 'Kirby', 'Aleena', 44)
# ('Interested', 'Harrell', 'Kate', 97)
# ('This Celluloid Dream', 'Barrett', 'Harper', 42)
# ("She Don't Want The World", 'Kirby', 'Aleena', 44)
# ('Points Of Authority (Album Version)', 'Harrell', 'Kate', 97)
# ('Gang Party (Leatherface)', 'Barrett', 'Harper', 42)
# ('Release Me', 'Kirby', 'Aleena', 44)
# ('Island In The Sun', 'Harrell', 'Kate', 97)
# ('Kun Puut Tekee SeittiÃ\x83Â¤', 'Barrett', 'Harper', 42)
# ('Fuori Dal Tunnel (Album Version)', 'Kirby', 'Aleena', 44)
# ('Flesh For Fantasy', 'Harrell', 'Kate', 97)
# ('Fireflies', 'Kirby', 'Aleena', 44)
# ("Can't Help Falling In Love (Album Version) (Studio)", 'Harrell', 'Kate', 97)
# ('Baby I Want You', 'Barrett', 'Harper', 42)
# ('Big Poppa', 'Kirby', 'Aleena', 44)
# ('Azure (Album)', 'Kirby', 'Aleena', 44)
# ('Brothers & Sisters', 'Kirby', 'Aleena', 44)
# ('Good Enough', 'Kirby', 'Aleena', 44)
# ('Cuentos chinos', 'Kirby', 'Aleena', 44)
# ('Hidden Love', 'Kirby', 'Aleena', 44)
# ('Promise Me', 'Kirby', 'Aleena', 44)
# ('Boombox', 'Kirby', 'Aleena', 44)
# ('Just Like You', 'Kirby', 'Aleena', 44)
# ('Woman Capture Man', 'Kirby', 'Aleena', 44)
# ('Watch Me Shine (Album)', 'Kirby', 'Aleena', 44)
# ('Booksmart Devil', 'Kirby', 'Aleena', 44)
# ('Lady', 'Kirby', 'Aleena', 44)
# ('Gay Porn', 'Cuevas', 'Chloe', 49)
# ('Heart Less', 'Kirby', 'Aleena', 44)
# ('Human Vulture', 'Cuevas', 'Chloe', 49)
# ('The State Of Massachusetts', 'Kirby', 'Aleena', 44)
# ('Beat It', 'Kirby', 'Aleena', 44)
# ('Girl Dreams', 'Cuevas', 'Chloe', 49)
# ('Intergalactic', 'Cuevas', 'Chloe', 49)
# ('Thnks fr th Mmrs', 'Kirby', 'Aleena', 44)
# ('221', 'Cuevas', 'Chloe', 49)
# ('A Hundred Moons', 'Kirby', 'Aleena', 44)
# ('Love Is Gonna Save Us ', 'Cuevas', 'Chloe', 49)
# ('Evolution (the Grand Design)', 'Kirby', 'Aleena', 44)
# ('Big Apple (Metro Mix)', 'Cuevas', 'Chloe', 49)
# ('Virtual Insanity', 'Kirby', 'Aleena', 44)
# ('Somebody To Love', 'Cuevas', 'Chloe', 49)
# ('Save The Last Dance For Me', 'Kirby', 'Aleena', 44)
# ('Read My Mind', 'Cuevas', 'Chloe', 49)
# ('Cat People (Putting Out Fire)', 'Kirby', 'Aleena', 44)
# ('ReprÃ\x83Â©sente', 'Cuevas', 'Chloe', 49)
# ('Lovefool', 'Kirby', 'Aleena', 44)
# ("I'm Not Gonna Teach Your Boyfriend How To Dance With You", 'Kirby', 'Aleena', 44)
# ('She Is Love', 'Cuevas', 'Chloe', 49)
# ('The Wrong Thing To Do (Album Version)', 'Cuevas', 'Chloe', 49)
# ('Sample Track 2', 'Kirby', 'Aleena', 44)
# ('Movement III - Linear Tableau with Intersecting Surprise', 'Cuevas', 'Chloe', 49)
# ('Green River Blues', 'Kirby', 'Aleena', 44)
# ('Walk On Water', 'Kirby', 'Aleena', 44)
# ('Fog On The Tyne (Live)', 'Cuevas', 'Chloe', 49)
# ('Jesus Walks', 'Kirby', 'Aleena', 44)
# ('Retourne Chez Elle', 'Cuevas', 'Chloe', 49)
# ('Runaway (Album Version)', 'Kirby', 'Aleena', 44)
# ("You've Got To Hide Your Love Away (Digitally Remastered 01)", 'Kirby', 'Aleena', 44)
# ("Don't Speak", 'Cuevas', 'Chloe', 49)
# ('God Is On The Radio', 'Kirby', 'Aleena', 44)
# ('Shots', 'Cuevas', 'Chloe', 49)
# ('High Anxiety', 'Cuevas', 'Chloe', 49)
# ('Mariella', 'Kirby', 'Aleena', 44)
# ('If This Is Love', 'Cuevas', 'Chloe', 49)
# ('Holding Out For A Hero', 'Kirby', 'Aleena', 44)
# ('Get Up Again', 'Cuevas', 'Chloe', 49)
# ('Journey To The Past  (LP Version)', 'Cuevas', 'Chloe', 49)
# ('Finale', 'Kirby', 'Aleena', 44)
# ('Just Dance', 'Cuevas', 'Chloe', 49)
# ('Dance With The Devil', 'Kirby', 'Aleena', 44)
# ('Bluish', 'Cuevas', 'Chloe', 49)
# ('A New Hope', 'Kirby', 'Aleena', 44)
# ('Loon Garden', 'Taylor', 'Molly', 35)
# ('Thank You', 'Cuevas', 'Chloe', 49)
# ('The Whammy', 'Kirby', 'Aleena', 44)
# ('All Across The World', 'Kirby', 'Aleena', 44)
# ('The Ponytail Parades', 'Cuevas', 'Chloe', 49)
# ('Song Away', 'Kirby', 'Aleena', 44)
# ('Hurt Feelings', 'Duffy', 'Jayden', 76)
# ('Cooler Than Me', 'Cuevas', 'Chloe', 49)
# ('Medlong', 'Kirby', 'Aleena', 44)
# ('So Long_ Babe (2006 Digital Remaster)', 'Duffy', 'Jayden', 76)
# ('I Remember Nothing [2007 Re-mastered Album Version]', 'Cuevas', 'Chloe', 49)
# ('Suspicious Minds', 'Kirby', 'Aleena', 44)
# ('Revelry', 'Cuevas', 'Chloe', 49)
# ('Gone', 'Kirby', 'Aleena', 44)
# ("It's My Own Fault", 'Cuevas', 'Chloe', 49)
# ("I Believe I'll Go Back Home", 'Kirby', 'Aleena', 44)
# ('Naviamente', 'Kirby', 'Aleena', 44)
# ('Can You Tell', 'Cuevas', 'Chloe', 49)
# ('What If I Do?', 'Kirby', 'Aleena', 44)
# ('Colors Of The Wind', 'Kirby', 'Aleena', 44)
# ('(Hon Vill Ha) Puls', 'Kirby', 'Aleena', 44)
# ('Cumbia En Do Menor', 'Cuevas', 'Chloe', 49)
# ('Marry Me', 'Kirby', 'Aleena', 44)
# ('Teenager', 'Kirby', 'Aleena', 44)
# ('Tudo Que Eu Sempre Quis', 'Cuevas', 'Chloe', 49)
# ('Audience Of One', 'Kirby', 'Aleena', 44)
# ('My Life Inside Your Heart', 'Kirby', 'Aleena', 44)
# ("Let's Go All The Way (Short Blix Mix)", 'Kirby', 'Aleena', 44)
# ('Crazy On You', 'Kirby', 'Aleena', 44)
# ('Cats In The Cradle', 'Kirby', 'Aleena', 44)
# ('You Took My Breath Away (2007 Remastered LP Version)', 'Kirby', 'Aleena', 44)
# ('A Foggy Day (In London Town) (Album Version)', 'Kirby', 'Aleena', 44)
# ('Have You Ever', 'Kirby', 'Aleena', 44)
# ('Fandangu Los Llobos', 'Kirby', 'Aleena', 44)
# ('Voices Of Violence (Album Version)', 'Kirby', 'Aleena', 44)
# ('Courtesy Laughs', 'Kirby', 'Aleena', 44)
# ("We Don't Care", 'Kirby', 'Aleena', 44)
# ('Gestern_Morgen', 'Kirby', 'Aleena', 44)
# ('Que Me Quedes Tu', 'Kirby', 'Aleena', 44)
# ('Da Baddest [Feat. Trey Songz] (Explicit Album Version)', 'Kirby', 'Aleena', 44)
# ('La Vie En Rose', 'Koch', 'Lily', 15)
# ('Think About Last Night', 'Koch', 'Lily', 15)
# ('Love Buzz', 'Koch', 'Lily', 15)
# ('Only In Dreams', 'Koch', 'Lily', 15)
# ('She Is My Sin', 'Koch', 'Lily', 15)
# ('Teach Me How To Dougie', 'Koch', 'Lily', 15)
# ('Silvia', 'Koch', 'Lily', 15)
# ('I Kissed A Girl', 'Koch', 'Lily', 15)
# ('Peep Show', 'Koch', 'Lily', 15)
# ('Not Fair', 'Koch', 'Lily', 15)
# ('Lump', 'Koch', 'Lily', 15)
# ('Right Now (Produced by Ayatollah)', 'Koch', 'Lily', 15)
# ('Take A Bow', 'Koch', 'Lily', 15)
# ('Back To The African Garden', 'Koch', 'Lily', 15)
# ('My Humps', 'Koch', 'Lily', 15)
# ("Show Me What I'm Looking For (Album Version)", 'Koch', 'Lily', 15)
# ('Dust in The Wind', 'Koch', 'Lily', 15)
# ('Xehasmeni Melodia', 'Koch', 'Lily', 15)
# ("Lakini's Juice", 'Koch', 'Lily', 15)
# ('Nuff Fire', 'Koch', 'Lily', 15)
# ('Mean Mean Son Of A Gun', 'Koch', 'Lily', 15)
# ('Ironmasters', 'Koch', 'Lily', 15)
# ('The Absence Of God (Album Version)', 'Koch', 'Lily', 15)
# ('Lost My Mind', 'Koch', 'Lily', 15)
# ('Mamma', 'Koch', 'Lily', 15)
# ('I Will Follow You into the Dark (Album Version)', 'Koch', 'Lily', 15)
# ("You're The One", 'Koch', 'Lily', 15)
# ('Cartel Gathering', 'Koch', 'Lily', 15)
# ('Si tu no estas', 'Koch', 'Lily', 15)
# ('The Ballad of Michael Valentine', 'Koch', 'Lily', 15)
# ('SinceritÃ\x83Â© Et Jalousie', 'Koch', 'Lily', 15)
# ('China Roses', 'Koch', 'Lily', 15)
# ('Jazz', 'Koch', 'Lily', 15)
# ('Love + Pain', 'Smith', 'Ryan', 26)
# ('Solitario Y Solo', 'Smith', 'Ryan', 26)
# ('Midwest Gospel Radio', 'Smith', 'Ryan', 26)
# ("Wavin'  Flag", 'Robinson', 'Ava', 50)
# ('Her Ghost In The Fog', 'Harrell', 'Kate', 97)
# ('Let It Rain', 'Harrell', 'Kate', 97)
# ('Sonne', 'Harrell', 'Kate', 97)
# ('If You Want To Sing Out_ Sing Out', 'Harrell', 'Kate', 97)
# ('Spente Le Stelle', 'Harrell', 'Kate', 97)
# ('Float On', 'Harrell', 'Kate', 97)
# ('En El Cielo No Hay Cerveza (In Heaven There Is No Beer)', 'Harrell', 'Kate', 97)
# ('Float On', 'Harrell', 'Kate', 97)
# ('Pills (Radio Edit) (Radio Edit)', 'Harrell', 'Kate', 97)
# ('Strut (1993 Digital Remaster)', 'Harrell', 'Kate', 97)
# ("My Baby Don't Love Me", 'Harrell', 'Kate', 97)
# ('Dog Days Are Over (Radio Edit)', 'Harrell', 'Kate', 97)
# ('Naked (Live)', 'Harrell', 'Kate', 97)
# ('Apologize', 'Harrell', 'Kate', 97)
# ('Full Circle', 'Harrell', 'Kate', 97)
# ("Don't Panic", 'Harrell', 'Kate', 97)
# ("You Were The King_ Now You're Unconscious (Album Version)", 'Harrell', 'Kate', 97)
# ('Born To Run', 'Harrell', 'Kate', 97)
# ('Undo', 'Harrell', 'Kate', 97)
# ("It Just Don't Stop", 'Harrell', 'Kate', 97)
# ('Be Your Own Girl', 'Harrell', 'Kate', 97)
# ("Ain't No Way (You Won't Love Me)", 'Harrell', 'Kate', 97)
# ('Filosofia Barata Y Zapatos De Goma', 'Harrell', 'Kate', 97)
# ('Boyz-N-The-Hood', 'Harrell', 'Kate', 97)
# ('1/2/2008', 'Harrell', 'Kate', 97)
# ('Unite (2009 Digital Remaster)', 'Harrell', 'Kate', 97)
# ('Take A Ride', 'Harrell', 'Kate', 97)
# ('Cuando Agosto Era 21', 'Harrell', 'Kate', 97)
# ('Napoleon Says', 'Harrell', 'Kate', 97)
# ('Sweet And Wild', 'Fox', 'Jayden', 101)
# ('Manchild', 'Fox', 'Jayden', 101)
# ('Szex & KV', 'Johnson', 'Ayla', 63)
# ('Pursuit Of Happiness (nightmare)', 'Burns', 'Lily', 32)
# ('Blue Blood', 'Gilmore', 'Morris', 23)
# ("Trashin' The Camp (Phil And 'N Sync Version)", 'Gilmore', 'Morris', 23)
# ('I Need You', 'Fox', 'Jayden', 101)
# ('Tired Of Being Sorry', 'Fox', 'Jayden', 101)
# ('The Invisible Man', 'Fox', 'Jayden', 101)
# ('Windy & Warm', 'Fox', 'Jayden', 101)
# ('No Good 4 You', 'White', 'Stefany', 83)
# ('Nothing Personal', 'Duffy', 'Jayden', 76)
# ('ConfesiÃ\x83Â³n', 'Owens', 'Cecilia', 6)
# ('I Found That Essence Rare', 'Owens', 'Cecilia', 6)
# ('Le Soir', 'Owens', 'Cecilia', 6)
# ('Last Day Of Our Love', 'Levine', 'Tegan', 80)
# ('Supermassive Black Hole (Twilight Soundtrack Version)', 'Barrett', 'Harper', 42)
# ('Lighten Up', 'Barrett', 'Harper', 42)
# ('Pienso En Ti', 'Barrett', 'Harper', 42)
# ('Amor Prohibido', 'Barrett', 'Harper', 42)
# ("Day 'N' Nite", 'Barrett', 'Harper', 42)
# ('Black Masks & Gasoline', 'Barrett', 'Harper', 42)
# ("I'm Like A Lawyer With The Way I'm Always Trying To Get You Off (Me & You)", 'Barrett', 'Harper', 42)
# ('Staple It Together', 'Barrett', 'Harper', 42)
# ('Slow Jamz (Feat. Kanye West & Jamie Foxx) (Edited Album Version)', 'Barrett', 'Harper', 42)
# ('Hey_ Soul Sister', 'Barrett', 'Harper', 42)
# ('Rehab', 'Barrett', 'Harper', 42)
# ('Van Helsing Boombox', 'Barrett', 'Harper', 42)
# ('The Stallion', 'Barrett', 'Harper', 42)
# ('Fireflies', 'Barrett', 'Harper', 42)
# ('I Want I Want', 'Barrett', 'Harper', 42)
# ('Railway', 'Barrett', 'Harper', 42)
# ('Clark Gable (Album)', 'Barrett', 'Harper', 42)
# ('Phaeton', 'Barrett', 'Harper', 42)
# ('Ucci Ucci feat. Nicki Minaj & The Chopper City Boyz', 'Barrett', 'Harper', 42)
# ('Choke', 'Barrett', 'Harper', 42)
# ('Stuck Between', 'Barrett', 'Harper', 42)
# ('Smell Of Desire.', 'Barrett', 'Harper', 42)
# ('Headlights Look Like Diamonds', 'Barrett', 'Harper', 42)
# ('Out Go The Lights', 'Barrett', 'Harper', 42)
# ('You & Me Song', 'Barrett', 'Harper', 42)
# ('Girls (Album version)', 'Barrett', 'Harper', 42)
# ('Wayfaring Stranger', 'Barrett', 'Harper', 42)
# ('Sweep The Flo (Featuring Diamond)', 'Barrett', 'Harper', 42)
# ('This Old House w/ When The Saints Medley', 'Barrett', 'Harper', 42)
# ('Brain Leech', 'Barrett', 'Harper', 42)
# ('Didgeridoo', 'Barrett', 'Harper', 42)
# ('LÃ\x83Â\xa0 OÃ\x83Â¹ Je Pars', 'Barrett', 'Harper', 42)
# ("I Wouldn't Be A Man", 'Barrett', 'Harper', 42)
# ('Soy AlbaÃ\x83Â±il', 'Cuevas', 'Chloe', 49)
# ('Ghost In The Mirror', 'Owens', 'Cecilia', 6)
# ('My Moon My Man', 'Griffin', 'Layla', 24)
# ('We Will Become Silhouettes (Album)', 'Levine', 'Tegan', 80)
# ('Life Without You', 'Levine', 'Tegan', 80)
# ('Miseria Cantare--The Beginning', 'Calhoun', 'Hannah', 64)
# ('Catch You Baby (Steve Pitron & Max Sanna Radio Edit)', 'Johnson', 'Sara', 95)
# ('My Blue Heaven', 'Johnson', 'Sara', 95)
# ('Crucificame', 'Johnson', 'Sara', 95)
# ('Invalid', 'Johnson', 'Sara', 95)
# ('I Can Dance', 'Norris', 'Kimber', 47)
# ('The World Is A Ghetto', 'Norris', 'Kimber', 47)
# ('Gone', 'Levine', 'Tegan', 80)
# ('Play', 'Levine', 'Tegan', 80)
# ('Second awakening', 'Larson', 'Devin', 60)
# ('Protoculture (Sankofa)', 'Levine', 'Tegan', 80)
# ('Emotion', 'Levine', 'Tegan', 80)
# ('Love Story', 'Santana', 'Colm', 67)
# ('Message In A Bottle', 'Levine', 'Tegan', 80)
# ("You'd Rather Run", 'Levine', 'Tegan', 80)
# ('Happy Working Song', 'Johnson', 'Martin', 55)
# ('Second Chance (Album Version)', 'Levine', 'Tegan', 80)
# ('Some Unholy War', 'Johnson', 'Martin', 55)
# ('Ride Wit Me', 'Levine', 'Tegan', 80)
# ('Soliloquy Of Chaos (Explicit)', 'Koch', 'Lily', 15)
# ("Who's Your Daddy? ", 'Levine', 'Tegan', 80)
# ('When It Rains (Album Version)', 'Koch', 'Lily', 15)
# ('Mama Said', 'Levine', 'Tegan', 80)
# ('Forever Not Yours (Album Version  - NY Mix II)', 'Koch', 'Lily', 15)
# ('Lovely Rita (feat. Bunny Rugs and U Roy)', 'Levine', 'Tegan', 80)
# ('Down To My Last', 'Koch', 'Lily', 15)
# ('Mudanca De Tempo', 'Levine', 'Tegan', 80)
# ('Walking In The Air', 'Koch', 'Lily', 15)
# ('Mayfield', 'Levine', 'Tegan', 80)
# ('Ring My Bell', 'Koch', 'Lily', 15)
# ('I C Love Affair', 'Levine', 'Tegan', 80)
# ('Slow Death', 'Koch', 'Lily', 15)
# ('Carry', 'Levine', 'Tegan', 80)
# ('Canada', 'Koch', 'Lily', 15)
# ('Pace E Guerra', 'Koch', 'Lily', 15)
# ('ReprÃ\x83Â©sente', 'Levine', 'Tegan', 80)
# ('Mercy:The Laundromat', 'Levine', 'Tegan', 80)
# ('Clockwork Skinhead', 'Levine', 'Tegan', 80)
# ('Wood And Wire', 'Levine', 'Tegan', 80)
# ('Best Of Both Worlds (Remastered Album Version)', 'Fox', 'Jayden', 101)
# ('Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)', 'Harris', 'Theodore', 14)
# ('My Brother Is Watching Me', 'Banks', 'Ann', 99)
# ('Over You', 'Levine', 'Tegan', 80)
# ('She Loves You', 'Fox', 'Jayden', 101)
# ('Big In Japan (Original)', 'Burns', 'Lily', 32)
# ('Mindjer dÃ\x83Â´ce mel', 'Levine', 'Tegan', 80)
# ('Flying Into a Star', 'Banks', 'Ann', 99)
# ('Marvin & Miles', 'Levine', 'Tegan', 80)
# ('Dog Days Are Over (Radio Edit)', 'Levine', 'Tegan', 80)
# ('Seven Nation Army', 'Levine', 'Tegan', 80)
# ('East Side Mags', 'Robinson', 'Ava', 13)
# ('The Scientist', 'Robinson', 'Ava', 13)
# ('Revelry', 'Levine', 'Tegan', 80)
# ('Backyard', 'Levine', 'Tegan', 80)
# ('The Way You Look Tonight (Live Version)', 'Owens', 'Cecilia', 6)
# ('The Mess I Made', 'Levine', 'Tegan', 80)
# ('My Apocalypse', 'Young', 'Kinsley', 85)
# ('Teenage Spaceman', 'Levine', 'Tegan', 80)
# ('Modern world', 'Young', 'Kinsley', 85)
# ('Invalid', 'Owens', 'Cecilia', 6)
# ('Everybody Everybody', 'Levine', 'Tegan', 80)
# ('Ye Feng Ling', 'Young', 'Kinsley', 85)
# ('Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)', 'Levine', 'Tegan', 80)
# ('Buttnaked', 'Young', 'Kinsley', 85)
# ('No One Knows', 'Levine', 'Tegan', 80)
# ('Il Solo Rimasto', 'Young', 'Kinsley', 85)
# ('Living In The U.S.A. (1991 Digital Remaster)', 'Levine', 'Tegan', 80)
# ('Drop The World', 'Young', 'Kinsley', 85)
# ('Stoke Up The Fire', 'Young', 'Kinsley', 85)
# ('Whiskey Girl', 'Levine', 'Tegan', 80)
# ('Muy_ Muy Temprano', 'Levine', 'Tegan', 80)
# ('Under The Northern Star', 'Young', 'Kinsley', 85)
# ('Genom tunna tyger', 'Rogers', 'Jacob', 18)
# ('Geh Deinen Weg', 'Rogers', 'Jacob', 18)
# ("Don't Let The Rain Come Down (Crooked Little Man)", 'Young', 'Kinsley', 85)
# ('Strut (1993 Digital Remaster)', 'Levine', 'Tegan', 80)
# ('Falling Inside The Black (Album Version)', 'Young', 'Kinsley', 85)
# ('Into The Cryptic Mist', 'Levine', 'Tegan', 80)
# ('Greenback Dollar', 'Young', 'Kinsley', 85)
# ('Ten Cent Pistol', 'Levine', 'Tegan', 80)
# ('Times Like These', 'Young', 'Kinsley', 85)
# ('House Of Broken Love', 'Young', 'Kinsley', 85)
# ('No Rain', 'Levine', 'Tegan', 80)
# ('Fly Away From Here', 'Burns', 'Lily', 32)
# ('Solar Flare', 'Levine', 'Tegan', 80)
# ('Kaaos ei karkaa', 'Young', 'Kinsley', 85)
# ("Baker's Blue Jay Yarn", 'Levine', 'Tegan', 80)
# ('Shortie Like Mine', 'Levine', 'Tegan', 80)
# ('Hold On', 'Young', 'Kinsley', 85)
# ('Adios', 'Levine', 'Tegan', 80)
# ('Shame', 'Young', 'Kinsley', 85)
# ('Madrugada Na Praia Deserta', 'Levine', 'Tegan', 80)
# ('Vanishing', 'Young', 'Kinsley', 85)
# ("I CAN'T GET STARTED", 'Levine', 'Tegan', 80)
# ('Do We Need This?', 'Levine', 'Tegan', 80)
# ('Howlin\x19 For You', 'Levine', 'Tegan', 80)
# ('Bleed It Out (Album Version)', 'Barrera', 'Adler', 100)
# ('Microdaze', 'Levine', 'Tegan', 80)
# ('Crosshairs', 'Levine', 'Tegan', 80)
# ('Breakdown', 'Levine', 'Tegan', 80)
# ('The Pretender', 'Levine', 'Tegan', 80)
# ('Jumpers (Album)', 'Levine', 'Tegan', 80)
# ('Pace Is The Trick', 'Levine', 'Tegan', 80)
# ('Dance Me To The End Of Love', 'Levine', 'Tegan', 80)
# ('Star Eyes', 'Jones', 'Matthew', 36)
# ('Headstrong (Album Version)', 'Levine', 'Tegan', 80)
# ('You Love Me Anyway (Album)', 'Jones', 'Matthew', 36)
# ('Not For You', 'Levine', 'Tegan', 80)
# ('El Juego Del Rap', 'Jones', 'Matthew', 36)
# ('U.S. Bombs', 'Robinson', 'Ava', 50)
# ('Colpa Del Whisky (Andrea Paci Radio Edit)', 'Jones', 'Matthew', 36)
# ('Streets Of Philadelphia', 'Levine', 'Tegan', 80)
# ("Hey Daddy (Daddy's Home)", 'Robinson', 'Ava', 50)
# ('Grand Designs', 'Jones', 'Matthew', 36)
# ('Columbus Avenue', 'Levine', 'Tegan', 80)
# ('Mariposa traicionera', 'Robinson', 'Ava', 50)
# ('Obsessed', 'Smith', 'Ryan', 26)
# ('Bubble Toes', 'Levine', 'Tegan', 80)
# ('Make Love To Your Mind', 'Robinson', 'Ava', 50)
# ('Natural Anthem (Album)', 'Smith', 'Ryan', 26)
# ('Love On The Rocks', 'Levine', 'Tegan', 80)
# ('Pass You By', 'Jones', 'Matthew', 36)
# ('Gone', 'Robinson', 'Ava', 50)
# ("Unless It's Kicks", 'Smith', 'Ryan', 26)
# ('DNA', 'Jones', 'Matthew', 36)
# ('Crazy Beautiful', 'Levine', 'Tegan', 80)
# ('Sonrisa', 'Levine', 'Tegan', 80)
# ('Call Me', 'Jones', 'Matthew', 36)
# ('Kromozom Bankal (Linathaleyco Mix)', 'Jones', 'Matthew', 36)
# ('Pea (Album Version)', 'Smith', 'Ryan', 26)
# ('Red Elephant', 'Smith', 'Ryan', 26)
# ('Your Decision', 'Levine', 'Tegan', 80)
# ('Stripes', 'Jones', 'Matthew', 36)
# ('Bleed It Out [Live At Milton Keynes]', 'Rogers', 'Jacob', 18)
# ("Ain't Misbehavin", 'Smith', 'Ryan', 26)
# ('Every Shining Time You Arrive (Album)', 'Jones', 'Matthew', 36)
# ("I'm Shady", 'Levine', 'Tegan', 80)
# ('Call 9-1-1 (Explicit)', 'Jones', 'Matthew', 36)
# ("Remember Me_ I'm The One Who Loves You", 'Jones', 'Matthew', 36)
# ("It Just Don't Stop", 'Jones', 'Matthew', 36)
# ('El Cuatrero', 'Jones', 'Matthew', 36)
# ('All Along The Watchtower', 'Jones', 'Matthew', 36)
# ('Kalidafun Parts 1&2', 'Jones', 'Matthew', 36)
# ('Rosemary', 'Jones', 'Matthew', 36)
# ('Blue Collar Man (Long Nights)', 'Jones', 'Matthew', 36)
# ('Su veneno', 'Jones', 'Matthew', 36)
# ('Hot N Cold (Manhattan Clique Remix Radio Edit)', 'Jones', 'Matthew', 36)
# ('Bebot', 'Jones', 'Matthew', 36)
# ('Lava Lava', 'Jones', 'Matthew', 36)
# ('Air & Lack Thereof', 'Jones', 'Matthew', 36)
# ('My Mamma Said', 'Levine', 'Tegan', 80)
# ('Piano Concerto No. 2 in G minor Op. 22 (2006 Digital Remaster): III.  Presto', 'Jones', 'Matthew', 36)
# ('Where Is My Mind?', 'Levine', 'Tegan', 80)
# ('Drunk Girls', 'Levine', 'Tegan', 80)
# ('Two Hearts', 'Jones', 'Matthew', 36)
# ('Reptilia', 'Jones', 'Matthew', 36)
# ('Clockwork Skinhead', 'Young', 'Kinsley', 85)
# ('Scream For More', 'Jones', 'Matthew', 36)
# ("God's Plan", 'Young', 'Kinsley', 85)
# ('Kiss It Better', 'Young', 'Kinsley', 85)
# ('All Of The Champs That Ever Lived', 'Jones', 'Matthew', 36)
# ('Something', 'Jones', 'Matthew', 36)
# ('Fireflies', 'Jones', 'Matthew', 36)
# ('English Summer Rain', 'Jones', 'Matthew', 36)
# ('Man/Bag Of Sand', 'Jones', 'Matthew', 36)
# ("Don't Think I Don't Think About It", 'Jones', 'Matthew', 36)
# ('Everlong', 'Jones', 'Matthew', 36)
# ('Transparency', 'Cuevas', 'Chloe', 49)
# ('Jambalaya (On The Bayou)', 'Jones', 'Matthew', 36)
# ("I CAN'T GET STARTED", 'Cuevas', 'Chloe', 49)
# ('Te Amo', 'Jones', 'Matthew', 36)
# ('Kellum (Album Version)', 'Jones', 'Matthew', 36)
# ('My All', 'Jones', 'Matthew', 36)
# ('Change Is Hard', 'Cuevas', 'Chloe', 49)
# ('Sugar (Jagz Kooner Mix)', 'Cuevas', 'Chloe', 49)
# ('Dumb Blood', 'Jones', 'Matthew', 36)
# ('Time Bomb', 'Jones', 'Matthew', 36)
# ('In The Closet', 'Jones', 'Matthew', 36)
# ("Don't Go", 'Jones', 'Matthew', 36)
# ('BedRock (Radio Edit) (feat.Lloyd)', 'Jones', 'Matthew', 36)
# ('Rock With Me', 'Jones', 'Matthew', 36)
# ('Motor Panir', 'Jones', 'Matthew', 36)
# ('Right Through You (LP Version)', 'Jones', 'Matthew', 36)
# ('Supermassive Black Hole (Twilight Soundtrack Version)', 'Jones', 'Matthew', 36)
# ('Brackett_ WI', 'Jones', 'Matthew', 36)
# ('Burn Them Prisons', 'Jones', 'Matthew', 36)
# ('Mighty K.C.', 'Jones', 'Matthew', 36)
# ('Tu Me Asustas', 'Jones', 'Matthew', 36)
# ('Barbwire', 'Jones', 'Matthew', 36)
# ('Ante Up (Robbin Hoodz Theory)', 'Jones', 'Matthew', 36)
# ('Crack A Bottle', 'Jones', 'Matthew', 36)
# ('Estoy AquÃ\x83Â\xad', 'Williams', 'Celeste', 53)
# ('Yeah!', 'Jones', 'Matthew', 36)
# ('Hanuman', 'Jones', 'Matthew', 36)
# ('I Wanna Be Sedated (Remastered Album Version )', 'Jones', 'Matthew', 36)
# ('Miserable At Best (Album)', 'Jones', 'Matthew', 36)
# ('Music Box', 'Graves', 'Jayden', 25)
# ('Visions', 'Graves', 'Jayden', 25)
# ('Calyx Virago', 'Harris', 'Theodore', 14)
# ('Drop The Mirror (EP Version)', 'Graves', 'Jayden', 25)
# ('Shook Ones pt. 2', 'Harris', 'Theodore', 14)
# ('Pretendo Hablarte', 'Graves', 'Jayden', 25)
# ('Bring Me To Life', 'Graves', 'Jayden', 25)
# ('Clear Blue Water', 'Graves', 'Jayden', 25)
# ("You're The One", 'Rodriguez', 'Mohammad', 88)
# ('Lord Xenu', 'Rodriguez', 'Mohammad', 88)
# ('Take Me To The River', 'Graves', 'Jayden', 25)
# ('Flat Beat', 'Graves', 'Jayden', 25)
# ('Never Too Far', 'Graves', 'Jayden', 25)
# ("Day 'N' Nite", 'Graves', 'Jayden', 25)
# ('El Hombre', 'Graves', 'Jayden', 25)
# ('Geek In The Pink [Phil Tan Remix]', 'Graves', 'Jayden', 25)
# ("You're The One", 'Graves', 'Jayden', 25)
# ('I Second That Emotion', 'Graves', 'Jayden', 25)
# ('Zen', 'White', 'Stefany', 83)
# ('Abrazame  (Version Acustica)', 'Garrison', 'Tucker', 40)
# ("You Ain't Right (Album Version)", 'Garrison', 'Tucker', 40)
# ('Provider (Remix Radio Edit)', 'Martin', 'James', 79)
# ('Aww Skeet Skeet', 'Lynch', 'Jacqueline', 29)
# ('The Sun In The Stream', 'Lynch', 'Jacqueline', 29)
# ('We Need To Talk (She And I Album Version)', 'Lynch', 'Jacqueline', 29)
# ('Pursuit Of Happiness (nightmare)', 'Lynch', 'Jacqueline', 29)
# ("Haven't We Lost Enough?  (LP Version)", 'Lynch', 'Jacqueline', 29)
# ('Sleepyhead', 'Lynch', 'Jacqueline', 29)
# ('Merry Go Round (Remastered Single Version)', 'Lynch', 'Jacqueline', 29)
# ('Rosa Branca', 'Taylor', 'Molly', 35)
# ('Like you better dead', 'Lynch', 'Jacqueline', 29)
# ('Newport Living (Album Version)', 'Taylor', 'Molly', 35)
# ('Too Far Gone', 'Lynch', 'Jacqueline', 29)
# ('Take Em To Church', 'Taylor', 'Molly', 35)
# ("Don't Walk Away", 'Lynch', 'Jacqueline', 29)
# ('Nube Inerte (con Aniki)', 'Lynch', 'Jacqueline', 29)
# ('Untitled', 'Lynch', 'Jacqueline', 29)
# ('A Dream', 'Lynch', 'Jacqueline', 29)
# ('Halo', 'Lynch', 'Jacqueline', 29)
# ('Getting Better (feat. The Mighty Diamonds)', 'Lynch', 'Jacqueline', 29)
# ('Sing Along [Featuring Dave Matthews]', 'Lynch', 'Jacqueline', 29)
# ('Run', 'Lynch', 'Jacqueline', 29)
# ('Come Softly To Me', 'Lynch', 'Jacqueline', 29)
# ('Let Down', 'Lynch', 'Jacqueline', 29)
# ('Demon Days', 'Lynch', 'Jacqueline', 29)
# ('Eton Boating Song/Wyoming Lullaby/The Wiffenpoof Song (Baa Baa Baa) (Medley)', 'Lynch', 'Jacqueline', 29)
# ('Pirate Jet', 'Lynch', 'Jacqueline', 29)
# ('Clear Blue Water', 'Lynch', 'Jacqueline', 29)
# ('Oh Yeah', 'Lynch', 'Jacqueline', 29)
# ('Sorrow (1997 Digital Remaster)', 'Gonzalez', 'Samuel', 61)
# ("Don't Take Away The Music", 'Lynch', 'Jacqueline', 29)
# ("Bigger Isn't Better", 'Gonzalez', 'Samuel', 61)
# ('Break My Body', 'Roth', 'Chloe', 78)
# ("I've Got Knives In My Eyes I'm Going Home Sick", 'Lynch', 'Jacqueline', 29)
# ('Effervescing Elephant', 'Lynch', 'Jacqueline', 29)
# ('If You Want To Sing Out_ Sing Out', 'Lynch', 'Jacqueline', 29)
# ('I Feel Wonderful (AM to PM Mix)', 'Summers', 'Kaylee', 8)
# ('Who Makes Your Money', 'Lynch', 'Jacqueline', 29)
# ('Fools', 'Lynch', 'Jacqueline', 29)
# ('Tive Sim', 'Lynch', 'Jacqueline', 29)
# ("It's Raining Again", 'Lynch', 'Jacqueline', 29)
# ('West One (Shine On Me)', 'Lynch', 'Jacqueline', 29)
# ('Abololo', 'Lynch', 'Jacqueline', 29)
# ('Bottom of a Bottle (Explicit Album Version)', 'Lynch', 'Jacqueline', 29)
# ('Unrecorded', 'Lynch', 'Jacqueline', 29)
# ('Roustabout (Bassnectar REMIX)', 'Lynch', 'Jacqueline', 29)
# ('The Vowels Pt. 2', 'Lynch', 'Jacqueline', 29)
# ('From Head To Toe', 'Lynch', 'Jacqueline', 29)
# ('On The Radio (Edit)', 'Lynch', 'Jacqueline', 29)
# ('Halo', 'Lynch', 'Jacqueline', 29)
# ('Only Time (Original Version)', 'Lynch', 'Jacqueline', 29)
# ('Ne me plaignez pas', 'Lynch', 'Jacqueline', 29)
# ('Audience Of One', 'Lynch', 'Jacqueline', 29)
# ('Ruby', 'Lynch', 'Jacqueline', 29)
# ('Reign Of The Tyrants', 'Lynch', 'Jacqueline', 29)
# ('The Ghost Of You (Album Version)', 'Lynch', 'Jacqueline', 29)
# ('Cupola', 'Lynch', 'Jacqueline', 29)
# ('Losers', 'Lynch', 'Jacqueline', 29)
# ('Gears', 'Lynch', 'Jacqueline', 29)
# ('Alejandro', 'Lynch', 'Jacqueline', 29)
# ('Superstar', 'Lynch', 'Jacqueline', 29)
# ("When My Baby's Beside Me", 'Lynch', 'Jacqueline', 29)
# ('Hold On To Me', 'Smith', 'Ryan', 26)
# ('Sehr kosmisch', 'Lynch', 'Jacqueline', 29)
# ('I Need You', 'Lynch', 'Jacqueline', 29)
# ('Cool Water', 'Lynch', 'Jacqueline', 29)
# ('In The Dark (ft. Christian Burns)', 'Lynch', 'Jacqueline', 29)
# ('Window In The Skies', 'Lynch', 'Jacqueline', 29)
# ('We Major', 'Lynch', 'Jacqueline', 29)
# ('Sweet And Wild', 'Lynch', 'Jacqueline', 29)
# ('Solar Powered', 'Lynch', 'Jacqueline', 29)
# ('The Real Slim Shady', 'Lynch', 'Jacqueline', 29)
# ('What Are You Looking For', 'Lynch', 'Jacqueline', 29)
# ('Secrets', 'Lynch', 'Jacqueline', 29)
# ('Wow_ I Can Get Sexual Too', 'Lynch', 'Jacqueline', 29)
# ('A Warm Place', 'Lynch', 'Jacqueline', 29)
# ('El Golpe', 'Lynch', 'Jacqueline', 29)
# ('Waste of Time', 'Lynch', 'Jacqueline', 29)
# ('Waters Of Nazareth (album version)', 'Lynch', 'Jacqueline', 29)
# ('Behind The Sea [Live In Chicago]', 'Lynch', 'Jacqueline', 29)
# ('Besos Y Caricias', 'Lynch', 'Jacqueline', 29)
# ('Maybe', 'Lynch', 'Jacqueline', 29)
# ('I Saw The Light', 'Lynch', 'Jacqueline', 29)
# ('A Girl Named You', 'Lynch', 'Jacqueline', 29)
# ('Last Cup Of Sorrow', 'Lynch', 'Jacqueline', 29)
# ('Rearview Mirror', 'Lynch', 'Jacqueline', 29)
# ('Supermassive Black Hole (Twilight Soundtrack Version)', 'Lynch', 'Jacqueline', 29)
# ('Just Because', 'Lynch', 'Jacqueline', 29)
# ("I'll Be Your Man", 'Lynch', 'Jacqueline', 29)
# ('Let Me Be The One', 'Lynch', 'Jacqueline', 29)
# ('Sit Down Baby', 'Lynch', 'Jacqueline', 29)
# ('So Bored', 'Lynch', 'Jacqueline', 29)
# ('The Ballad Of Sal Villanueva (Album Version)', 'Lynch', 'Jacqueline', 29)
# ('Quutamo', 'Lynch', 'Jacqueline', 29)
# ('Turn The Radio Off', 'Lynch', 'Jacqueline', 29)
# ('En Nat Bliver Det Sommer', 'Lynch', 'Jacqueline', 29)
# ('Fast As I Can', 'Lynch', 'Jacqueline', 29)
# ('Slip', 'Lynch', 'Jacqueline', 29)
# ('The Garden', 'Lynch', 'Jacqueline', 29)
# ("I'd Like To Know", 'Lynch', 'Jacqueline', 29)
# ('Hello Walls', 'Lynch', 'Jacqueline', 29)
# ('Como Me Mira', 'Lynch', 'Jacqueline', 29)
# ('Imanol', 'Herman', 'Magdalene', 77)
# ('Beautiful', 'Lynch', 'Jacqueline', 29)
# ('Sample Track 2', 'Herman', 'Magdalene', 77)
# ('Up And Gone', 'Lynch', 'Jacqueline', 29)
# ('Bust A Move', 'Lynch', 'Jacqueline', 29)
# ('La Bayamesa', 'Lynch', 'Jacqueline', 29)
# ('Marry Me', 'Lynch', 'Jacqueline', 29)
# ('Dans Ma Bulle (Edit Radio - Live 2006)', 'Lynch', 'Jacqueline', 29)
# ('The Beginning (Single Remix)', 'Lynch', 'Jacqueline', 29)
# ('Hello', 'Lynch', 'Jacqueline', 29)
# ("Imagination (12'' Version)", 'Lynch', 'Jacqueline', 29)
# ('Palma Solane', 'Cuevas', 'Chloe', 49)
# ('Never Say Never', 'Lynch', 'Jacqueline', 29)
# ('Sunburn [Live]', 'Lynch', 'Jacqueline', 29)
# ('Up The Bracket', 'Cuevas', 'Chloe', 49)
# ('Love Story', 'Lynch', 'Jacqueline', 29)
# ('Be Aware', 'Lynch', 'Jacqueline', 29)
# ('House Of Broken Love', 'Lynch', 'Jacqueline', 29)
# ('DonÃ\x82Â´t Believe The Hype', 'Lynch', 'Jacqueline', 29)
# ('I Kissed A Girl', 'Lynch', 'Jacqueline', 29)
# ('Imanol', 'Lynch', 'Jacqueline', 29)
# ('Crazy In The Night (Barking At Airplanes)', 'Lynch', 'Jacqueline', 29)
# ('Joy', 'Lynch', 'Jacqueline', 29)
# ('Howlin\x19 For You', 'Lynch', 'Jacqueline', 29)
# ('Disavow your God (Album Version)', 'Lynch', 'Jacqueline', 29)
# ('Monsoon', 'Lynch', 'Jacqueline', 29)
# ('Paper Planes', 'Cuevas', 'Chloe', 49)
# ('Odessa', 'Lynch', 'Jacqueline', 29)
# ('Meltdown (Amended Album Version)', 'Cuevas', 'Chloe', 49)
# ('El Infeliz', 'Lynch', 'Jacqueline', 29)
# ('All I Do Is Dream Of You (Album Version)', 'Cuevas', 'Chloe', 49)
# ('Photograph', 'Lynch', 'Jacqueline', 29)
# ('Back Sliders Wine', 'Cuevas', 'Chloe', 49)
# ('Billionaire [feat. Bruno Mars]  (Explicit Album Version)', 'Hess', 'Aiden', 86)
# ("Mean Ol'World", 'Banks', 'Ann', 99)
# ('En Mi Mundo', 'Miles', 'Jahiem', 43)
# ("We'll Never Know", 'Miles', 'Jahiem', 43)
# ('Cabaret Blanco', 'Miles', 'Jahiem', 43)
# ('Tarkus', 'Owens', 'Cecilia', 6)
# ('Weird Era', 'Graves', 'Jayden', 25)
# ('No Surprise', 'Graves', 'Jayden', 25)
# ('Club Tropicana', 'Graves', 'Jayden', 25)
# ('Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)', 'Graves', 'Jayden', 25)
# ('Depot Blues', 'Graves', 'Jayden', 25)
# ('Lucky (Album Version)', 'Graves', 'Jayden', 25)
# ('Talking In Your Sleep', 'Graves', 'Jayden', 25)
# ('Such Great Heights', 'Graves', 'Jayden', 25)
# ('Always Will (LP Version)', 'Graves', 'Jayden', 25)
# ('Above The Clouds (Edited)', 'Graves', 'Jayden', 25)
# ('Coldest Winter', 'Graves', 'Jayden', 25)
# ('Nan Ni Wan', 'Graves', 'Jayden', 25)
# ('Back In The Day', 'Graves', 'Jayden', 25)
# ('Vielas De Alfama', 'Burke', 'Maia', 51)
# ('Epilogue', 'Graves', 'Jayden', 25)
# ('Non E_ Per Te_ Per Me', 'Burke', 'Maia', 51)
# ('Fight For Your Life', 'Graves', 'Jayden', 25)
# ('ReprÃ\x83Â©sente', 'Graves', 'Jayden', 25)
# ("Run_ Don't Walk", 'Graves', 'Jayden', 25)
# ('The Door', 'Graves', 'Jayden', 25)
# ('Love Always', 'Graves', 'Jayden', 25)
# ('Bring Me To Life', 'Graves', 'Jayden', 25)
# ('The Snow Prelude No. 2', 'Graves', 'Jayden', 25)
# ('Ayer Me Dijo Un Ave', 'Graves', 'Jayden', 25)
# ('Basic Space', 'Graves', 'Jayden', 25)
# ('Big Munny', 'Graves', 'Jayden', 25)
# ('Ms. Jackson', 'Graves', 'Jayden', 25)
# ('The Only One', 'Graves', 'Jayden', 25)
# ("Po' Folks", 'Graves', 'Jayden', 25)
# ('Fool For Your Loving', 'Graves', 'Jayden', 25)
# ('Who Can Compare', 'Graves', 'Jayden', 25)
# ('PrÃ\x83Â³fugos', 'Graves', 'Jayden', 25)
# ('Home', 'Graves', 'Jayden', 25)
# ('Dismantle. Repair.', 'Kirby', 'Aleena', 44)
# ('Shitlist', 'Kirby', 'Aleena', 44)
# ('Fingers Become Thumbs', 'Kirby', 'Aleena', 44)
# ('Call Me', 'Kirby', 'Aleena', 44)
# ('Billionaire [feat. Bruno Mars]  (Explicit Album Version)', 'Kirby', 'Aleena', 44)
# ('Smile', 'Kirby', 'Aleena', 44)
# ('Fall Back Down (Album Version)', 'Kirby', 'Aleena', 44)
# ("I'm Still Breathing", 'Kirby', 'Aleena', 44)
# ('Punks (Krafty Kuts Remix)', 'Kirby', 'Aleena', 44)
# ('All Summer Long (Album Version)', 'George', 'Rylan', 16)
# ('On A Gloomy Evening', 'Kirby', 'Aleena', 44)
# ('When You Were Young', 'George', 'Rylan', 16)
# ('Ghost Dream', 'Kirby', 'Aleena', 44)
# ('Rooftop Gambler', 'Kirby', 'Aleena', 44)
# ("Can't Help But Wait (Album Version)", 'George', 'Rylan', 16)
# ('La Pared', 'Kirby', 'Aleena', 44)
# ('Tennessee Waltz (Live)', 'George', 'Rylan', 16)
# ('D is for Dangerous', 'Kirby', 'Aleena', 44)
# ('Ghost Of A Good Thing', 'George', 'Rylan', 16)
# ('Lift Me Up', 'Kirby', 'Aleena', 44)
# ('Snookered', 'Kirby', 'Aleena', 44)
# ('Psycho', 'Kirby', 'Aleena', 44)
# ('Snow [Hey Oh] (Album Version)', 'Kirby', 'Aleena', 44)
# ('Memphis_ Tennessee', 'Kirby', 'Aleena', 44)
# ('Jump (Live)', 'Kirby', 'Aleena', 44)
# ('Streets Of New York (City Life)', 'Kirby', 'Aleena', 44)
# ('Another Town', 'Kirby', 'Aleena', 44)
# ('Well Did You Evah!', 'Kirby', 'Aleena', 44)
# ("What's The Difference", 'Kirby', 'Aleena', 44)
# ('Advanced (Ton T.B. Mix)', 'Kirby', 'Aleena', 44)
# ('Apologize', 'Kirby', 'Aleena', 44)
# ('The Maestro', 'Kirby', 'Aleena', 44)
# ('The Only Exception (Album Version)', 'Kirby', 'Aleena', 44)
# ...
# ('Pursuit Of Happiness (nightmare)', 'Koch', 'Lily', 15)
# ('Road To Zion', 'Koch', 'Lily', 15)
# ('Pushing Me Away (Album Version)', 'Koch', 'Lily', 15)
# ('Killa', 'Koch', 'Lily', 15)
# ('Lonesome Road', 'Koch', 'Lily', 15)
# ('Hey There Mr. Brooks (feat. Feat. Shawn Mike of Alesana)', 'Koch', 'Lily', 15)
# ('The Chariot', 'Koch', 'Lily', 15)
# ('Twilight Time', 'Burns', 'Lily', 32)
# ("Don't Lie", 'Burns', 'Lily', 32)
# ('Invalid', 'Cook', 'Kaleb', 54)
# ('Wrong Turn', 'Cook', 'Kaleb', 54)
# ("Jim Henson's Dead", 'Bell', 'Jayden', 91)
# ('Shell Shock', 'Klein', 'Jacob', 73)
# ('Women Lose Weight (Feat: Slick Rick)', 'Klein', 'Jacob', 73)
# ("Won't Go Home Without You", 'Klein', 'Jacob', 73)
# ('Hey_ Soul Sister', 'Klein', 'Jacob', 73)
# ("I'm In Miami Bitch", 'Klein', 'Jacob', 73)
# ('Sexy Bitch', 'Klein', 'Jacob', 73)
# ('The Cure & The Cause (Dennis Ferrer Remix)', 'Klein', 'Jacob', 73)
# ('Staring At Me', 'Klein', 'Jacob', 73)
# ('The Second You Sleep', 'Klein', 'Jacob', 73)
# ('Wide Eyes', 'Klein', 'Jacob', 73)
# ('La Resistance (Medley) (LP Version)', 'Klein', 'Jacob', 73)
# ('Restless', 'Klein', 'Jacob', 73)
# ('Noc...', 'Klein', 'Jacob', 73)
# ('Like You', 'Klein', 'Jacob', 73)
# ('God Put A Smile Upon Your Face', 'Klein', 'Jacob', 73)
# ('Playboy', 'Klein', 'Jacob', 73)
# ('Every Time You Go', 'Klein', 'Jacob', 73)
# ('Natural Anthem (Album)', 'Klein', 'Jacob', 73)
# ('Taylor', 'Hess', 'Aiden', 86)
# ('Naked As We Can', 'Hess', 'Aiden', 86)
# ('Fantasy', 'Hess', 'Aiden', 86)
# ('Epilogue', 'Hess', 'Aiden', 86)
# ("Groovin'", 'Hess', 'Aiden', 86)
# ("Ain't No Way (You Won't Love Me)", 'Griffin', 'Layla', 24)
# ('Rome', 'Griffin', 'Layla', 24)
# ('Highway Through My Home', 'Griffin', 'Layla', 24)
# ('143', 'Griffin', 'Layla', 24)
# ('Dreams-Come-True-Girl', 'Griffin', 'Layla', 24)
# ("I Don't Feel Like Dancin'", 'Griffin', 'Layla', 24)
# ('Right On Time (Album Version)', 'Griffin', 'Layla', 24)
# ('Black Lines', 'Smith', 'Ryan', 26)
# ('Uprising', 'Griffin', 'Layla', 24)
# ('Man Makes The Zoo', 'Smith', 'Ryan', 26)
# ('Blacks/Radio', 'Griffin', 'Layla', 24)
# ('Love Dealer (Featuring Justin Timberlake)', 'Smith', 'Ryan', 26)
# ('ReprÃ\x83Â©sente', 'Griffin', 'Layla', 24)
# ('Hey_ Soul Sister', 'Smith', 'Ryan', 26)
# ('Up And Gone', 'Griffin', 'Layla', 24)
# ('Te Conoci', 'Griffin', 'Layla', 24)
# ('Bottle Pop', 'Smith', 'Ryan', 26)
# ('My Love Will Follow You', 'Griffin', 'Layla', 24)
# ('Found Home', 'Smith', 'Ryan', 26)
# ('My December', 'Griffin', 'Layla', 24)
# ('The Perfect Kiss', 'Smith', 'Ryan', 26)
# ("You're Gonna Make Me Lonesome When You Go", 'Griffin', 'Layla', 24)
# ('Shortie Like Mine', 'Smith', 'Ryan', 26)
# ('Domination', 'Smith', 'Ryan', 26)
# ('Inside My Love (Digitally Remastered 93)', 'Cuevas', 'Chloe', 49)
# ('Structure', 'Cuevas', 'Chloe', 49)
# ('Killing In The Name', 'Cuevas', 'Chloe', 49)
# ("Girl You Know It's True", 'Gay', 'Katherine', 57)
# ('Waterfall (Spirit Of The Rainforest Album Version)', 'Cuevas', 'Chloe', 49)
# ('Robot Soul (Radio Edit)', 'Cuevas', 'Chloe', 49)
# ('Blindfold', 'Cuevas', 'Chloe', 49)
# ("I'm Yours (Album Version)", 'Cuevas', 'Chloe', 49)
# ('Say Hello', 'Watkins', 'Avery', 30)
# ('(I Just) Died In Your Arms', 'Cuevas', 'Chloe', 49)
# ('Sweet Jane', 'Watkins', 'Avery', 30)
# ('Gears', 'Cuevas', 'Chloe', 49)
# ('Seven Nation Army (Album Version)', 'Watkins', 'Avery', 30)
# ('Fix You', 'Cuevas', 'Chloe', 49)
# ('It Could Be Sweet', 'Watkins', 'Avery', 30)
# ('If This Was The Last Song', 'Cuevas', 'Chloe', 49)
# ('Poppiholla', 'Watkins', 'Avery', 30)
# ('The Unforgiven III', 'Smith', 'Ryann', 92)
# ('Apresurate', 'Cuevas', 'Chloe', 49)
# ('There Is', 'Watkins', 'Avery', 30)
# ('Would That Make U Love Me', 'Watkins', 'Avery', 30)
# ('Screaming Infidelities', 'Cuevas', 'Chloe', 49)
# ('Big Idea', 'Watkins', 'Avery', 30)
# ('Bulletproof', 'Cuevas', 'Chloe', 49)
# ('The Tune', 'Watkins', 'Avery', 30)
# ('Trani', 'Cuevas', 'Chloe', 49)
# ('Girl Money', 'Watkins', 'Avery', 30)
# ('Chloe Dancer/Crown Of Thorns', 'Cuevas', 'Chloe', 49)
# ('The Bachelor and the Bride', 'Watkins', 'Avery', 30)
# ('M', 'Watkins', 'Avery', 30)
# ("Nothin' On You [feat. Bruno Mars] (Album Version)", 'Cuevas', 'Chloe', 49)
# ('You Sent Me Flying / Cherry', 'Watkins', 'Avery', 30)
# ('Faithless', 'Cuevas', 'Chloe', 49)
# ('You Only Live Once', 'Watkins', 'Avery', 30)
# ('Tempting Time', 'Cuevas', 'Chloe', 49)
# ('Flowers In December', 'Watkins', 'Avery', 30)
# ('Take It Back', 'Cuevas', 'Chloe', 49)
# ('Behind Two Hills&A Swimming Pool', 'Watkins', 'Avery', 30)
# ('My First Kiss (Feat. Ke$ha) [Album Version]', 'Cuevas', 'Chloe', 49)
# ('Straight Outta Compton (Extended Mix) (Edit) (Explicit)', 'Watkins', 'Avery', 30)
# ("Goin' Home", 'Cuevas', 'Chloe', 49)
# ('Sick', 'Watkins', 'Avery', 30)
# ('Fix You', 'Cuevas', 'Chloe', 49)
# ('Half Of My Heart', 'Cuevas', 'Chloe', 49)
# ('Revelry', 'Cuevas', 'Chloe', 49)
# ('World Coming Down', 'Cuevas', 'Chloe', 49)
# ('Fire', 'Cuevas', 'Chloe', 49)
# ('Shoot Me Down', 'Cuevas', 'Chloe', 49)
# ('Juice (Know The Ledge)', 'Cuevas', 'Chloe', 49)
# ("Hymne A L'Amour (Album Version)", 'Cuevas', 'Chloe', 49)
# ("We're Only Gonna Die (Album Version)", 'Cuevas', 'Chloe', 49)
# ('Next Hype', 'Cuevas', 'Chloe', 49)
# ('Fireflies', 'Cuevas', 'Chloe', 49)
# ('Hotel California', 'Cuevas', 'Chloe', 49)
# ('Little Wing', 'Cuevas', 'Chloe', 49)
# ('Smothered (Album Version)', 'Cuevas', 'Chloe', 49)
# ('Try Your Best', 'Cuevas', 'Chloe', 49)
# ('Le Courage Des Oiseaux', 'Cuevas', 'Chloe', 49)
# ('Lips Like Morphine (Album Version)', 'Cuevas', 'Chloe', 49)
# ('Kiedys zrozumiesz', 'Cuevas', 'Chloe', 49)
# ("Fallin' Apart", 'Parker', 'Braden', 74)
# ("Don't Cry (Original)", 'Cuevas', 'Chloe', 49)
# ('Transparency', 'Cuevas', 'Chloe', 49)
# ('La Suerte De Mi Vida', 'Cuevas', 'Chloe', 49)
# ('Redwing', 'Cuevas', 'Chloe', 49)
# ('Starfish-On-The-Toast (2008 Digital Remaster)', 'Cuevas', 'Chloe', 49)
# ('Illusions', 'Cuevas', 'Chloe', 49)
# ('Bright Lights (Remastered Version)', 'Rodriguez', 'Mohammad', 88)
# ('Field Goal', 'Rodriguez', 'Mohammad', 88)
# ('Nah!', 'Rodriguez', 'Mohammad', 88)
# ('By The Way', 'Rodriguez', 'Mohammad', 88)
# ('Keep On Running', 'Rodriguez', 'Mohammad', 88)
# ('I Dont Wanna Wait', 'Rodriguez', 'Mohammad', 88)
# ('Echonomix', 'Rodriguez', 'Mohammad', 88)
# ('One By One', 'Rodriguez', 'Mohammad', 88)
# ('Sin Miedo a Nada (con Amaia Montero)', 'Jones', 'Matthew', 36)
# ('Bonnie Brae', 'Jones', 'Matthew', 36)
# ('War', 'Jones', 'Matthew', 36)
# ('Sad Lisa', 'Jones', 'Matthew', 36)
# ('The House That Nat Built (Album Version)', 'Jones', 'Matthew', 36)
# ('Jealous Minds Think Alike', 'Jones', 'Matthew', 36)
# ("My Mother's Eyes", 'Jones', 'Matthew', 36)
# ('Make Her Say', 'Jones', 'Matthew', 36)
# ('Viaje Sin Rumbo (2004 Digital Remaster)', 'Jones', 'Matthew', 36)
# ('Dreamdancer', 'Jones', 'Matthew', 36)
# ('The Queen of Nothing', 'Jones', 'Matthew', 36)
# ('Riot In Cell Block Number Nine', 'Smith', 'Ryann', 92)
# ('Sehr kosmisch', 'Jones', 'Matthew', 36)
# ('Everything You Love (Album Version)', 'Smith', 'Ryann', 92)
# ("Someone Else's Life", 'Smith', 'Ryann', 92)
# ('Godine prolaze', 'Smith', 'Ryann', 92)
# ('Private Affair (Amended Album Version)', 'Jones', 'Matthew', 36)
# ('Ginko Biloba', 'Jones', 'Matthew', 36)
# ('Three Day Weekend', 'Jones', 'Matthew', 36)
# ('Meen Dah Elly Nseik', 'Jones', 'Matthew', 36)
# ('Boot On The Seat', 'Jones', 'Matthew', 36)
# ('FaFaFa (Radio Edit)', 'Jones', 'Matthew', 36)
# ('Human After All', 'Jones', 'Matthew', 36)
# ('Somebody To Love', 'Jones', 'Matthew', 36)
# ('Real Love', 'Jones', 'Matthew', 36)
# ('Subterranean Homesick Blues (Album Version)', 'Jones', 'Matthew', 36)
# ("Can't Break Thru", 'Jones', 'Matthew', 36)
# ('Get Me Bodied', 'Rosales', 'Austin', 12)
# ('Maybe', 'Cuevas', 'Chloe', 49)
# ('Walk To The Water', 'Cuevas', 'Chloe', 49)
# ("I CAN'T GET STARTED", 'Cuevas', 'Chloe', 49)
# ('Breath After Breath', 'Cuevas', 'Chloe', 49)
# ('Head Over Heels', 'Cuevas', 'Chloe', 49)
# ('Lonely As You', 'Cuevas', 'Chloe', 49)
# ('One Year_ Six Months', 'Gonzalez', 'Samuel', 61)
# ('Against The Wall', 'Cuevas', 'Chloe', 49)
# ('Knocking On Forbidden Doors', 'Cuevas', 'Chloe', 49)
# ('Hey Hey', 'Cuevas', 'Chloe', 49)
# ('Somebody To Love', 'Cuevas', 'Chloe', 49)
# ('Genom tunna tyger', 'Cuevas', 'Chloe', 49)
# ('The Little Things Give You Away [Live At Milton Keynes]', 'Cuevas', 'Chloe', 49)
# ('Devil May Care', 'Miles', 'Jahiem', 43)
# ("Tell Me I'm A Wreck", 'Cuevas', 'Chloe', 49)
# ('Constellations', 'Cuevas', 'Chloe', 49)
# ('Vuelve', 'Cuevas', 'Chloe', 49)
# ('Give Me Anything', 'Cuevas', 'Chloe', 49)
# ('Worm Infested', 'Cuevas', 'Chloe', 49)
# ('Headlights Look Like Diamonds', 'Young', 'Kinsley', 85)
# ('Hands Up', 'Cuevas', 'Chloe', 49)
# ('Sweet And Wild', 'Young', 'Kinsley', 85)
# ('Satellite Mind', 'Cuevas', 'Chloe', 49)
# ("You're The One", 'Cuevas', 'Chloe', 49)
# ('Did You Get My Message? (Live From Montalvo)', 'Young', 'Kinsley', 85)
# ('N A Whitemanzeyez', 'Cuevas', 'Chloe', 49)
# ('Karma Police', 'Young', 'Kinsley', 85)
# ('Puto', 'Robinson', 'Ava', 50)
# ('Killing Lies', 'Robinson', 'Ava', 50)
# ('Hallelujah', 'Smith', 'Ryan', 26)
# ("Ghosts 'n' Stuff (Original Instrumental Mix)", 'Young', 'Kinsley', 85)
# ("You're The Voice", 'Cuevas', 'Chloe', 49)
# ('Inside Of You', 'Robinson', 'Ava', 50)
# ('Clean Up Woman (Single/LP Version)', 'Smith', 'Ryan', 26)
# ('Tranen Gelachen', 'Cuevas', 'Chloe', 49)
# ('The Small Print', 'Young', 'Kinsley', 85)
# ('A QuÃ\x83Â© Niegas El Delirio (MalagueÃ\x83Â±a) (Live)', 'Cuevas', 'Chloe', 49)
# ("It's My Life (Radio Edit)", 'Young', 'Kinsley', 85)
# ('Sit Down. Stand Up', 'Cuevas', 'Chloe', 49)
# ('Purple Weed', 'Young', 'Kinsley', 85)
# ("Someone Else's Arms", 'Cuevas', 'Chloe', 49)
# ("The Future Ain't What It Used To Be", 'Young', 'Kinsley', 85)
# ('A-Punk (Album)', 'Cuevas', 'Chloe', 49)
# ('Time To Pretend', 'Cuevas', 'Chloe', 49)
# ('Luna y Sol', 'Young', 'Kinsley', 85)
# ('Touch My Horn', 'Cuevas', 'Chloe', 49)
# ('Eternity', 'Young', 'Kinsley', 85)
# ('Dyed in the Wool (Album Version)', 'Cuevas', 'Chloe', 49)
# ('Wretchrospective (feat. Vis)', 'Fox', 'Jayden', 101)
# ('Simple', 'Young', 'Kinsley', 85)
# ('Riecht wie Teen Spirit (Smells Like Teen Spirit)', 'Fox', 'Jayden', 101)
# ('Adrenalin', 'Cuevas', 'Chloe', 49)
# ('Bread & Water', 'George', 'Rylan', 16)
# ('VooDoo', 'Young', 'Kinsley', 85)
# ('Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)', 'Cuevas', 'Chloe', 49)
# ("Frankie's Office", 'Fox', 'Jayden', 101)
# ('Fireflies', 'Fox', 'Jayden', 101)
# ('Summer Breeze', 'George', 'Rylan', 16)
# ('Love Shack', 'Young', 'Kinsley', 85)
# ('Alexandra', 'Fox', 'Jayden', 101)
# ('Canada', 'George', 'Rylan', 16)
# ('Anthem For The Underdog', 'Fox', 'Jayden', 101)
# ('Revelry', 'Young', 'Kinsley', 85)
# ('Get Ready To Bounce Recall 08', 'George', 'Rylan', 16)
# ('The Good Fight', 'Young', 'Kinsley', 85)
# ('Low Land Moan', 'Young', 'Kinsley', 85)
# ('In', 'Rodriguez', 'Mohammad', 88)
# ('Sway', 'George', 'Rylan', 16)
# ('I Miss You Now', 'Young', 'Kinsley', 85)
# ('Masculine Eclipse', 'George', 'Rylan', 16)
# ('As If Set Afire', 'Rodriguez', 'Mohammad', 88)
# ('Underwater World', 'Young', 'Kinsley', 85)
# ('Our Last Time', 'George', 'Rylan', 16)
# ('T.N.T. For The Brain (112 Bpm) (Radio Edit)', 'Rodriguez', 'Mohammad', 88)
# ('Tattered Banners And Bloody Flags', 'Young', 'Kinsley', 85)
# ('The Great Escape (Album Version) (Explicit)', 'George', 'Rylan', 16)
# ('Lacreme napulitane', 'Jones', 'Matthew', 36)
# ('Autobiography', 'Rodriguez', 'Mohammad', 88)
# ('The Ecstasy Of Gold', 'Young', 'Kinsley', 85)
# ('Kryptonite', 'George', 'Rylan', 16)
# ('No Fool (For Love)', 'Jones', 'Matthew', 36)
# ('Pray', 'Young', 'Kinsley', 85)
# ('Bubble Toes', 'George', 'Rylan', 16)
# ('Lotus', 'Young', 'Kinsley', 85)
# ('You Belong With Me', 'Jones', 'Matthew', 36)
# ('Candy Rain', 'George', 'Rylan', 16)
# ('Firestarter', 'Young', 'Kinsley', 85)
# ('Addicted', 'Jones', 'Matthew', 36)
# ('The Evil That Men Do (1998 Digital Remaster)', 'George', 'Rylan', 16)
# ('All Around Me', 'Young', 'Kinsley', 85)
# ('Everyday', 'George', 'Rylan', 16)
# ('Feel It', 'Young', 'Kinsley', 85)
# ('Overload', 'Young', 'Kinsley', 85)
# ('Hold You', 'George', 'Rylan', 16)
# ('The Way She Moves', 'George', 'Rylan', 16)
# ('I Want Your Love', 'George', 'Rylan', 16)
# ('Corrido de Boxeo', 'Cuevas', 'Chloe', 49)
# ('When I Grow Up', 'George', 'Rylan', 16)
# ('Yellow', 'Cuevas', 'Chloe', 49)
# ('She Likes (Bittersweet Love)', 'George', 'Rylan', 16)
# ('Believe That', 'Cuevas', 'Chloe', 49)
# ('Through The Fire And Flames (Album Version)', 'George', 'Rylan', 16)
# ('Lucky (Album Version)', 'Cuevas', 'Chloe', 49)
# ('Is She Weird', 'Cuevas', 'Chloe', 49)
# ('Without Me', 'George', 'Rylan', 16)
# ('Cry No More', 'Cuevas', 'Chloe', 49)
# ('Lotus', 'George', 'Rylan', 16)
# ('Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)', 'Cuevas', 'Chloe', 49)
# ('Le Million', 'George', 'Rylan', 16)
# ('Only Superstition', 'Cuevas', 'Chloe', 49)
# ('Bedroom Suite', 'Roth', 'Chloe', 78)
# ('A New Arrangement', 'George', 'Rylan', 16)
# ('The Only Exception (Album Version)', 'Roth', 'Chloe', 78)
# ('Sinisten tÃ\x83Â¤htien alla', 'Cuevas', 'Chloe', 49)
# ('Knee 2', 'George', 'Rylan', 16)
# ('SinceritÃ\x83Â© Et Jalousie', 'Cuevas', 'Chloe', 49)
# ('Her Voice Is Beyond Her Years', 'George', 'Rylan', 16)
# ('If You Leave Me Now', 'George', 'Rylan', 16)
# ('SinceritÃ\x83Â© Et Jalousie', 'Harris', 'Bronson', 33)
# ('Diamond Dave', 'George', 'Rylan', 16)
# ('1999', 'Harris', 'Bronson', 33)
# ('King Of Pain (Live/Unplugged Version)', 'George', 'Rylan', 16)
# ('Rebirthing (Album Version)', 'Harris', 'Bronson', 33)
# ('Beauty and the Beast', 'George', 'Rylan', 16)
# ('Dressed For Friend Requests (Album Version)', 'George', 'Rylan', 16)
# ("You're The One", 'George', 'Rylan', 16)
# ("Tuesday's Child", 'George', 'Rylan', 16)
# ('All The Right Moves', 'George', 'Rylan', 16)
# ('Wicked', 'George', 'Rylan', 16)
# ('My Distressor 40Khz ReRub Mix', 'George', 'Rylan', 16)
# ('Six Days At The Bottom Of The Ocean', 'George', 'Rylan', 16)
# ('Little Bird', 'Cuevas', 'Chloe', 49)
# ('The Horizon Has Been Defeated', 'Cuevas', 'Chloe', 49)
# ('Everything In Its Right Place', 'George', 'Rylan', 16)
# ('Heretics', 'Cuevas', 'Chloe', 49)
# ('Sabbra Cadabra', 'George', 'Rylan', 16)
# ('Catch You Baby (Steve Pitron & Max Sanna Radio Edit)', 'Cuevas', 'Chloe', 49)
# ('Shattered', 'Cuevas', 'Chloe', 49)
# ('As The Rhyme Goes On', 'George', 'Rylan', 16)
# ('Settle For A Slowdown', 'Cuevas', 'Chloe', 49)
# ('Daniel Cowman', 'George', 'Rylan', 16)
# ('Make You Sin', 'Cuevas', 'Chloe', 49)
# ('Roc U', 'Cuevas', 'Chloe', 49)
# ('Sexy Bitch', 'George', 'Rylan', 16)
# ('Sayonara-Nostalgia', 'George', 'Rylan', 16)
# ('In The Hands Of The Gods (Featuring Biz Markie)', 'Cuevas', 'Chloe', 49)
# ("Don't Forget To Breathe", 'Cuevas', 'Chloe', 49)
# ("Now You're Gone", 'George', 'Rylan', 16)
# ('Undo', 'Cuevas', 'Chloe', 49)
# ('G4L', 'George', 'Rylan', 16)
# ('Hello', 'George', 'Rylan', 16)
# ('Tamale', 'Cuevas', 'Chloe', 49)
# ('Another Place', 'George', 'Rylan', 16)
# ('Straight To Hell', 'Cuevas', 'Chloe', 49)
# ('Cry Me A River', 'Cuevas', 'Chloe', 49)
# ('Un Camino Hasta Vos', 'George', 'Rylan', 16)
# ('Sura (2008 Digital Remaster)', 'Cuevas', 'Chloe', 49)
# ('Pursuit Of Happiness (nightmare)', 'George', 'Rylan', 16)
# ('Forever', 'Cuevas', 'Chloe', 49)
# ('Homesick [Acoustic]', 'George', 'Rylan', 16)
# ('Dead And Gone [feat. Justin Timberlake] (Explicit Album Version)', 'Bell', 'Jayden', 91)
# ("It'll Be a Long Time (Album Version)", 'George', 'Rylan', 16)
# ('Esta Es Para Hacerte FÃ\x83Â©liz', 'Cuevas', 'Chloe', 49)
# ('Spin Spin Sugar', 'Bell', 'Jayden', 91)
# ('This War Is Ours (The Guillotine II)', 'George', 'Rylan', 16)
# ('La Vida Es Un Ratico', 'Cuevas', 'Chloe', 49)
# ('Never Mind', 'George', 'Rylan', 16)
# ('Possession', 'Cuevas', 'Chloe', 49)
# ("Don't Start Me Talkin'", 'George', 'Rylan', 16)
# ('Back To Life (However Do You Want Me) (2003 Digital Remaster) (Feat. Caron Wheeler)', 'George', 'Rylan', 16)
# ('Dog Days Are Over (Radio Edit)', 'Cuevas', 'Chloe', 49)
# ('Heresy  (LP Version)', 'George', 'Rylan', 16)
# ('Remedy', 'Cuevas', 'Chloe', 49)
# ('Frozen Angel', 'Cuevas', 'Chloe', 49)
# ('The Pretender', 'George', 'Rylan', 16)
# ('Besos De Ceniza', 'George', 'Rylan', 16)
# ('Rose', 'George', 'Rylan', 16)
# ('The Haunting', 'George', 'Rylan', 16)
# ('Anything You Say (Unreleased Version)', 'Davis', 'Elijah', 5)

# %%
## TO-DO: Add in the SELECT statement to verify the data was entered into the table
## Confirm query 3 user output with song = "All Hands Against His Own'"
query = """
SELECT firstName, lastName
FROM user_by_song
WHERE song = 'All Hands Against His Own'
"""
query = session.execute(query)
print(query)
for row in query:
    print(row)
# Out:
# <cassandra.cluster.ResultSet object at 0x7fa1b193d070>
# Row(firstname='Lynch', lastname='Jacqueline')
# Row(firstname='Levine', lastname='Tegan')
# Row(firstname='Johnson', lastname='Sara')

# %% [markdown]
# ### Drop the tables before closing out the sessions

# %%
## TO-DO: Drop the table before closing out the sessions

# %% [markdown]
# ### Close the session and cluster connection¶

# %%
session.shutdown()
cluster.shutdown()
