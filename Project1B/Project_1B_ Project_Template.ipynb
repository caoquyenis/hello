# %% [markdown]
# # Part I. ETL Pipeline for Pre-Processing the Files

# %%
# Import Python packages 
import pandas as pd
import cassandra
import re
import os
import glob
import numpy as np
import json
import csv

# %% [markdown]
# ## PLEASE RUN THE FOLLOWING CODE FOR PRE-PROCESSING THE FILES

# %% [markdown]
# #### Import Python packages

# %% [markdown]
# # Import Python packages
# import pandas as pd
# import cassandra
# import re
# import os
# import glob
# import numpy as np
# import json
# import csv

# %% [markdown]
# #### Creating list of filepaths to process original event csv data files

# %%
# checking your current working directory
print(os.getcwd())

# Get your current folder and subfolder event data
filepath = os.getcwd() + '/event_data'

# Create a for loop to create a list of files and collect each filepath
for root, dirs, files in os.walk(filepath):
    
# join the file path and roots with the subdirectories using glob
    file_path_list = glob.glob(os.path.join(root,'*'))
    #print(file_path_list)
# Out:
# /Users/genie/project1b

# %% [markdown]
# #### Processing the files to create the data file csv that will be used for Apache Casssandra tables

# %%
# initiating an empty list of rows that will be generated from each file
full_data_rows_list = [] 
    
# for every filepath in the file path list 
for f in file_path_list:

# reading csv file 
    with open(f, 'r', encoding = 'utf8', newline='') as csvfile: 
        # creating a csv reader object 
        csvreader = csv.reader(csvfile) 
        next(csvreader)
        
 # extracting each data row one by one and append it        
        for line in csvreader:
            #print(line)
            full_data_rows_list.append(line) 
            
# uncomment the code below if you would like to get total number of rows 
#print(len(full_data_rows_list))
# uncomment the code below if you would like to check to see what the list of event data rows will look like
#print(full_data_rows_list)

# creating a smaller event data csv file called event_datafile_full csv that will be used to insert data into the \
# Apache Cassandra tables
csv.register_dialect('myDialect', quoting=csv.QUOTE_ALL, skipinitialspace=True)

with open('event_datafile_new.csv', 'w', encoding = 'utf8', newline='') as f:
    writer = csv.writer(f, dialect='myDialect')
    writer.writerow(['artist','firstName','gender','itemInSession','lastName','length',\
                'level','location','sessionId','song','userId'])
    for row in full_data_rows_list:
        if (row[0] == ''):
            continue
        writer.writerow((row[0], row[2], row[3], row[4], row[5], row[6], row[7], row[8], row[12], row[13], row[16]))

# %%
# check the number of rows in your csv file
with open('event_datafile_new.csv', 'r', encoding = 'utf8') as f:
    print(sum(1 for line in f))
# Out:
# 6821

# %% [markdown]
# # Part II. Complete the Apache Cassandra coding portion of your project.
#
# ## Now you are ready to work with the CSV file titled <font color=red>event_datafile_new.csv</font>, located within the Workspace directory.  The event_datafile_new.csv contains the following columns:
# - artist
# - firstName of user
# - gender of user
# - item number in session
# - last name of user
# - length of the song
# - level (paid or free song)
# - location of the user
# - sessionId
# - song title
# - userId
#
# The image below is a screenshot of what the denormalized data should appear like in the <font color=red>**event_datafile_new.csv**</font> after the code above is run:<br>
#
# <img src="images/image_event_datafile_new.jpg">

# %% [markdown]
# ## Begin writing your Apache Cassandra code in the cells below

# %% [markdown]
# #### Creating a Cluster

# %%
# This should make a connection to a Cassandra instance your local machine 
# (127.0.0.1)

from cassandra.cluster import Cluster
cluster = Cluster()

# To establish connection and begin executing queries, need a session
session = cluster.connect()

# %% [markdown]
# #### Create Keyspace

# %%
# TO-DO: Create a Keyspace 
try:
    session.execute (
        """CREATE KEYSPACE IF NOT EXISTS udacity
        WITH REPLICATION = {
            'class' : 'SimpleStrategy', 'replication_factor' : 1
        }
        """
    )
except Exception as e:
    print(e)

# %% [markdown]
# #### Set Keyspace

# %%
# TO-DO: Set KEYSPACE to the keyspace specified above
try:
    session.set_keyspace ('udacity')
except Exception as e:
    print(e)

# %% [markdown]
# ## Create queries to ask the following three questions of the data
#
# ### 1. Give me the artist, song title and song's length in the music app history that was heard during  sessionId = 338, and itemInSession  = 4
#
#
# ### 2. Give me only the following: name of artist, song (sorted by itemInSession) and user (first and last name) for userid = 10, sessionid = 182
#
#
# ### 3. Give me every user name (first and last) in my music app history who listened to the song 'All Hands Against His Own'

# %% [markdown]
# ### Now we need to create tables to run the following queries. Remember, with Apache Cassandra you model the database tables on the queries you want to run.

# %%
query = "drop TABLE IF EXISTS music_by_sessionid_iteminsession "
session.execute(query)

# %%
## TO-DO: Query 1:  Give me the artist, song title and song's length in the music app history that was heard during \
## sessionId = 338, and itemInSession = 4
query = "CREATE TABLE IF NOT EXISTS music_by_sessionid_iteminsession "
query = query + """(
sessionId int, itemInsession int, artist text, song text, length float, 
PRIMARY KEY(sessionId, itemInSession))
"""
try:
    session.execute(query)
except Exception as e:
    print(e)

# %%
## TO-DO: Assign the INSERT statements into the `query` variable
# Insert data into table for query 1
file = 'event_datafile_new.csv'
with open(file, encoding = 'utf8') as f:
    csvreader = csv.reader(f)
    next(csvreader)
    for line in csvreader:
        query = "INSERT INTO music_by_sessionid_iteminsession (sessionId, itemInSession, artist, song, length)"
        query = query + "VALUES (%s, %s, %s, %s, %s)"
        print(line[8])
        print((line[0], line[1], line[2], line[3], line[4],float(line[5]),line[6],line[7],line[8],line[9],line[10]))
        ## TO-DO: Assign which column element should be assigned for each column in the INSERT statement.
        ## For e.g., to INSERT artist_name and user first_name, you would change the code below to `line[0], line[1]`
        session.execute(query, (int(line[8]), int(line[3]), line[0], line[9], float(line[5])))
# Out:
# 583
# ('Harmonia', 'Ryan', 'M', '0', 'Smith', 655.77751, 'free', 'San Jose-Sunnyvale-Santa Clara, CA', '583', 'Sehr kosmisch', '26')
# 583
# ('The Prodigy', 'Ryan', 'M', '1', 'Smith', 260.07465, 'free', 'San Jose-Sunnyvale-Santa Clara, CA', '583', 'The Big Gundown', '26')
# 583
# ('Train', 'Ryan', 'M', '2', 'Smith', 205.45261, 'free', 'San Jose-Sunnyvale-Santa Clara, CA', '583', 'Marry Me', '26')
# 597
# ('Sony Wonder', 'Samuel', 'M', '0', 'Gonzalez', 218.06975, 'free', 'Houston-The Woodlands-Sugar Land, TX', '597', 'Blackbird', '61')
# 602
# ('Van Halen', 'Tegan', 'F', '2', 'Levine', 289.38404, 'paid', 'Portland-South Portland, ME', '602', 'Best Of Both Worlds (Remastered Album Version)', '80')
# 602
# ('Magic Sam', 'Tegan', 'F', '3', 'Levine', 132.04853, 'paid', 'Portland-South Portland, ME', '602', 'Call Me If You Need Me', '80')
# 602
# ('Edward Sharpe & The Magnetic Zeros', 'Tegan', 'F', '4', 'Levine', 306.31138, 'paid', 'Portland-South Portland, ME', '602', 'Home', '80')
# 602
# ('Usher featuring will.i.am', 'Tegan', 'F', '5', 'Levine', 395.72853, 'paid', 'Portland-South Portland, ME', '602', 'OMG', '80')
# 602
# ('Helen Reddy', 'Tegan', 'F', '7', 'Levine', 176.50893, 'paid', 'Portland-South Portland, ME', '602', 'Candle On The Water', '80')
# 602
# ('Taylor Swift', 'Tegan', 'F', '8', 'Levine', 201.06404, 'paid', 'Portland-South Portland, ME', '602', 'Our Song', '80')
# 602
# ('Sean Paul', 'Tegan', 'F', '9', 'Levine', 245.34159, 'paid', 'Portland-South Portland, ME', '602', 'Baby Boy [feat. Beyonce]', '80')
# 582
# ('Soundgarden', 'Lily', 'F', '0', 'Koch', 272.19546, 'paid', 'Chicago-Naperville-Elgin, IL-IN-WI', '582', 'Black Hole Sun', '15')
# 602
# ('The Killers', 'Tegan', 'F', '10', 'Levine', 360.75057, 'paid', 'Portland-South Portland, ME', '602', 'Human', '80')
# 582
# ('Amy Winehouse', 'Lily', 'F', '1', 'Koch', 165.11955, 'paid', 'Chicago-Naperville-Elgin, IL-IN-WI', '582', 'Addicted', '15')
# 582
# ('Steve Anderson', 'Lily', 'F', '2', 'Koch', 265.06404, 'paid', 'Chicago-Naperville-Elgin, IL-IN-WI', '582', 'Air', '15')
# 582
# ('Rob Zombie', 'Lily', 'F', '3', 'Koch', 220.13342, 'paid', 'Chicago-Naperville-Elgin, IL-IN-WI', '582', 'Superbeast', '15')
# 582
# ('Deadmau5 & Kaskade', 'Lily', 'F', '4', 'Koch', 595.56526, 'paid', 'Chicago-Naperville-Elgin, IL-IN-WI', '582', 'I Remember', '15')
# 607
# ('Shania Twain', 'Ryan', 'M', '0', 'Smith', 213.7073, 'free', 'San Jose-Sunnyvale-Santa Clara, CA', '607', "Don't Be Stupid (You Know I Love You)", '26')
# 607
# ('Los Campesinos', 'Ryan', 'M', '1', 'Smith', 138.10893, 'free', 'San Jose-Sunnyvale-Santa Clara, CA', '607', 'We throw parties_ you throw knives', '26')
# 606
# ('Ill Nino', 'Chloe', 'F', '1', 'Cuevas', 188.9171, 'paid', 'San Francisco-Oakland-Hayward, CA', '606', 'How Can I Live (Spanish version) (Album Version)', '49')
# 606
# ('Mia X', 'Chloe', 'F', '2', 'Cuevas', 236.09424, 'paid', 'San Francisco-Oakland-Hayward, CA', '606', 'Thugs Like Me', '49')
# 606
# ('Rage Against The Machine', 'Chloe', 'F', '3', 'Cuevas', 314.40934, 'paid', 'San Francisco-Oakland-Hayward, CA', '606', 'Killing In The Name', '49')
# 606
# ('Asia 2001', 'Chloe', 'F', '4', 'Cuevas', 150.30812, 'paid', 'San Francisco-Oakland-Hayward, CA', '606', 'Epilogue', '49')
# 606
# ('Muse', 'Chloe', 'F', '5', 'Cuevas', 228.93669, 'paid', 'San Francisco-Oakland-Hayward, CA', '606', 'Endlessly', '49')
# 606
# ('Rise Against', 'Chloe', 'F', '6', 'Cuevas', 221.17832, 'paid', 'San Francisco-Oakland-Hayward, CA', '606', 'Torches', '49')
# 591
# ('Modest Mouse', 'Mohammad', 'M', '3', 'Rodriguez', 259.47383, 'free', 'Sacramento--Roseville--Arden-Arcade, CA', '591', 'The Good Times Are Killing Me', '88')
# 606
# ('Marc Anthony', 'Chloe', 'F', '7', 'Cuevas', 314.43546, 'paid', 'San Francisco-Oakland-Hayward, CA', '606', 'Te Conozco Bien', '49')
# 606
# ('Regina Spektor', 'Chloe', 'F', '8', 'Cuevas', 191.08526, 'paid', 'San Francisco-Oakland-Hayward, CA', '606', 'The Calculation (Album Version)', '49')
# 611
# ('Nina Sky', 'Tegan', 'F', '0', 'Levine', 101.92934, 'paid', 'Portland-South Portland, ME', '611', 'Goodbye (Interlude)', '80')
# 324
# ('Five Iron Frenzy', 'Avery', 'F', '0', 'Watkins', 236.09424, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Canada', '30')
# 324
# ('Kudai', 'Avery', 'F', '2', 'Watkins', 256.62649, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Ven', '30')
# 324
# ('Pulp', 'Avery', 'F', '3', 'Watkins', 260.8322, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Do You Remember The First Time?', '30')
# 324
# ("SinÃ\x83Â©ad O'Connor", 'Avery', 'F', '4', 'Watkins', 282.51383, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'I Want Your (Hands On Me)', '30')
# 611
# ('Paul Brown', 'Tegan', 'F', '3', 'Levine', 232.54159, 'paid', 'Portland-South Portland, ME', '611', 'Chill Out', '80')
# 324
# ('Lasgo', 'Avery', 'F', '5', 'Watkins', 220.13342, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Something (Radio Edit)', '30')
# 611
# ('Patty Loveless', 'Tegan', 'F', '4', 'Levine', 188.13342, 'paid', 'Portland-South Portland, ME', '611', "What's A Broken Heart", '80')
# 324
# ('Eddie Vedder', 'Avery', 'F', '6', 'Watkins', 236.30322, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Society', '30')
# 611
# ('Rogue Wave', 'Tegan', 'F', '5', 'Levine', 234.13506, 'paid', 'Portland-South Portland, ME', '611', 'Christians In Black', '80')
# 324
# ('Muse', 'Avery', 'F', '7', 'Watkins', 304.84853, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Uprising', '30')
# 611
# ('Amanda Blank', 'Tegan', 'F', '6', 'Levine', 175.09832, 'paid', 'Portland-South Portland, ME', '611', 'Might Like You Better', '80')
# 324
# ('The Smiths', 'Avery', 'F', '8', 'Watkins', 162.24608, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Sheila Take A Bow', '30')
# 611
# ("Old 97's", 'Tegan', 'F', '7', 'Levine', 231.28771, 'paid', 'Portland-South Portland, ME', '611', 'Victoria (LP Version)', '80')
# 324
# ('Selena', 'Avery', 'F', '9', 'Watkins', 316.42077, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Dreaming Of You', '30')
# 611
# ('Fat Joe', 'Tegan', 'F', '8', 'Levine', 267.10159, 'paid', 'Portland-South Portland, ME', '611', "What's Luv? (Featuring Ja-Rule & Ashanti) (Explicit Album Version)", '80')
# 324
# ('Stars', 'Avery', 'F', '10', 'Watkins', 193.33179, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Soft Revolution', '30')
# 611
# ('James Blunt', 'Tegan', 'F', '9', 'Levine', 298.4224, 'paid', 'Portland-South Portland, ME', '611', 'Same Mistake  (Album Version)', '80')
# 324
# ('Mayday Parade', 'Avery', 'F', '11', 'Watkins', 203.28444, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Bruised And Scarred (Album Version)', '30')
# 611
# ('Die Mooskirchner', 'Tegan', 'F', '10', 'Levine', 169.29914, 'paid', 'Portland-South Portland, ME', '611', "Frisch und g'sund", '80')
# 324
# ('Gorillaz', 'Avery', 'F', '12', 'Watkins', 211.77424, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Rockit', '30')
# 611
# ('Toby Keith', 'Tegan', 'F', '12', 'Levine', 208.48281, 'paid', 'Portland-South Portland, ME', '611', "Should've Been A Cowboy", '80')
# 324
# ('Modest Mouse', 'Avery', 'F', '13', 'Watkins', 284.18567, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Little Motel', '30')
# 611
# ('Future Rock', 'Tegan', 'F', '13', 'Levine', 239.90812, 'paid', 'Portland-South Portland, ME', '611', 'Gears', '80')
# 324
# ('Noel Pointer', 'Avery', 'F', '14', 'Watkins', 259.7873, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Superwoman (Where Were You When I Needed You) (Digitally Remastered)', '30')
# 611
# ('Callenish Circle', 'Tegan', 'F', '14', 'Levine', 226.11546, 'paid', 'Portland-South Portland, ME', '611', 'Forgotten', '80')
# 575
# ('Foo Fighters', 'Rylan', 'M', '0', 'George', 250.14812, 'paid', 'Birmingham-Hoover, AL', '575', 'Everlong', '16')
# 324
# ('Portishead', 'Avery', 'F', '15', 'Watkins', 238.73261, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Hunter', '30')
# 611
# ('Taylor Swift', 'Tegan', 'F', '15', 'Levine', 245.36771, 'paid', 'Portland-South Portland, ME', '611', 'The Way I Loved You', '80')
# 575
# ('J-Live', 'Rylan', 'M', '1', 'George', 256.93995, 'paid', 'Birmingham-Hoover, AL', '575', 'Longevity', '16')
# 324
# ('The White Stripes', 'Avery', 'F', '16', 'Watkins', 110.47138, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Fell In Love With A Girl', '30')
# 611
# ('Dwight Yoakam', 'Tegan', 'F', '16', 'Levine', 239.3073, 'paid', 'Portland-South Portland, ME', '611', "You're The One", '80')
# 324
# ('The Black Keys', 'Avery', 'F', '17', 'Watkins', 238.99383, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Lies', '30')
# 575
# ('Five', 'Rylan', 'M', '2', 'George', 207.62077, 'paid', 'Birmingham-Hoover, AL', '575', "Got The Feelin'", '16')
# 611
# ('Ra', 'Tegan', 'F', '17', 'Levine', 319.9473, 'paid', 'Portland-South Portland, ME', '611', 'Do You Call My Name', '80')
# 575
# ('Coolio feat. L.V.', 'Rylan', 'M', '4', 'George', 241.57995, 'paid', 'Birmingham-Hoover, AL', '575', "Gangsta's Paradise (LP Version)", '16')
# 324
# ('Paramore', 'Avery', 'F', '18', 'Watkins', 211.51302, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Misery Business (Album Version)', '30')
# 324
# ('Leggo Beast', 'Avery', 'F', '19', 'Watkins', 321.93261, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Itchy Feet', '30')
# 575
# ('Nneka', 'Rylan', 'M', '5', 'George', 226.79465, 'paid', 'Birmingham-Hoover, AL', '575', 'Gypsy', '16')
# 611
# ("Diam's", 'Tegan', 'F', '18', 'Levine', 250.72281, 'paid', 'Portland-South Portland, ME', '611', 'Dans Ma Bulle (Edit Radio - Live 2006)', '80')
# 575
# ('Haley Bonar', 'Rylan', 'M', '6', 'George', 149.26322, 'paid', 'Birmingham-Hoover, AL', '575', 'Give It Up', '16')
# 611
# ('Mansun', 'Tegan', 'F', '19', 'Levine', 140.53832, 'paid', 'Portland-South Portland, ME', '611', 'Love Remains (Home Demo)', '80')
# 324
# ('3 Doors Down', 'Avery', 'F', '20', 'Watkins', 237.13914, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Here Without You', '30')
# 575
# ('The Corrs', 'Rylan', 'M', '7', 'George', 168.07138, 'paid', 'Birmingham-Hoover, AL', '575', 'Toss The Feathers (Instrumental) ( LP Version )', '16')
# 611
# ('Big Tymers', 'Tegan', 'F', '20', 'Levine', 197.79873, 'paid', 'Portland-South Portland, ME', '611', 'Big', '80')
# 324
# ('Thursday', 'Avery', 'F', '21', 'Watkins', 215.37914, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'I Am The Killer (Album Version)', '30')
# 575
# ('Motion City Soundtrack', 'Rylan', 'M', '8', 'George', 111.49016, 'paid', 'Birmingham-Hoover, AL', '575', "Don't Call It A Comeback (Album Version)", '16')
# 611
# ('Usher', 'Tegan', 'F', '21', 'Levine', 224.10404, 'paid', 'Portland-South Portland, ME', '611', "Hey Daddy (Daddy's Home)", '80')
# 575
# ('Juanes', 'Rylan', 'M', '10', 'George', 233.40363, 'paid', 'Birmingham-Hoover, AL', '575', 'No Siento Penas', '16')
# 324
# ('The Wombats', 'Avery', 'F', '22', 'Watkins', 164.70159, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Kill The Director [Radio Edit]', '30')
# 611
# ('Katy Perry', 'Tegan', 'F', '22', 'Levine', 179.40853, 'paid', 'Portland-South Portland, ME', '611', 'I Kissed A Girl', '80')
# 575
# ('As I Lay Dying', 'Rylan', 'M', '11', 'George', 231.78404, 'paid', 'Birmingham-Hoover, AL', '575', 'The Darkest Nights', '16')
# 324
# ('BjÃ\x83Â¶rk', 'Avery', 'F', '23', 'Watkins', 348.57751, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Undo', '30')
# 611
# ('The Bobby Fuller Four', 'Tegan', 'F', '23', 'Levine', 138.60526, 'paid', 'Portland-South Portland, ME', '611', 'I Fought The Law (LP Version)', '80')
# 575
# ('Charly GarcÃ\x83Â\xada', 'Rylan', 'M', '12', 'George', 330.89261, 'paid', 'Birmingham-Hoover, AL', '575', 'Influencia', '16')
# 611
# ('New Bomb Turks', 'Tegan', 'F', '24', 'Levine', 60.55138, 'paid', 'Portland-South Portland, ME', '611', 'Too Much', '80')
# 611
# ('The Black Keys', 'Tegan', 'F', '25', 'Levine', 196.91057, 'paid', 'Portland-South Portland, ME', '611', 'All Hands Against His Own', '80')
# 324
# ('PeterLicht', 'Avery', 'F', '24', 'Watkins', 305.97179, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Blaues Blau', '30')
# 611
# ('John Mayer', 'Tegan', 'F', '26', 'Levine', 359.23546, 'paid', 'Portland-South Portland, ME', '611', 'Friends_ Lovers Or Nothing', '80')
# 575
# ('Stone Temple Pilots', 'Rylan', 'M', '13', 'George', 255.32036, 'paid', 'Birmingham-Hoover, AL', '575', 'A Song For Sleeping (LP Version)', '16')
# 324
# ('Bad Lieutenant', 'Avery', 'F', '25', 'Watkins', 266.84036, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Head Into Tomorrow', '30')
# 575
# ('Lily Allen', 'Rylan', 'M', '14', 'George', 192.49587, 'paid', 'Birmingham-Hoover, AL', '575', 'Smile Version Revisited (Mark Ronson Remix) (Explicit)', '16')
# 611
# ('Neil Halstead', 'Tegan', 'F', '27', 'Levine', 294.29506, 'paid', 'Portland-South Portland, ME', '611', 'A Gentle Heart', '80')
# 324
# ('Juanes', 'Avery', 'F', '26', 'Watkins', 222.37995, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Un DÃ\x83Â\xada Normal', '30')
# 575
# ('Distance', 'Rylan', 'M', '15', 'George', 300.87791, 'paid', 'Birmingham-Hoover, AL', '575', 'Ska', '16')
# 324
# ('Slipknot', 'Avery', 'F', '27', 'Watkins', 253.98812, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'The Heretic Anthem (Album Version)', '30')
# 611
# ('Franz Ferdinand', 'Tegan', 'F', '28', 'Levine', 137.56036, 'paid', 'Portland-South Portland, ME', '611', 'Tell Her Tonight', '80')
# 575
# ('Jedi Mind Tricks', 'Rylan', 'M', '16', 'George', 232.88118, 'paid', 'Birmingham-Hoover, AL', '575', 'Suicide', '16')
# 611
# ('Miles Davis', 'Tegan', 'F', '29', 'Levine', 285.20444, 'paid', 'Portland-South Portland, ME', '611', 'Stella By Starlight', '80')
# 324
# ('B.o.B', 'Avery', 'F', '28', 'Watkins', 269.63546, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', "Nothin' On You [feat. Bruno Mars] (Album Version)", '30')
# 575
# ('The Avett Brothers', 'Rylan', 'M', '17', 'George', 300.85179, 'paid', 'Birmingham-Hoover, AL', '575', 'I And Love And You', '16')
# 611
# ('Joshua Bell / Paul Coker', 'Tegan', 'F', '30', 'Levine', 275.93098, 'paid', 'Portland-South Portland, ME', '611', 'Caprice viennois op.2', '80')
# 324
# ('Bad Brains', 'Avery', 'F', '29', 'Watkins', 32.31302, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', "Joshua's Song (1991 Digital Remaster)", '30')
# 324
# ('Shakira ft. Wyclef Jean', 'Avery', 'F', '30', 'Watkins', 215.90159, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', "Hips Don't Lie", '30')
# 575
# ('Band Of Horses', 'Rylan', 'M', '18', 'George', 321.14893, 'paid', 'Birmingham-Hoover, AL', '575', 'The Funeral (Album Version)', '16')
# 611
# ('Alesana', 'Tegan', 'F', '31', 'Levine', 185.33832, 'paid', 'Portland-South Portland, ME', '611', 'Ambrosia', '80')
# 324
# ('Samy Deluxe', 'Avery', 'F', '31', 'Watkins', 236.77342, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Einfach Ich', '30')
# 611
# ('Corona', 'Tegan', 'F', '32', 'Levine', 408.60689, 'paid', 'Portland-South Portland, ME', '611', 'Higher Messiah', '80')
# 324
# ('The Presets', 'Avery', 'F', '32', 'Watkins', 267.54567, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'If I Know You', '30')
# 324
# ('Pixies', 'Avery', 'F', '33', 'Watkins', 98.92526, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'In Heaven', '30')
# 611
# ('Existone', 'Tegan', 'F', '33', 'Levine', 652.30322, 'paid', 'Portland-South Portland, ME', '611', 'Wounded Soul', '80')
# 324
# ('John Mayer', 'Avery', 'F', '34', 'Watkins', 258.16771, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Bold As Love', '30')
# 324
# ('Zakir Hussain', 'Avery', 'F', '35', 'Watkins', 722.442, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'The Great ndian Desert', '30')
# 611
# ('Jag Panzer', 'Tegan', 'F', '34', 'Levine', 200.38485, 'paid', 'Portland-South Portland, ME', '611', 'Face Of Fear', '80')
# 611
# ('Two Door Cinema Club', 'Tegan', 'F', '35', 'Levine', 189.67465, 'paid', 'Portland-South Portland, ME', '611', 'What You Know', '80')
# 611
# ('Little Anthony & The Imperials', 'Tegan', 'F', '36', 'Levine', 127.42485, 'paid', 'Portland-South Portland, ME', '611', 'Hurt', '80')
# 324
# ('AndrÃ\x83Â©s Cepeda', 'Avery', 'F', '36', 'Watkins', 211.80036, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Me Lleva Tiempo', '30')
# 611
# ('Herb Alpert And The Tijuana Brass', 'Tegan', 'F', '37', 'Levine', 132.80608, 'paid', 'Portland-South Portland, ME', '611', "So What's New", '80')
# 324
# ('Ozma', 'Avery', 'F', '37', 'Watkins', 144.53506, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Flight Of Yuri Gagarin', '30')
# 611
# ('Ozric Tentacles', 'Tegan', 'F', '38', 'Levine', 461.21751, 'paid', 'Portland-South Portland, ME', '611', 'Mooncalf', '80')
# 324
# ('Evanescence', 'Avery', 'F', '38', 'Watkins', 263.78404, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'My Immortal (Album Version)', '30')
# 324
# ('Weezer', 'Avery', 'F', '39', 'Watkins', 232.85506, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Velouria', '30')
# 369
# ('Flying Lotus', 'Jahiem', 'M', '0', 'Miles', 115.33016, 'free', 'San Antonio-New Braunfels, TX', '369', 'Bad Actors', '43')
# 611
# ('Ben Folds', 'Tegan', 'F', '39', 'Levine', 250.87955, 'paid', 'Portland-South Portland, ME', '611', "Bitches Ain't Shit", '80')
# 324
# ('matchbox twenty', 'Avery', 'F', '40', 'Watkins', 229.14567, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Unwell (Album Version)', '30')
# 611
# ('Deftones', 'Tegan', 'F', '40', 'Levine', 189.75302, 'paid', 'Portland-South Portland, ME', '611', 'Feiticeira (LP Version)', '80')
# 324
# ('Silverchair', 'Avery', 'F', '41', 'Watkins', 319.13751, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Without You (Album Version)', '30')
# 611
# ('Muse', 'Tegan', 'F', '41', 'Levine', 258.06322, 'paid', 'Portland-South Portland, ME', '611', 'Map Of The Problematique', '80')
# 324
# ('Zen CafÃ\x83Â©', 'Avery', 'F', '42', 'Watkins', 259.02975, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Kotona kaikuu', '30')
# 611
# ('Mariah Carey / Twista', 'Tegan', 'F', '42', 'Levine', 194.7424, 'paid', 'Portland-South Portland, ME', '611', 'One And Only', '80')
# 324
# ('Strike Anywhere', 'Avery', 'F', '43', 'Watkins', 120.00608, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Gunpowder', '30')
# 324
# ('Tri Sestry', 'Avery', 'F', '44', 'Watkins', 97.72363, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Had Stupid', '30')
# 324
# ('Don Williams', 'Avery', 'F', '45', 'Watkins', 191.03302, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', "If Hollywood Don't Need You", '30')
# 324
# ('The Nerves', 'Avery', 'F', '46', 'Watkins', 92.86485, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Are You Famous?', '30')
# 324
# ('Ulf Wakenius', 'Avery', 'F', '47', 'Watkins', 324.15302, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Good Morning Susie Soho', '30')
# 324
# ('The Kooks', 'Avery', 'F', '48', 'Watkins', 168.72444, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'She Moves In Her Own Way', '30')
# 324
# ('New Radicals', 'Avery', 'F', '49', 'Watkins', 300.82567, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'You Get What You Give', '30')
# 324
# ('Wolfmother', 'Avery', 'F', '50', 'Watkins', 333.7922, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Where Eagles Have Been', '30')
# 324
# ('The Shins', 'Avery', 'F', '51', 'Watkins', 225.61914, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Spilt Needles (Album)', '30')
# 324
# ('Nickel Creek', 'Avery', 'F', '52', 'Watkins', 248.58077, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Reasons Why', '30')
# 324
# ('Pigeon John', 'Avery', 'F', '53', 'Watkins', 180.00934, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Crazy', '30')
# 324
# ('Eels', 'Avery', 'F', '54', 'Watkins', 211.48689, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Love Of The Loveless', '30')
# 324
# ('Harmonia', 'Avery', 'F', '55', 'Watkins', 655.77751, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Sehr kosmisch', '30')
# 324
# ('Marina And The Diamonds', 'Avery', 'F', '56', 'Watkins', 182.59546, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Oh No! (album version)', '30')
# 324
# ('Eminem', 'Avery', 'F', '57', 'Watkins', 284.86485, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'The Real Slim Shady', '30')
# 324
# ('Hassisen Kone', 'Avery', 'F', '58', 'Watkins', 162.61179, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'REIPPAINA KÃ\x83Â\x84YMME REKKAIN ALLE', '30')
# 324
# ('Dwight Yoakam', 'Avery', 'F', '59', 'Watkins', 239.3073, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', "You're The One", '30')
# 324
# ('Sunlounger', 'Avery', 'F', '60', 'Watkins', 594.15465, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'White Sand', '30')
# 324
# ("Youssou N'Dour", 'Avery', 'F', '61', 'Watkins', 238.39302, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Tan bi (Heat_ Breeze_ Tenderness) / Chaleur_ brise_ tendress', '30')
# 324
# ('The Decemberists', 'Avery', 'F', '62', 'Watkins', 209.08363, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Red Right Ankle', '30')
# 324
# ('The Ruts', 'Avery', 'F', '63', 'Watkins', 185.75628, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Savage Circle', '30')
# 324
# ('Adrian Legg', 'Avery', 'F', '64', 'Watkins', 122.77506, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'The One-Eyed Turk', '30')
# 324
# ('Bedrock', 'Avery', 'F', '66', 'Watkins', 664.0322, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Set In Stone', '30')
# 605
# ('Prince & The Revolution', 'Kate', 'F', '0', 'Harrell', 280.00608, 'paid', 'Lansing-East Lansing, MI', '605', "Let's Go Crazy (LP Version)", '97')
# 605
# ('The Zombies', 'Kate', 'F', '1', 'Harrell', 157.33506, 'paid', 'Lansing-East Lansing, MI', '605', "She's Coming Home", '97')
# 605
# ('Portishead', 'Kate', 'F', '2', 'Harrell', 238.0273, 'paid', 'Lansing-East Lansing, MI', '605', 'Numb', '97')
# 324
# ('Jack Johnson', 'Avery', 'F', '67', 'Watkins', 212.68853, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Breakdown', '30')
# 605
# ('Justice', 'Kate', 'F', '3', 'Harrell', 205.50485, 'paid', 'Lansing-East Lansing, MI', '605', 'Let There Be Lite (Album Version)', '97')
# 324
# ('Snow Patrol', 'Avery', 'F', '68', 'Watkins', 223.18975, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Set Down Your Glass', '30')
# 605
# ('Lemon Jelly', 'Kate', 'F', '4', 'Harrell', 238.47138, 'paid', 'Lansing-East Lansing, MI', '605', 'Nice Weather For Ducks', '97')
# 324
# ('The Lucksmiths', 'Avery', 'F', '69', 'Watkins', 153.70404, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Tale Of Two Cities', '30')
# 605
# ('Ben Kweller', 'Kate', 'F', '5', 'Harrell', 188.60363, 'paid', 'Lansing-East Lansing, MI', '605', 'Magic', '97')
# 324
# ('Fedde le Grand Pres. Flamingo', 'Avery', 'F', '70', 'Watkins', 396.32934, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Take No Shhh (Original Mix)', '30')
# 605
# ('Rodrigo y Gabriela', 'Kate', 'F', '6', 'Harrell', 233.40363, 'paid', 'Lansing-East Lansing, MI', '605', 'VIKING MAN', '97')
# 605
# ('Black Eyed Peas', 'Kate', 'F', '7', 'Harrell', 289.12281, 'paid', 'Lansing-East Lansing, MI', '605', 'I Gotta Feeling', '97')
# 324
# ('Five Iron Frenzy', 'Avery', 'F', '71', 'Watkins', 236.09424, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Canada', '30')
# 598
# ('Creedence Clearwater Revival', 'Ava', 'F', '0', 'Robinson', 164.57098, 'free', 'New Haven-Milford, CT', '598', 'Down On The Corner', '50')
# 598
# ('Kings Of Leon', 'Ava', 'F', '1', 'Robinson', 186.69669, 'free', 'New Haven-Milford, CT', '598', 'Camaro', '50')
# 324
# ('Fireflight', 'Avery', 'F', '72', 'Watkins', 201.16853, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Unbreakable', '30')
# 605
# ('Steppenwolf', 'Kate', 'F', '8', 'Harrell', 208.14322, 'paid', 'Lansing-East Lansing, MI', '605', 'Born To Be Wild', '97')
# 598
# ('New Found Glory', 'Ava', 'F', '2', 'Robinson', 222.69342, 'free', 'New Haven-Milford, CT', '598', 'the king of wishful thinking', '50')
# 324
# ('The Pussycat Dolls', 'Avery', 'F', '73', 'Watkins', 221.1522, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Elevator', '30')
# 605
# ('Eric Clapton', 'Kate', 'F', '9', 'Harrell', 208.48281, 'paid', 'Lansing-East Lansing, MI', '605', 'Willie And The Hand Jive', '97')
# 531
# ('Josh Groban', 'Devin', 'M', '1', 'Larson', 260.70159, 'free', 'Tampa-St. Petersburg-Clearwater, FL', '531', 'Little Drummer Boy [featuring guitarist Andy McKee] (Album Version)', '60')
# 324
# ('The Dresden Dolls', 'Avery', 'F', '74', 'Watkins', 286.40608, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Coin-Operated Boy', '30')
# 605
# ('Pixies', 'Kate', 'F', '10', 'Harrell', 229.3024, 'paid', 'Lansing-East Lansing, MI', '605', 'Where Is My Mind?', '97')
# 531
# ('Creedence Clearwater Revival', 'Devin', 'M', '2', 'Larson', 271.882, 'free', 'Tampa-St. Petersburg-Clearwater, FL', '531', 'I Put A Spell On You', '60')
# 605
# ('The Smiths', 'Kate', 'F', '11', 'Harrell', 123.01016, 'paid', 'Lansing-East Lansing, MI', '605', 'Girlfriend In A Coma', '97')
# 324
# ('Danger Doom', 'Avery', 'F', '75', 'Watkins', 187.27138, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'No Names (Black Debbie) (Album Version)', '30')
# 605
# ('Taylor Swift', 'Kate', 'F', '12', 'Harrell', 233.89995, 'paid', 'Lansing-East Lansing, MI', '605', 'Love Story', '97')
# 324
# ('Vilma Palma e Vampiros', 'Avery', 'F', '76', 'Watkins', 281.99138, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'La pachanga', '30')
# 605
# ('Busta Rhymes feat. Pharrell', 'Kate', 'F', '13', 'Harrell', 220.47302, 'paid', 'Lansing-East Lansing, MI', '605', 'Light Your Ass On Fire', '97')
# 324
# ('Little People', 'Avery', 'F', '77', 'Watkins', 230.1122, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Above The Clouds', '30')
# 605
# ('Dwight Yoakam', 'Kate', 'F', '14', 'Harrell', 239.3073, 'paid', 'Lansing-East Lansing, MI', '605', "You're The One", '97')
# 324
# ('Amy Winehouse', 'Avery', 'F', '78', 'Watkins', 164.85832, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'He Can Only Hold Her', '30')
# 605
# ('Ernie K-Doe', 'Kate', 'F', '15', 'Harrell', 160.96608, 'paid', 'Lansing-East Lansing, MI', '605', 'Te-Ta-Te-Ta-Ta (2002 Digital Remaster)', '97')
# 324
# ('Alesana', 'Avery', 'F', '79', 'Watkins', 242.49424, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Congratulations_ I Hate You', '30')
# 605
# ('Dwight Yoakam', 'Kate', 'F', '16', 'Harrell', 239.3073, 'paid', 'Lansing-East Lansing, MI', '605', "You're The One", '97')
# 324
# ('Gazpacho', 'Avery', 'F', '80', 'Watkins', 253.51791, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Premonicion', '30')
# 605
# ('Black Lips', 'Kate', 'F', '17', 'Harrell', 162.76853, 'paid', 'Lansing-East Lansing, MI', '605', 'Lock and Key', '97')
# 605
# ('Kanye West', 'Kate', 'F', '18', 'Harrell', 311.84934, 'paid', 'Lansing-East Lansing, MI', '605', 'Stronger', '97')
# 324
# ('Arcade Fire', 'Avery', 'F', '81', 'Watkins', 136.69832, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Neon Bible', '30')
# 324
# ('Barry Tuckwell/Academy of St Martin-in-the-Fields/Sir Neville Marriner', 'Avery', 'F', '82', 'Watkins', 277.15873, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)', '30')
# 605
# ('Fanfarlo', 'Kate', 'F', '19', 'Harrell', 270.78485, 'paid', 'Lansing-East Lansing, MI', '605', "I'm a Pilot", '97')
# 324
# ('Crystal Castles', 'Avery', 'F', '83', 'Watkins', 251.08853, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Empathy', '30')
# 605
# ('Zeca Baleiro', 'Kate', 'F', '20', 'Harrell', 452.8322, 'paid', 'Lansing-East Lansing, MI', '605', 'Brigitte Bardot', '97')
# 324
# ('Angus & Julia Stone', 'Avery', 'F', '86', 'Watkins', 236.95628, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Just A Boy', '30')
# 324
# ('Julian Casablancas', 'Avery', 'F', '87', 'Watkins', 302.47138, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', '4 Chords of the Apocalypse', '30')
# 605
# ('Fat Joe', 'Kate', 'F', '21', 'Harrell', 241.34485, 'paid', 'Lansing-East Lansing, MI', '605', 'Safe 2 Say [The Incredible] (Album Version - Amended)', '97')
# 324
# ("Usher Featuring Lil' Jon & Ludacris", 'Avery', 'F', '88', 'Watkins', 250.38322, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Yeah!', '30')
# 605
# ('Pat Benatar', 'Kate', 'F', '22', 'Harrell', 290.37669, 'paid', 'Lansing-East Lansing, MI', '605', "Don't Walk Away", '97')
# 324
# ('Fergie', 'Avery', 'F', '89', 'Watkins', 248.39791, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Losing My Ground', '30')
# 605
# ('Muse', 'Kate', 'F', '23', 'Harrell', 209.50159, 'paid', 'Lansing-East Lansing, MI', '605', 'Supermassive Black Hole (Twilight Soundtrack Version)', '97')
# 324
# ('Two Door Cinema Club', 'Avery', 'F', '90', 'Watkins', 168.09751, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Undercover Martyn', '30')
# 605
# ('Spineshank', 'Kate', 'F', '24', 'Harrell', 167.26159, 'paid', 'Lansing-East Lansing, MI', '605', 'Intake (Album Version)', '97')
# 324
# ('Whitney Houston Duet With Mariah Carey', 'Avery', 'F', '91', 'Watkins', 273.34485, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'When You Believe', '30')
# 605
# ('Death Cab for Cutie', 'Kate', 'F', '25', 'Harrell', 488.64608, 'paid', 'Lansing-East Lansing, MI', '605', 'Transatlanticism', '97')
# 324
# ('Noir DÃ\x83Â©sir', 'Avery', 'F', '92', 'Watkins', 374.77832, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Ces Gens LÃ\x83Â\xa0', '30')
# 605
# ('Paramore', 'Kate', 'F', '26', 'Harrell', 243.51302, 'paid', 'Lansing-East Lansing, MI', '605', 'Emergency (Album Version)', '97')
# 324
# ('My Chemical Romance', 'Avery', 'F', '93', 'Watkins', 188.05506, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Cemetery Drive (Album Version)', '30')
# 605
# ('Vincent Vincent And The Villains', 'Kate', 'F', '27', 'Harrell', 154.64444, 'paid', 'Lansing-East Lansing, MI', '605', 'On My Own', '97')
# 324
# ('Phoenix', 'Avery', 'F', '94', 'Watkins', 229.79873, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Run Run Run', '30')
# 605
# ('Beastie Boys', 'Kate', 'F', '28', 'Harrell', 193.54077, 'paid', 'Lansing-East Lansing, MI', '605', 'Skills To Pay The Bills', '97')
# 554
# ('Natasha Bedingfield', 'Lily', 'F', '0', 'Burns', 216.65914, 'free', 'New York-Newark-Jersey City, NY-NJ-PA', '554', 'These Words', '32')
# 324
# ('Calle 13', 'Avery', 'F', '95', 'Watkins', 239.3073, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'AtrÃ\x83Â©vete te te', '30')
# 605
# ('Sondre Lerche', 'Kate', 'F', '29', 'Harrell', 215.71873, 'paid', 'Lansing-East Lansing, MI', '605', 'Modern Nature', '97')
# 554
# ('Cecilia', 'Lily', 'F', '1', 'Burns', 157.77914, 'free', 'New York-Newark-Jersey City, NY-NJ-PA', '554', 'Ultimo Baile', '32')
# 324
# ('Air', 'Avery', 'F', '96', 'Watkins', 258.58567, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Mayfair Song', '30')
# 605
# ('Five Iron Frenzy', 'Kate', 'F', '30', 'Harrell', 236.09424, 'paid', 'Lansing-East Lansing, MI', '605', 'Canada', '97')
# 554
# ('Kings Of Convenience', 'Lily', 'F', '2', 'Burns', 245.02812, 'free', 'New York-Newark-Jersey City, NY-NJ-PA', '554', 'Riot On An Empty Street', '32')
# 324
# ('Rhonda Vincent', 'Avery', 'F', '97', 'Watkins', 142.78485, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', "You're In My Heart", '30')
# 605
# ('Soulwax', 'Kate', 'F', '31', 'Harrell', 277.002, 'paid', 'Lansing-East Lansing, MI', '605', 'E Talking', '97')
# 554
# ('Red', 'Lily', 'F', '3', 'Burns', 227.52608, 'free', 'New York-Newark-Jersey City, NY-NJ-PA', '554', 'Mystery of You', '32')
# 324
# ('Sugababes', 'Avery', 'F', '98', 'Watkins', 275.93098, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Overload', '30')
# 554
# ('Eminem / Dr. Dre', 'Lily', 'F', '4', 'Burns', 309.83791, 'free', 'New York-Newark-Jersey City, NY-NJ-PA', '554', 'Say What You Say', '32')
# 605
# ('Michael Jackson', 'Kate', 'F', '32', 'Harrell', 278.282, 'paid', 'Lansing-East Lansing, MI', '605', 'Scream', '97')
# 324
# ('Dominique A', 'Avery', 'F', '99', 'Watkins', 153.20771, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Le Courage Des Oiseaux', '30')
# 605
# ('Linkin Park', 'Kate', 'F', '33', 'Harrell', 259.86567, 'paid', 'Lansing-East Lansing, MI', '605', 'My December', '97')
# 324
# ('Five Iron Frenzy', 'Avery', 'F', '100', 'Watkins', 236.09424, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Canada', '30')
# 324
# ('Dear Nora', 'Avery', 'F', '101', 'Watkins', 59.66322, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Give Me Some Of Yr Love', '30')
# 605
# ('The Police', 'Kate', 'F', '34', 'Harrell', 290.24608, 'paid', 'Lansing-East Lansing, MI', '605', 'Message In A Bottle', '97')
# 324
# ('Cocoon', 'Avery', 'F', '102', 'Watkins', 159.97342, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Microwave', '30')
# 485
# ('Coldplay', 'Celeste', 'F', '0', 'Williams', 349.93587, 'free', 'Klamath Falls, OR', '485', 'A Rush Of Blood To The Head', '53')
# 526
# ('Peter And Gordon', 'Maia', 'F', '0', 'Burke', 161.14893, 'free', 'Houston-The Woodlands-Sugar Land, TX', '526', 'A World Without Love', '51')
# 324
# ('Gotye', 'Avery', 'F', '103', 'Watkins', 360.33261, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Coming Back', '30')
# 605
# ('Maps', 'Kate', 'F', '35', 'Harrell', 255.9473, 'paid', 'Lansing-East Lansing, MI', '605', 'To The Sky', '97')
# 526
# ('Joshua Radin', 'Maia', 'F', '1', 'Burke', 169.32526, 'free', 'Houston-The Woodlands-Sugar Land, TX', '526', "I'd Rather Be With You", '51')
# 621
# ("D'Angelo", 'Chloe', 'F', '3', 'Cuevas', 344.94649, 'paid', 'San Francisco-Oakland-Hayward, CA', '621', 'When We Get By', '49')
# 485
# ('Blockhead', 'Celeste', 'F', '1', 'Williams', 289.56689, 'free', 'Klamath Falls, OR', '485', 'The Music Scene', '53')
# 588
# ('Nine Inch Nails', 'Ayla', 'F', '0', 'Johnson', 300.64281, 'free', 'Santa Rosa, CA', '588', 'Terrible Lie', '63')
# 526
# ('La Roux', 'Maia', 'F', '2', 'Burke', 208.03873, 'free', 'Houston-The Woodlands-Sugar Land, TX', '526', 'Colourless Colour', '51')
# 605
# ('Lil Wayne / Shanell', 'Kate', 'F', '36', 'Harrell', 216.81587, 'paid', 'Lansing-East Lansing, MI', '605', 'American Star', '97')
# 324
# ('RÃ\x83Â¶yksopp', 'Avery', 'F', '104', 'Watkins', 300.14649, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'What Else Is There?', '30')
# 621
# ("Jack's Mannequin", 'Chloe', 'F', '4', 'Cuevas', 172.90404, 'paid', 'San Francisco-Oakland-Hayward, CA', '621', 'Spinning (Album Version)', '49')
# 605
# ('FM Static', 'Kate', 'F', '37', 'Harrell', 170.81424, 'paid', 'Lansing-East Lansing, MI', '605', 'Definitely Maybe', '97')
# 324
# ('Joy Division', 'Avery', 'F', '105', 'Watkins', 209.03138, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Disorder [2007 Re-mastered Album Version]', '30')
# 621
# ('N.E.R.D.', 'Chloe', 'F', '5', 'Cuevas', 259.23873, 'paid', 'San Francisco-Oakland-Hayward, CA', '621', 'Rock Star', '49')
# 605
# ('Mickie Krause', 'Kate', 'F', '38', 'Harrell', 204.17261, 'paid', 'Lansing-East Lansing, MI', '605', 'Orange TrÃ\x83Â¤gt Nur Die MÃ\x83Â¼llabfuhr (Go West)', '97')
# 324
# ('Steadman', 'Avery', 'F', '106', 'Watkins', 234.1873, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Wave Goodbye (Real/Rhapsody Version)', '30')
# 605
# ('The Like', 'Kate', 'F', '39', 'Harrell', 245.68118, 'paid', 'Lansing-East Lansing, MI', '605', 'We Are Lost', '97')
# 621
# ('Future Rock', 'Chloe', 'F', '6', 'Cuevas', 239.90812, 'paid', 'San Francisco-Oakland-Hayward, CA', '621', 'Gears', '49')
# 404
# ('The All-American Rejects', 'Harper', 'M', '1', 'Barrett', 213.08036, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Gives You Hell', '42')
# 324
# ('Bruce Springsteen', 'Avery', 'F', '107', 'Watkins', 270.54975, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'Born To Run', '30')
# 605
# ('OneRepublic', 'Kate', 'F', '40', 'Harrell', 230.63465, 'paid', 'Lansing-East Lansing, MI', '605', 'Say (All I Need)', '97')
# 621
# ('Owl City', 'Chloe', 'F', '7', 'Cuevas', 133.74649, 'paid', 'San Francisco-Oakland-Hayward, CA', '621', 'Meteor Shower', '49')
# 404
# ('Justin Nozuka', 'Harper', 'M', '2', 'Barrett', 215.64036, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', "I'm In Peace", '42')
# 621
# ('Marina And The Diamonds', 'Chloe', 'F', '8', 'Cuevas', 262.97424, 'paid', 'San Francisco-Oakland-Hayward, CA', '621', 'I Am Not a Robot', '49')
# 324
# ('The Serendipity Singers', 'Avery', 'F', '108', 'Watkins', 163.21261, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', "Don't Let The Rain Come Down (Crooked Little Man)", '30')
# 605
# ('Haujobb', 'Kate', 'F', '41', 'Harrell', 225.12281, 'paid', 'Lansing-East Lansing, MI', '605', 'Maternal Instinct', '97')
# 404
# ('Cyndi Lauper', 'Harper', 'M', '3', 'Barrett', 156.96934, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'My Baby Just Cares For Me', '42')
# 324
# ('Usher featuring will.i.am', 'Avery', 'F', '109', 'Watkins', 395.72853, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'OMG', '30')
# 621
# ('Depeche Mode', 'Chloe', 'F', '9', 'Cuevas', 397.42649, 'paid', 'San Francisco-Oakland-Hayward, CA', '621', 'Everything Counts (Live) (Single Version)', '49')
# 404
# ('Red Hot Chili Peppers', 'Harper', 'M', '4', 'Barrett', 240.32608, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Especially In Michigan (Album Version)', '42')
# 605
# ('3 Doors Down', 'Kate', 'F', '42', 'Harrell', 233.74322, 'paid', 'Lansing-East Lansing, MI', '605', 'Kryptonite', '97')
# 404
# ('The Newbeats', 'Harper', 'M', '5', 'Barrett', 109.24363, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Bread And Butter', '42')
# 605
# ('Kings Of Leon', 'Kate', 'F', '43', 'Harrell', 260.38812, 'paid', 'Lansing-East Lansing, MI', '605', 'Dusty', '97')
# 324
# ('Los Lobos', 'Avery', 'F', '110', 'Watkins', 174.18404, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', 'La Bamba', '30')
# 404
# ('Drake / Kanye West / Lil Wayne / Eminem', 'Harper', 'M', '7', 'Barrett', 357.66812, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Forever', '42')
# 621
# ('Ginuwine', 'Chloe', 'F', '10', 'Cuevas', 244.27057, 'paid', 'San Francisco-Oakland-Hayward, CA', '621', "I'm In Love", '49')
# 324
# ('Descendents', 'Avery', 'F', '111', 'Watkins', 89.23383, 'paid', 'San Jose-Sunnyvale-Santa Clara, CA', '324', "I'm Not A Loser", '30')
# 605
# ('Jennifer Love Hewitt', 'Kate', 'F', '44', 'Harrell', 222.17098, 'paid', 'Lansing-East Lansing, MI', '605', 'BareNaked', '97')
# 621
# ('The Cinematic Orchestra', 'Chloe', 'F', '11', 'Cuevas', 613.74649, 'paid', 'San Francisco-Oakland-Hayward, CA', '621', 'Burn Out', '49')
# 404
# ('La Fuga', 'Harper', 'M', '8', 'Barrett', 217.70404, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Baja por diversion (directo 05)', '42')
# 605
# ('Killswitch Engage', 'Kate', 'F', '45', 'Harrell', 259.89179, 'paid', 'Lansing-East Lansing, MI', '605', 'Hope Is... (Album Version)', '97')
# 404
# ('Kid Cudi Vs Crookers', 'Harper', 'M', '9', 'Barrett', 162.97751, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', "Day 'N' Nite", '42')
# 605
# ('Beirut', 'Kate', 'F', '46', 'Harrell', 213.68118, 'paid', 'Lansing-East Lansing, MI', '605', 'La Llorona', '97')
# 404
# ('Fall Out Boy', 'Harper', 'M', '10', 'Barrett', 181.36771, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Dance_ Dance', '42')
# 605
# ("Christina Aguilera / Lil' Kim / Mya / Pink", 'Kate', 'F', '47', 'Harrell', 264.93342, 'paid', 'Lansing-East Lansing, MI', '605', 'Lady Marmalade', '97')
# 404
# ('Harold Budd', 'Harper', 'M', '11', 'Barrett', 392.85506, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Algebra Of Darkness (Album Version)', '42')
# 605
# ('Eric Burdon & War', 'Kate', 'F', '48', 'Harrell', 281.93914, 'paid', 'Lansing-East Lansing, MI', '605', 'Jimbo (Album Version)', '97')
# 404
# ('Cass McCombs', 'Harper', 'M', '12', 'Barrett', 234.13506, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Deseret', '42')
# 605
# ('The Black Keys', 'Kate', 'F', '49', 'Harrell', 139.51955, 'paid', 'Lansing-East Lansing, MI', '605', "I'll Be Your Man", '97')
# 404
# ('Leona Naess', 'Harper', 'M', '13', 'Barrett', 223.03302, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Christmas', '42')
# 605
# ('Alliance Ethnik', 'Kate', 'F', '50', 'Harrell', 252.21179, 'paid', 'Lansing-East Lansing, MI', '605', 'ReprÃ\x83Â©sente', '97')
# 404
# ('Nando Reis', 'Harper', 'M', '14', 'Barrett', 254.6673, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'A Letra "A', '42')
# 605
# ('Kris Allen', 'Kate', 'F', '55', 'Harrell', 212.50567, 'paid', 'Lansing-East Lansing, MI', '605', "Live Like We're Dying", '97')
# 605
# ('Muse', 'Kate', 'F', '56', 'Harrell', 224.44363, 'paid', 'Lansing-East Lansing, MI', '605', 'Muscle Museum (Soulwax Remix)', '97')
# 404
# ('Goldfrapp', 'Harper', 'M', '15', 'Barrett', 228.0224, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Lovely Head', '42')
# 605
# ('Slash', 'Kate', 'F', '57', 'Harrell', 189.23057, 'paid', 'Lansing-East Lansing, MI', '605', 'Doctor Alibi (featuring Lemmy Kilmister)', '97')
# 404
# ('D.R.I.', 'Harper', 'M', '16', 'Barrett', 66.61179, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Stupid_ Stupid War (Dealing With It)', '42')
# 404
# ('Beastie Boys', 'Harper', 'M', '17', 'Barrett', 211.722, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Unite (2009 Digital Remaster)', '42')
# 605
# ('Cat Power', 'Kate', 'F', '58', 'Harrell', 218.3571, 'paid', 'Lansing-East Lansing, MI', '605', 'Hate', '97')
# 404
# ('Kings Of Leon', 'Harper', 'M', '18', 'Barrett', 201.79546, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Revelry', '42')
# 605
# ('Hot Water Music', 'Kate', 'F', '59', 'Harrell', 201.40363, 'paid', 'Lansing-East Lansing, MI', '605', 'Translocation', '97')
# 404
# ('Miranda Lambert', 'Harper', 'M', '19', 'Barrett', 251.61098, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Me And Charlie Talking', '42')
# 605
# ('Brandy duet with Monica', 'Kate', 'F', '60', 'Harrell', 294.79138, 'paid', 'Lansing-East Lansing, MI', '605', 'The Boy Is Mine (Duet With Monica) (LP Version)', '97')
# 404
# ('The Heavy', 'Harper', 'M', '20', 'Barrett', 197.35465, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'How You Like Me Now?', '42')
# 605
# ('Streetlight Manifesto', 'Kate', 'F', '61', 'Harrell', 327.91465, 'paid', 'Lansing-East Lansing, MI', '605', 'Point/Counterpoint (Album Version)', '97')
# 404
# ('Blitzen Trapper', 'Harper', 'M', '21', 'Barrett', 171.15383, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Murder Babe (Album)', '42')
# 404
# ('Megan McCauley', 'Harper', 'M', '22', 'Barrett', 228.57098, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Die For You', '42')
# 605
# ('Jack Johnson', 'Kate', 'F', '62', 'Harrell', 207.64689, 'paid', 'Lansing-East Lansing, MI', '605', 'Better Together', '97')
# 404
# ('Passion Pit', 'Harper', 'M', '23', 'Barrett', 243.69587, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Eyes As Candles', '42')
# 619
# ('Strunz & Farah', 'Aleena', 'F', '0', 'Kirby', 315.32363, 'paid', 'Waterloo-Cedar Falls, IA', '619', 'Zagros', '44')
# 605
# ('Minus The Bear', 'Kate', 'F', '63', 'Harrell', 230.45179, 'paid', 'Lansing-East Lansing, MI', '605', 'Part 2', '97')
# 404
# ('Van Halen', 'Harper', 'M', '24', 'Barrett', 102.5824, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Eruption (Album Version)', '42')
# 605
# ('Pavement', 'Kate', 'F', '64', 'Harrell', 149.83791, 'paid', 'Lansing-East Lansing, MI', '605', 'Heaven Is A Truck', '97')
# 404
# ('Alliance Ethnik', 'Harper', 'M', '25', 'Barrett', 195.94404, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'SinceritÃ\x83Â© Et Jalousie', '42')
# 619
# ('Pieces Of A Dream', 'Aleena', 'F', '1', 'Kirby', 311.562, 'paid', 'Waterloo-Cedar Falls, IA', '619', 'Keep It Smooth', '44')
# 605
# ('Creedence Clearwater Revival', 'Kate', 'F', '65', 'Harrell', 315.42812, 'paid', 'Lansing-East Lansing, MI', '605', 'Born On The Bayou', '97')
# 404
# ('Anouk', 'Harper', 'M', '26', 'Barrett', 268.5122, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', "It's So Hard", '42')
# 619
# ('Jaco Pastorius Big Band', 'Aleena', 'F', '2', 'Kirby', 69.3024, 'paid', 'Waterloo-Cedar Falls, IA', '619', 'Amerika (Album Version)', '44')
# 619
# ('Avril Lavigne', 'Aleena', 'F', '3', 'Kirby', 222.9024, 'paid', 'Waterloo-Cedar Falls, IA', '619', "I'm With You", '44')
# 605
# ('Gonzalo Rubalcaba', 'Kate', 'F', '66', 'Harrell', 525.47873, 'paid', 'Lansing-East Lansing, MI', '605', 'Circuito III', '97')
# 404
# ('BjÃ\x83Â¶rk', 'Harper', 'M', '27', 'Barrett', 348.57751, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Undo', '42')
# 619
# ('Ska-P', 'Aleena', 'F', '4', 'Kirby', 298.13506, 'paid', 'Waterloo-Cedar Falls, IA', '619', 'Casposos', '44')
# 404
# ('The Strokes', 'Harper', 'M', '28', 'Barrett', 155.34975, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Is This It', '42')
# 619
# ('Jesse Belvin', 'Aleena', 'F', '5', 'Kirby', 184.63302, 'paid', 'Waterloo-Cedar Falls, IA', '619', 'Goodnight My Love', '44')
# 404
# ('Alliance Ethnik', 'Harper', 'M', '29', 'Barrett', 265.76934, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Creil City', '42')
# 605
# ('The Gerbils', 'Kate', 'F', '67', 'Harrell', 27.01016, 'paid', 'Lansing-East Lansing, MI', '605', '(iii)', '97')
# 605
# ('KJ-52', 'Kate', 'F', '68', 'Harrell', 275.77424, 'paid', 'Lansing-East Lansing, MI', '605', 'Life After Death', '97')
# 619
# ('Mariah Carey', 'Aleena', 'F', '7', 'Kirby', 242.96444, 'paid', 'Waterloo-Cedar Falls, IA', '619', 'All I Want For Christmas Is You', '44')
# 404
# ('Glen Hansard & Marketa Irglova', 'Harper', 'M', '30', 'Barrett', 282.67057, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'The Moon (Album version)', '42')
# 605
# ('Dion & The Belmonts', 'Kate', 'F', '69', 'Harrell', 152.31955, 'paid', 'Lansing-East Lansing, MI', '605', 'A Teenager In Love', '97')
# 600
# ('Jack Johnson', 'Kynnedi', 'F', '0', 'Sanchez', 236.93016, 'free', 'Cedar Rapids, IA', '600', 'Bubble Toes', '89')
# 619
# ('Beastie Boys', 'Aleena', 'F', '8', 'Kirby', 172.22485, 'paid', 'Waterloo-Cedar Falls, IA', '619', 'The Maestro', '44')
# 605
# ('Lesley Gore', 'Kate', 'F', '70', 'Harrell', 134.37342, 'paid', 'Lansing-East Lansing, MI', '605', "It's My Party", '97')
# 404
# ('Dr. Dre / Snoop Dogg', 'Harper', 'M', '31', 'Barrett', 161.51465, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'The Next Episode', '42')
# 619
# ('Pearl Jam', 'Aleena', 'F', '9', 'Kirby', 67.44771, 'paid', 'Waterloo-Cedar Falls, IA', '619', 'Encore Break', '44')
# 600
# ('Cake', 'Kynnedi', 'F', '1', 'Sanchez', 179.09506, 'free', 'Cedar Rapids, IA', '600', 'Commissioning A Symphony In C', '89')
# 605
# ('Phoenix', 'Kate', 'F', '71', 'Harrell', 278.07302, 'paid', 'Lansing-East Lansing, MI', '605', 'Rome', '97')
# 619
# ('Alesana', 'Aleena', 'F', '10', 'Kirby', 285.51791, 'paid', 'Waterloo-Cedar Falls, IA', '619', 'Seduction (album)', '44')
# 404
# ('The Kooks', 'Harper', 'M', '32', 'Barrett', 168.72444, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'She Moves In Her Own Way', '42')
# 404
# ('Dakis', 'Harper', 'M', '33', 'Barrett', 162.48118, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'La Petite Marie (2005 Digital Remaster)', '42')
# 605
# ('Limp Bizkit', 'Kate', 'F', '72', 'Harrell', 214.5171, 'paid', 'Lansing-East Lansing, MI', '605', "Rollin' (Air Raid Vehicle)", '97')
# 619
# ('JET', 'Aleena', 'F', '11', 'Kirby', 261.3024, 'paid', 'Waterloo-Cedar Falls, IA', '619', 'Move On (Album Version)', '44')
# 404
# ('Mickie Krause', 'Harper', 'M', '34', 'Barrett', 204.17261, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Orange TrÃ\x83Â¤gt Nur Die MÃ\x83Â¼llabfuhr (Go West)', '42')
# 605
# ('Hot Chip', 'Kate', 'F', '73', 'Harrell', 314.69669, 'paid', 'Lansing-East Lansing, MI', '605', 'My Piano (DJ-Kicks)', '97')
# 619
# ('Yung Berg', 'Aleena', 'F', '12', 'Kirby', 230.63465, 'paid', 'Waterloo-Cedar Falls, IA', '619', "Do That There (featuring Dude 'N Nem)", '44')
# 404
# ('Kings Of Leon', 'Harper', 'M', '35', 'Barrett', 237.53098, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Closer', '42')
# 619
# ('Johan', 'Aleena', 'F', '13', 'Kirby', 190.27546, 'paid', 'Waterloo-Cedar Falls, IA', '619', 'Life On Mars', '44')
# 605
# ('Crystal Castles', 'Kate', 'F', '74', 'Harrell', 138.91873, 'paid', 'Lansing-East Lansing, MI', '605', 'Love And Caring', '97')
# 404
# ('Thirteen Senses', 'Harper', 'M', '36', 'Barrett', 286.45832, 'paid', 'New York-Newark-Jersey City, NY-NJ-PA', '404', 'Lead Us', '42')
# 605
# ('Eisbrecher', 'Kate', 'F', '76', 'Harrell', 241.89342, 'paid', 'Lansing-East Lansing, MI', '605', 'Adrenalin', '97')
# 619
# ('Buckcherry', 'Aleena', 'F', '14', 'Kirby', 201.79546, 'paid', 'Waterloo-Cedar Falls, IA', '619', 'Crazy Bitch (Album Version)', '44')
# 404
# ...
# 977
# ('Lonnie Johnson', 'Kinsley', 'F', '23', 'Young', 194.55955, 'paid', 'Red Bluff, CA', '977', 'Low Land Moan', '85')
# 1097
# ('Leggo Beast', 'Mohammad', 'M', '2', 'Rodriguez', 376.58077, 'paid', 'Sacramento--Roseville--Arden-Arcade, CA', '1097', 'In', '88')
# 1076
# ('The Pussycat Dolls', 'Rylan', 'M', '4', 'George', 190.95465, 'paid', 'Birmingham-Hoover, AL', '1076', 'Sway', '16')
# 977
# ('Stereophonics', 'Kinsley', 'F', '24', 'Young', 290.53342, 'paid', 'Red Bluff, CA', '977', 'I Miss You Now', '85')
# 1076
# ('The Beautiful South', 'Rylan', 'M', '5', 'George', 236.5122, 'paid', 'Birmingham-Hoover, AL', '1076', 'Masculine Eclipse', '16')
# 1097
# ('The Acacia Strain', 'Mohammad', 'M', '3', 'Rodriguez', 194.21995, 'paid', 'Sacramento--Roseville--Arden-Arcade, CA', '1097', 'As If Set Afire', '88')
# 977
# ('ATB', 'Kinsley', 'F', '25', 'Young', 251.48036, 'paid', 'Red Bluff, CA', '977', 'Underwater World', '85')
# 1076
# ('The Robert Cray Band', 'Rylan', 'M', '6', 'George', 309.52444, 'paid', 'Birmingham-Hoover, AL', '1076', 'Our Last Time', '16')
# 1097
# ('Enigma', 'Mohammad', 'M', '4', 'Rodriguez', 242.78159, 'paid', 'Sacramento--Roseville--Arden-Arcade, CA', '1097', 'T.N.T. For The Brain (112 Bpm) (Radio Edit)', '88')
# 977
# ('Amon Amarth', 'Kinsley', 'F', '26', 'Young', 268.2771, 'paid', 'Red Bluff, CA', '977', 'Tattered Banners And Bloody Flags', '85')
# 1076
# ('We Are Scientists', 'Rylan', 'M', '7', 'George', 198.89587, 'paid', 'Birmingham-Hoover, AL', '1076', 'The Great Escape (Album Version) (Explicit)', '16')
# 1100
# ('Roberto Murolo', 'Matthew', 'M', '0', 'Jones', 188.02893, 'paid', 'Janesville-Beloit, WI', '1100', 'Lacreme napulitane', '36')
# 1097
# ('Ashlee Simpson', 'Mohammad', 'M', '5', 'Rodriguez', 214.43873, 'paid', 'Sacramento--Roseville--Arden-Arcade, CA', '1097', 'Autobiography', '88')
# 977
# ('Metallica', 'Kinsley', 'F', '27', 'Young', 152.60689, 'paid', 'Red Bluff, CA', '977', 'The Ecstasy Of Gold', '85')
# 1076
# ('3 Doors Down', 'Rylan', 'M', '8', 'George', 233.74322, 'paid', 'Birmingham-Hoover, AL', '1076', 'Kryptonite', '16')
# 1100
# ('Hazell Dean', 'Matthew', 'M', '1', 'Jones', 367.98649, 'paid', 'Janesville-Beloit, WI', '1100', 'No Fool (For Love)', '36')
# 977
# ('Apocalyptica', 'Kinsley', 'F', '28', 'Young', 262.5824, 'paid', 'Red Bluff, CA', '977', 'Pray', '85')
# 1076
# ('Jack Johnson', 'Rylan', 'M', '9', 'George', 236.93016, 'paid', 'Birmingham-Hoover, AL', '1076', 'Bubble Toes', '16')
# 977
# ('Cage The Elephant', 'Kinsley', 'F', '29', 'Young', 196.38812, 'paid', 'Red Bluff, CA', '977', 'Lotus', '85')
# 1100
# ('Taylor Swift', 'Matthew', 'M', '2', 'Jones', 230.47791, 'paid', 'Janesville-Beloit, WI', '1100', 'You Belong With Me', '36')
# 1076
# ('Soul For Real', 'Rylan', 'M', '10', 'George', 271.25506, 'paid', 'Birmingham-Hoover, AL', '1076', 'Candy Rain', '16')
# 977
# ('The Prodigy', 'Kinsley', 'F', '30', 'Young', 225.09669, 'paid', 'Red Bluff, CA', '977', 'Firestarter', '85')
# 1100
# ('Amy Winehouse', 'Matthew', 'M', '3', 'Jones', 165.11955, 'paid', 'Janesville-Beloit, WI', '1100', 'Addicted', '36')
# 1076
# ('Iron Maiden', 'Rylan', 'M', '11', 'George', 275.19955, 'paid', 'Birmingham-Hoover, AL', '1076', 'The Evil That Men Do (1998 Digital Remaster)', '16')
# 977
# ('David Crowder*Band', 'Kinsley', 'F', '31', 'Young', 276.74077, 'paid', 'Red Bluff, CA', '977', 'All Around Me', '85')
# 1076
# ('The Cinematic Orchestra', 'Rylan', 'M', '12', 'George', 622.2624, 'paid', 'Birmingham-Hoover, AL', '1076', 'Everyday', '16')
# 977
# ('Three 6 Mafia vs. TiÃ\x83Â«sto with Sean Kingston and Flo Rida', 'Kinsley', 'F', '32', 'Young', 241.05751, 'paid', 'Red Bluff, CA', '977', 'Feel It', '85')
# 977
# ('Sugababes', 'Kinsley', 'F', '33', 'Young', 275.93098, 'paid', 'Red Bluff, CA', '977', 'Overload', '85')
# 1076
# ('Gyptian', 'Rylan', 'M', '13', 'George', 233.09016, 'paid', 'Birmingham-Hoover, AL', '1076', 'Hold You', '16')
# 1076
# ('Zion / Akon', 'Rylan', 'M', '14', 'George', 233.19465, 'paid', 'Birmingham-Hoover, AL', '1076', 'The Way She Moves', '16')
# 1076
# ('Transvision Vamp', 'Rylan', 'M', '15', 'George', 209.91955, 'paid', 'Birmingham-Hoover, AL', '1076', 'I Want Your Love', '16')
# 1096
# ('Ry Cooder', 'Chloe', 'F', '37', 'Cuevas', 201.56036, 'paid', 'San Francisco-Oakland-Hayward, CA', '1096', 'Corrido de Boxeo', '49')
# 1076
# ('The Pussycat Dolls', 'Rylan', 'M', '16', 'George', 245.18485, 'paid', 'Birmingham-Hoover, AL', '1076', 'When I Grow Up', '16')
# 1096
# ('Coldplay', 'Chloe', 'F', '38', 'Cuevas', 268.30322, 'paid', 'San Francisco-Oakland-Hayward, CA', '1096', 'Yellow', '49')
# 1076
# ('Forever The Sickest Kids', 'Rylan', 'M', '17', 'George', 169.482, 'paid', 'Birmingham-Hoover, AL', '1076', 'She Likes (Bittersweet Love)', '16')
# 1096
# ('Lil Wayne / Blaque / Mannie Fresh', 'Chloe', 'F', '39', 'Cuevas', 255.34649, 'paid', 'San Francisco-Oakland-Hayward, CA', '1096', 'Believe That', '49')
# 1076
# ('Dragonforce', 'Rylan', 'M', '18', 'George', 441.02485, 'paid', 'Birmingham-Hoover, AL', '1076', 'Through The Fire And Flames (Album Version)', '16')
# 1096
# ('Jason Mraz & Colbie Caillat', 'Chloe', 'F', '40', 'Cuevas', 189.6224, 'paid', 'San Francisco-Oakland-Hayward, CA', '1096', 'Lucky (Album Version)', '49')
# 1096
# ('Pixies', 'Chloe', 'F', '41', 'Cuevas', 181.13261, 'paid', 'San Francisco-Oakland-Hayward, CA', '1096', 'Is She Weird', '49')
# 1076
# ('Eminem', 'Rylan', 'M', '19', 'George', 251.55873, 'paid', 'Birmingham-Hoover, AL', '1076', 'Without Me', '16')
# 1096
# ('Buju Banton', 'Chloe', 'F', '42', 'Cuevas', 232.48934, 'paid', 'San Francisco-Oakland-Hayward, CA', '1096', 'Cry No More', '49')
# 1076
# ('Cage The Elephant', 'Rylan', 'M', '20', 'George', 196.38812, 'paid', 'Birmingham-Hoover, AL', '1076', 'Lotus', '16')
# 1096
# ('Barry Tuckwell/Academy of St Martin-in-the-Fields/Sir Neville Marriner', 'Chloe', 'F', '43', 'Cuevas', 277.15873, 'paid', 'San Francisco-Oakland-Hayward, CA', '1096', 'Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)', '49')
# 1076
# ('Ste Strausz', 'Rylan', 'M', '21', 'George', 285.36118, 'paid', 'Birmingham-Hoover, AL', '1076', 'Le Million', '16')
# 1096
# ('Coldplay', 'Chloe', 'F', '44', 'Cuevas', 228.62322, 'paid', 'San Francisco-Oakland-Hayward, CA', '1096', 'Only Superstition', '49')
# 1059
# ('Joe Christmas', 'Chloe', 'F', '0', 'Roth', 185.7824, 'free', 'Indianapolis-Carmel-Anderson, IN', '1059', 'Bedroom Suite', '78')
# 1076
# ('Bright Eyes', 'Rylan', 'M', '22', 'George', 313.23383, 'paid', 'Birmingham-Hoover, AL', '1076', 'A New Arrangement', '16')
# 1059
# ('Paramore', 'Chloe', 'F', '1', 'Roth', 267.65016, 'free', 'Indianapolis-Carmel-Anderson, IN', '1059', 'The Only Exception (Album Version)', '78')
# 1096
# ('J. Karjalainen & Mustat Lasit', 'Chloe', 'F', '45', 'Cuevas', 336.74404, 'paid', 'San Francisco-Oakland-Hayward, CA', '1096', 'Sinisten tÃ\x83Â¤htien alla', '49')
# 1076
# ('Philip Glass', 'Rylan', 'M', '23', 'George', 368.40444, 'paid', 'Birmingham-Hoover, AL', '1076', 'Knee 2', '16')
# 1096
# ('Alliance Ethnik', 'Chloe', 'F', '46', 'Cuevas', 195.94404, 'paid', 'San Francisco-Oakland-Hayward, CA', '1096', 'SinceritÃ\x83Â© Et Jalousie', '49')
# 1076
# ('Mew', 'Rylan', 'M', '24', 'George', 167.75791, 'paid', 'Birmingham-Hoover, AL', '1076', 'Her Voice Is Beyond Her Years', '16')
# 1076
# ('Ive Mendes', 'Rylan', 'M', '25', 'George', 238.94159, 'paid', 'Birmingham-Hoover, AL', '1076', 'If You Leave Me Now', '16')
# 1026
# ('Alliance Ethnik', 'Bronson', 'M', '1', 'Harris', 195.94404, 'free', 'Eugene, OR', '1026', 'SinceritÃ\x83Â© Et Jalousie', '33')
# 1076
# ('the bird and the bee', 'Rylan', 'M', '26', 'George', 193.802, 'paid', 'Birmingham-Hoover, AL', '1076', 'Diamond Dave', '16')
# 1026
# ('Common / Sadat X', 'Bronson', 'M', '2', 'Harris', 256.20853, 'free', 'Eugene, OR', '1026', '1999', '33')
# 1076
# ('Alanis Morissette', 'Rylan', 'M', '27', 'George', 245.15873, 'paid', 'Birmingham-Hoover, AL', '1076', 'King Of Pain (Live/Unplugged Version)', '16')
# 1026
# ('Skillet', 'Bronson', 'M', '7', 'Harris', 233.32526, 'free', 'Eugene, OR', '1026', 'Rebirthing (Album Version)', '33')
# 1076
# ('James Galway;Julian Lee', 'Rylan', 'M', '28', 'George', 218.67057, 'paid', 'Birmingham-Hoover, AL', '1076', 'Beauty and the Beast', '16')
# 1076
# ('Drop Dead_ Gorgeous', 'Rylan', 'M', '29', 'George', 156.70812, 'paid', 'Birmingham-Hoover, AL', '1076', 'Dressed For Friend Requests (Album Version)', '16')
# 1076
# ('Dwight Yoakam', 'Rylan', 'M', '30', 'George', 239.3073, 'paid', 'Birmingham-Hoover, AL', '1076', "You're The One", '16')
# 1076
# ('Trouble', 'Rylan', 'M', '31', 'George', 205.11302, 'paid', 'Birmingham-Hoover, AL', '1076', "Tuesday's Child", '16')
# 1076
# ('OneRepublic', 'Rylan', 'M', '33', 'George', 237.97506, 'paid', 'Birmingham-Hoover, AL', '1076', 'All The Right Moves', '16')
# 1076
# ('Switchblade Symphony', 'Rylan', 'M', '34', 'George', 259.5522, 'paid', 'Birmingham-Hoover, AL', '1076', 'Wicked', '16')
# 1076
# ('Sharooz', 'Rylan', 'M', '35', 'George', 234.05669, 'paid', 'Birmingham-Hoover, AL', '1076', 'My Distressor 40Khz ReRub Mix', '16')
# 1076
# ('Explosions In The Sky', 'Rylan', 'M', '36', 'George', 522.9971, 'paid', 'Birmingham-Hoover, AL', '1076', 'Six Days At The Bottom Of The Ocean', '16')
# 1114
# ('Emmylou Harris', 'Chloe', 'F', '1', 'Cuevas', 194.63791, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'Little Bird', '49')
# 1114
# ('Jack Johnson', 'Chloe', 'F', '2', 'Cuevas', 153.67791, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'The Horizon Has Been Defeated', '49')
# 1076
# ('Radiohead', 'Rylan', 'M', '37', 'George', 249.93914, 'paid', 'Birmingham-Hoover, AL', '1076', 'Everything In Its Right Place', '16')
# 1114
# ('Andrew Bird', 'Chloe', 'F', '3', 'Cuevas', 215.87546, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'Heretics', '49')
# 1076
# ('Metallica', 'Rylan', 'M', '38', 'George', 380.21179, 'paid', 'Birmingham-Hoover, AL', '1076', 'Sabbra Cadabra', '16')
# 1114
# ('Lonnie Gordon', 'Chloe', 'F', '4', 'Cuevas', 181.21098, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'Catch You Baby (Steve Pitron & Max Sanna Radio Edit)', '49')
# 1114
# ('Dropkick Murphys', 'Chloe', 'F', '5', 'Cuevas', 167.73179, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'Shattered', '49')
# 1076
# ('Eric B. & Rakim', 'Rylan', 'M', '39', 'George', 240.32608, 'paid', 'Birmingham-Hoover, AL', '1076', 'As The Rhyme Goes On', '16')
# 1114
# ('Dierks Bentley', 'Chloe', 'F', '6', 'Cuevas', 223.242, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'Settle For A Slowdown', '49')
# 1076
# ('Regina Spektor', 'Rylan', 'M', '40', 'George', 290.14159, 'paid', 'Birmingham-Hoover, AL', '1076', 'Daniel Cowman', '16')
# 1114
# ('Angelspit', 'Chloe', 'F', '7', 'Cuevas', 241.94567, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'Make You Sin', '49')
# 1114
# ('Young Gunz / Beanie Sigel', 'Chloe', 'F', '8', 'Cuevas', 292.44036, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'Roc U', '49')
# 1076
# ('DJ Dizzy', 'Rylan', 'M', '41', 'George', 221.1522, 'paid', 'Birmingham-Hoover, AL', '1076', 'Sexy Bitch', '16')
# 1076
# ('Base Ball Bear', 'Rylan', 'M', '42', 'George', 255.60771, 'paid', 'Birmingham-Hoover, AL', '1076', 'Sayonara-Nostalgia', '16')
# 1114
# ('Morcheeba', 'Chloe', 'F', '9', 'Cuevas', 101.95546, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'In The Hands Of The Gods (Featuring Biz Markie)', '49')
# 1114
# ('Bitter:Sweet', 'Chloe', 'F', '10', 'Cuevas', 194.16771, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', "Don't Forget To Breathe", '49')
# 1076
# ('Basshunter Feat. DJ Mental Theo\x19s Bazzheadz', 'Rylan', 'M', '43', 'George', 152.65914, 'paid', 'Birmingham-Hoover, AL', '1076', "Now You're Gone", '16')
# 1114
# ('BjÃ\x83Â¶rk', 'Chloe', 'F', '11', 'Cuevas', 348.57751, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'Undo', '49')
# 1076
# ('Rihanna', 'Rylan', 'M', '44', 'George', 239.75138, 'paid', 'Birmingham-Hoover, AL', '1076', 'G4L', '16')
# 1076
# ('Evanescence', 'Rylan', 'M', '45', 'George', 220.3424, 'paid', 'Birmingham-Hoover, AL', '1076', 'Hello', '16')
# 1114
# ('Mr. Vegas', 'Chloe', 'F', '12', 'Cuevas', 240.69179, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'Tamale', '49')
# 1076
# ('Mischa Daniels', 'Rylan', 'M', '46', 'George', 419.81342, 'paid', 'Birmingham-Hoover, AL', '1076', 'Another Place', '16')
# 1114
# ('The Menzingers', 'Chloe', 'F', '13', 'Cuevas', 276.00934, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'Straight To Hell', '49')
# 1114
# ('Justin Timberlake', 'Chloe', 'F', '14', 'Cuevas', 288.93995, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'Cry Me A River', '49')
# 1076
# ('Vilma Palma e Vampiros', 'Rylan', 'M', '47', 'George', 338.18077, 'paid', 'Birmingham-Hoover, AL', '1076', 'Un Camino Hasta Vos', '16')
# 1114
# ('CCCP - Fedeli Alla Linea', 'Chloe', 'F', '15', 'Cuevas', 329.66485, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'Sura (2008 Digital Remaster)', '49')
# 1076
# ('Kid Cudi / MGMT / Ratatat', 'Rylan', 'M', '48', 'George', 295.67955, 'paid', 'Birmingham-Hoover, AL', '1076', 'Pursuit Of Happiness (nightmare)', '16')
# 1114
# ('Drake / Kanye West / Lil Wayne / Eminem', 'Chloe', 'F', '16', 'Cuevas', 357.66812, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'Forever', '49')
# 1076
# ('A Day To Remember', 'Rylan', 'M', '49', 'George', 247.64036, 'paid', 'Birmingham-Hoover, AL', '1076', 'Homesick [Acoustic]', '16')
# 1085
# ('T.I.', 'Jayden', 'M', '0', 'Bell', 299.75465, 'free', 'Dallas-Fort Worth-Arlington, TX', '1085', 'Dead And Gone [feat. Justin Timberlake] (Explicit Album Version)', '91')
# 1076
# ('The Offspring', 'Rylan', 'M', '50', 'George', 163.3171, 'paid', 'Birmingham-Hoover, AL', '1076', "It'll Be a Long Time (Album Version)", '16')
# 1114
# ('Jorge Gonzalez', 'Chloe', 'F', '17', 'Cuevas', 272.14322, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'Esta Es Para Hacerte FÃ\x83Â©liz', '49')
# 1085
# ('Sneaker Pimps', 'Jayden', 'M', '1', 'Bell', 260.91057, 'free', 'Dallas-Fort Worth-Arlington, TX', '1085', 'Spin Spin Sugar', '91')
# 1076
# ('Escape The Fate', 'Rylan', 'M', '51', 'George', 266.73587, 'paid', 'Birmingham-Hoover, AL', '1076', 'This War Is Ours (The Guillotine II)', '16')
# 1114
# ('Juanes', 'Chloe', 'F', '18', 'Cuevas', 243.27791, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'La Vida Es Un Ratico', '49')
# 1076
# ('The Replacements', 'Rylan', 'M', '52', 'George', 170.57914, 'paid', 'Birmingham-Hoover, AL', '1076', 'Never Mind', '16')
# 1114
# ('Sarah McLachlan', 'Chloe', 'F', '19', 'Cuevas', 278.90893, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'Possession', '49')
# 1076
# ('Sonny Boy Williamson', 'Rylan', 'M', '53', 'George', 152.24118, 'paid', 'Birmingham-Hoover, AL', '1076', "Don't Start Me Talkin'", '16')
# 1076
# ('Soul II Soul Featuring Caron Wheeler', 'Rylan', 'M', '54', 'George', 225.2273, 'paid', 'Birmingham-Hoover, AL', '1076', 'Back To Life (However Do You Want Me) (2003 Digital Remaster) (Feat. Caron Wheeler)', '16')
# 1114
# ('Florence + The Machine', 'Chloe', 'F', '20', 'Cuevas', 219.66322, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'Dog Days Are Over (Radio Edit)', '49')
# 1076
# ('Pantera', 'Rylan', 'M', '55', 'George', 286.69342, 'paid', 'Birmingham-Hoover, AL', '1076', 'Heresy  (LP Version)', '16')
# 1114
# ('Cold', 'Chloe', 'F', '21', 'Cuevas', 177.76281, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'Remedy', '49')
# 1114
# ('Norther', 'Chloe', 'F', '22', 'Cuevas', 246.54322, 'paid', 'San Francisco-Oakland-Hayward, CA', '1114', 'Frozen Angel', '49')
# 1076
# ('Foo Fighters', 'Rylan', 'M', '57', 'George', 271.38567, 'paid', 'Birmingham-Hoover, AL', '1076', 'The Pretender', '16')
# 1076
# ('Timbiriche', 'Rylan', 'M', '58', 'George', 202.60526, 'paid', 'Birmingham-Hoover, AL', '1076', 'Besos De Ceniza', '16')
# 1076
# ('A Perfect Circle', 'Rylan', 'M', '59', 'George', 206.05342, 'paid', 'Birmingham-Hoover, AL', '1076', 'Rose', '16')
# 1076
# ('Anberlin', 'Rylan', 'M', '60', 'George', 348.682, 'paid', 'Birmingham-Hoover, AL', '1076', 'The Haunting', '16')
# 985
# ('Deas Vail', 'Elijah', 'M', '0', 'Davis', 237.68771, 'free', 'Detroit-Warren-Dearborn, MI', '985', 'Anything You Say (Unreleased Version)', '5')

# %% [markdown]
# #### Do a SELECT to verify that the data have been inserted into each table

# %%
## TO-DO: Add in the SELECT statement to verify the data was entered into the table
query = """
SELECT artist, song, length 
FROM music_by_sessionid_iteminsession
WHERE sessionId = 338
AND itemInSession = 4
"""
query = session.execute(query)
print(query)
for row in query:
    print(row)
# Out:
# <cassandra.cluster.ResultSet object at 0x7f9418ddea90>
# Row(artist='Faithless', song='Music Matters (Mark Knight Dub)', length=495.30731201171875)

# %% [markdown]
# ### COPY AND REPEAT THE ABOVE THREE CELLS FOR EACH OF THE THREE QUESTIONS

# %%
query = "drop TABLE IF EXISTS music_by_artist_song_user "
session.execute(query)
query = "CREATE TABLE IF NOT EXISTS music_by_artist_song_user "
query = query + """(
userId int, sessionId int, artist text, song text, firstName text, lastName text, 
PRIMARY KEY(userId, sessionId))
"""
try:
    session.execute(query)
except Exception as e:
    print(e)

# %%
## TO-DO: Query 2: Give me only the following: name of artist, song (sorted by itemInSession) and user (first and last name)\
## for userid = 10, sessionid = 182
file = 'event_datafile_new.csv'
with open(file, encoding = 'utf8') as f:
    csvreader = csv.reader(f)
    next(csvreader)
    for line in csvreader:
        query = "INSERT INTO music_by_artist_song_user (userId, sessionId, artist, song, firstName, lastName)"
        query = query + "VALUES (%s, %s, %s, %s, %s, %s)"
        print(line[8])
        print((int(line[10]), int(line[8]), line[0], line[9], line[1],line[4]))
        ## TO-DO: Assign which column element should be assigned for each column in the INSERT statement.
        ## For e.g., to INSERT artist_name and user first_name, you would change the code below to `line[0], line[1]`
        session.execute(query, (int(line[10]), int(line[8]), line[0], line[9], line[1], line[4]))

query = """
SELECT artist, song, firstName, lastName 
FROM music_by_artist_song_user
WHERE userId = 10
AND sessionId = 182
"""
query = session.execute(query)
print(query)
for row in query:
    print(row)
# Out:
# 583
# (26, 583, 'Harmonia', 'Sehr kosmisch', 'Ryan', 'Smith')
# 583
# (26, 583, 'The Prodigy', 'The Big Gundown', 'Ryan', 'Smith')
# 583
# (26, 583, 'Train', 'Marry Me', 'Ryan', 'Smith')
# 597
# (61, 597, 'Sony Wonder', 'Blackbird', 'Samuel', 'Gonzalez')
# 602
# (80, 602, 'Van Halen', 'Best Of Both Worlds (Remastered Album Version)', 'Tegan', 'Levine')
# 602
# (80, 602, 'Magic Sam', 'Call Me If You Need Me', 'Tegan', 'Levine')
# 602
# (80, 602, 'Edward Sharpe & The Magnetic Zeros', 'Home', 'Tegan', 'Levine')
# 602
# (80, 602, 'Usher featuring will.i.am', 'OMG', 'Tegan', 'Levine')
# 602
# (80, 602, 'Helen Reddy', 'Candle On The Water', 'Tegan', 'Levine')
# 602
# (80, 602, 'Taylor Swift', 'Our Song', 'Tegan', 'Levine')
# 602
# (80, 602, 'Sean Paul', 'Baby Boy [feat. Beyonce]', 'Tegan', 'Levine')
# 582
# (15, 582, 'Soundgarden', 'Black Hole Sun', 'Lily', 'Koch')
# 602
# (80, 602, 'The Killers', 'Human', 'Tegan', 'Levine')
# 582
# (15, 582, 'Amy Winehouse', 'Addicted', 'Lily', 'Koch')
# 582
# (15, 582, 'Steve Anderson', 'Air', 'Lily', 'Koch')
# 582
# (15, 582, 'Rob Zombie', 'Superbeast', 'Lily', 'Koch')
# 582
# (15, 582, 'Deadmau5 & Kaskade', 'I Remember', 'Lily', 'Koch')
# 607
# (26, 607, 'Shania Twain', "Don't Be Stupid (You Know I Love You)", 'Ryan', 'Smith')
# 607
# (26, 607, 'Los Campesinos', 'We throw parties_ you throw knives', 'Ryan', 'Smith')
# 606
# (49, 606, 'Ill Nino', 'How Can I Live (Spanish version) (Album Version)', 'Chloe', 'Cuevas')
# 606
# (49, 606, 'Mia X', 'Thugs Like Me', 'Chloe', 'Cuevas')
# 606
# (49, 606, 'Rage Against The Machine', 'Killing In The Name', 'Chloe', 'Cuevas')
# 606
# (49, 606, 'Asia 2001', 'Epilogue', 'Chloe', 'Cuevas')
# 606
# (49, 606, 'Muse', 'Endlessly', 'Chloe', 'Cuevas')
# 606
# (49, 606, 'Rise Against', 'Torches', 'Chloe', 'Cuevas')
# 591
# (88, 591, 'Modest Mouse', 'The Good Times Are Killing Me', 'Mohammad', 'Rodriguez')
# 606
# (49, 606, 'Marc Anthony', 'Te Conozco Bien', 'Chloe', 'Cuevas')
# 606
# (49, 606, 'Regina Spektor', 'The Calculation (Album Version)', 'Chloe', 'Cuevas')
# 611
# (80, 611, 'Nina Sky', 'Goodbye (Interlude)', 'Tegan', 'Levine')
# 324
# (30, 324, 'Five Iron Frenzy', 'Canada', 'Avery', 'Watkins')
# 324
# (30, 324, 'Kudai', 'Ven', 'Avery', 'Watkins')
# 324
# (30, 324, 'Pulp', 'Do You Remember The First Time?', 'Avery', 'Watkins')
# 324
# (30, 324, "SinÃ\x83Â©ad O'Connor", 'I Want Your (Hands On Me)', 'Avery', 'Watkins')
# 611
# (80, 611, 'Paul Brown', 'Chill Out', 'Tegan', 'Levine')
# 324
# (30, 324, 'Lasgo', 'Something (Radio Edit)', 'Avery', 'Watkins')
# 611
# (80, 611, 'Patty Loveless', "What's A Broken Heart", 'Tegan', 'Levine')
# 324
# (30, 324, 'Eddie Vedder', 'Society', 'Avery', 'Watkins')
# 611
# (80, 611, 'Rogue Wave', 'Christians In Black', 'Tegan', 'Levine')
# 324
# (30, 324, 'Muse', 'Uprising', 'Avery', 'Watkins')
# 611
# (80, 611, 'Amanda Blank', 'Might Like You Better', 'Tegan', 'Levine')
# 324
# (30, 324, 'The Smiths', 'Sheila Take A Bow', 'Avery', 'Watkins')
# 611
# (80, 611, "Old 97's", 'Victoria (LP Version)', 'Tegan', 'Levine')
# 324
# (30, 324, 'Selena', 'Dreaming Of You', 'Avery', 'Watkins')
# 611
# (80, 611, 'Fat Joe', "What's Luv? (Featuring Ja-Rule & Ashanti) (Explicit Album Version)", 'Tegan', 'Levine')
# 324
# (30, 324, 'Stars', 'Soft Revolution', 'Avery', 'Watkins')
# 611
# (80, 611, 'James Blunt', 'Same Mistake  (Album Version)', 'Tegan', 'Levine')
# 324
# (30, 324, 'Mayday Parade', 'Bruised And Scarred (Album Version)', 'Avery', 'Watkins')
# 611
# (80, 611, 'Die Mooskirchner', "Frisch und g'sund", 'Tegan', 'Levine')
# 324
# (30, 324, 'Gorillaz', 'Rockit', 'Avery', 'Watkins')
# 611
# (80, 611, 'Toby Keith', "Should've Been A Cowboy", 'Tegan', 'Levine')
# 324
# (30, 324, 'Modest Mouse', 'Little Motel', 'Avery', 'Watkins')
# 611
# (80, 611, 'Future Rock', 'Gears', 'Tegan', 'Levine')
# 324
# (30, 324, 'Noel Pointer', 'Superwoman (Where Were You When I Needed You) (Digitally Remastered)', 'Avery', 'Watkins')
# 611
# (80, 611, 'Callenish Circle', 'Forgotten', 'Tegan', 'Levine')
# 575
# (16, 575, 'Foo Fighters', 'Everlong', 'Rylan', 'George')
# 324
# (30, 324, 'Portishead', 'Hunter', 'Avery', 'Watkins')
# 611
# (80, 611, 'Taylor Swift', 'The Way I Loved You', 'Tegan', 'Levine')
# 575
# (16, 575, 'J-Live', 'Longevity', 'Rylan', 'George')
# 324
# (30, 324, 'The White Stripes', 'Fell In Love With A Girl', 'Avery', 'Watkins')
# 611
# (80, 611, 'Dwight Yoakam', "You're The One", 'Tegan', 'Levine')
# 324
# (30, 324, 'The Black Keys', 'Lies', 'Avery', 'Watkins')
# 575
# (16, 575, 'Five', "Got The Feelin'", 'Rylan', 'George')
# 611
# (80, 611, 'Ra', 'Do You Call My Name', 'Tegan', 'Levine')
# 575
# (16, 575, 'Coolio feat. L.V.', "Gangsta's Paradise (LP Version)", 'Rylan', 'George')
# 324
# (30, 324, 'Paramore', 'Misery Business (Album Version)', 'Avery', 'Watkins')
# 324
# (30, 324, 'Leggo Beast', 'Itchy Feet', 'Avery', 'Watkins')
# 575
# (16, 575, 'Nneka', 'Gypsy', 'Rylan', 'George')
# 611
# (80, 611, "Diam's", 'Dans Ma Bulle (Edit Radio - Live 2006)', 'Tegan', 'Levine')
# 575
# (16, 575, 'Haley Bonar', 'Give It Up', 'Rylan', 'George')
# 611
# (80, 611, 'Mansun', 'Love Remains (Home Demo)', 'Tegan', 'Levine')
# 324
# (30, 324, '3 Doors Down', 'Here Without You', 'Avery', 'Watkins')
# 575
# (16, 575, 'The Corrs', 'Toss The Feathers (Instrumental) ( LP Version )', 'Rylan', 'George')
# 611
# (80, 611, 'Big Tymers', 'Big', 'Tegan', 'Levine')
# 324
# (30, 324, 'Thursday', 'I Am The Killer (Album Version)', 'Avery', 'Watkins')
# 575
# (16, 575, 'Motion City Soundtrack', "Don't Call It A Comeback (Album Version)", 'Rylan', 'George')
# 611
# (80, 611, 'Usher', "Hey Daddy (Daddy's Home)", 'Tegan', 'Levine')
# 575
# (16, 575, 'Juanes', 'No Siento Penas', 'Rylan', 'George')
# 324
# (30, 324, 'The Wombats', 'Kill The Director [Radio Edit]', 'Avery', 'Watkins')
# 611
# (80, 611, 'Katy Perry', 'I Kissed A Girl', 'Tegan', 'Levine')
# 575
# (16, 575, 'As I Lay Dying', 'The Darkest Nights', 'Rylan', 'George')
# 324
# (30, 324, 'BjÃ\x83Â¶rk', 'Undo', 'Avery', 'Watkins')
# 611
# (80, 611, 'The Bobby Fuller Four', 'I Fought The Law (LP Version)', 'Tegan', 'Levine')
# 575
# (16, 575, 'Charly GarcÃ\x83Â\xada', 'Influencia', 'Rylan', 'George')
# 611
# (80, 611, 'New Bomb Turks', 'Too Much', 'Tegan', 'Levine')
# 611
# (80, 611, 'The Black Keys', 'All Hands Against His Own', 'Tegan', 'Levine')
# 324
# (30, 324, 'PeterLicht', 'Blaues Blau', 'Avery', 'Watkins')
# 611
# (80, 611, 'John Mayer', 'Friends_ Lovers Or Nothing', 'Tegan', 'Levine')
# 575
# (16, 575, 'Stone Temple Pilots', 'A Song For Sleeping (LP Version)', 'Rylan', 'George')
# 324
# (30, 324, 'Bad Lieutenant', 'Head Into Tomorrow', 'Avery', 'Watkins')
# 575
# (16, 575, 'Lily Allen', 'Smile Version Revisited (Mark Ronson Remix) (Explicit)', 'Rylan', 'George')
# 611
# (80, 611, 'Neil Halstead', 'A Gentle Heart', 'Tegan', 'Levine')
# 324
# (30, 324, 'Juanes', 'Un DÃ\x83Â\xada Normal', 'Avery', 'Watkins')
# 575
# (16, 575, 'Distance', 'Ska', 'Rylan', 'George')
# 324
# (30, 324, 'Slipknot', 'The Heretic Anthem (Album Version)', 'Avery', 'Watkins')
# 611
# (80, 611, 'Franz Ferdinand', 'Tell Her Tonight', 'Tegan', 'Levine')
# 575
# (16, 575, 'Jedi Mind Tricks', 'Suicide', 'Rylan', 'George')
# 611
# (80, 611, 'Miles Davis', 'Stella By Starlight', 'Tegan', 'Levine')
# 324
# (30, 324, 'B.o.B', "Nothin' On You [feat. Bruno Mars] (Album Version)", 'Avery', 'Watkins')
# 575
# (16, 575, 'The Avett Brothers', 'I And Love And You', 'Rylan', 'George')
# 611
# (80, 611, 'Joshua Bell / Paul Coker', 'Caprice viennois op.2', 'Tegan', 'Levine')
# 324
# (30, 324, 'Bad Brains', "Joshua's Song (1991 Digital Remaster)", 'Avery', 'Watkins')
# 324
# (30, 324, 'Shakira ft. Wyclef Jean', "Hips Don't Lie", 'Avery', 'Watkins')
# 575
# (16, 575, 'Band Of Horses', 'The Funeral (Album Version)', 'Rylan', 'George')
# 611
# (80, 611, 'Alesana', 'Ambrosia', 'Tegan', 'Levine')
# 324
# (30, 324, 'Samy Deluxe', 'Einfach Ich', 'Avery', 'Watkins')
# 611
# (80, 611, 'Corona', 'Higher Messiah', 'Tegan', 'Levine')
# 324
# (30, 324, 'The Presets', 'If I Know You', 'Avery', 'Watkins')
# 324
# (30, 324, 'Pixies', 'In Heaven', 'Avery', 'Watkins')
# 611
# (80, 611, 'Existone', 'Wounded Soul', 'Tegan', 'Levine')
# 324
# (30, 324, 'John Mayer', 'Bold As Love', 'Avery', 'Watkins')
# 324
# (30, 324, 'Zakir Hussain', 'The Great ndian Desert', 'Avery', 'Watkins')
# 611
# (80, 611, 'Jag Panzer', 'Face Of Fear', 'Tegan', 'Levine')
# 611
# (80, 611, 'Two Door Cinema Club', 'What You Know', 'Tegan', 'Levine')
# 611
# (80, 611, 'Little Anthony & The Imperials', 'Hurt', 'Tegan', 'Levine')
# 324
# (30, 324, 'AndrÃ\x83Â©s Cepeda', 'Me Lleva Tiempo', 'Avery', 'Watkins')
# 611
# (80, 611, 'Herb Alpert And The Tijuana Brass', "So What's New", 'Tegan', 'Levine')
# 324
# (30, 324, 'Ozma', 'Flight Of Yuri Gagarin', 'Avery', 'Watkins')
# 611
# (80, 611, 'Ozric Tentacles', 'Mooncalf', 'Tegan', 'Levine')
# 324
# (30, 324, 'Evanescence', 'My Immortal (Album Version)', 'Avery', 'Watkins')
# 324
# (30, 324, 'Weezer', 'Velouria', 'Avery', 'Watkins')
# 369
# (43, 369, 'Flying Lotus', 'Bad Actors', 'Jahiem', 'Miles')
# 611
# (80, 611, 'Ben Folds', "Bitches Ain't Shit", 'Tegan', 'Levine')
# 324
# (30, 324, 'matchbox twenty', 'Unwell (Album Version)', 'Avery', 'Watkins')
# 611
# (80, 611, 'Deftones', 'Feiticeira (LP Version)', 'Tegan', 'Levine')
# 324
# (30, 324, 'Silverchair', 'Without You (Album Version)', 'Avery', 'Watkins')
# 611
# (80, 611, 'Muse', 'Map Of The Problematique', 'Tegan', 'Levine')
# 324
# (30, 324, 'Zen CafÃ\x83Â©', 'Kotona kaikuu', 'Avery', 'Watkins')
# 611
# (80, 611, 'Mariah Carey / Twista', 'One And Only', 'Tegan', 'Levine')
# 324
# (30, 324, 'Strike Anywhere', 'Gunpowder', 'Avery', 'Watkins')
# 324
# (30, 324, 'Tri Sestry', 'Had Stupid', 'Avery', 'Watkins')
# 324
# (30, 324, 'Don Williams', "If Hollywood Don't Need You", 'Avery', 'Watkins')
# 324
# (30, 324, 'The Nerves', 'Are You Famous?', 'Avery', 'Watkins')
# 324
# (30, 324, 'Ulf Wakenius', 'Good Morning Susie Soho', 'Avery', 'Watkins')
# 324
# (30, 324, 'The Kooks', 'She Moves In Her Own Way', 'Avery', 'Watkins')
# 324
# (30, 324, 'New Radicals', 'You Get What You Give', 'Avery', 'Watkins')
# 324
# (30, 324, 'Wolfmother', 'Where Eagles Have Been', 'Avery', 'Watkins')
# 324
# (30, 324, 'The Shins', 'Spilt Needles (Album)', 'Avery', 'Watkins')
# 324
# (30, 324, 'Nickel Creek', 'Reasons Why', 'Avery', 'Watkins')
# 324
# (30, 324, 'Pigeon John', 'Crazy', 'Avery', 'Watkins')
# 324
# (30, 324, 'Eels', 'Love Of The Loveless', 'Avery', 'Watkins')
# 324
# (30, 324, 'Harmonia', 'Sehr kosmisch', 'Avery', 'Watkins')
# 324
# (30, 324, 'Marina And The Diamonds', 'Oh No! (album version)', 'Avery', 'Watkins')
# 324
# (30, 324, 'Eminem', 'The Real Slim Shady', 'Avery', 'Watkins')
# 324
# (30, 324, 'Hassisen Kone', 'REIPPAINA KÃ\x83Â\x84YMME REKKAIN ALLE', 'Avery', 'Watkins')
# 324
# (30, 324, 'Dwight Yoakam', "You're The One", 'Avery', 'Watkins')
# 324
# (30, 324, 'Sunlounger', 'White Sand', 'Avery', 'Watkins')
# 324
# (30, 324, "Youssou N'Dour", 'Tan bi (Heat_ Breeze_ Tenderness) / Chaleur_ brise_ tendress', 'Avery', 'Watkins')
# 324
# (30, 324, 'The Decemberists', 'Red Right Ankle', 'Avery', 'Watkins')
# 324
# (30, 324, 'The Ruts', 'Savage Circle', 'Avery', 'Watkins')
# 324
# (30, 324, 'Adrian Legg', 'The One-Eyed Turk', 'Avery', 'Watkins')
# 324
# (30, 324, 'Bedrock', 'Set In Stone', 'Avery', 'Watkins')
# 605
# (97, 605, 'Prince & The Revolution', "Let's Go Crazy (LP Version)", 'Kate', 'Harrell')
# 605
# (97, 605, 'The Zombies', "She's Coming Home", 'Kate', 'Harrell')
# 605
# (97, 605, 'Portishead', 'Numb', 'Kate', 'Harrell')
# 324
# (30, 324, 'Jack Johnson', 'Breakdown', 'Avery', 'Watkins')
# 605
# (97, 605, 'Justice', 'Let There Be Lite (Album Version)', 'Kate', 'Harrell')
# 324
# (30, 324, 'Snow Patrol', 'Set Down Your Glass', 'Avery', 'Watkins')
# 605
# (97, 605, 'Lemon Jelly', 'Nice Weather For Ducks', 'Kate', 'Harrell')
# 324
# (30, 324, 'The Lucksmiths', 'Tale Of Two Cities', 'Avery', 'Watkins')
# 605
# (97, 605, 'Ben Kweller', 'Magic', 'Kate', 'Harrell')
# 324
# (30, 324, 'Fedde le Grand Pres. Flamingo', 'Take No Shhh (Original Mix)', 'Avery', 'Watkins')
# 605
# (97, 605, 'Rodrigo y Gabriela', 'VIKING MAN', 'Kate', 'Harrell')
# 605
# (97, 605, 'Black Eyed Peas', 'I Gotta Feeling', 'Kate', 'Harrell')
# 324
# (30, 324, 'Five Iron Frenzy', 'Canada', 'Avery', 'Watkins')
# 598
# (50, 598, 'Creedence Clearwater Revival', 'Down On The Corner', 'Ava', 'Robinson')
# 598
# (50, 598, 'Kings Of Leon', 'Camaro', 'Ava', 'Robinson')
# 324
# (30, 324, 'Fireflight', 'Unbreakable', 'Avery', 'Watkins')
# 605
# (97, 605, 'Steppenwolf', 'Born To Be Wild', 'Kate', 'Harrell')
# 598
# (50, 598, 'New Found Glory', 'the king of wishful thinking', 'Ava', 'Robinson')
# 324
# (30, 324, 'The Pussycat Dolls', 'Elevator', 'Avery', 'Watkins')
# 605
# (97, 605, 'Eric Clapton', 'Willie And The Hand Jive', 'Kate', 'Harrell')
# 531
# (60, 531, 'Josh Groban', 'Little Drummer Boy [featuring guitarist Andy McKee] (Album Version)', 'Devin', 'Larson')
# 324
# (30, 324, 'The Dresden Dolls', 'Coin-Operated Boy', 'Avery', 'Watkins')
# 605
# (97, 605, 'Pixies', 'Where Is My Mind?', 'Kate', 'Harrell')
# 531
# (60, 531, 'Creedence Clearwater Revival', 'I Put A Spell On You', 'Devin', 'Larson')
# 605
# (97, 605, 'The Smiths', 'Girlfriend In A Coma', 'Kate', 'Harrell')
# 324
# (30, 324, 'Danger Doom', 'No Names (Black Debbie) (Album Version)', 'Avery', 'Watkins')
# 605
# (97, 605, 'Taylor Swift', 'Love Story', 'Kate', 'Harrell')
# 324
# (30, 324, 'Vilma Palma e Vampiros', 'La pachanga', 'Avery', 'Watkins')
# 605
# (97, 605, 'Busta Rhymes feat. Pharrell', 'Light Your Ass On Fire', 'Kate', 'Harrell')
# 324
# (30, 324, 'Little People', 'Above The Clouds', 'Avery', 'Watkins')
# 605
# (97, 605, 'Dwight Yoakam', "You're The One", 'Kate', 'Harrell')
# 324
# (30, 324, 'Amy Winehouse', 'He Can Only Hold Her', 'Avery', 'Watkins')
# 605
# (97, 605, 'Ernie K-Doe', 'Te-Ta-Te-Ta-Ta (2002 Digital Remaster)', 'Kate', 'Harrell')
# 324
# (30, 324, 'Alesana', 'Congratulations_ I Hate You', 'Avery', 'Watkins')
# 605
# (97, 605, 'Dwight Yoakam', "You're The One", 'Kate', 'Harrell')
# 324
# (30, 324, 'Gazpacho', 'Premonicion', 'Avery', 'Watkins')
# 605
# (97, 605, 'Black Lips', 'Lock and Key', 'Kate', 'Harrell')
# 605
# (97, 605, 'Kanye West', 'Stronger', 'Kate', 'Harrell')
# 324
# (30, 324, 'Arcade Fire', 'Neon Bible', 'Avery', 'Watkins')
# 324
# (30, 324, 'Barry Tuckwell/Academy of St Martin-in-the-Fields/Sir Neville Marriner', 'Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)', 'Avery', 'Watkins')
# 605
# (97, 605, 'Fanfarlo', "I'm a Pilot", 'Kate', 'Harrell')
# 324
# (30, 324, 'Crystal Castles', 'Empathy', 'Avery', 'Watkins')
# 605
# (97, 605, 'Zeca Baleiro', 'Brigitte Bardot', 'Kate', 'Harrell')
# 324
# (30, 324, 'Angus & Julia Stone', 'Just A Boy', 'Avery', 'Watkins')
# 324
# (30, 324, 'Julian Casablancas', '4 Chords of the Apocalypse', 'Avery', 'Watkins')
# 605
# (97, 605, 'Fat Joe', 'Safe 2 Say [The Incredible] (Album Version - Amended)', 'Kate', 'Harrell')
# 324
# (30, 324, "Usher Featuring Lil' Jon & Ludacris", 'Yeah!', 'Avery', 'Watkins')
# 605
# (97, 605, 'Pat Benatar', "Don't Walk Away", 'Kate', 'Harrell')
# 324
# (30, 324, 'Fergie', 'Losing My Ground', 'Avery', 'Watkins')
# 605
# (97, 605, 'Muse', 'Supermassive Black Hole (Twilight Soundtrack Version)', 'Kate', 'Harrell')
# 324
# (30, 324, 'Two Door Cinema Club', 'Undercover Martyn', 'Avery', 'Watkins')
# 605
# (97, 605, 'Spineshank', 'Intake (Album Version)', 'Kate', 'Harrell')
# 324
# (30, 324, 'Whitney Houston Duet With Mariah Carey', 'When You Believe', 'Avery', 'Watkins')
# 605
# (97, 605, 'Death Cab for Cutie', 'Transatlanticism', 'Kate', 'Harrell')
# 324
# (30, 324, 'Noir DÃ\x83Â©sir', 'Ces Gens LÃ\x83Â\xa0', 'Avery', 'Watkins')
# 605
# (97, 605, 'Paramore', 'Emergency (Album Version)', 'Kate', 'Harrell')
# 324
# (30, 324, 'My Chemical Romance', 'Cemetery Drive (Album Version)', 'Avery', 'Watkins')
# 605
# (97, 605, 'Vincent Vincent And The Villains', 'On My Own', 'Kate', 'Harrell')
# 324
# (30, 324, 'Phoenix', 'Run Run Run', 'Avery', 'Watkins')
# 605
# (97, 605, 'Beastie Boys', 'Skills To Pay The Bills', 'Kate', 'Harrell')
# 554
# (32, 554, 'Natasha Bedingfield', 'These Words', 'Lily', 'Burns')
# 324
# (30, 324, 'Calle 13', 'AtrÃ\x83Â©vete te te', 'Avery', 'Watkins')
# 605
# (97, 605, 'Sondre Lerche', 'Modern Nature', 'Kate', 'Harrell')
# 554
# (32, 554, 'Cecilia', 'Ultimo Baile', 'Lily', 'Burns')
# 324
# (30, 324, 'Air', 'Mayfair Song', 'Avery', 'Watkins')
# 605
# (97, 605, 'Five Iron Frenzy', 'Canada', 'Kate', 'Harrell')
# 554
# (32, 554, 'Kings Of Convenience', 'Riot On An Empty Street', 'Lily', 'Burns')
# 324
# (30, 324, 'Rhonda Vincent', "You're In My Heart", 'Avery', 'Watkins')
# 605
# (97, 605, 'Soulwax', 'E Talking', 'Kate', 'Harrell')
# 554
# (32, 554, 'Red', 'Mystery of You', 'Lily', 'Burns')
# 324
# (30, 324, 'Sugababes', 'Overload', 'Avery', 'Watkins')
# 554
# (32, 554, 'Eminem / Dr. Dre', 'Say What You Say', 'Lily', 'Burns')
# 605
# (97, 605, 'Michael Jackson', 'Scream', 'Kate', 'Harrell')
# 324
# (30, 324, 'Dominique A', 'Le Courage Des Oiseaux', 'Avery', 'Watkins')
# 605
# (97, 605, 'Linkin Park', 'My December', 'Kate', 'Harrell')
# 324
# (30, 324, 'Five Iron Frenzy', 'Canada', 'Avery', 'Watkins')
# 324
# (30, 324, 'Dear Nora', 'Give Me Some Of Yr Love', 'Avery', 'Watkins')
# 605
# (97, 605, 'The Police', 'Message In A Bottle', 'Kate', 'Harrell')
# 324
# (30, 324, 'Cocoon', 'Microwave', 'Avery', 'Watkins')
# 485
# (53, 485, 'Coldplay', 'A Rush Of Blood To The Head', 'Celeste', 'Williams')
# 526
# (51, 526, 'Peter And Gordon', 'A World Without Love', 'Maia', 'Burke')
# 324
# (30, 324, 'Gotye', 'Coming Back', 'Avery', 'Watkins')
# 605
# (97, 605, 'Maps', 'To The Sky', 'Kate', 'Harrell')
# 526
# (51, 526, 'Joshua Radin', "I'd Rather Be With You", 'Maia', 'Burke')
# 621
# (49, 621, "D'Angelo", 'When We Get By', 'Chloe', 'Cuevas')
# 485
# (53, 485, 'Blockhead', 'The Music Scene', 'Celeste', 'Williams')
# 588
# (63, 588, 'Nine Inch Nails', 'Terrible Lie', 'Ayla', 'Johnson')
# 526
# (51, 526, 'La Roux', 'Colourless Colour', 'Maia', 'Burke')
# 605
# (97, 605, 'Lil Wayne / Shanell', 'American Star', 'Kate', 'Harrell')
# 324
# (30, 324, 'RÃ\x83Â¶yksopp', 'What Else Is There?', 'Avery', 'Watkins')
# 621
# (49, 621, "Jack's Mannequin", 'Spinning (Album Version)', 'Chloe', 'Cuevas')
# 605
# (97, 605, 'FM Static', 'Definitely Maybe', 'Kate', 'Harrell')
# 324
# (30, 324, 'Joy Division', 'Disorder [2007 Re-mastered Album Version]', 'Avery', 'Watkins')
# 621
# (49, 621, 'N.E.R.D.', 'Rock Star', 'Chloe', 'Cuevas')
# 605
# (97, 605, 'Mickie Krause', 'Orange TrÃ\x83Â¤gt Nur Die MÃ\x83Â¼llabfuhr (Go West)', 'Kate', 'Harrell')
# 324
# (30, 324, 'Steadman', 'Wave Goodbye (Real/Rhapsody Version)', 'Avery', 'Watkins')
# 605
# (97, 605, 'The Like', 'We Are Lost', 'Kate', 'Harrell')
# 621
# (49, 621, 'Future Rock', 'Gears', 'Chloe', 'Cuevas')
# 404
# (42, 404, 'The All-American Rejects', 'Gives You Hell', 'Harper', 'Barrett')
# 324
# (30, 324, 'Bruce Springsteen', 'Born To Run', 'Avery', 'Watkins')
# 605
# (97, 605, 'OneRepublic', 'Say (All I Need)', 'Kate', 'Harrell')
# 621
# (49, 621, 'Owl City', 'Meteor Shower', 'Chloe', 'Cuevas')
# 404
# (42, 404, 'Justin Nozuka', "I'm In Peace", 'Harper', 'Barrett')
# 621
# (49, 621, 'Marina And The Diamonds', 'I Am Not a Robot', 'Chloe', 'Cuevas')
# 324
# (30, 324, 'The Serendipity Singers', "Don't Let The Rain Come Down (Crooked Little Man)", 'Avery', 'Watkins')
# 605
# (97, 605, 'Haujobb', 'Maternal Instinct', 'Kate', 'Harrell')
# 404
# (42, 404, 'Cyndi Lauper', 'My Baby Just Cares For Me', 'Harper', 'Barrett')
# 324
# (30, 324, 'Usher featuring will.i.am', 'OMG', 'Avery', 'Watkins')
# 621
# (49, 621, 'Depeche Mode', 'Everything Counts (Live) (Single Version)', 'Chloe', 'Cuevas')
# 404
# (42, 404, 'Red Hot Chili Peppers', 'Especially In Michigan (Album Version)', 'Harper', 'Barrett')
# 605
# (97, 605, '3 Doors Down', 'Kryptonite', 'Kate', 'Harrell')
# 404
# (42, 404, 'The Newbeats', 'Bread And Butter', 'Harper', 'Barrett')
# 605
# (97, 605, 'Kings Of Leon', 'Dusty', 'Kate', 'Harrell')
# 324
# (30, 324, 'Los Lobos', 'La Bamba', 'Avery', 'Watkins')
# 404
# (42, 404, 'Drake / Kanye West / Lil Wayne / Eminem', 'Forever', 'Harper', 'Barrett')
# 621
# (49, 621, 'Ginuwine', "I'm In Love", 'Chloe', 'Cuevas')
# 324
# (30, 324, 'Descendents', "I'm Not A Loser", 'Avery', 'Watkins')
# 605
# (97, 605, 'Jennifer Love Hewitt', 'BareNaked', 'Kate', 'Harrell')
# 621
# (49, 621, 'The Cinematic Orchestra', 'Burn Out', 'Chloe', 'Cuevas')
# 404
# (42, 404, 'La Fuga', 'Baja por diversion (directo 05)', 'Harper', 'Barrett')
# 605
# (97, 605, 'Killswitch Engage', 'Hope Is... (Album Version)', 'Kate', 'Harrell')
# 404
# (42, 404, 'Kid Cudi Vs Crookers', "Day 'N' Nite", 'Harper', 'Barrett')
# 605
# (97, 605, 'Beirut', 'La Llorona', 'Kate', 'Harrell')
# 404
# (42, 404, 'Fall Out Boy', 'Dance_ Dance', 'Harper', 'Barrett')
# 605
# (97, 605, "Christina Aguilera / Lil' Kim / Mya / Pink", 'Lady Marmalade', 'Kate', 'Harrell')
# 404
# (42, 404, 'Harold Budd', 'Algebra Of Darkness (Album Version)', 'Harper', 'Barrett')
# 605
# (97, 605, 'Eric Burdon & War', 'Jimbo (Album Version)', 'Kate', 'Harrell')
# 404
# (42, 404, 'Cass McCombs', 'Deseret', 'Harper', 'Barrett')
# 605
# (97, 605, 'The Black Keys', "I'll Be Your Man", 'Kate', 'Harrell')
# 404
# (42, 404, 'Leona Naess', 'Christmas', 'Harper', 'Barrett')
# 605
# (97, 605, 'Alliance Ethnik', 'ReprÃ\x83Â©sente', 'Kate', 'Harrell')
# 404
# (42, 404, 'Nando Reis', 'A Letra "A', 'Harper', 'Barrett')
# 605
# (97, 605, 'Kris Allen', "Live Like We're Dying", 'Kate', 'Harrell')
# 605
# (97, 605, 'Muse', 'Muscle Museum (Soulwax Remix)', 'Kate', 'Harrell')
# 404
# (42, 404, 'Goldfrapp', 'Lovely Head', 'Harper', 'Barrett')
# 605
# (97, 605, 'Slash', 'Doctor Alibi (featuring Lemmy Kilmister)', 'Kate', 'Harrell')
# 404
# (42, 404, 'D.R.I.', 'Stupid_ Stupid War (Dealing With It)', 'Harper', 'Barrett')
# 404
# (42, 404, 'Beastie Boys', 'Unite (2009 Digital Remaster)', 'Harper', 'Barrett')
# 605
# (97, 605, 'Cat Power', 'Hate', 'Kate', 'Harrell')
# 404
# (42, 404, 'Kings Of Leon', 'Revelry', 'Harper', 'Barrett')
# 605
# (97, 605, 'Hot Water Music', 'Translocation', 'Kate', 'Harrell')
# 404
# (42, 404, 'Miranda Lambert', 'Me And Charlie Talking', 'Harper', 'Barrett')
# 605
# (97, 605, 'Brandy duet with Monica', 'The Boy Is Mine (Duet With Monica) (LP Version)', 'Kate', 'Harrell')
# 404
# (42, 404, 'The Heavy', 'How You Like Me Now?', 'Harper', 'Barrett')
# 605
# (97, 605, 'Streetlight Manifesto', 'Point/Counterpoint (Album Version)', 'Kate', 'Harrell')
# 404
# (42, 404, 'Blitzen Trapper', 'Murder Babe (Album)', 'Harper', 'Barrett')
# 404
# (42, 404, 'Megan McCauley', 'Die For You', 'Harper', 'Barrett')
# 605
# (97, 605, 'Jack Johnson', 'Better Together', 'Kate', 'Harrell')
# 404
# (42, 404, 'Passion Pit', 'Eyes As Candles', 'Harper', 'Barrett')
# 619
# (44, 619, 'Strunz & Farah', 'Zagros', 'Aleena', 'Kirby')
# 605
# (97, 605, 'Minus The Bear', 'Part 2', 'Kate', 'Harrell')
# 404
# (42, 404, 'Van Halen', 'Eruption (Album Version)', 'Harper', 'Barrett')
# 605
# (97, 605, 'Pavement', 'Heaven Is A Truck', 'Kate', 'Harrell')
# 404
# (42, 404, 'Alliance Ethnik', 'SinceritÃ\x83Â© Et Jalousie', 'Harper', 'Barrett')
# 619
# (44, 619, 'Pieces Of A Dream', 'Keep It Smooth', 'Aleena', 'Kirby')
# 605
# (97, 605, 'Creedence Clearwater Revival', 'Born On The Bayou', 'Kate', 'Harrell')
# 404
# (42, 404, 'Anouk', "It's So Hard", 'Harper', 'Barrett')
# 619
# (44, 619, 'Jaco Pastorius Big Band', 'Amerika (Album Version)', 'Aleena', 'Kirby')
# 619
# (44, 619, 'Avril Lavigne', "I'm With You", 'Aleena', 'Kirby')
# 605
# (97, 605, 'Gonzalo Rubalcaba', 'Circuito III', 'Kate', 'Harrell')
# 404
# (42, 404, 'BjÃ\x83Â¶rk', 'Undo', 'Harper', 'Barrett')
# 619
# (44, 619, 'Ska-P', 'Casposos', 'Aleena', 'Kirby')
# 404
# (42, 404, 'The Strokes', 'Is This It', 'Harper', 'Barrett')
# 619
# (44, 619, 'Jesse Belvin', 'Goodnight My Love', 'Aleena', 'Kirby')
# 404
# (42, 404, 'Alliance Ethnik', 'Creil City', 'Harper', 'Barrett')
# 605
# (97, 605, 'The Gerbils', '(iii)', 'Kate', 'Harrell')
# 605
# (97, 605, 'KJ-52', 'Life After Death', 'Kate', 'Harrell')
# 619
# (44, 619, 'Mariah Carey', 'All I Want For Christmas Is You', 'Aleena', 'Kirby')
# 404
# (42, 404, 'Glen Hansard & Marketa Irglova', 'The Moon (Album version)', 'Harper', 'Barrett')
# 605
# (97, 605, 'Dion & The Belmonts', 'A Teenager In Love', 'Kate', 'Harrell')
# 600
# (89, 600, 'Jack Johnson', 'Bubble Toes', 'Kynnedi', 'Sanchez')
# 619
# (44, 619, 'Beastie Boys', 'The Maestro', 'Aleena', 'Kirby')
# 605
# (97, 605, 'Lesley Gore', "It's My Party", 'Kate', 'Harrell')
# 404
# (42, 404, 'Dr. Dre / Snoop Dogg', 'The Next Episode', 'Harper', 'Barrett')
# 619
# (44, 619, 'Pearl Jam', 'Encore Break', 'Aleena', 'Kirby')
# 600
# (89, 600, 'Cake', 'Commissioning A Symphony In C', 'Kynnedi', 'Sanchez')
# 605
# (97, 605, 'Phoenix', 'Rome', 'Kate', 'Harrell')
# 619
# (44, 619, 'Alesana', 'Seduction (album)', 'Aleena', 'Kirby')
# 404
# (42, 404, 'The Kooks', 'She Moves In Her Own Way', 'Harper', 'Barrett')
# 404
# (42, 404, 'Dakis', 'La Petite Marie (2005 Digital Remaster)', 'Harper', 'Barrett')
# 605
# (97, 605, 'Limp Bizkit', "Rollin' (Air Raid Vehicle)", 'Kate', 'Harrell')
# 619
# (44, 619, 'JET', 'Move On (Album Version)', 'Aleena', 'Kirby')
# 404
# (42, 404, 'Mickie Krause', 'Orange TrÃ\x83Â¤gt Nur Die MÃ\x83Â¼llabfuhr (Go West)', 'Harper', 'Barrett')
# 605
# (97, 605, 'Hot Chip', 'My Piano (DJ-Kicks)', 'Kate', 'Harrell')
# 619
# (44, 619, 'Yung Berg', "Do That There (featuring Dude 'N Nem)", 'Aleena', 'Kirby')
# 404
# (42, 404, 'Kings Of Leon', 'Closer', 'Harper', 'Barrett')
# 619
# (44, 619, 'Johan', 'Life On Mars', 'Aleena', 'Kirby')
# 605
# (97, 605, 'Crystal Castles', 'Love And Caring', 'Kate', 'Harrell')
# 404
# (42, 404, 'Thirteen Senses', 'Lead Us', 'Harper', 'Barrett')
# 605
# (97, 605, 'Eisbrecher', 'Adrenalin', 'Kate', 'Harrell')
# 619
# (44, 619, 'Buckcherry', 'Crazy Bitch (Album Version)', 'Aleena', 'Kirby')
# 404
# (42, 404, 'Band Of Horses', 'The General Specific (Album)', 'Harper', 'Barrett')
# 605
# (97, 605, 'Darkseed', 'Speak Silence', 'Kate', 'Harrell')
# 619
# (44, 619, 'Caetano Veloso', 'O Samba E O Tango', 'Aleena', 'Kirby')
# 404
# (42, 404, 'Maria Arredondo', 'Burning', 'Harper', 'Barrett')
# 619
# (44, 619, 'Boyzone', 'All That I Need', 'Aleena', 'Kirby')
# 605
# (97, 605, 'Coldplay', 'Trouble', 'Kate', 'Harrell')
# 404
# (42, 404, 'matchbox twenty', 'Unwell (Album Version)', 'Harper', 'Barrett')
# 619
# (44, 619, 'Sussie 4', 'On Time', 'Aleena', 'Kirby')
# 605
# (97, 605, 'Klaxons', 'Golden Skans', 'Kate', 'Harrell')
# 404
# (42, 404, 'Prince', 'Hot Thing ( LP Version )', 'Harper', 'Barrett')
# 605
# (97, 605, 'Dwight Yoakam', "You're The One", 'Kate', 'Harrell')
# 619
# (44, 619, 'Damian Marley / Capleton / Drag-On / Stephen Marley', 'It Was Written', 'Aleena', 'Kirby')
# 605
# (97, 605, 'Markus KrunegÃ\x83Â¥rd', 'Genom tunna tyger', 'Kate', 'Harrell')
# 404
# (42, 404, 'Kamera', 'I Was Made', 'Harper', 'Barrett')
# 605
# (97, 605, 'Rainer Weichhold vs. Dandi & Ugo', 'Infinite Template', 'Kate', 'Harrell')
# 619
# (44, 619, 'Sondre Lerche', 'Face The Blood', 'Aleena', 'Kirby')
# 404
# (42, 404, 'John Mayer', 'Slow Dancing In A Burning Room', 'Harper', 'Barrett')
# 619
# (44, 619, 'Mystikal', 'Alright', 'Aleena', 'Kirby')
# 404
# (42, 404, 'Luis Fonsi', 'Aunque Estes Con El', 'Harper', 'Barrett')
# 619
# (44, 619, 'Angelic Upstarts', 'Two Million Voices', 'Aleena', 'Kirby')
# 605
# (97, 605, 'Tonic', 'Count On Me (Somebody)', 'Kate', 'Harrell')
# 619
# (44, 619, 'Enya', 'Exile', 'Aleena', 'Kirby')
# 404
# (42, 404, 'Lily Allen', "Everyone's At It", 'Harper', 'Barrett')
# 605
# (97, 605, 'Lissi Dancefloor Disaster', "I'M Gonna Keep On Driving My Car", 'Kate', 'Harrell')
# 619
# (44, 619, 'M.I.A.', 'Paper Planes', 'Aleena', 'Kirby')
# 605
# (97, 605, 'India.Arie', 'Interested', 'Kate', 'Harrell')
# 404
# (42, 404, 'AFI', 'This Celluloid Dream', 'Harper', 'Barrett')
# 619
# (44, 619, '3 Doors Down', "She Don't Want The World", 'Aleena', 'Kirby')
# 605
# (97, 605, 'Linkin Park', 'Points Of Authority (Album Version)', 'Kate', 'Harrell')
# 404
# (42, 404, 'Leatherface and Hot Water Music', 'Gang Party (Leatherface)', 'Harper', 'Barrett')
# 619
# (44, 619, 'Agnes', 'Release Me', 'Aleena', 'Kirby')
# 605
# (97, 605, 'Weezer', 'Island In The Sun', 'Kate', 'Harrell')
# 404
# (42, 404, 'Scandinavian Music Group', 'Kun Puut Tekee SeittiÃ\x83Â¤', 'Harper', 'Barrett')
# 619
# (44, 619, 'Caparezza', 'Fuori Dal Tunnel (Album Version)', 'Aleena', 'Kirby')
# 605
# (97, 605, 'Billy Idol', 'Flesh For Fantasy', 'Kate', 'Harrell')
# 619
# (44, 619, 'Charttraxx Karaoke', 'Fireflies', 'Aleena', 'Kirby')
# 605
# (97, 605, 'Michael BublÃ\x83Â©', "Can't Help Falling In Love (Album Version) (Studio)", 'Kate', 'Harrell')
# 404
# (42, 404, 'Amos Lee', 'Baby I Want You', 'Harper', 'Barrett')
# 619
# (44, 619, 'The Notorious B.I.G.', 'Big Poppa', 'Aleena', 'Kirby')
# 619
# (44, 619, 'The Spinanes', 'Azure (Album)', 'Aleena', 'Kirby')
# 619
# (44, 619, 'Coldplay', 'Brothers & Sisters', 'Aleena', 'Kirby')
# 619
# (44, 619, 'Evanescence', 'Good Enough', 'Aleena', 'Kirby')
# 619
# (44, 619, 'L-Kan', 'Cuentos chinos', 'Aleena', 'Kirby')
# 619
# (44, 619, 'Peter Mulvey', 'Hidden Love', 'Aleena', 'Kirby')
# 619
# (44, 619, 'Beverley Craven', 'Promise Me', 'Aleena', 'Kirby')
# 619
# (44, 619, 'The Lonely Island / Julian Casablancas', 'Boombox', 'Aleena', 'Kirby')
# 619
# (44, 619, 'Three Days Grace', 'Just Like You', 'Aleena', 'Kirby')
# 619
# (44, 619, 'The Ethiopians', 'Woman Capture Man', 'Aleena', 'Kirby')
# 619
# (44, 619, 'Fozzy', 'Watch Me Shine (Album)', 'Aleena', 'Kirby')
# 619
# (44, 619, 'Silversun Pickups', 'Booksmart Devil', 'Aleena', 'Kirby')
# 619
# (44, 619, 'Lionel Richie', 'Lady', 'Aleena', 'Kirby')
# 630
# (49, 630, 'Margaret Cho', 'Gay Porn', 'Chloe', 'Cuevas')
# 619
# (44, 619, 'A Day To Remember', 'Heart Less', 'Aleena', 'Kirby')
# 630
# (49, 630, 'Armored Saint', 'Human Vulture', 'Chloe', 'Cuevas')
# 619
# (44, 619, 'The Dropkick Murphys', 'The State Of Massachusetts', 'Aleena', 'Kirby')
# 619
# (44, 619, 'Fall Out Boy', 'Beat It', 'Aleena', 'Kirby')
# 630
# (49, 630, 'Beck', 'Girl Dreams', 'Chloe', 'Cuevas')
# 630
# (49, 630, 'Beastie Boys', 'Intergalactic', 'Chloe', 'Cuevas')
# 619
# (44, 619, 'Fall Out Boy', 'Thnks fr th Mmrs', 'Aleena', 'Kirby')
# 630
# (49, 630, 'keller williams', '221', 'Chloe', 'Cuevas')
# 619
# (44, 619, 'Al Gromer Khan', 'A Hundred Moons', 'Aleena', 'Kirby')
# 630
# (49, 630, 'Benny Benassi Presents The Biz', 'Love Is Gonna Save Us ', 'Chloe', 'Cuevas')
# 619
# (44, 619, 'Symphony X', 'Evolution (the Grand Design)', 'Aleena', 'Kirby')
# 630
# (49, 630, 'Kajagoogoo', 'Big Apple (Metro Mix)', 'Chloe', 'Cuevas')
# 619
# (44, 619, 'Jamiroquai', 'Virtual Insanity', 'Aleena', 'Kirby')
# 630
# (49, 630, 'Justin Bieber', 'Somebody To Love', 'Chloe', 'Cuevas')
# 619
# (44, 619, 'Bruce Willis', 'Save The Last Dance For Me', 'Aleena', 'Kirby')
# 630
# (49, 630, 'The Killers', 'Read My Mind', 'Chloe', 'Cuevas')
# 619
# (44, 619, 'Sharleen Spiteri', 'Cat People (Putting Out Fire)', 'Aleena', 'Kirby')
# 630
# (49, 630, 'Alliance Ethnik', 'ReprÃ\x83Â©sente', 'Chloe', 'Cuevas')
# 619
# (44, 619, 'The Cardigans', 'Lovefool', 'Aleena', 'Kirby')
# 619
# (44, 619, 'Black Kids', "I'm Not Gonna Teach Your Boyfriend How To Dance With You", 'Aleena', 'Kirby')
# 630
# (49, 630, 'Parachute', 'She Is Love', 'Chloe', 'Cuevas')
# 630
# (49, 630, 'Mudcrutch', 'The Wrong Thing To Do (Album Version)', 'Chloe', 'Cuevas')
# 619
# (44, 619, 'Simon Harris', 'Sample Track 2', 'Aleena', 'Kirby')
# 630
# (49, 630, 'Sufjan Stevens', 'Movement III - Linear Tableau with Intersecting Surprise', 'Chloe', 'Cuevas')
# 619
# (44, 619, 'Charlie Patton', 'Green River Blues', 'Aleena', 'Kirby')
# 619
# (44, 619, 'Basshunter', 'Walk On Water', 'Aleena', 'Kirby')
# 630
# (49, 630, 'Lindisfarne', 'Fog On The Tyne (Live)', 'Chloe', 'Cuevas')
# 619
# (44, 619, 'Kanye West', 'Jesus Walks', 'Aleena', 'Kirby')
# 630
# (49, 630, 'Ariane Moffatt', 'Retourne Chez Elle', 'Chloe', 'Cuevas')
# 619
# (44, 619, 'Linkin Park', 'Runaway (Album Version)', 'Aleena', 'Kirby')
# 619
# (44, 619, 'The Beach Boys', "You've Got To Hide Your Love Away (Digitally Remastered 01)", 'Aleena', 'Kirby')
# 630
# (49, 630, 'No Doubt', "Don't Speak", 'Chloe', 'Cuevas')
# 619
# (44, 619, 'Queens Of The Stone Age', 'God Is On The Radio', 'Aleena', 'Kirby')
# 630
# (49, 630, 'LMFAO / Lil Jon', 'Shots', 'Chloe', 'Cuevas')
# 630
# (49, 630, 'The Suicide Machines', 'High Anxiety', 'Chloe', 'Cuevas')
# 619
# (44, 619, 'Kate Nash', 'Mariella', 'Aleena', 'Kirby')
# 630
# (49, 630, 'The Saturdays', 'If This Is Love', 'Chloe', 'Cuevas')
# 619
# (44, 619, 'Frou Frou', 'Holding Out For A Hero', 'Aleena', 'Kirby')
# 630
# (49, 630, 'Flaw', 'Get Up Again', 'Chloe', 'Cuevas')
# 630
# (49, 630, 'Liz Callaway', 'Journey To The Past  (LP Version)', 'Chloe', 'Cuevas')
# 619
# (44, 619, 'Les MisÃ\x83Â©rables - Original London Cast', 'Finale', 'Aleena', 'Kirby')
# 630
# (49, 630, "Lady GaGa / Colby O'Donis", 'Just Dance', 'Chloe', 'Cuevas')
# 619
# (44, 619, 'Cozy Powell', 'Dance With The Devil', 'Aleena', 'Kirby')
# 630
# (49, 630, 'Animal Collective', 'Bluish', 'Chloe', 'Cuevas')
# 619
# (44, 619, 'Blink-182', 'A New Hope', 'Aleena', 'Kirby')
# 482
# (35, 482, 'Charisma', 'Loon Garden', 'Molly', 'Taylor')
# 630
# (49, 630, 'Dido', 'Thank You', 'Chloe', 'Cuevas')
# 619
# (44, 619, "Screamin' Jay Hawkins", 'The Whammy', 'Aleena', 'Kirby')
# 619
# (44, 619, 'Silverchair', 'All Across The World', 'Aleena', 'Kirby')
# 630
# (49, 630, 'Emery', 'The Ponytail Parades', 'Chloe', 'Cuevas')
# 619
# (44, 619, 'Hockey', 'Song Away', 'Aleena', 'Kirby')
# 561
# (76, 561, 'Flight Of The Conchords', 'Hurt Feelings', 'Jayden', 'Duffy')
# 630
# (49, 630, 'Mike Posner', 'Cooler Than Me', 'Chloe', 'Cuevas')
# 619
# (44, 619, 'Juana Molina', 'Medlong', 'Aleena', 'Kirby')
# 561
# (76, 561, 'Nancy Sinatra', 'So Long_ Babe (2006 Digital Remaster)', 'Jayden', 'Duffy')
# 630
# (49, 630, 'Joy Division', 'I Remember Nothing [2007 Re-mastered Album Version]', 'Chloe', 'Cuevas')
# 619
# (44, 619, 'Elvis Presley', 'Suspicious Minds', 'Aleena', 'Kirby')
# 630
# (49, 630, 'Kings Of Leon', 'Revelry', 'Chloe', 'Cuevas')
# 619
# (44, 619, "Kanye West / Consequence / Cam'Ron", 'Gone', 'Aleena', 'Kirby')
# 630
# (49, 630, 'Johnny Winter', "It's My Own Fault", 'Chloe', 'Cuevas')
# 619
# (44, 619, 'Greg Brown', "I Believe I'll Go Back Home", 'Aleena', 'Kirby')
# 619
# (44, 619, 'Wim Mertens', 'Naviamente', 'Aleena', 'Kirby')
# 630
# (49, 630, 'Ra Ra Riot', 'Can You Tell', 'Chloe', 'Cuevas')
# 619
# (44, 619, 'Foo Fighters', 'What If I Do?', 'Aleena', 'Kirby')
# 619
# (44, 619, 'Vanessa Williams', 'Colors Of The Wind', 'Aleena', 'Kirby')
# 619
# (44, 619, 'Gyllene Tider', '(Hon Vill Ha) Puls', 'Aleena', 'Kirby')
# 630
# (49, 630, 'Ska Cubano', 'Cumbia En Do Menor', 'Chloe', 'Cuevas')
# 619
# (44, 619, 'Train', 'Marry Me', 'Aleena', 'Kirby')
# 619
# (44, 619, 'Camera Obscura', 'Teenager', 'Aleena', 'Kirby')
# 630
# (49, 630, 'Liah', 'Tudo Que Eu Sempre Quis', 'Chloe', 'Cuevas')
# 619
# (44, 619, 'Rise Against', 'Audience Of One', 'Aleena', 'Kirby')
# 619
# (44, 619, 'Rise Against', 'My Life Inside Your Heart', 'Aleena', 'Kirby')
# 619
# (44, 619, 'Sly Fox', "Let's Go All The Way (Short Blix Mix)", 'Aleena', 'Kirby')
# 619
# (44, 619, 'Heart', 'Crazy On You', 'Aleena', 'Kirby')
# 619
# (44, 619, 'Ugly Kid Joe', 'Cats In The Cradle', 'Aleena', 'Kirby')
# 637
# (44, 637, 'Traveling Wilburys', 'You Took My Breath Away (2007 Remastered LP Version)', 'Aleena', 'Kirby')
# 637
# (44, 637, 'Michael BublÃ\x83Â©', 'A Foggy Day (In London Town) (Album Version)', 'Aleena', 'Kirby')
# 637
# (44, 637, 'S Club 7', 'Have You Ever', 'Aleena', 'Kirby')
# 637
# (44, 637, 'Hevia', 'Fandangu Los Llobos', 'Aleena', 'Kirby')
# 637
# (44, 637, 'Billy Talent', 'Voices Of Violence (Album Version)', 'Aleena', 'Kirby')
# 637
# (44, 637, 'Phoenix', 'Courtesy Laughs', 'Aleena', 'Kirby')
# 637
# (44, 637, 'Kanye West', "We Don't Care", 'Aleena', 'Kirby')
# 637
# (44, 637, 'Damero feat. Nevis Peak', 'Gestern_Morgen', 'Aleena', 'Kirby')
# 637
# (44, 637, 'Shakira', 'Que Me Quedes Tu', 'Aleena', 'Kirby')
# 637
# (44, 637, 'Big Kuntry King', 'Da Baddest [Feat. Trey Songz] (Explicit Album Version)', 'Aleena', 'Kirby')
# 818
# (15, 818, 'Dee Dee Bridgewater', 'La Vie En Rose', 'Lily', 'Koch')
# 818
# (15, 818, "Tim O'brien", 'Think About Last Night', 'Lily', 'Koch')
# 818
# (15, 818, 'Nirvana', 'Love Buzz', 'Lily', 'Koch')
# 818
# (15, 818, 'Weezer', 'Only In Dreams', 'Lily', 'Koch')
# 818
# (15, 818, 'Nightwish', 'She Is My Sin', 'Lily', 'Koch')
# 818
# (15, 818, 'California Swag District', 'Teach Me How To Dougie', 'Lily', 'Koch')
# 818
# (15, 818, 'Miike Snow', 'Silvia', 'Lily', 'Koch')
# 818
# (15, 818, 'Katy Perry', 'I Kissed A Girl', 'Lily', 'Koch')
# 818
# (15, 818, 'Sikth', 'Peep Show', 'Lily', 'Koch')
# 818
# (15, 818, 'Lily Allen', 'Not Fair', 'Lily', 'Koch')
# 818
# (15, 818, 'The Presidents of the United States of America', 'Lump', 'Lily', 'Koch')
# 818
# (15, 818, 'Wordsworth', 'Right Now (Produced by Ayatollah)', 'Lily', 'Koch')
# 818
# (15, 818, 'Rihanna', 'Take A Bow', 'Lily', 'Koch')
# 818
# (15, 818, 'Tomas Bodin', 'Back To The African Garden', 'Lily', 'Koch')
# 818
# (15, 818, 'Black Eyed Peas', 'My Humps', 'Lily', 'Koch')
# 818
# (15, 818, 'Carolina Liar', "Show Me What I'm Looking For (Album Version)", 'Lily', 'Koch')
# 818
# (15, 818, 'Kansas', 'Dust in The Wind', 'Lily', 'Koch')
# 818
# (15, 818, 'Onar', 'Xehasmeni Melodia', 'Lily', 'Koch')
# 818
# (15, 818, 'Live', "Lakini's Juice", 'Lily', 'Koch')
# 818
# (15, 818, 'Abstract Rude', 'Nuff Fire', 'Lily', 'Koch')
# 818
# (15, 818, 'Johnny Horton', 'Mean Mean Son Of A Gun', 'Lily', 'Koch')
# 818
# (15, 818, "The Men They Couldn't Hang", 'Ironmasters', 'Lily', 'Koch')
# 818
# (15, 818, 'Rilo Kiley', 'The Absence Of God (Album Version)', 'Lily', 'Koch')
# 818
# (15, 818, 'Shwayze', 'Lost My Mind', 'Lily', 'Koch')
# 818
# (15, 818, 'Bram Vermeulen', 'Mamma', 'Lily', 'Koch')
# 818
# (15, 818, 'Death Cab for Cutie', 'I Will Follow You into the Dark (Album Version)', 'Lily', 'Koch')
# 818
# (15, 818, 'Dwight Yoakam', "You're The One", 'Lily', 'Koch')
# 818
# (15, 818, 'Jadakiss / Ghostface Killah / Raekwon', 'Cartel Gathering', 'Lily', 'Koch')
# 818
# (15, 818, 'Rosana', 'Si tu no estas', 'Lily', 'Koch')
# 818
# (15, 818, 'The Killers', 'The Ballad of Michael Valentine', 'Lily', 'Koch')
# 818
# (15, 818, 'Alliance Ethnik', 'SinceritÃ\x83Â© Et Jalousie', 'Lily', 'Koch')
# 818
# (15, 818, 'Enya', 'China Roses', 'Lily', 'Koch')
# 818
# (15, 818, 'Aya RL', 'Jazz', 'Lily', 'Koch')
# 820
# (26, 820, 'Clor', 'Love + Pain', 'Ryan', 'Smith')
# 820
# (26, 820, 'Alejandro Fernandez', 'Solitario Y Solo', 'Ryan', 'Smith')
# 820
# (26, 820, 'Yonder Mountain String Band', 'Midwest Gospel Radio', 'Ryan', 'Smith')
# 824
# (50, 824, "K'Naan", "Wavin'  Flag", 'Ava', 'Robinson')
# 828
# (97, 828, 'Cradle Of Filth', 'Her Ghost In The Fog', 'Kate', 'Harrell')
# 828
# (97, 828, 'Amanda Marshall', 'Let It Rain', 'Kate', 'Harrell')
# 828
# (97, 828, 'Rammstein', 'Sonne', 'Kate', 'Harrell')
# 828
# (97, 828, 'Cat Stevens', 'If You Want To Sing Out_ Sing Out', 'Kate', 'Harrell')
# 828
# (97, 828, 'Emma Shapplin', 'Spente Le Stelle', 'Kate', 'Harrell')
# 828
# (97, 828, 'Modest Mouse', 'Float On', 'Kate', 'Harrell')
# 828
# (97, 828, 'Flaco Jimenez', 'En El Cielo No Hay Cerveza (In Heaven There Is No Beer)', 'Kate', 'Harrell')
# 828
# (97, 828, 'Modest Mouse', 'Float On', 'Kate', 'Harrell')
# 828
# (97, 828, 'Cedric Gervais feat. Second Sun', 'Pills (Radio Edit) (Radio Edit)', 'Kate', 'Harrell')
# 828
# (97, 828, 'Sheena Easton', 'Strut (1993 Digital Remaster)', 'Kate', 'Harrell')
# 828
# (97, 828, 'Everything But The Girl', "My Baby Don't Love Me", 'Kate', 'Harrell')
# 828
# (97, 828, 'Florence + The Machine', 'Dog Days Are Over (Radio Edit)', 'Kate', 'Harrell')
# 828
# (97, 828, 'BoDeans', 'Naked (Live)', 'Kate', 'Harrell')
# 828
# (97, 828, 'OneRepublic', 'Apologize', 'Kate', 'Harrell')
# 828
# (97, 828, 'Miley Cyrus', 'Full Circle', 'Kate', 'Harrell')
# 828
# (97, 828, 'Coldplay', "Don't Panic", 'Kate', 'Harrell')
# 828
# (97, 828, 'Atreyu', "You Were The King_ Now You're Unconscious (Album Version)", 'Kate', 'Harrell')
# 828
# (97, 828, 'Bruce Springsteen', 'Born To Run', 'Kate', 'Harrell')
# 828
# (97, 828, 'BjÃ\x83Â¶rk', 'Undo', 'Kate', 'Harrell')
# 828
# (97, 828, 'Big Shug', "It Just Don't Stop", 'Kate', 'Harrell')
# 828
# (97, 828, 'The Wallflowers', 'Be Your Own Girl', 'Kate', 'Harrell')
# 828
# (97, 828, 'Chris Brown', "Ain't No Way (You Won't Love Me)", 'Kate', 'Harrell')
# 828
# (97, 828, 'Charly GarcÃ\x83Â\xada', 'Filosofia Barata Y Zapatos De Goma', 'Kate', 'Harrell')
# 828
# (97, 828, 'N.W.A ft. Eazy-E', 'Boyz-N-The-Hood', 'Kate', 'Harrell')
# 828
# (97, 828, 'The Mighty Mighty Bosstones', '1/2/2008', 'Kate', 'Harrell')
# 828
# (97, 828, 'Beastie Boys', 'Unite (2009 Digital Remaster)', 'Kate', 'Harrell')
# 828
# (97, 828, 'Yuksek', 'Take A Ride', 'Kate', 'Harrell')
# 828
# (97, 828, 'Fernando Ubiergo', 'Cuando Agosto Era 21', 'Kate', 'Harrell')
# 828
# (97, 828, 'Phoenix', 'Napoleon Says', 'Kate', 'Harrell')
# 790
# (101, 790, 'Radney Foster', 'Sweet And Wild', 'Jayden', 'Fox')
# 790
# (101, 790, 'Neneh Cherry', 'Manchild', 'Jayden', 'Fox')
# 785
# (63, 785, 'Hooligans', 'Szex & KV', 'Ayla', 'Johnson')
# 786
# (32, 786, 'Kid Cudi / MGMT / Ratatat', 'Pursuit Of Happiness (nightmare)', 'Lily', 'Burns')
# 351
# (23, 351, 'Foals', 'Blue Blood', 'Morris', 'Gilmore')
# 351
# (23, 351, "'N Sync/Phil Collins", "Trashin' The Camp (Phil And 'N Sync Version)", 'Morris', 'Gilmore')
# 838
# (101, 838, 'Kristian Stanfill', 'I Need You', 'Jayden', 'Fox')
# 838
# (101, 838, 'Enrique Iglesias', 'Tired Of Being Sorry', 'Jayden', 'Fox')
# 838
# (101, 838, 'Michael Cretu', 'The Invisible Man', 'Jayden', 'Fox')
# 838
# (101, 838, 'Tommy Emmanuel', 'Windy & Warm', 'Jayden', 'Fox')
# 772
# (83, 772, 'Cherise', 'No Good 4 You', 'Stefany', 'White')
# 662
# (76, 662, 'Anna Waronker', 'Nothing Personal', 'Jayden', 'Duffy')
# 763
# (6, 763, 'King ChangÃ\x83Â³', 'ConfesiÃ\x83Â³n', 'Cecilia', 'Owens')
# 763
# (6, 763, 'Gang Of Four', 'I Found That Essence Rare', 'Cecilia', 'Owens')
# 763
# (6, 763, 'Line Renaud', 'Le Soir', 'Cecilia', 'Owens')
# 823
# (80, 823, 'the bird and the bee', 'Last Day Of Our Love', 'Tegan', 'Levine')
# 275
# (42, 275, 'Muse', 'Supermassive Black Hole (Twilight Soundtrack Version)', 'Harper', 'Barrett')
# 275
# (42, 275, 'Beastie Boys', 'Lighten Up', 'Harper', 'Barrett')
# 275
# (42, 275, 'Shakira', 'Pienso En Ti', 'Harper', 'Barrett')
# 275
# (42, 275, 'Selena', 'Amor Prohibido', 'Harper', 'Barrett')
# 275
# (42, 275, 'Kid Cudi Vs Crookers', "Day 'N' Nite", 'Harper', 'Barrett')
# 275
# (42, 275, 'Rise Against', 'Black Masks & Gasoline', 'Harper', 'Barrett')
# 275
# (42, 275, 'Fall Out Boy', "I'm Like A Lawyer With The Way I'm Always Trying To Get You Off (Me & You)", 'Harper', 'Barrett')
# 275
# (42, 275, 'Jack Johnson', 'Staple It Together', 'Harper', 'Barrett')
# 275
# (42, 275, 'Twista feat. Kayne West & Jamie Foxx', 'Slow Jamz (Feat. Kanye West & Jamie Foxx) (Edited Album Version)', 'Harper', 'Barrett')
# 275
# (42, 275, 'Train', 'Hey_ Soul Sister', 'Harper', 'Barrett')
# 275
# (42, 275, 'Rihanna', 'Rehab', 'Harper', 'Barrett')
# 275
# (42, 275, 'Man Man', 'Van Helsing Boombox', 'Harper', 'Barrett')
# 275
# (42, 275, 'Ween', 'The Stallion', 'Harper', 'Barrett')
# 275
# (42, 275, 'Charttraxx Karaoke', 'Fireflies', 'Harper', 'Barrett')
# 275
# (42, 275, 'Digitalism', 'I Want I Want', 'Harper', 'Barrett')
# 275
# (42, 275, 'Dispatch', 'Railway', 'Harper', 'Barrett')
# 275
# (42, 275, 'Postal Service', 'Clark Gable (Album)', 'Harper', 'Barrett')
# 275
# (42, 275, 'Patricia Barber', 'Phaeton', 'Harper', 'Barrett')
# 275
# (42, 275, 'Enur', 'Ucci Ucci feat. Nicki Minaj & The Chopper City Boyz', 'Harper', 'Barrett')
# 275
# (42, 275, 'Hybrid', 'Choke', 'Harper', 'Barrett')
# 275
# (42, 275, 'Riverside', 'Stuck Between', 'Harper', 'Barrett')
# 275
# (42, 275, 'Enigma', 'Smell Of Desire.', 'Harper', 'Barrett')
# 275
# (42, 275, 'Arcade Fire', 'Headlights Look Like Diamonds', 'Harper', 'Barrett')
# 275
# (42, 275, 'Spoon', 'Out Go The Lights', 'Harper', 'Barrett')
# 275
# (42, 275, 'The Wannadies', 'You & Me Song', 'Harper', 'Barrett')
# 275
# (42, 275, 'Tricky', 'Girls (Album version)', 'Harper', 'Barrett')
# 275
# (42, 275, 'Tony Rice', 'Wayfaring Stranger', 'Harper', 'Barrett')
# 275
# (42, 275, 'Rasheeda', 'Sweep The Flo (Featuring Diamond)', 'Harper', 'Barrett')
# 275
# (42, 275, 'George Younce', 'This Old House w/ When The Saints Medley', 'Harper', 'Barrett')
# 275
# (42, 275, 'Alex Gopher', 'Brain Leech', 'Harper', 'Barrett')
# 275
# (42, 275, 'Aphex Twin', 'Didgeridoo', 'Harper', 'Barrett')
# 275
# (42, 275, 'Emmanuel Moire', 'LÃ\x83Â\xa0 OÃ\x83Â¹ Je Pars', 'Harper', 'Barrett')
# 275
# (42, 275, 'Josh Turner', "I Wouldn't Be A Man", 'Harper', 'Barrett')
# 336
# (49, 336, 'Carlos Y JosÃ\x83Â©', 'Soy AlbaÃ\x83Â±il', 'Chloe', 'Cuevas')
# 288
# (6, 288, 'Motionless in White', 'Ghost In The Mirror', 'Cecilia', 'Owens')
# 395
# (24, 395, 'Feist', 'My Moon My Man', 'Layla', 'Griffin')
# 398
# (80, 398, 'Postal Service', 'We Will Become Silhouettes (Album)', 'Tegan', 'Levine')
# 398
# (80, 398, 'Stevie Ray Vaughan And Double Trouble', 'Life Without You', 'Tegan', 'Levine')
# 166
# (64, 166, 'AFI', 'Miseria Cantare--The Beginning', 'Hannah', 'Calhoun')
# 276
# (95, 276, 'Lonnie Gordon', 'Catch You Baby (Steve Pitron & Max Sanna Radio Edit)', 'Sara', 'Johnson')
# 276
# (95, 276, 'Harry Connick_ Jr.', 'My Blue Heaven', 'Sara', 'Johnson')
# 276
# (95, 276, 'Andres Calamaro', 'Crucificame', 'Sara', 'Johnson')
# 276
# (95, 276, 'Tub Ring', 'Invalid', 'Sara', 'Johnson')
# 142
# (47, 142, 'Brian Poole & The Tremeloes', 'I Can Dance', 'Kimber', 'Norris')
# 142
# (47, 142, 'War', 'The World Is A Ghetto', 'Kimber', 'Norris')
# 409
# (80, 409, "Kanye West / Consequence / Cam'Ron", 'Gone', 'Tegan', 'Levine')
# 409
# (80, 409, 'David Banner', 'Play', 'Tegan', 'Levine')
# 271
# (60, 271, 'Kreator', 'Second awakening', 'Devin', 'Larson')
# 409
# (80, 409, 'Cipher', 'Protoculture (Sankofa)', 'Tegan', 'Levine')
# 409
# (80, 409, 'Daft Punk', 'Emotion', 'Tegan', 'Levine')
# 66
# (67, 66, 'Taylor Swift', 'Love Story', 'Colm', 'Santana')
# 409
# (80, 409, 'The Police', 'Message In A Bottle', 'Tegan', 'Levine')
# 409
# (80, 409, 'JayMay', "You'd Rather Run", 'Tegan', 'Levine')
# 331
# (55, 331, 'Amy Adams', 'Happy Working Song', 'Martin', 'Johnson')
# 409
# (80, 409, 'Shinedown', 'Second Chance (Album Version)', 'Tegan', 'Levine')
# 331
# (55, 331, 'Amy Winehouse', 'Some Unholy War', 'Martin', 'Johnson')
# 409
# (80, 409, 'T.I. & DJ Drama', 'Ride Wit Me', 'Tegan', 'Levine')
# 362
# (15, 362, 'Gang Starr', 'Soliloquy Of Chaos (Explicit)', 'Lily', 'Koch')
# 409
# (80, 409, 'Benny Benassi', "Who's Your Daddy? ", 'Tegan', 'Levine')
# 362
# (15, 362, 'Paramore', 'When It Rains (Album Version)', 'Lily', 'Koch')
# 409
# (80, 409, 'Metallica', 'Mama Said', 'Tegan', 'Levine')
# 362
# (15, 362, 'A-Ha', 'Forever Not Yours (Album Version  - NY Mix II)', 'Lily', 'Koch')
# 409
# (80, 409, 'Easy Star All-Stars', 'Lovely Rita (feat. Bunny Rugs and U Roy)', 'Tegan', 'Levine')
# 362
# (15, 362, 'Alter Bridge', 'Down To My Last', 'Lily', 'Koch')
# 409
# (80, 409, 'O Terco', 'Mudanca De Tempo', 'Tegan', 'Levine')
# 362
# (15, 362, 'Nightwish', 'Walking In The Air', 'Lily', 'Koch')
# 409
# (80, 409, 'Augustana', 'Mayfield', 'Tegan', 'Levine')
# 362
# (15, 362, 'Anita Ward', 'Ring My Bell', 'Lily', 'Koch')
# 409
# (80, 409, 'Gaz Nevada', 'I C Love Affair', 'Tegan', 'Levine')
# 362
# (15, 362, "Flamin' Groovies", 'Slow Death', 'Lily', 'Koch')
# 409
# (80, 409, 'isis', 'Carry', 'Tegan', 'Levine')
# 362
# (15, 362, 'Five Iron Frenzy', 'Canada', 'Lily', 'Koch')
# 362
# (15, 362, 'Frankie HI-NRG MC', 'Pace E Guerra', 'Lily', 'Koch')
# 416
# (80, 416, 'Alliance Ethnik', 'ReprÃ\x83Â©sente', 'Tegan', 'Levine')
# 416
# (80, 416, 'Pavement', 'Mercy:The Laundromat', 'Tegan', 'Levine')
# 416
# (80, 416, '4 Skins', 'Clockwork Skinhead', 'Tegan', 'Levine')
# 416
# (80, 416, 'Thrice', 'Wood And Wire', 'Tegan', 'Levine')
# 408
# (101, 408, 'Van Halen', 'Best Of Both Worlds (Remastered Album Version)', 'Jayden', 'Fox')
# 340
# (14, 340, 'Barry Tuckwell/Academy of St Martin-in-the-Fields/Sir Neville Marriner', 'Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)', 'Theodore', 'Harris')
# 227
# (99, 227, 'Hot Chip', 'My Brother Is Watching Me', 'Ann', 'Banks')
# 416
# (80, 416, 'Lasgo', 'Over You', 'Tegan', 'Levine')
# 408
# (101, 408, 'Peter Sellers', 'She Loves You', 'Jayden', 'Fox')
# 363
# (32, 363, 'Alphaville', 'Big In Japan (Original)', 'Lily', 'Burns')
# 416
# (80, 416, 'Eneida Marta', 'Mindjer dÃ\x83Â´ce mel', 'Tegan', 'Levine')
# 227
# (99, 227, 'Astral Projection', 'Flying Into a Star', 'Ann', 'Banks')
# 416
# (80, 416, 'Gare du Nord', 'Marvin & Miles', 'Tegan', 'Levine')
# 416
# (80, 416, 'Florence + The Machine', 'Dog Days Are Over (Radio Edit)', 'Tegan', 'Levine')
# 416
# (80, 416, 'The White Stripes', 'Seven Nation Army', 'Tegan', 'Levine')
# 108
# (13, 108, 'Bouncing Souls', 'East Side Mags', 'Ava', 'Robinson')
# 108
# (13, 108, 'Coldplay', 'The Scientist', 'Ava', 'Robinson')
# 416
# (80, 416, 'Kings Of Leon', 'Revelry', 'Tegan', 'Levine')
# 416
# (80, 416, 'Mad Caddies', 'Backyard', 'Tegan', 'Levine')
# 406
# (6, 406, 'Phil Collins', 'The Way You Look Tonight (Live Version)', 'Cecilia', 'Owens')
# 416
# (80, 416, 'Parachute', 'The Mess I Made', 'Tegan', 'Levine')
# 368
# (85, 368, 'Escape The Fate', 'My Apocalypse', 'Kinsley', 'Young')
# 416
# (80, 416, 'Booka Shade', 'Teenage Spaceman', 'Tegan', 'Levine')
# 368
# (85, 368, 'Modern Lovers', 'Modern world', 'Kinsley', 'Young')
# 423
# (6, 423, 'Tub Ring', 'Invalid', 'Cecilia', 'Owens')
# 416
# (80, 416, 'Black Box', 'Everybody Everybody', 'Tegan', 'Levine')
# 368
# (85, 368, 'Cass Phang', 'Ye Feng Ling', 'Kinsley', 'Young')
# 416
# ...
# 998
# (36, 998, 'Alex Ubago', 'Sin Miedo a Nada (con Amaia Montero)', 'Matthew', 'Jones')
# 998
# (36, 998, 'The Twilight Singers', 'Bonnie Brae', 'Matthew', 'Jones')
# 998
# (36, 998, 'Chikita Violenta', 'War', 'Matthew', 'Jones')
# 998
# (36, 998, 'Cat Stevens', 'Sad Lisa', 'Matthew', 'Jones')
# 998
# (36, 998, 'Kenny Garrett', 'The House That Nat Built (Album Version)', 'Matthew', 'Jones')
# 998
# (36, 998, 'You Me At Six', 'Jealous Minds Think Alike', 'Matthew', 'Jones')
# 998
# (36, 998, 'Nellie Lutcher', "My Mother's Eyes", 'Matthew', 'Jones')
# 998
# (36, 998, 'Kid Cudi / Kanye West / Common', 'Make Her Say', 'Matthew', 'Jones')
# 998
# (36, 998, 'Tiro De Gracia', 'Viaje Sin Rumbo (2004 Digital Remaster)', 'Matthew', 'Jones')
# 998
# (36, 998, 'polarkreis 18', 'Dreamdancer', 'Matthew', 'Jones')
# 998
# (36, 998, '+ / - {Plus/Minus}', 'The Queen of Nothing', 'Matthew', 'Jones')
# 1092
# (92, 1092, 'Dr Feelgood', 'Riot In Cell Block Number Nine', 'Ryann', 'Smith')
# 998
# (36, 998, 'Harmonia', 'Sehr kosmisch', 'Matthew', 'Jones')
# 1092
# (92, 1092, 'Chimaira', 'Everything You Love (Album Version)', 'Ryann', 'Smith')
# 1092
# (92, 1092, 'Joshua Radin', "Someone Else's Life", 'Ryann', 'Smith')
# 1092
# (92, 1092, 'Bajaga & Instruktori', 'Godine prolaze', 'Ryann', 'Smith')
# 998
# (36, 998, 'The Virgins', 'Private Affair (Amended Album Version)', 'Matthew', 'Jones')
# 998
# (36, 998, "SA Rawls / Still Flyin' / Still Flyin'", 'Ginko Biloba', 'Matthew', 'Jones')
# 998
# (36, 998, 'Grown Ups', 'Three Day Weekend', 'Matthew', 'Jones')
# 998
# (36, 998, 'Nancy Ajram', 'Meen Dah Elly Nseik', 'Matthew', 'Jones')
# 998
# (36, 998, 'The Donkeys', 'Boot On The Seat', 'Matthew', 'Jones')
# 998
# (36, 998, 'Datarock', 'FaFaFa (Radio Edit)', 'Matthew', 'Jones')
# 998
# (36, 998, 'Daft Punk', 'Human After All', 'Matthew', 'Jones')
# 998
# (36, 998, 'Justin Bieber', 'Somebody To Love', 'Matthew', 'Jones')
# 998
# (36, 998, 'Beach House', 'Real Love', 'Matthew', 'Jones')
# 998
# (36, 998, 'The Walkmen', 'Subterranean Homesick Blues (Album Version)', 'Matthew', 'Jones')
# 998
# (36, 998, 'Busted / Charlie Simpson / Mattie Jay / James Bourne', "Can't Break Thru", 'Matthew', 'Jones')
# 1078
# (12, 1078, 'BeyoncÃ\x83Â©', 'Get Me Bodied', 'Austin', 'Rosales')
# 1096
# (49, 1096, 'Sick Puppies', 'Maybe', 'Chloe', 'Cuevas')
# 1096
# (49, 1096, 'U2', 'Walk To The Water', 'Chloe', 'Cuevas')
# 1096
# (49, 1096, 'Ron Carter', "I CAN'T GET STARTED", 'Chloe', 'Cuevas')
# 1096
# (49, 1096, 'Duran Duran', 'Breath After Breath', 'Chloe', 'Cuevas')
# 1096
# (49, 1096, 'Tears For Fears', 'Head Over Heels', 'Chloe', 'Cuevas')
# 1096
# (49, 1096, 'Foo Fighters', 'Lonely As You', 'Chloe', 'Cuevas')
# 1064
# (61, 1064, 'Yellowcard', 'One Year_ Six Months', 'Samuel', 'Gonzalez')
# 1096
# (49, 1096, 'Big Tymers', 'Against The Wall', 'Chloe', 'Cuevas')
# 1096
# (49, 1096, 'Enigma', 'Knocking On Forbidden Doors', 'Chloe', 'Cuevas')
# 1096
# (49, 1096, 'Dennis Ferrer', 'Hey Hey', 'Chloe', 'Cuevas')
# 1096
# (49, 1096, 'Justin Bieber', 'Somebody To Love', 'Chloe', 'Cuevas')
# 1096
# (49, 1096, 'Markus KrunegÃ\x83Â¥rd', 'Genom tunna tyger', 'Chloe', 'Cuevas')
# 1096
# (49, 1096, 'Linkin Park', 'The Little Things Give You Away [Live At Milton Keynes]', 'Chloe', 'Cuevas')
# 618
# (43, 618, 'Jamie Cullum', 'Devil May Care', 'Jahiem', 'Miles')
# 1096
# (49, 1096, 'Every Avenue', "Tell Me I'm A Wreck", 'Chloe', 'Cuevas')
# 1096
# (49, 1096, 'Jack Johnson', 'Constellations', 'Chloe', 'Cuevas')
# 1096
# (49, 1096, 'Shakira', 'Vuelve', 'Chloe', 'Cuevas')
# 1096
# (49, 1096, 'The Maine', 'Give Me Anything', 'Chloe', 'Cuevas')
# 1096
# (49, 1096, 'Cannibal Corpse', 'Worm Infested', 'Chloe', 'Cuevas')
# 977
# (85, 977, 'Arcade Fire', 'Headlights Look Like Diamonds', 'Kinsley', 'Young')
# 1096
# (49, 1096, 'Black Eyed Peas', 'Hands Up', 'Chloe', 'Cuevas')
# 977
# (85, 977, 'Radney Foster', 'Sweet And Wild', 'Kinsley', 'Young')
# 1096
# (49, 1096, 'Metric', 'Satellite Mind', 'Chloe', 'Cuevas')
# 1096
# (49, 1096, 'Dwight Yoakam', "You're The One", 'Chloe', 'Cuevas')
# 977
# (85, 977, 'Jason Mraz', 'Did You Get My Message? (Live From Montalvo)', 'Kinsley', 'Young')
# 1096
# (49, 1096, 'Kutt Calhoun', 'N A Whitemanzeyez', 'Chloe', 'Cuevas')
# 977
# (85, 977, 'Radiohead', 'Karma Police', 'Kinsley', 'Young')
# 1050
# (50, 1050, 'Molotov', 'Puto', 'Ava', 'Robinson')
# 1050
# (50, 1050, 'The Strokes', 'Killing Lies', 'Ava', 'Robinson')
# 1090
# (26, 1090, 'Rufus Wainwright', 'Hallelujah', 'Ryan', 'Smith')
# 977
# (85, 977, 'Deadmau5', "Ghosts 'n' Stuff (Original Instrumental Mix)", 'Kinsley', 'Young')
# 1096
# (49, 1096, 'John Farnham', "You're The Voice", 'Chloe', 'Cuevas')
# 1050
# (50, 1050, 'Infant Sorrow', 'Inside Of You', 'Ava', 'Robinson')
# 1090
# (26, 1090, 'Betty Wright', 'Clean Up Woman (Single/LP Version)', 'Ryan', 'Smith')
# 1096
# (49, 1096, 'Guus Meeuwis', 'Tranen Gelachen', 'Chloe', 'Cuevas')
# 977
# (85, 977, 'Muse', 'The Small Print', 'Kinsley', 'Young')
# 1096
# (49, 1096, 'Estrella Morente', 'A QuÃ\x83Â© Niegas El Delirio (MalagueÃ\x83Â±a) (Live)', 'Chloe', 'Cuevas')
# 977
# (85, 977, 'Dr. Alban', "It's My Life (Radio Edit)", 'Kinsley', 'Young')
# 1096
# (49, 1096, 'Radiohead', 'Sit Down. Stand Up', 'Chloe', 'Cuevas')
# 977
# (85, 977, 'Mondo Marcio', 'Purple Weed', 'Kinsley', 'Young')
# 1096
# (49, 1096, 'Mae', "Someone Else's Arms", 'Chloe', 'Cuevas')
# 977
# (85, 977, 'Meat Loaf / Jennifer Hudson', "The Future Ain't What It Used To Be", 'Kinsley', 'Young')
# 1096
# (49, 1096, 'Vampire Weekend', 'A-Punk (Album)', 'Chloe', 'Cuevas')
# 1096
# (49, 1096, 'MGMT', 'Time To Pretend', 'Chloe', 'Cuevas')
# 977
# (85, 977, 'Federico Aubele', 'Luna y Sol', 'Kinsley', 'Young')
# 1096
# (49, 1096, 'Jesse Rose', 'Touch My Horn', 'Chloe', 'Cuevas')
# 977
# (85, 977, 'Orion', 'Eternity', 'Kinsley', 'Young')
# 1096
# (49, 1096, 'Circa Survive', 'Dyed in the Wool (Album Version)', 'Chloe', 'Cuevas')
# 1060
# (101, 1060, 'Wretch 32_ Vis', 'Wretchrospective (feat. Vis)', 'Jayden', 'Fox')
# 977
# (85, 977, 'Simian Mobile Disco', 'Simple', 'Kinsley', 'Young')
# 1060
# (101, 1060, 'ErdmÃ\x83Â¶bel', 'Riecht wie Teen Spirit (Smells Like Teen Spirit)', 'Jayden', 'Fox')
# 1096
# (49, 1096, 'Eisbrecher', 'Adrenalin', 'Chloe', 'Cuevas')
# 1076
# (16, 1076, 'Ryan Bingham', 'Bread & Water', 'Rylan', 'George')
# 977
# (85, 977, 'Ashanti', 'VooDoo', 'Kinsley', 'Young')
# 1096
# (49, 1096, 'Barry Tuckwell/Academy of St Martin-in-the-Fields/Sir Neville Marriner', 'Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)', 'Chloe', 'Cuevas')
# 1060
# (101, 1060, 'Clint Eastwood', "Frankie's Office", 'Jayden', 'Fox')
# 1060
# (101, 1060, 'Charttraxx Karaoke', 'Fireflies', 'Jayden', 'Fox')
# 1076
# (16, 1076, 'Jason Mraz', 'Summer Breeze', 'Rylan', 'George')
# 977
# (85, 977, "The B-52's", 'Love Shack', 'Kinsley', 'Young')
# 1060
# (101, 1060, 'Aventura', 'Alexandra', 'Jayden', 'Fox')
# 1076
# (16, 1076, 'Five Iron Frenzy', 'Canada', 'Rylan', 'George')
# 1060
# (101, 1060, '12 Stones', 'Anthem For The Underdog', 'Jayden', 'Fox')
# 977
# (85, 977, 'Kings Of Leon', 'Revelry', 'Kinsley', 'Young')
# 1076
# (16, 1076, 'Brooklyn Bounce', 'Get Ready To Bounce Recall 08', 'Rylan', 'George')
# 977
# (85, 977, 'Dashboard Confessional', 'The Good Fight', 'Kinsley', 'Young')
# 977
# (85, 977, 'Lonnie Johnson', 'Low Land Moan', 'Kinsley', 'Young')
# 1097
# (88, 1097, 'Leggo Beast', 'In', 'Mohammad', 'Rodriguez')
# 1076
# (16, 1076, 'The Pussycat Dolls', 'Sway', 'Rylan', 'George')
# 977
# (85, 977, 'Stereophonics', 'I Miss You Now', 'Kinsley', 'Young')
# 1076
# (16, 1076, 'The Beautiful South', 'Masculine Eclipse', 'Rylan', 'George')
# 1097
# (88, 1097, 'The Acacia Strain', 'As If Set Afire', 'Mohammad', 'Rodriguez')
# 977
# (85, 977, 'ATB', 'Underwater World', 'Kinsley', 'Young')
# 1076
# (16, 1076, 'The Robert Cray Band', 'Our Last Time', 'Rylan', 'George')
# 1097
# (88, 1097, 'Enigma', 'T.N.T. For The Brain (112 Bpm) (Radio Edit)', 'Mohammad', 'Rodriguez')
# 977
# (85, 977, 'Amon Amarth', 'Tattered Banners And Bloody Flags', 'Kinsley', 'Young')
# 1076
# (16, 1076, 'We Are Scientists', 'The Great Escape (Album Version) (Explicit)', 'Rylan', 'George')
# 1100
# (36, 1100, 'Roberto Murolo', 'Lacreme napulitane', 'Matthew', 'Jones')
# 1097
# (88, 1097, 'Ashlee Simpson', 'Autobiography', 'Mohammad', 'Rodriguez')
# 977
# (85, 977, 'Metallica', 'The Ecstasy Of Gold', 'Kinsley', 'Young')
# 1076
# (16, 1076, '3 Doors Down', 'Kryptonite', 'Rylan', 'George')
# 1100
# (36, 1100, 'Hazell Dean', 'No Fool (For Love)', 'Matthew', 'Jones')
# 977
# (85, 977, 'Apocalyptica', 'Pray', 'Kinsley', 'Young')
# 1076
# (16, 1076, 'Jack Johnson', 'Bubble Toes', 'Rylan', 'George')
# 977
# (85, 977, 'Cage The Elephant', 'Lotus', 'Kinsley', 'Young')
# 1100
# (36, 1100, 'Taylor Swift', 'You Belong With Me', 'Matthew', 'Jones')
# 1076
# (16, 1076, 'Soul For Real', 'Candy Rain', 'Rylan', 'George')
# 977
# (85, 977, 'The Prodigy', 'Firestarter', 'Kinsley', 'Young')
# 1100
# (36, 1100, 'Amy Winehouse', 'Addicted', 'Matthew', 'Jones')
# 1076
# (16, 1076, 'Iron Maiden', 'The Evil That Men Do (1998 Digital Remaster)', 'Rylan', 'George')
# 977
# (85, 977, 'David Crowder*Band', 'All Around Me', 'Kinsley', 'Young')
# 1076
# (16, 1076, 'The Cinematic Orchestra', 'Everyday', 'Rylan', 'George')
# 977
# (85, 977, 'Three 6 Mafia vs. TiÃ\x83Â«sto with Sean Kingston and Flo Rida', 'Feel It', 'Kinsley', 'Young')
# 977
# (85, 977, 'Sugababes', 'Overload', 'Kinsley', 'Young')
# 1076
# (16, 1076, 'Gyptian', 'Hold You', 'Rylan', 'George')
# 1076
# (16, 1076, 'Zion / Akon', 'The Way She Moves', 'Rylan', 'George')
# 1076
# (16, 1076, 'Transvision Vamp', 'I Want Your Love', 'Rylan', 'George')
# 1096
# (49, 1096, 'Ry Cooder', 'Corrido de Boxeo', 'Chloe', 'Cuevas')
# 1076
# (16, 1076, 'The Pussycat Dolls', 'When I Grow Up', 'Rylan', 'George')
# 1096
# (49, 1096, 'Coldplay', 'Yellow', 'Chloe', 'Cuevas')
# 1076
# (16, 1076, 'Forever The Sickest Kids', 'She Likes (Bittersweet Love)', 'Rylan', 'George')
# 1096
# (49, 1096, 'Lil Wayne / Blaque / Mannie Fresh', 'Believe That', 'Chloe', 'Cuevas')
# 1076
# (16, 1076, 'Dragonforce', 'Through The Fire And Flames (Album Version)', 'Rylan', 'George')
# 1096
# (49, 1096, 'Jason Mraz & Colbie Caillat', 'Lucky (Album Version)', 'Chloe', 'Cuevas')
# 1096
# (49, 1096, 'Pixies', 'Is She Weird', 'Chloe', 'Cuevas')
# 1076
# (16, 1076, 'Eminem', 'Without Me', 'Rylan', 'George')
# 1096
# (49, 1096, 'Buju Banton', 'Cry No More', 'Chloe', 'Cuevas')
# 1076
# (16, 1076, 'Cage The Elephant', 'Lotus', 'Rylan', 'George')
# 1096
# (49, 1096, 'Barry Tuckwell/Academy of St Martin-in-the-Fields/Sir Neville Marriner', 'Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)', 'Chloe', 'Cuevas')
# 1076
# (16, 1076, 'Ste Strausz', 'Le Million', 'Rylan', 'George')
# 1096
# (49, 1096, 'Coldplay', 'Only Superstition', 'Chloe', 'Cuevas')
# 1059
# (78, 1059, 'Joe Christmas', 'Bedroom Suite', 'Chloe', 'Roth')
# 1076
# (16, 1076, 'Bright Eyes', 'A New Arrangement', 'Rylan', 'George')
# 1059
# (78, 1059, 'Paramore', 'The Only Exception (Album Version)', 'Chloe', 'Roth')
# 1096
# (49, 1096, 'J. Karjalainen & Mustat Lasit', 'Sinisten tÃ\x83Â¤htien alla', 'Chloe', 'Cuevas')
# 1076
# (16, 1076, 'Philip Glass', 'Knee 2', 'Rylan', 'George')
# 1096
# (49, 1096, 'Alliance Ethnik', 'SinceritÃ\x83Â© Et Jalousie', 'Chloe', 'Cuevas')
# 1076
# (16, 1076, 'Mew', 'Her Voice Is Beyond Her Years', 'Rylan', 'George')
# 1076
# (16, 1076, 'Ive Mendes', 'If You Leave Me Now', 'Rylan', 'George')
# 1026
# (33, 1026, 'Alliance Ethnik', 'SinceritÃ\x83Â© Et Jalousie', 'Bronson', 'Harris')
# 1076
# (16, 1076, 'the bird and the bee', 'Diamond Dave', 'Rylan', 'George')
# 1026
# (33, 1026, 'Common / Sadat X', '1999', 'Bronson', 'Harris')
# 1076
# (16, 1076, 'Alanis Morissette', 'King Of Pain (Live/Unplugged Version)', 'Rylan', 'George')
# 1026
# (33, 1026, 'Skillet', 'Rebirthing (Album Version)', 'Bronson', 'Harris')
# 1076
# (16, 1076, 'James Galway;Julian Lee', 'Beauty and the Beast', 'Rylan', 'George')
# 1076
# (16, 1076, 'Drop Dead_ Gorgeous', 'Dressed For Friend Requests (Album Version)', 'Rylan', 'George')
# 1076
# (16, 1076, 'Dwight Yoakam', "You're The One", 'Rylan', 'George')
# 1076
# (16, 1076, 'Trouble', "Tuesday's Child", 'Rylan', 'George')
# 1076
# (16, 1076, 'OneRepublic', 'All The Right Moves', 'Rylan', 'George')
# 1076
# (16, 1076, 'Switchblade Symphony', 'Wicked', 'Rylan', 'George')
# 1076
# (16, 1076, 'Sharooz', 'My Distressor 40Khz ReRub Mix', 'Rylan', 'George')
# 1076
# (16, 1076, 'Explosions In The Sky', 'Six Days At The Bottom Of The Ocean', 'Rylan', 'George')
# 1114
# (49, 1114, 'Emmylou Harris', 'Little Bird', 'Chloe', 'Cuevas')
# 1114
# (49, 1114, 'Jack Johnson', 'The Horizon Has Been Defeated', 'Chloe', 'Cuevas')
# 1076
# (16, 1076, 'Radiohead', 'Everything In Its Right Place', 'Rylan', 'George')
# 1114
# (49, 1114, 'Andrew Bird', 'Heretics', 'Chloe', 'Cuevas')
# 1076
# (16, 1076, 'Metallica', 'Sabbra Cadabra', 'Rylan', 'George')
# 1114
# (49, 1114, 'Lonnie Gordon', 'Catch You Baby (Steve Pitron & Max Sanna Radio Edit)', 'Chloe', 'Cuevas')
# 1114
# (49, 1114, 'Dropkick Murphys', 'Shattered', 'Chloe', 'Cuevas')
# 1076
# (16, 1076, 'Eric B. & Rakim', 'As The Rhyme Goes On', 'Rylan', 'George')
# 1114
# (49, 1114, 'Dierks Bentley', 'Settle For A Slowdown', 'Chloe', 'Cuevas')
# 1076
# (16, 1076, 'Regina Spektor', 'Daniel Cowman', 'Rylan', 'George')
# 1114
# (49, 1114, 'Angelspit', 'Make You Sin', 'Chloe', 'Cuevas')
# 1114
# (49, 1114, 'Young Gunz / Beanie Sigel', 'Roc U', 'Chloe', 'Cuevas')
# 1076
# (16, 1076, 'DJ Dizzy', 'Sexy Bitch', 'Rylan', 'George')
# 1076
# (16, 1076, 'Base Ball Bear', 'Sayonara-Nostalgia', 'Rylan', 'George')
# 1114
# (49, 1114, 'Morcheeba', 'In The Hands Of The Gods (Featuring Biz Markie)', 'Chloe', 'Cuevas')
# 1114
# (49, 1114, 'Bitter:Sweet', "Don't Forget To Breathe", 'Chloe', 'Cuevas')
# 1076
# (16, 1076, 'Basshunter Feat. DJ Mental Theo\x19s Bazzheadz', "Now You're Gone", 'Rylan', 'George')
# 1114
# (49, 1114, 'BjÃ\x83Â¶rk', 'Undo', 'Chloe', 'Cuevas')
# 1076
# (16, 1076, 'Rihanna', 'G4L', 'Rylan', 'George')
# 1076
# (16, 1076, 'Evanescence', 'Hello', 'Rylan', 'George')
# 1114
# (49, 1114, 'Mr. Vegas', 'Tamale', 'Chloe', 'Cuevas')
# 1076
# (16, 1076, 'Mischa Daniels', 'Another Place', 'Rylan', 'George')
# 1114
# (49, 1114, 'The Menzingers', 'Straight To Hell', 'Chloe', 'Cuevas')
# 1114
# (49, 1114, 'Justin Timberlake', 'Cry Me A River', 'Chloe', 'Cuevas')
# 1076
# (16, 1076, 'Vilma Palma e Vampiros', 'Un Camino Hasta Vos', 'Rylan', 'George')
# 1114
# (49, 1114, 'CCCP - Fedeli Alla Linea', 'Sura (2008 Digital Remaster)', 'Chloe', 'Cuevas')
# 1076
# (16, 1076, 'Kid Cudi / MGMT / Ratatat', 'Pursuit Of Happiness (nightmare)', 'Rylan', 'George')
# 1114
# (49, 1114, 'Drake / Kanye West / Lil Wayne / Eminem', 'Forever', 'Chloe', 'Cuevas')
# 1076
# (16, 1076, 'A Day To Remember', 'Homesick [Acoustic]', 'Rylan', 'George')
# 1085
# (91, 1085, 'T.I.', 'Dead And Gone [feat. Justin Timberlake] (Explicit Album Version)', 'Jayden', 'Bell')
# 1076
# (16, 1076, 'The Offspring', "It'll Be a Long Time (Album Version)", 'Rylan', 'George')
# 1114
# (49, 1114, 'Jorge Gonzalez', 'Esta Es Para Hacerte FÃ\x83Â©liz', 'Chloe', 'Cuevas')
# 1085
# (91, 1085, 'Sneaker Pimps', 'Spin Spin Sugar', 'Jayden', 'Bell')
# 1076
# (16, 1076, 'Escape The Fate', 'This War Is Ours (The Guillotine II)', 'Rylan', 'George')
# 1114
# (49, 1114, 'Juanes', 'La Vida Es Un Ratico', 'Chloe', 'Cuevas')
# 1076
# (16, 1076, 'The Replacements', 'Never Mind', 'Rylan', 'George')
# 1114
# (49, 1114, 'Sarah McLachlan', 'Possession', 'Chloe', 'Cuevas')
# 1076
# (16, 1076, 'Sonny Boy Williamson', "Don't Start Me Talkin'", 'Rylan', 'George')
# 1076
# (16, 1076, 'Soul II Soul Featuring Caron Wheeler', 'Back To Life (However Do You Want Me) (2003 Digital Remaster) (Feat. Caron Wheeler)', 'Rylan', 'George')
# 1114
# (49, 1114, 'Florence + The Machine', 'Dog Days Are Over (Radio Edit)', 'Chloe', 'Cuevas')
# 1076
# (16, 1076, 'Pantera', 'Heresy  (LP Version)', 'Rylan', 'George')
# 1114
# (49, 1114, 'Cold', 'Remedy', 'Chloe', 'Cuevas')
# 1114
# (49, 1114, 'Norther', 'Frozen Angel', 'Chloe', 'Cuevas')
# 1076
# (16, 1076, 'Foo Fighters', 'The Pretender', 'Rylan', 'George')
# 1076
# (16, 1076, 'Timbiriche', 'Besos De Ceniza', 'Rylan', 'George')
# 1076
# (16, 1076, 'A Perfect Circle', 'Rose', 'Rylan', 'George')
# 1076
# (16, 1076, 'Anberlin', 'The Haunting', 'Rylan', 'George')
# 985
# (5, 985, 'Deas Vail', 'Anything You Say (Unreleased Version)', 'Elijah', 'Davis')
# <cassandra.cluster.ResultSet object at 0x7f9448f5a0d0>
# Row(artist='Lonnie Gordon', song='Catch You Baby (Steve Pitron & Max Sanna Radio Edit)', firstname='Sylvie', lastname='Cruz')

# %%
## TO-DO: Query 3: Give me every user name (first and last) in my music app history who listened to the song 'All Hands Against His Own'

query = "drop TABLE IF EXISTS user_by_song "
session.execute(query)
query = "CREATE TABLE IF NOT EXISTS user_by_song "
query = query + """(
firstName text, lastName text, song text, 
PRIMARY KEY(song))
"""
try:
    session.execute(query)
except Exception as e:
    print(e)

# %%
file = 'event_datafile_new.csv'
with open(file, encoding = 'utf8') as f:
    csvreader = csv.reader(f)
    next(csvreader)
    for line in csvreader:
        query = "INSERT INTO user_by_song (firstName, lastName, song)"
        query = query + "VALUES (%s, %s, %s)"
        print((line[1], line[4], line[9]))
        ## TO-DO: Assign which column element should be assigned for each column in the INSERT statement.
        ## For e.g., to INSERT artist_name and user first_name, you would change the code below to `line[0], line[1]`
        session.execute(query, (line[1], line[4], line[9]))
# Out:
# ('Ryan', 'Smith', 'Sehr kosmisch')
# ('Ryan', 'Smith', 'The Big Gundown')
# ('Ryan', 'Smith', 'Marry Me')
# ('Samuel', 'Gonzalez', 'Blackbird')
# ('Tegan', 'Levine', 'Best Of Both Worlds (Remastered Album Version)')
# ('Tegan', 'Levine', 'Call Me If You Need Me')
# ('Tegan', 'Levine', 'Home')
# ('Tegan', 'Levine', 'OMG')
# ('Tegan', 'Levine', 'Candle On The Water')
# ('Tegan', 'Levine', 'Our Song')
# ('Tegan', 'Levine', 'Baby Boy [feat. Beyonce]')
# ('Lily', 'Koch', 'Black Hole Sun')
# ('Tegan', 'Levine', 'Human')
# ('Lily', 'Koch', 'Addicted')
# ('Lily', 'Koch', 'Air')
# ('Lily', 'Koch', 'Superbeast')
# ('Lily', 'Koch', 'I Remember')
# ('Ryan', 'Smith', "Don't Be Stupid (You Know I Love You)")
# ('Ryan', 'Smith', 'We throw parties_ you throw knives')
# ('Chloe', 'Cuevas', 'How Can I Live (Spanish version) (Album Version)')
# ('Chloe', 'Cuevas', 'Thugs Like Me')
# ('Chloe', 'Cuevas', 'Killing In The Name')
# ('Chloe', 'Cuevas', 'Epilogue')
# ('Chloe', 'Cuevas', 'Endlessly')
# ('Chloe', 'Cuevas', 'Torches')
# ('Mohammad', 'Rodriguez', 'The Good Times Are Killing Me')
# ('Chloe', 'Cuevas', 'Te Conozco Bien')
# ('Chloe', 'Cuevas', 'The Calculation (Album Version)')
# ('Tegan', 'Levine', 'Goodbye (Interlude)')
# ('Avery', 'Watkins', 'Canada')
# ('Avery', 'Watkins', 'Ven')
# ('Avery', 'Watkins', 'Do You Remember The First Time?')
# ('Avery', 'Watkins', 'I Want Your (Hands On Me)')
# ('Tegan', 'Levine', 'Chill Out')
# ('Avery', 'Watkins', 'Something (Radio Edit)')
# ('Tegan', 'Levine', "What's A Broken Heart")
# ('Avery', 'Watkins', 'Society')
# ('Tegan', 'Levine', 'Christians In Black')
# ('Avery', 'Watkins', 'Uprising')
# ('Tegan', 'Levine', 'Might Like You Better')
# ('Avery', 'Watkins', 'Sheila Take A Bow')
# ('Tegan', 'Levine', 'Victoria (LP Version)')
# ('Avery', 'Watkins', 'Dreaming Of You')
# ('Tegan', 'Levine', "What's Luv? (Featuring Ja-Rule & Ashanti) (Explicit Album Version)")
# ('Avery', 'Watkins', 'Soft Revolution')
# ('Tegan', 'Levine', 'Same Mistake  (Album Version)')
# ('Avery', 'Watkins', 'Bruised And Scarred (Album Version)')
# ('Tegan', 'Levine', "Frisch und g'sund")
# ('Avery', 'Watkins', 'Rockit')
# ('Tegan', 'Levine', "Should've Been A Cowboy")
# ('Avery', 'Watkins', 'Little Motel')
# ('Tegan', 'Levine', 'Gears')
# ('Avery', 'Watkins', 'Superwoman (Where Were You When I Needed You) (Digitally Remastered)')
# ('Tegan', 'Levine', 'Forgotten')
# ('Rylan', 'George', 'Everlong')
# ('Avery', 'Watkins', 'Hunter')
# ('Tegan', 'Levine', 'The Way I Loved You')
# ('Rylan', 'George', 'Longevity')
# ('Avery', 'Watkins', 'Fell In Love With A Girl')
# ('Tegan', 'Levine', "You're The One")
# ('Avery', 'Watkins', 'Lies')
# ('Rylan', 'George', "Got The Feelin'")
# ('Tegan', 'Levine', 'Do You Call My Name')
# ('Rylan', 'George', "Gangsta's Paradise (LP Version)")
# ('Avery', 'Watkins', 'Misery Business (Album Version)')
# ('Avery', 'Watkins', 'Itchy Feet')
# ('Rylan', 'George', 'Gypsy')
# ('Tegan', 'Levine', 'Dans Ma Bulle (Edit Radio - Live 2006)')
# ('Rylan', 'George', 'Give It Up')
# ('Tegan', 'Levine', 'Love Remains (Home Demo)')
# ('Avery', 'Watkins', 'Here Without You')
# ('Rylan', 'George', 'Toss The Feathers (Instrumental) ( LP Version )')
# ('Tegan', 'Levine', 'Big')
# ('Avery', 'Watkins', 'I Am The Killer (Album Version)')
# ('Rylan', 'George', "Don't Call It A Comeback (Album Version)")
# ('Tegan', 'Levine', "Hey Daddy (Daddy's Home)")
# ('Rylan', 'George', 'No Siento Penas')
# ('Avery', 'Watkins', 'Kill The Director [Radio Edit]')
# ('Tegan', 'Levine', 'I Kissed A Girl')
# ('Rylan', 'George', 'The Darkest Nights')
# ('Avery', 'Watkins', 'Undo')
# ('Tegan', 'Levine', 'I Fought The Law (LP Version)')
# ('Rylan', 'George', 'Influencia')
# ('Tegan', 'Levine', 'Too Much')
# ('Tegan', 'Levine', 'All Hands Against His Own')
# ('Avery', 'Watkins', 'Blaues Blau')
# ('Tegan', 'Levine', 'Friends_ Lovers Or Nothing')
# ('Rylan', 'George', 'A Song For Sleeping (LP Version)')
# ('Avery', 'Watkins', 'Head Into Tomorrow')
# ('Rylan', 'George', 'Smile Version Revisited (Mark Ronson Remix) (Explicit)')
# ('Tegan', 'Levine', 'A Gentle Heart')
# ('Avery', 'Watkins', 'Un DÃ\x83Â\xada Normal')
# ('Rylan', 'George', 'Ska')
# ('Avery', 'Watkins', 'The Heretic Anthem (Album Version)')
# ('Tegan', 'Levine', 'Tell Her Tonight')
# ('Rylan', 'George', 'Suicide')
# ('Tegan', 'Levine', 'Stella By Starlight')
# ('Avery', 'Watkins', "Nothin' On You [feat. Bruno Mars] (Album Version)")
# ('Rylan', 'George', 'I And Love And You')
# ('Tegan', 'Levine', 'Caprice viennois op.2')
# ('Avery', 'Watkins', "Joshua's Song (1991 Digital Remaster)")
# ('Avery', 'Watkins', "Hips Don't Lie")
# ('Rylan', 'George', 'The Funeral (Album Version)')
# ('Tegan', 'Levine', 'Ambrosia')
# ('Avery', 'Watkins', 'Einfach Ich')
# ('Tegan', 'Levine', 'Higher Messiah')
# ('Avery', 'Watkins', 'If I Know You')
# ('Avery', 'Watkins', 'In Heaven')
# ('Tegan', 'Levine', 'Wounded Soul')
# ('Avery', 'Watkins', 'Bold As Love')
# ('Avery', 'Watkins', 'The Great ndian Desert')
# ('Tegan', 'Levine', 'Face Of Fear')
# ('Tegan', 'Levine', 'What You Know')
# ('Tegan', 'Levine', 'Hurt')
# ('Avery', 'Watkins', 'Me Lleva Tiempo')
# ('Tegan', 'Levine', "So What's New")
# ('Avery', 'Watkins', 'Flight Of Yuri Gagarin')
# ('Tegan', 'Levine', 'Mooncalf')
# ('Avery', 'Watkins', 'My Immortal (Album Version)')
# ('Avery', 'Watkins', 'Velouria')
# ('Jahiem', 'Miles', 'Bad Actors')
# ('Tegan', 'Levine', "Bitches Ain't Shit")
# ('Avery', 'Watkins', 'Unwell (Album Version)')
# ('Tegan', 'Levine', 'Feiticeira (LP Version)')
# ('Avery', 'Watkins', 'Without You (Album Version)')
# ('Tegan', 'Levine', 'Map Of The Problematique')
# ('Avery', 'Watkins', 'Kotona kaikuu')
# ('Tegan', 'Levine', 'One And Only')
# ('Avery', 'Watkins', 'Gunpowder')
# ('Avery', 'Watkins', 'Had Stupid')
# ('Avery', 'Watkins', "If Hollywood Don't Need You")
# ('Avery', 'Watkins', 'Are You Famous?')
# ('Avery', 'Watkins', 'Good Morning Susie Soho')
# ('Avery', 'Watkins', 'She Moves In Her Own Way')
# ('Avery', 'Watkins', 'You Get What You Give')
# ('Avery', 'Watkins', 'Where Eagles Have Been')
# ('Avery', 'Watkins', 'Spilt Needles (Album)')
# ('Avery', 'Watkins', 'Reasons Why')
# ('Avery', 'Watkins', 'Crazy')
# ('Avery', 'Watkins', 'Love Of The Loveless')
# ('Avery', 'Watkins', 'Sehr kosmisch')
# ('Avery', 'Watkins', 'Oh No! (album version)')
# ('Avery', 'Watkins', 'The Real Slim Shady')
# ('Avery', 'Watkins', 'REIPPAINA KÃ\x83Â\x84YMME REKKAIN ALLE')
# ('Avery', 'Watkins', "You're The One")
# ('Avery', 'Watkins', 'White Sand')
# ('Avery', 'Watkins', 'Tan bi (Heat_ Breeze_ Tenderness) / Chaleur_ brise_ tendress')
# ('Avery', 'Watkins', 'Red Right Ankle')
# ('Avery', 'Watkins', 'Savage Circle')
# ('Avery', 'Watkins', 'The One-Eyed Turk')
# ('Avery', 'Watkins', 'Set In Stone')
# ('Kate', 'Harrell', "Let's Go Crazy (LP Version)")
# ('Kate', 'Harrell', "She's Coming Home")
# ('Kate', 'Harrell', 'Numb')
# ('Avery', 'Watkins', 'Breakdown')
# ('Kate', 'Harrell', 'Let There Be Lite (Album Version)')
# ('Avery', 'Watkins', 'Set Down Your Glass')
# ('Kate', 'Harrell', 'Nice Weather For Ducks')
# ('Avery', 'Watkins', 'Tale Of Two Cities')
# ('Kate', 'Harrell', 'Magic')
# ('Avery', 'Watkins', 'Take No Shhh (Original Mix)')
# ('Kate', 'Harrell', 'VIKING MAN')
# ('Kate', 'Harrell', 'I Gotta Feeling')
# ('Avery', 'Watkins', 'Canada')
# ('Ava', 'Robinson', 'Down On The Corner')
# ('Ava', 'Robinson', 'Camaro')
# ('Avery', 'Watkins', 'Unbreakable')
# ('Kate', 'Harrell', 'Born To Be Wild')
# ('Ava', 'Robinson', 'the king of wishful thinking')
# ('Avery', 'Watkins', 'Elevator')
# ('Kate', 'Harrell', 'Willie And The Hand Jive')
# ('Devin', 'Larson', 'Little Drummer Boy [featuring guitarist Andy McKee] (Album Version)')
# ('Avery', 'Watkins', 'Coin-Operated Boy')
# ('Kate', 'Harrell', 'Where Is My Mind?')
# ('Devin', 'Larson', 'I Put A Spell On You')
# ('Kate', 'Harrell', 'Girlfriend In A Coma')
# ('Avery', 'Watkins', 'No Names (Black Debbie) (Album Version)')
# ('Kate', 'Harrell', 'Love Story')
# ('Avery', 'Watkins', 'La pachanga')
# ('Kate', 'Harrell', 'Light Your Ass On Fire')
# ('Avery', 'Watkins', 'Above The Clouds')
# ('Kate', 'Harrell', "You're The One")
# ('Avery', 'Watkins', 'He Can Only Hold Her')
# ('Kate', 'Harrell', 'Te-Ta-Te-Ta-Ta (2002 Digital Remaster)')
# ('Avery', 'Watkins', 'Congratulations_ I Hate You')
# ('Kate', 'Harrell', "You're The One")
# ('Avery', 'Watkins', 'Premonicion')
# ('Kate', 'Harrell', 'Lock and Key')
# ('Kate', 'Harrell', 'Stronger')
# ('Avery', 'Watkins', 'Neon Bible')
# ('Avery', 'Watkins', 'Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)')
# ('Kate', 'Harrell', "I'm a Pilot")
# ('Avery', 'Watkins', 'Empathy')
# ('Kate', 'Harrell', 'Brigitte Bardot')
# ('Avery', 'Watkins', 'Just A Boy')
# ('Avery', 'Watkins', '4 Chords of the Apocalypse')
# ('Kate', 'Harrell', 'Safe 2 Say [The Incredible] (Album Version - Amended)')
# ('Avery', 'Watkins', 'Yeah!')
# ('Kate', 'Harrell', "Don't Walk Away")
# ('Avery', 'Watkins', 'Losing My Ground')
# ('Kate', 'Harrell', 'Supermassive Black Hole (Twilight Soundtrack Version)')
# ('Avery', 'Watkins', 'Undercover Martyn')
# ('Kate', 'Harrell', 'Intake (Album Version)')
# ('Avery', 'Watkins', 'When You Believe')
# ('Kate', 'Harrell', 'Transatlanticism')
# ('Avery', 'Watkins', 'Ces Gens LÃ\x83Â\xa0')
# ('Kate', 'Harrell', 'Emergency (Album Version)')
# ('Avery', 'Watkins', 'Cemetery Drive (Album Version)')
# ('Kate', 'Harrell', 'On My Own')
# ('Avery', 'Watkins', 'Run Run Run')
# ('Kate', 'Harrell', 'Skills To Pay The Bills')
# ('Lily', 'Burns', 'These Words')
# ('Avery', 'Watkins', 'AtrÃ\x83Â©vete te te')
# ('Kate', 'Harrell', 'Modern Nature')
# ('Lily', 'Burns', 'Ultimo Baile')
# ('Avery', 'Watkins', 'Mayfair Song')
# ('Kate', 'Harrell', 'Canada')
# ('Lily', 'Burns', 'Riot On An Empty Street')
# ('Avery', 'Watkins', "You're In My Heart")
# ('Kate', 'Harrell', 'E Talking')
# ('Lily', 'Burns', 'Mystery of You')
# ('Avery', 'Watkins', 'Overload')
# ('Lily', 'Burns', 'Say What You Say')
# ('Kate', 'Harrell', 'Scream')
# ('Avery', 'Watkins', 'Le Courage Des Oiseaux')
# ('Kate', 'Harrell', 'My December')
# ('Avery', 'Watkins', 'Canada')
# ('Avery', 'Watkins', 'Give Me Some Of Yr Love')
# ('Kate', 'Harrell', 'Message In A Bottle')
# ('Avery', 'Watkins', 'Microwave')
# ('Celeste', 'Williams', 'A Rush Of Blood To The Head')
# ('Maia', 'Burke', 'A World Without Love')
# ('Avery', 'Watkins', 'Coming Back')
# ('Kate', 'Harrell', 'To The Sky')
# ('Maia', 'Burke', "I'd Rather Be With You")
# ('Chloe', 'Cuevas', 'When We Get By')
# ('Celeste', 'Williams', 'The Music Scene')
# ('Ayla', 'Johnson', 'Terrible Lie')
# ('Maia', 'Burke', 'Colourless Colour')
# ('Kate', 'Harrell', 'American Star')
# ('Avery', 'Watkins', 'What Else Is There?')
# ('Chloe', 'Cuevas', 'Spinning (Album Version)')
# ('Kate', 'Harrell', 'Definitely Maybe')
# ('Avery', 'Watkins', 'Disorder [2007 Re-mastered Album Version]')
# ('Chloe', 'Cuevas', 'Rock Star')
# ('Kate', 'Harrell', 'Orange TrÃ\x83Â¤gt Nur Die MÃ\x83Â¼llabfuhr (Go West)')
# ('Avery', 'Watkins', 'Wave Goodbye (Real/Rhapsody Version)')
# ('Kate', 'Harrell', 'We Are Lost')
# ('Chloe', 'Cuevas', 'Gears')
# ('Harper', 'Barrett', 'Gives You Hell')
# ('Avery', 'Watkins', 'Born To Run')
# ('Kate', 'Harrell', 'Say (All I Need)')
# ('Chloe', 'Cuevas', 'Meteor Shower')
# ('Harper', 'Barrett', "I'm In Peace")
# ('Chloe', 'Cuevas', 'I Am Not a Robot')
# ('Avery', 'Watkins', "Don't Let The Rain Come Down (Crooked Little Man)")
# ('Kate', 'Harrell', 'Maternal Instinct')
# ('Harper', 'Barrett', 'My Baby Just Cares For Me')
# ('Avery', 'Watkins', 'OMG')
# ('Chloe', 'Cuevas', 'Everything Counts (Live) (Single Version)')
# ('Harper', 'Barrett', 'Especially In Michigan (Album Version)')
# ('Kate', 'Harrell', 'Kryptonite')
# ('Harper', 'Barrett', 'Bread And Butter')
# ('Kate', 'Harrell', 'Dusty')
# ('Avery', 'Watkins', 'La Bamba')
# ('Harper', 'Barrett', 'Forever')
# ('Chloe', 'Cuevas', "I'm In Love")
# ('Avery', 'Watkins', "I'm Not A Loser")
# ('Kate', 'Harrell', 'BareNaked')
# ('Chloe', 'Cuevas', 'Burn Out')
# ('Harper', 'Barrett', 'Baja por diversion (directo 05)')
# ('Kate', 'Harrell', 'Hope Is... (Album Version)')
# ('Harper', 'Barrett', "Day 'N' Nite")
# ('Kate', 'Harrell', 'La Llorona')
# ('Harper', 'Barrett', 'Dance_ Dance')
# ('Kate', 'Harrell', 'Lady Marmalade')
# ('Harper', 'Barrett', 'Algebra Of Darkness (Album Version)')
# ('Kate', 'Harrell', 'Jimbo (Album Version)')
# ('Harper', 'Barrett', 'Deseret')
# ('Kate', 'Harrell', "I'll Be Your Man")
# ('Harper', 'Barrett', 'Christmas')
# ('Kate', 'Harrell', 'ReprÃ\x83Â©sente')
# ('Harper', 'Barrett', 'A Letra "A')
# ('Kate', 'Harrell', "Live Like We're Dying")
# ('Kate', 'Harrell', 'Muscle Museum (Soulwax Remix)')
# ('Harper', 'Barrett', 'Lovely Head')
# ('Kate', 'Harrell', 'Doctor Alibi (featuring Lemmy Kilmister)')
# ('Harper', 'Barrett', 'Stupid_ Stupid War (Dealing With It)')
# ('Harper', 'Barrett', 'Unite (2009 Digital Remaster)')
# ('Kate', 'Harrell', 'Hate')
# ('Harper', 'Barrett', 'Revelry')
# ('Kate', 'Harrell', 'Translocation')
# ('Harper', 'Barrett', 'Me And Charlie Talking')
# ('Kate', 'Harrell', 'The Boy Is Mine (Duet With Monica) (LP Version)')
# ('Harper', 'Barrett', 'How You Like Me Now?')
# ('Kate', 'Harrell', 'Point/Counterpoint (Album Version)')
# ('Harper', 'Barrett', 'Murder Babe (Album)')
# ('Harper', 'Barrett', 'Die For You')
# ('Kate', 'Harrell', 'Better Together')
# ('Harper', 'Barrett', 'Eyes As Candles')
# ('Aleena', 'Kirby', 'Zagros')
# ('Kate', 'Harrell', 'Part 2')
# ('Harper', 'Barrett', 'Eruption (Album Version)')
# ('Kate', 'Harrell', 'Heaven Is A Truck')
# ('Harper', 'Barrett', 'SinceritÃ\x83Â© Et Jalousie')
# ('Aleena', 'Kirby', 'Keep It Smooth')
# ('Kate', 'Harrell', 'Born On The Bayou')
# ('Harper', 'Barrett', "It's So Hard")
# ('Aleena', 'Kirby', 'Amerika (Album Version)')
# ('Aleena', 'Kirby', "I'm With You")
# ('Kate', 'Harrell', 'Circuito III')
# ('Harper', 'Barrett', 'Undo')
# ('Aleena', 'Kirby', 'Casposos')
# ('Harper', 'Barrett', 'Is This It')
# ('Aleena', 'Kirby', 'Goodnight My Love')
# ('Harper', 'Barrett', 'Creil City')
# ('Kate', 'Harrell', '(iii)')
# ('Kate', 'Harrell', 'Life After Death')
# ('Aleena', 'Kirby', 'All I Want For Christmas Is You')
# ('Harper', 'Barrett', 'The Moon (Album version)')
# ('Kate', 'Harrell', 'A Teenager In Love')
# ('Kynnedi', 'Sanchez', 'Bubble Toes')
# ('Aleena', 'Kirby', 'The Maestro')
# ('Kate', 'Harrell', "It's My Party")
# ('Harper', 'Barrett', 'The Next Episode')
# ('Aleena', 'Kirby', 'Encore Break')
# ('Kynnedi', 'Sanchez', 'Commissioning A Symphony In C')
# ('Kate', 'Harrell', 'Rome')
# ('Aleena', 'Kirby', 'Seduction (album)')
# ('Harper', 'Barrett', 'She Moves In Her Own Way')
# ('Harper', 'Barrett', 'La Petite Marie (2005 Digital Remaster)')
# ('Kate', 'Harrell', "Rollin' (Air Raid Vehicle)")
# ('Aleena', 'Kirby', 'Move On (Album Version)')
# ('Harper', 'Barrett', 'Orange TrÃ\x83Â¤gt Nur Die MÃ\x83Â¼llabfuhr (Go West)')
# ('Kate', 'Harrell', 'My Piano (DJ-Kicks)')
# ('Aleena', 'Kirby', "Do That There (featuring Dude 'N Nem)")
# ('Harper', 'Barrett', 'Closer')
# ('Aleena', 'Kirby', 'Life On Mars')
# ('Kate', 'Harrell', 'Love And Caring')
# ('Harper', 'Barrett', 'Lead Us')
# ('Kate', 'Harrell', 'Adrenalin')
# ('Aleena', 'Kirby', 'Crazy Bitch (Album Version)')
# ('Harper', 'Barrett', 'The General Specific (Album)')
# ('Kate', 'Harrell', 'Speak Silence')
# ('Aleena', 'Kirby', 'O Samba E O Tango')
# ('Harper', 'Barrett', 'Burning')
# ('Aleena', 'Kirby', 'All That I Need')
# ('Kate', 'Harrell', 'Trouble')
# ('Harper', 'Barrett', 'Unwell (Album Version)')
# ('Aleena', 'Kirby', 'On Time')
# ('Kate', 'Harrell', 'Golden Skans')
# ('Harper', 'Barrett', 'Hot Thing ( LP Version )')
# ('Kate', 'Harrell', "You're The One")
# ('Aleena', 'Kirby', 'It Was Written')
# ('Kate', 'Harrell', 'Genom tunna tyger')
# ('Harper', 'Barrett', 'I Was Made')
# ('Kate', 'Harrell', 'Infinite Template')
# ('Aleena', 'Kirby', 'Face The Blood')
# ('Harper', 'Barrett', 'Slow Dancing In A Burning Room')
# ('Aleena', 'Kirby', 'Alright')
# ('Harper', 'Barrett', 'Aunque Estes Con El')
# ('Aleena', 'Kirby', 'Two Million Voices')
# ('Kate', 'Harrell', 'Count On Me (Somebody)')
# ('Aleena', 'Kirby', 'Exile')
# ('Harper', 'Barrett', "Everyone's At It")
# ('Kate', 'Harrell', "I'M Gonna Keep On Driving My Car")
# ('Aleena', 'Kirby', 'Paper Planes')
# ('Kate', 'Harrell', 'Interested')
# ('Harper', 'Barrett', 'This Celluloid Dream')
# ('Aleena', 'Kirby', "She Don't Want The World")
# ('Kate', 'Harrell', 'Points Of Authority (Album Version)')
# ('Harper', 'Barrett', 'Gang Party (Leatherface)')
# ('Aleena', 'Kirby', 'Release Me')
# ('Kate', 'Harrell', 'Island In The Sun')
# ('Harper', 'Barrett', 'Kun Puut Tekee SeittiÃ\x83Â¤')
# ('Aleena', 'Kirby', 'Fuori Dal Tunnel (Album Version)')
# ('Kate', 'Harrell', 'Flesh For Fantasy')
# ('Aleena', 'Kirby', 'Fireflies')
# ('Kate', 'Harrell', "Can't Help Falling In Love (Album Version) (Studio)")
# ('Harper', 'Barrett', 'Baby I Want You')
# ('Aleena', 'Kirby', 'Big Poppa')
# ('Aleena', 'Kirby', 'Azure (Album)')
# ('Aleena', 'Kirby', 'Brothers & Sisters')
# ('Aleena', 'Kirby', 'Good Enough')
# ('Aleena', 'Kirby', 'Cuentos chinos')
# ('Aleena', 'Kirby', 'Hidden Love')
# ('Aleena', 'Kirby', 'Promise Me')
# ('Aleena', 'Kirby', 'Boombox')
# ('Aleena', 'Kirby', 'Just Like You')
# ('Aleena', 'Kirby', 'Woman Capture Man')
# ('Aleena', 'Kirby', 'Watch Me Shine (Album)')
# ('Aleena', 'Kirby', 'Booksmart Devil')
# ('Aleena', 'Kirby', 'Lady')
# ('Chloe', 'Cuevas', 'Gay Porn')
# ('Aleena', 'Kirby', 'Heart Less')
# ('Chloe', 'Cuevas', 'Human Vulture')
# ('Aleena', 'Kirby', 'The State Of Massachusetts')
# ('Aleena', 'Kirby', 'Beat It')
# ('Chloe', 'Cuevas', 'Girl Dreams')
# ('Chloe', 'Cuevas', 'Intergalactic')
# ('Aleena', 'Kirby', 'Thnks fr th Mmrs')
# ('Chloe', 'Cuevas', '221')
# ('Aleena', 'Kirby', 'A Hundred Moons')
# ('Chloe', 'Cuevas', 'Love Is Gonna Save Us ')
# ('Aleena', 'Kirby', 'Evolution (the Grand Design)')
# ('Chloe', 'Cuevas', 'Big Apple (Metro Mix)')
# ('Aleena', 'Kirby', 'Virtual Insanity')
# ('Chloe', 'Cuevas', 'Somebody To Love')
# ('Aleena', 'Kirby', 'Save The Last Dance For Me')
# ('Chloe', 'Cuevas', 'Read My Mind')
# ('Aleena', 'Kirby', 'Cat People (Putting Out Fire)')
# ('Chloe', 'Cuevas', 'ReprÃ\x83Â©sente')
# ('Aleena', 'Kirby', 'Lovefool')
# ('Aleena', 'Kirby', "I'm Not Gonna Teach Your Boyfriend How To Dance With You")
# ('Chloe', 'Cuevas', 'She Is Love')
# ('Chloe', 'Cuevas', 'The Wrong Thing To Do (Album Version)')
# ('Aleena', 'Kirby', 'Sample Track 2')
# ('Chloe', 'Cuevas', 'Movement III - Linear Tableau with Intersecting Surprise')
# ('Aleena', 'Kirby', 'Green River Blues')
# ('Aleena', 'Kirby', 'Walk On Water')
# ('Chloe', 'Cuevas', 'Fog On The Tyne (Live)')
# ('Aleena', 'Kirby', 'Jesus Walks')
# ('Chloe', 'Cuevas', 'Retourne Chez Elle')
# ('Aleena', 'Kirby', 'Runaway (Album Version)')
# ('Aleena', 'Kirby', "You've Got To Hide Your Love Away (Digitally Remastered 01)")
# ('Chloe', 'Cuevas', "Don't Speak")
# ('Aleena', 'Kirby', 'God Is On The Radio')
# ('Chloe', 'Cuevas', 'Shots')
# ('Chloe', 'Cuevas', 'High Anxiety')
# ('Aleena', 'Kirby', 'Mariella')
# ('Chloe', 'Cuevas', 'If This Is Love')
# ('Aleena', 'Kirby', 'Holding Out For A Hero')
# ('Chloe', 'Cuevas', 'Get Up Again')
# ('Chloe', 'Cuevas', 'Journey To The Past  (LP Version)')
# ('Aleena', 'Kirby', 'Finale')
# ('Chloe', 'Cuevas', 'Just Dance')
# ('Aleena', 'Kirby', 'Dance With The Devil')
# ('Chloe', 'Cuevas', 'Bluish')
# ('Aleena', 'Kirby', 'A New Hope')
# ('Molly', 'Taylor', 'Loon Garden')
# ('Chloe', 'Cuevas', 'Thank You')
# ('Aleena', 'Kirby', 'The Whammy')
# ('Aleena', 'Kirby', 'All Across The World')
# ('Chloe', 'Cuevas', 'The Ponytail Parades')
# ('Aleena', 'Kirby', 'Song Away')
# ('Jayden', 'Duffy', 'Hurt Feelings')
# ('Chloe', 'Cuevas', 'Cooler Than Me')
# ('Aleena', 'Kirby', 'Medlong')
# ('Jayden', 'Duffy', 'So Long_ Babe (2006 Digital Remaster)')
# ('Chloe', 'Cuevas', 'I Remember Nothing [2007 Re-mastered Album Version]')
# ('Aleena', 'Kirby', 'Suspicious Minds')
# ('Chloe', 'Cuevas', 'Revelry')
# ('Aleena', 'Kirby', 'Gone')
# ('Chloe', 'Cuevas', "It's My Own Fault")
# ('Aleena', 'Kirby', "I Believe I'll Go Back Home")
# ('Aleena', 'Kirby', 'Naviamente')
# ('Chloe', 'Cuevas', 'Can You Tell')
# ('Aleena', 'Kirby', 'What If I Do?')
# ('Aleena', 'Kirby', 'Colors Of The Wind')
# ('Aleena', 'Kirby', '(Hon Vill Ha) Puls')
# ('Chloe', 'Cuevas', 'Cumbia En Do Menor')
# ('Aleena', 'Kirby', 'Marry Me')
# ('Aleena', 'Kirby', 'Teenager')
# ('Chloe', 'Cuevas', 'Tudo Que Eu Sempre Quis')
# ('Aleena', 'Kirby', 'Audience Of One')
# ('Aleena', 'Kirby', 'My Life Inside Your Heart')
# ('Aleena', 'Kirby', "Let's Go All The Way (Short Blix Mix)")
# ('Aleena', 'Kirby', 'Crazy On You')
# ('Aleena', 'Kirby', 'Cats In The Cradle')
# ('Aleena', 'Kirby', 'You Took My Breath Away (2007 Remastered LP Version)')
# ('Aleena', 'Kirby', 'A Foggy Day (In London Town) (Album Version)')
# ('Aleena', 'Kirby', 'Have You Ever')
# ('Aleena', 'Kirby', 'Fandangu Los Llobos')
# ('Aleena', 'Kirby', 'Voices Of Violence (Album Version)')
# ('Aleena', 'Kirby', 'Courtesy Laughs')
# ('Aleena', 'Kirby', "We Don't Care")
# ('Aleena', 'Kirby', 'Gestern_Morgen')
# ('Aleena', 'Kirby', 'Que Me Quedes Tu')
# ('Aleena', 'Kirby', 'Da Baddest [Feat. Trey Songz] (Explicit Album Version)')
# ('Lily', 'Koch', 'La Vie En Rose')
# ('Lily', 'Koch', 'Think About Last Night')
# ('Lily', 'Koch', 'Love Buzz')
# ('Lily', 'Koch', 'Only In Dreams')
# ('Lily', 'Koch', 'She Is My Sin')
# ('Lily', 'Koch', 'Teach Me How To Dougie')
# ('Lily', 'Koch', 'Silvia')
# ('Lily', 'Koch', 'I Kissed A Girl')
# ('Lily', 'Koch', 'Peep Show')
# ('Lily', 'Koch', 'Not Fair')
# ('Lily', 'Koch', 'Lump')
# ('Lily', 'Koch', 'Right Now (Produced by Ayatollah)')
# ('Lily', 'Koch', 'Take A Bow')
# ('Lily', 'Koch', 'Back To The African Garden')
# ('Lily', 'Koch', 'My Humps')
# ('Lily', 'Koch', "Show Me What I'm Looking For (Album Version)")
# ('Lily', 'Koch', 'Dust in The Wind')
# ('Lily', 'Koch', 'Xehasmeni Melodia')
# ('Lily', 'Koch', "Lakini's Juice")
# ('Lily', 'Koch', 'Nuff Fire')
# ('Lily', 'Koch', 'Mean Mean Son Of A Gun')
# ('Lily', 'Koch', 'Ironmasters')
# ('Lily', 'Koch', 'The Absence Of God (Album Version)')
# ('Lily', 'Koch', 'Lost My Mind')
# ('Lily', 'Koch', 'Mamma')
# ('Lily', 'Koch', 'I Will Follow You into the Dark (Album Version)')
# ('Lily', 'Koch', "You're The One")
# ('Lily', 'Koch', 'Cartel Gathering')
# ('Lily', 'Koch', 'Si tu no estas')
# ('Lily', 'Koch', 'The Ballad of Michael Valentine')
# ('Lily', 'Koch', 'SinceritÃ\x83Â© Et Jalousie')
# ('Lily', 'Koch', 'China Roses')
# ('Lily', 'Koch', 'Jazz')
# ('Ryan', 'Smith', 'Love + Pain')
# ('Ryan', 'Smith', 'Solitario Y Solo')
# ('Ryan', 'Smith', 'Midwest Gospel Radio')
# ('Ava', 'Robinson', "Wavin'  Flag")
# ('Kate', 'Harrell', 'Her Ghost In The Fog')
# ('Kate', 'Harrell', 'Let It Rain')
# ('Kate', 'Harrell', 'Sonne')
# ('Kate', 'Harrell', 'If You Want To Sing Out_ Sing Out')
# ('Kate', 'Harrell', 'Spente Le Stelle')
# ('Kate', 'Harrell', 'Float On')
# ('Kate', 'Harrell', 'En El Cielo No Hay Cerveza (In Heaven There Is No Beer)')
# ('Kate', 'Harrell', 'Float On')
# ('Kate', 'Harrell', 'Pills (Radio Edit) (Radio Edit)')
# ('Kate', 'Harrell', 'Strut (1993 Digital Remaster)')
# ('Kate', 'Harrell', "My Baby Don't Love Me")
# ('Kate', 'Harrell', 'Dog Days Are Over (Radio Edit)')
# ('Kate', 'Harrell', 'Naked (Live)')
# ('Kate', 'Harrell', 'Apologize')
# ('Kate', 'Harrell', 'Full Circle')
# ('Kate', 'Harrell', "Don't Panic")
# ('Kate', 'Harrell', "You Were The King_ Now You're Unconscious (Album Version)")
# ('Kate', 'Harrell', 'Born To Run')
# ('Kate', 'Harrell', 'Undo')
# ('Kate', 'Harrell', "It Just Don't Stop")
# ('Kate', 'Harrell', 'Be Your Own Girl')
# ('Kate', 'Harrell', "Ain't No Way (You Won't Love Me)")
# ('Kate', 'Harrell', 'Filosofia Barata Y Zapatos De Goma')
# ('Kate', 'Harrell', 'Boyz-N-The-Hood')
# ('Kate', 'Harrell', '1/2/2008')
# ('Kate', 'Harrell', 'Unite (2009 Digital Remaster)')
# ('Kate', 'Harrell', 'Take A Ride')
# ('Kate', 'Harrell', 'Cuando Agosto Era 21')
# ('Kate', 'Harrell', 'Napoleon Says')
# ('Jayden', 'Fox', 'Sweet And Wild')
# ('Jayden', 'Fox', 'Manchild')
# ('Ayla', 'Johnson', 'Szex & KV')
# ('Lily', 'Burns', 'Pursuit Of Happiness (nightmare)')
# ('Morris', 'Gilmore', 'Blue Blood')
# ('Morris', 'Gilmore', "Trashin' The Camp (Phil And 'N Sync Version)")
# ('Jayden', 'Fox', 'I Need You')
# ('Jayden', 'Fox', 'Tired Of Being Sorry')
# ('Jayden', 'Fox', 'The Invisible Man')
# ('Jayden', 'Fox', 'Windy & Warm')
# ('Stefany', 'White', 'No Good 4 You')
# ('Jayden', 'Duffy', 'Nothing Personal')
# ('Cecilia', 'Owens', 'ConfesiÃ\x83Â³n')
# ('Cecilia', 'Owens', 'I Found That Essence Rare')
# ('Cecilia', 'Owens', 'Le Soir')
# ('Tegan', 'Levine', 'Last Day Of Our Love')
# ('Harper', 'Barrett', 'Supermassive Black Hole (Twilight Soundtrack Version)')
# ('Harper', 'Barrett', 'Lighten Up')
# ('Harper', 'Barrett', 'Pienso En Ti')
# ('Harper', 'Barrett', 'Amor Prohibido')
# ('Harper', 'Barrett', "Day 'N' Nite")
# ('Harper', 'Barrett', 'Black Masks & Gasoline')
# ('Harper', 'Barrett', "I'm Like A Lawyer With The Way I'm Always Trying To Get You Off (Me & You)")
# ('Harper', 'Barrett', 'Staple It Together')
# ('Harper', 'Barrett', 'Slow Jamz (Feat. Kanye West & Jamie Foxx) (Edited Album Version)')
# ('Harper', 'Barrett', 'Hey_ Soul Sister')
# ('Harper', 'Barrett', 'Rehab')
# ('Harper', 'Barrett', 'Van Helsing Boombox')
# ('Harper', 'Barrett', 'The Stallion')
# ('Harper', 'Barrett', 'Fireflies')
# ('Harper', 'Barrett', 'I Want I Want')
# ('Harper', 'Barrett', 'Railway')
# ('Harper', 'Barrett', 'Clark Gable (Album)')
# ('Harper', 'Barrett', 'Phaeton')
# ('Harper', 'Barrett', 'Ucci Ucci feat. Nicki Minaj & The Chopper City Boyz')
# ('Harper', 'Barrett', 'Choke')
# ('Harper', 'Barrett', 'Stuck Between')
# ('Harper', 'Barrett', 'Smell Of Desire.')
# ('Harper', 'Barrett', 'Headlights Look Like Diamonds')
# ('Harper', 'Barrett', 'Out Go The Lights')
# ('Harper', 'Barrett', 'You & Me Song')
# ('Harper', 'Barrett', 'Girls (Album version)')
# ('Harper', 'Barrett', 'Wayfaring Stranger')
# ('Harper', 'Barrett', 'Sweep The Flo (Featuring Diamond)')
# ('Harper', 'Barrett', 'This Old House w/ When The Saints Medley')
# ('Harper', 'Barrett', 'Brain Leech')
# ('Harper', 'Barrett', 'Didgeridoo')
# ('Harper', 'Barrett', 'LÃ\x83Â\xa0 OÃ\x83Â¹ Je Pars')
# ('Harper', 'Barrett', "I Wouldn't Be A Man")
# ('Chloe', 'Cuevas', 'Soy AlbaÃ\x83Â±il')
# ('Cecilia', 'Owens', 'Ghost In The Mirror')
# ('Layla', 'Griffin', 'My Moon My Man')
# ('Tegan', 'Levine', 'We Will Become Silhouettes (Album)')
# ('Tegan', 'Levine', 'Life Without You')
# ('Hannah', 'Calhoun', 'Miseria Cantare--The Beginning')
# ('Sara', 'Johnson', 'Catch You Baby (Steve Pitron & Max Sanna Radio Edit)')
# ('Sara', 'Johnson', 'My Blue Heaven')
# ('Sara', 'Johnson', 'Crucificame')
# ('Sara', 'Johnson', 'Invalid')
# ('Kimber', 'Norris', 'I Can Dance')
# ('Kimber', 'Norris', 'The World Is A Ghetto')
# ('Tegan', 'Levine', 'Gone')
# ('Tegan', 'Levine', 'Play')
# ('Devin', 'Larson', 'Second awakening')
# ('Tegan', 'Levine', 'Protoculture (Sankofa)')
# ('Tegan', 'Levine', 'Emotion')
# ('Colm', 'Santana', 'Love Story')
# ('Tegan', 'Levine', 'Message In A Bottle')
# ('Tegan', 'Levine', "You'd Rather Run")
# ('Martin', 'Johnson', 'Happy Working Song')
# ('Tegan', 'Levine', 'Second Chance (Album Version)')
# ('Martin', 'Johnson', 'Some Unholy War')
# ('Tegan', 'Levine', 'Ride Wit Me')
# ('Lily', 'Koch', 'Soliloquy Of Chaos (Explicit)')
# ('Tegan', 'Levine', "Who's Your Daddy? ")
# ('Lily', 'Koch', 'When It Rains (Album Version)')
# ('Tegan', 'Levine', 'Mama Said')
# ('Lily', 'Koch', 'Forever Not Yours (Album Version  - NY Mix II)')
# ('Tegan', 'Levine', 'Lovely Rita (feat. Bunny Rugs and U Roy)')
# ('Lily', 'Koch', 'Down To My Last')
# ('Tegan', 'Levine', 'Mudanca De Tempo')
# ('Lily', 'Koch', 'Walking In The Air')
# ('Tegan', 'Levine', 'Mayfield')
# ('Lily', 'Koch', 'Ring My Bell')
# ('Tegan', 'Levine', 'I C Love Affair')
# ('Lily', 'Koch', 'Slow Death')
# ('Tegan', 'Levine', 'Carry')
# ('Lily', 'Koch', 'Canada')
# ('Lily', 'Koch', 'Pace E Guerra')
# ('Tegan', 'Levine', 'ReprÃ\x83Â©sente')
# ('Tegan', 'Levine', 'Mercy:The Laundromat')
# ('Tegan', 'Levine', 'Clockwork Skinhead')
# ('Tegan', 'Levine', 'Wood And Wire')
# ('Jayden', 'Fox', 'Best Of Both Worlds (Remastered Album Version)')
# ('Theodore', 'Harris', 'Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)')
# ('Ann', 'Banks', 'My Brother Is Watching Me')
# ('Tegan', 'Levine', 'Over You')
# ('Jayden', 'Fox', 'She Loves You')
# ('Lily', 'Burns', 'Big In Japan (Original)')
# ('Tegan', 'Levine', 'Mindjer dÃ\x83Â´ce mel')
# ('Ann', 'Banks', 'Flying Into a Star')
# ('Tegan', 'Levine', 'Marvin & Miles')
# ('Tegan', 'Levine', 'Dog Days Are Over (Radio Edit)')
# ('Tegan', 'Levine', 'Seven Nation Army')
# ('Ava', 'Robinson', 'East Side Mags')
# ('Ava', 'Robinson', 'The Scientist')
# ('Tegan', 'Levine', 'Revelry')
# ('Tegan', 'Levine', 'Backyard')
# ('Cecilia', 'Owens', 'The Way You Look Tonight (Live Version)')
# ('Tegan', 'Levine', 'The Mess I Made')
# ('Kinsley', 'Young', 'My Apocalypse')
# ('Tegan', 'Levine', 'Teenage Spaceman')
# ('Kinsley', 'Young', 'Modern world')
# ('Cecilia', 'Owens', 'Invalid')
# ('Tegan', 'Levine', 'Everybody Everybody')
# ('Kinsley', 'Young', 'Ye Feng Ling')
# ('Tegan', 'Levine', 'Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)')
# ('Kinsley', 'Young', 'Buttnaked')
# ('Tegan', 'Levine', 'No One Knows')
# ('Kinsley', 'Young', 'Il Solo Rimasto')
# ('Tegan', 'Levine', 'Living In The U.S.A. (1991 Digital Remaster)')
# ('Kinsley', 'Young', 'Drop The World')
# ('Kinsley', 'Young', 'Stoke Up The Fire')
# ('Tegan', 'Levine', 'Whiskey Girl')
# ('Tegan', 'Levine', 'Muy_ Muy Temprano')
# ('Kinsley', 'Young', 'Under The Northern Star')
# ('Jacob', 'Rogers', 'Genom tunna tyger')
# ('Jacob', 'Rogers', 'Geh Deinen Weg')
# ('Kinsley', 'Young', "Don't Let The Rain Come Down (Crooked Little Man)")
# ('Tegan', 'Levine', 'Strut (1993 Digital Remaster)')
# ('Kinsley', 'Young', 'Falling Inside The Black (Album Version)')
# ('Tegan', 'Levine', 'Into The Cryptic Mist')
# ('Kinsley', 'Young', 'Greenback Dollar')
# ('Tegan', 'Levine', 'Ten Cent Pistol')
# ('Kinsley', 'Young', 'Times Like These')
# ('Kinsley', 'Young', 'House Of Broken Love')
# ('Tegan', 'Levine', 'No Rain')
# ('Lily', 'Burns', 'Fly Away From Here')
# ('Tegan', 'Levine', 'Solar Flare')
# ('Kinsley', 'Young', 'Kaaos ei karkaa')
# ('Tegan', 'Levine', "Baker's Blue Jay Yarn")
# ('Tegan', 'Levine', 'Shortie Like Mine')
# ('Kinsley', 'Young', 'Hold On')
# ('Tegan', 'Levine', 'Adios')
# ('Kinsley', 'Young', 'Shame')
# ('Tegan', 'Levine', 'Madrugada Na Praia Deserta')
# ('Kinsley', 'Young', 'Vanishing')
# ('Tegan', 'Levine', "I CAN'T GET STARTED")
# ('Tegan', 'Levine', 'Do We Need This?')
# ('Tegan', 'Levine', 'Howlin\x19 For You')
# ('Adler', 'Barrera', 'Bleed It Out (Album Version)')
# ('Tegan', 'Levine', 'Microdaze')
# ('Tegan', 'Levine', 'Crosshairs')
# ('Tegan', 'Levine', 'Breakdown')
# ('Tegan', 'Levine', 'The Pretender')
# ('Tegan', 'Levine', 'Jumpers (Album)')
# ('Tegan', 'Levine', 'Pace Is The Trick')
# ('Tegan', 'Levine', 'Dance Me To The End Of Love')
# ('Matthew', 'Jones', 'Star Eyes')
# ('Tegan', 'Levine', 'Headstrong (Album Version)')
# ('Matthew', 'Jones', 'You Love Me Anyway (Album)')
# ('Tegan', 'Levine', 'Not For You')
# ('Matthew', 'Jones', 'El Juego Del Rap')
# ('Ava', 'Robinson', 'U.S. Bombs')
# ('Matthew', 'Jones', 'Colpa Del Whisky (Andrea Paci Radio Edit)')
# ('Tegan', 'Levine', 'Streets Of Philadelphia')
# ('Ava', 'Robinson', "Hey Daddy (Daddy's Home)")
# ('Matthew', 'Jones', 'Grand Designs')
# ('Tegan', 'Levine', 'Columbus Avenue')
# ('Ava', 'Robinson', 'Mariposa traicionera')
# ('Ryan', 'Smith', 'Obsessed')
# ('Tegan', 'Levine', 'Bubble Toes')
# ('Ava', 'Robinson', 'Make Love To Your Mind')
# ('Ryan', 'Smith', 'Natural Anthem (Album)')
# ('Tegan', 'Levine', 'Love On The Rocks')
# ('Matthew', 'Jones', 'Pass You By')
# ('Ava', 'Robinson', 'Gone')
# ('Ryan', 'Smith', "Unless It's Kicks")
# ('Matthew', 'Jones', 'DNA')
# ('Tegan', 'Levine', 'Crazy Beautiful')
# ('Tegan', 'Levine', 'Sonrisa')
# ('Matthew', 'Jones', 'Call Me')
# ('Matthew', 'Jones', 'Kromozom Bankal (Linathaleyco Mix)')
# ('Ryan', 'Smith', 'Pea (Album Version)')
# ('Ryan', 'Smith', 'Red Elephant')
# ('Tegan', 'Levine', 'Your Decision')
# ('Matthew', 'Jones', 'Stripes')
# ('Jacob', 'Rogers', 'Bleed It Out [Live At Milton Keynes]')
# ('Ryan', 'Smith', "Ain't Misbehavin")
# ('Matthew', 'Jones', 'Every Shining Time You Arrive (Album)')
# ('Tegan', 'Levine', "I'm Shady")
# ('Matthew', 'Jones', 'Call 9-1-1 (Explicit)')
# ('Matthew', 'Jones', "Remember Me_ I'm The One Who Loves You")
# ('Matthew', 'Jones', "It Just Don't Stop")
# ('Matthew', 'Jones', 'El Cuatrero')
# ('Matthew', 'Jones', 'All Along The Watchtower')
# ('Matthew', 'Jones', 'Kalidafun Parts 1&2')
# ('Matthew', 'Jones', 'Rosemary')
# ('Matthew', 'Jones', 'Blue Collar Man (Long Nights)')
# ('Matthew', 'Jones', 'Su veneno')
# ('Matthew', 'Jones', 'Hot N Cold (Manhattan Clique Remix Radio Edit)')
# ('Matthew', 'Jones', 'Bebot')
# ('Matthew', 'Jones', 'Lava Lava')
# ('Matthew', 'Jones', 'Air & Lack Thereof')
# ('Tegan', 'Levine', 'My Mamma Said')
# ('Matthew', 'Jones', 'Piano Concerto No. 2 in G minor Op. 22 (2006 Digital Remaster): III.  Presto')
# ('Tegan', 'Levine', 'Where Is My Mind?')
# ('Tegan', 'Levine', 'Drunk Girls')
# ('Matthew', 'Jones', 'Two Hearts')
# ('Matthew', 'Jones', 'Reptilia')
# ('Kinsley', 'Young', 'Clockwork Skinhead')
# ('Matthew', 'Jones', 'Scream For More')
# ('Kinsley', 'Young', "God's Plan")
# ('Kinsley', 'Young', 'Kiss It Better')
# ('Matthew', 'Jones', 'All Of The Champs That Ever Lived')
# ('Matthew', 'Jones', 'Something')
# ('Matthew', 'Jones', 'Fireflies')
# ('Matthew', 'Jones', 'English Summer Rain')
# ('Matthew', 'Jones', 'Man/Bag Of Sand')
# ('Matthew', 'Jones', "Don't Think I Don't Think About It")
# ('Matthew', 'Jones', 'Everlong')
# ('Chloe', 'Cuevas', 'Transparency')
# ('Matthew', 'Jones', 'Jambalaya (On The Bayou)')
# ('Chloe', 'Cuevas', "I CAN'T GET STARTED")
# ('Matthew', 'Jones', 'Te Amo')
# ('Matthew', 'Jones', 'Kellum (Album Version)')
# ('Matthew', 'Jones', 'My All')
# ('Chloe', 'Cuevas', 'Change Is Hard')
# ('Chloe', 'Cuevas', 'Sugar (Jagz Kooner Mix)')
# ('Matthew', 'Jones', 'Dumb Blood')
# ('Matthew', 'Jones', 'Time Bomb')
# ('Matthew', 'Jones', 'In The Closet')
# ('Matthew', 'Jones', "Don't Go")
# ('Matthew', 'Jones', 'BedRock (Radio Edit) (feat.Lloyd)')
# ('Matthew', 'Jones', 'Rock With Me')
# ('Matthew', 'Jones', 'Motor Panir')
# ('Matthew', 'Jones', 'Right Through You (LP Version)')
# ('Matthew', 'Jones', 'Supermassive Black Hole (Twilight Soundtrack Version)')
# ('Matthew', 'Jones', 'Brackett_ WI')
# ('Matthew', 'Jones', 'Burn Them Prisons')
# ('Matthew', 'Jones', 'Mighty K.C.')
# ('Matthew', 'Jones', 'Tu Me Asustas')
# ('Matthew', 'Jones', 'Barbwire')
# ('Matthew', 'Jones', 'Ante Up (Robbin Hoodz Theory)')
# ('Matthew', 'Jones', 'Crack A Bottle')
# ('Celeste', 'Williams', 'Estoy AquÃ\x83Â\xad')
# ('Matthew', 'Jones', 'Yeah!')
# ('Matthew', 'Jones', 'Hanuman')
# ('Matthew', 'Jones', 'I Wanna Be Sedated (Remastered Album Version )')
# ('Matthew', 'Jones', 'Miserable At Best (Album)')
# ('Jayden', 'Graves', 'Music Box')
# ('Jayden', 'Graves', 'Visions')
# ('Theodore', 'Harris', 'Calyx Virago')
# ('Jayden', 'Graves', 'Drop The Mirror (EP Version)')
# ('Theodore', 'Harris', 'Shook Ones pt. 2')
# ('Jayden', 'Graves', 'Pretendo Hablarte')
# ('Jayden', 'Graves', 'Bring Me To Life')
# ('Jayden', 'Graves', 'Clear Blue Water')
# ('Mohammad', 'Rodriguez', "You're The One")
# ('Mohammad', 'Rodriguez', 'Lord Xenu')
# ('Jayden', 'Graves', 'Take Me To The River')
# ('Jayden', 'Graves', 'Flat Beat')
# ('Jayden', 'Graves', 'Never Too Far')
# ('Jayden', 'Graves', "Day 'N' Nite")
# ('Jayden', 'Graves', 'El Hombre')
# ('Jayden', 'Graves', 'Geek In The Pink [Phil Tan Remix]')
# ('Jayden', 'Graves', "You're The One")
# ('Jayden', 'Graves', 'I Second That Emotion')
# ('Stefany', 'White', 'Zen')
# ('Tucker', 'Garrison', 'Abrazame  (Version Acustica)')
# ('Tucker', 'Garrison', "You Ain't Right (Album Version)")
# ('James', 'Martin', 'Provider (Remix Radio Edit)')
# ('Jacqueline', 'Lynch', 'Aww Skeet Skeet')
# ('Jacqueline', 'Lynch', 'The Sun In The Stream')
# ('Jacqueline', 'Lynch', 'We Need To Talk (She And I Album Version)')
# ('Jacqueline', 'Lynch', 'Pursuit Of Happiness (nightmare)')
# ('Jacqueline', 'Lynch', "Haven't We Lost Enough?  (LP Version)")
# ('Jacqueline', 'Lynch', 'Sleepyhead')
# ('Jacqueline', 'Lynch', 'Merry Go Round (Remastered Single Version)')
# ('Molly', 'Taylor', 'Rosa Branca')
# ('Jacqueline', 'Lynch', 'Like you better dead')
# ('Molly', 'Taylor', 'Newport Living (Album Version)')
# ('Jacqueline', 'Lynch', 'Too Far Gone')
# ('Molly', 'Taylor', 'Take Em To Church')
# ('Jacqueline', 'Lynch', "Don't Walk Away")
# ('Jacqueline', 'Lynch', 'Nube Inerte (con Aniki)')
# ('Jacqueline', 'Lynch', 'Untitled')
# ('Jacqueline', 'Lynch', 'A Dream')
# ('Jacqueline', 'Lynch', 'Halo')
# ('Jacqueline', 'Lynch', 'Getting Better (feat. The Mighty Diamonds)')
# ('Jacqueline', 'Lynch', 'Sing Along [Featuring Dave Matthews]')
# ('Jacqueline', 'Lynch', 'Run')
# ('Jacqueline', 'Lynch', 'Come Softly To Me')
# ('Jacqueline', 'Lynch', 'Let Down')
# ('Jacqueline', 'Lynch', 'Demon Days')
# ('Jacqueline', 'Lynch', 'Eton Boating Song/Wyoming Lullaby/The Wiffenpoof Song (Baa Baa Baa) (Medley)')
# ('Jacqueline', 'Lynch', 'Pirate Jet')
# ('Jacqueline', 'Lynch', 'Clear Blue Water')
# ('Jacqueline', 'Lynch', 'Oh Yeah')
# ('Samuel', 'Gonzalez', 'Sorrow (1997 Digital Remaster)')
# ('Jacqueline', 'Lynch', "Don't Take Away The Music")
# ('Samuel', 'Gonzalez', "Bigger Isn't Better")
# ('Chloe', 'Roth', 'Break My Body')
# ('Jacqueline', 'Lynch', "I've Got Knives In My Eyes I'm Going Home Sick")
# ('Jacqueline', 'Lynch', 'Effervescing Elephant')
# ('Jacqueline', 'Lynch', 'If You Want To Sing Out_ Sing Out')
# ('Kaylee', 'Summers', 'I Feel Wonderful (AM to PM Mix)')
# ('Jacqueline', 'Lynch', 'Who Makes Your Money')
# ('Jacqueline', 'Lynch', 'Fools')
# ('Jacqueline', 'Lynch', 'Tive Sim')
# ('Jacqueline', 'Lynch', "It's Raining Again")
# ('Jacqueline', 'Lynch', 'West One (Shine On Me)')
# ('Jacqueline', 'Lynch', 'Abololo')
# ('Jacqueline', 'Lynch', 'Bottom of a Bottle (Explicit Album Version)')
# ('Jacqueline', 'Lynch', 'Unrecorded')
# ('Jacqueline', 'Lynch', 'Roustabout (Bassnectar REMIX)')
# ('Jacqueline', 'Lynch', 'The Vowels Pt. 2')
# ('Jacqueline', 'Lynch', 'From Head To Toe')
# ('Jacqueline', 'Lynch', 'On The Radio (Edit)')
# ('Jacqueline', 'Lynch', 'Halo')
# ('Jacqueline', 'Lynch', 'Only Time (Original Version)')
# ('Jacqueline', 'Lynch', 'Ne me plaignez pas')
# ('Jacqueline', 'Lynch', 'Audience Of One')
# ('Jacqueline', 'Lynch', 'Ruby')
# ('Jacqueline', 'Lynch', 'Reign Of The Tyrants')
# ('Jacqueline', 'Lynch', 'The Ghost Of You (Album Version)')
# ('Jacqueline', 'Lynch', 'Cupola')
# ('Jacqueline', 'Lynch', 'Losers')
# ('Jacqueline', 'Lynch', 'Gears')
# ('Jacqueline', 'Lynch', 'Alejandro')
# ('Jacqueline', 'Lynch', 'Superstar')
# ('Jacqueline', 'Lynch', "When My Baby's Beside Me")
# ('Ryan', 'Smith', 'Hold On To Me')
# ('Jacqueline', 'Lynch', 'Sehr kosmisch')
# ('Jacqueline', 'Lynch', 'I Need You')
# ('Jacqueline', 'Lynch', 'Cool Water')
# ('Jacqueline', 'Lynch', 'In The Dark (ft. Christian Burns)')
# ('Jacqueline', 'Lynch', 'Window In The Skies')
# ('Jacqueline', 'Lynch', 'We Major')
# ('Jacqueline', 'Lynch', 'Sweet And Wild')
# ('Jacqueline', 'Lynch', 'Solar Powered')
# ('Jacqueline', 'Lynch', 'The Real Slim Shady')
# ('Jacqueline', 'Lynch', 'What Are You Looking For')
# ('Jacqueline', 'Lynch', 'Secrets')
# ('Jacqueline', 'Lynch', 'Wow_ I Can Get Sexual Too')
# ('Jacqueline', 'Lynch', 'A Warm Place')
# ('Jacqueline', 'Lynch', 'El Golpe')
# ('Jacqueline', 'Lynch', 'Waste of Time')
# ('Jacqueline', 'Lynch', 'Waters Of Nazareth (album version)')
# ('Jacqueline', 'Lynch', 'Behind The Sea [Live In Chicago]')
# ('Jacqueline', 'Lynch', 'Besos Y Caricias')
# ('Jacqueline', 'Lynch', 'Maybe')
# ('Jacqueline', 'Lynch', 'I Saw The Light')
# ('Jacqueline', 'Lynch', 'A Girl Named You')
# ('Jacqueline', 'Lynch', 'Last Cup Of Sorrow')
# ('Jacqueline', 'Lynch', 'Rearview Mirror')
# ('Jacqueline', 'Lynch', 'Supermassive Black Hole (Twilight Soundtrack Version)')
# ('Jacqueline', 'Lynch', 'Just Because')
# ('Jacqueline', 'Lynch', "I'll Be Your Man")
# ('Jacqueline', 'Lynch', 'Let Me Be The One')
# ('Jacqueline', 'Lynch', 'Sit Down Baby')
# ('Jacqueline', 'Lynch', 'So Bored')
# ('Jacqueline', 'Lynch', 'The Ballad Of Sal Villanueva (Album Version)')
# ('Jacqueline', 'Lynch', 'Quutamo')
# ('Jacqueline', 'Lynch', 'Turn The Radio Off')
# ('Jacqueline', 'Lynch', 'En Nat Bliver Det Sommer')
# ('Jacqueline', 'Lynch', 'Fast As I Can')
# ('Jacqueline', 'Lynch', 'Slip')
# ('Jacqueline', 'Lynch', 'The Garden')
# ('Jacqueline', 'Lynch', "I'd Like To Know")
# ('Jacqueline', 'Lynch', 'Hello Walls')
# ('Jacqueline', 'Lynch', 'Como Me Mira')
# ('Magdalene', 'Herman', 'Imanol')
# ('Jacqueline', 'Lynch', 'Beautiful')
# ('Magdalene', 'Herman', 'Sample Track 2')
# ('Jacqueline', 'Lynch', 'Up And Gone')
# ('Jacqueline', 'Lynch', 'Bust A Move')
# ('Jacqueline', 'Lynch', 'La Bayamesa')
# ('Jacqueline', 'Lynch', 'Marry Me')
# ('Jacqueline', 'Lynch', 'Dans Ma Bulle (Edit Radio - Live 2006)')
# ('Jacqueline', 'Lynch', 'The Beginning (Single Remix)')
# ('Jacqueline', 'Lynch', 'Hello')
# ('Jacqueline', 'Lynch', "Imagination (12'' Version)")
# ('Chloe', 'Cuevas', 'Palma Solane')
# ('Jacqueline', 'Lynch', 'Never Say Never')
# ('Jacqueline', 'Lynch', 'Sunburn [Live]')
# ('Chloe', 'Cuevas', 'Up The Bracket')
# ('Jacqueline', 'Lynch', 'Love Story')
# ('Jacqueline', 'Lynch', 'Be Aware')
# ('Jacqueline', 'Lynch', 'House Of Broken Love')
# ('Jacqueline', 'Lynch', 'DonÃ\x82Â´t Believe The Hype')
# ('Jacqueline', 'Lynch', 'I Kissed A Girl')
# ('Jacqueline', 'Lynch', 'Imanol')
# ('Jacqueline', 'Lynch', 'Crazy In The Night (Barking At Airplanes)')
# ('Jacqueline', 'Lynch', 'Joy')
# ('Jacqueline', 'Lynch', 'Howlin\x19 For You')
# ('Jacqueline', 'Lynch', 'Disavow your God (Album Version)')
# ('Jacqueline', 'Lynch', 'Monsoon')
# ('Chloe', 'Cuevas', 'Paper Planes')
# ('Jacqueline', 'Lynch', 'Odessa')
# ('Chloe', 'Cuevas', 'Meltdown (Amended Album Version)')
# ('Jacqueline', 'Lynch', 'El Infeliz')
# ('Chloe', 'Cuevas', 'All I Do Is Dream Of You (Album Version)')
# ('Jacqueline', 'Lynch', 'Photograph')
# ('Chloe', 'Cuevas', 'Back Sliders Wine')
# ('Aiden', 'Hess', 'Billionaire [feat. Bruno Mars]  (Explicit Album Version)')
# ('Ann', 'Banks', "Mean Ol'World")
# ('Jahiem', 'Miles', 'En Mi Mundo')
# ('Jahiem', 'Miles', "We'll Never Know")
# ('Jahiem', 'Miles', 'Cabaret Blanco')
# ('Cecilia', 'Owens', 'Tarkus')
# ('Jayden', 'Graves', 'Weird Era')
# ('Jayden', 'Graves', 'No Surprise')
# ('Jayden', 'Graves', 'Club Tropicana')
# ('Jayden', 'Graves', 'Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)')
# ('Jayden', 'Graves', 'Depot Blues')
# ('Jayden', 'Graves', 'Lucky (Album Version)')
# ('Jayden', 'Graves', 'Talking In Your Sleep')
# ('Jayden', 'Graves', 'Such Great Heights')
# ('Jayden', 'Graves', 'Always Will (LP Version)')
# ('Jayden', 'Graves', 'Above The Clouds (Edited)')
# ('Jayden', 'Graves', 'Coldest Winter')
# ('Jayden', 'Graves', 'Nan Ni Wan')
# ('Jayden', 'Graves', 'Back In The Day')
# ('Maia', 'Burke', 'Vielas De Alfama')
# ('Jayden', 'Graves', 'Epilogue')
# ('Maia', 'Burke', 'Non E_ Per Te_ Per Me')
# ('Jayden', 'Graves', 'Fight For Your Life')
# ('Jayden', 'Graves', 'ReprÃ\x83Â©sente')
# ('Jayden', 'Graves', "Run_ Don't Walk")
# ('Jayden', 'Graves', 'The Door')
# ('Jayden', 'Graves', 'Love Always')
# ('Jayden', 'Graves', 'Bring Me To Life')
# ('Jayden', 'Graves', 'The Snow Prelude No. 2')
# ('Jayden', 'Graves', 'Ayer Me Dijo Un Ave')
# ('Jayden', 'Graves', 'Basic Space')
# ('Jayden', 'Graves', 'Big Munny')
# ('Jayden', 'Graves', 'Ms. Jackson')
# ('Jayden', 'Graves', 'The Only One')
# ('Jayden', 'Graves', "Po' Folks")
# ('Jayden', 'Graves', 'Fool For Your Loving')
# ('Jayden', 'Graves', 'Who Can Compare')
# ('Jayden', 'Graves', 'PrÃ\x83Â³fugos')
# ('Jayden', 'Graves', 'Home')
# ('Aleena', 'Kirby', 'Dismantle. Repair.')
# ('Aleena', 'Kirby', 'Shitlist')
# ('Aleena', 'Kirby', 'Fingers Become Thumbs')
# ('Aleena', 'Kirby', 'Call Me')
# ('Aleena', 'Kirby', 'Billionaire [feat. Bruno Mars]  (Explicit Album Version)')
# ('Aleena', 'Kirby', 'Smile')
# ('Aleena', 'Kirby', 'Fall Back Down (Album Version)')
# ('Aleena', 'Kirby', "I'm Still Breathing")
# ('Aleena', 'Kirby', 'Punks (Krafty Kuts Remix)')
# ('Rylan', 'George', 'All Summer Long (Album Version)')
# ('Aleena', 'Kirby', 'On A Gloomy Evening')
# ('Rylan', 'George', 'When You Were Young')
# ('Aleena', 'Kirby', 'Ghost Dream')
# ('Aleena', 'Kirby', 'Rooftop Gambler')
# ('Rylan', 'George', "Can't Help But Wait (Album Version)")
# ('Aleena', 'Kirby', 'La Pared')
# ('Rylan', 'George', 'Tennessee Waltz (Live)')
# ('Aleena', 'Kirby', 'D is for Dangerous')
# ('Rylan', 'George', 'Ghost Of A Good Thing')
# ('Aleena', 'Kirby', 'Lift Me Up')
# ('Aleena', 'Kirby', 'Snookered')
# ('Aleena', 'Kirby', 'Psycho')
# ('Aleena', 'Kirby', 'Snow [Hey Oh] (Album Version)')
# ('Aleena', 'Kirby', 'Memphis_ Tennessee')
# ('Aleena', 'Kirby', 'Jump (Live)')
# ('Aleena', 'Kirby', 'Streets Of New York (City Life)')
# ('Aleena', 'Kirby', 'Another Town')
# ('Aleena', 'Kirby', 'Well Did You Evah!')
# ('Aleena', 'Kirby', "What's The Difference")
# ('Aleena', 'Kirby', 'Advanced (Ton T.B. Mix)')
# ('Aleena', 'Kirby', 'Apologize')
# ('Aleena', 'Kirby', 'The Maestro')
# ('Aleena', 'Kirby', 'The Only Exception (Album Version)')
# ('Aleena', 'Kirby', 'Hasta siempre')
# ('Aleena', 'Kirby', 'Howlin\x19 For You')
# ('Aleena', 'Kirby', 'Feeling Good')
# ('Aleena', 'Kirby', "Daddy's Little Girl")
# ('Aleena', 'Kirby', 'Now Behold The Lamb')
# ('Aleena', 'Kirby', 'Make Me Happy')
# ('Cecilia', 'Owens', 'Timeless')
# ('Aleena', 'Kirby', 'Lost And Found')
# ('Aleena', 'Kirby', 'The Calculation (Album Version)')
# ('Aleena', 'Kirby', 'Rain')
# ('Aleena', 'Kirby', 'Beautiful Calm Driving')
# ('Aleena', 'Kirby', 'Lead Me Home')
# ('Aleena', 'Kirby', 'Crack A Bottle')
# ('Aleena', 'Kirby', 'Oxford Comma (Album)')
# ('Lily', 'Burns', 'Guess Who')
# ('Sylvie', 'Cruz', 'If You Want Me (Live)')
# ('Jordan', 'Hicks', 'Tonight (Single Mix)')
# ('Sylvie', 'Cruz', 'The Islander')
# ('Brantley', 'West', 'As Rosas NÃ\x83Â£o Falam')
# ('Brantley', 'West', 'I Think Ur A Contra')
# ('Brantley', 'West', 'Hassle')
# ('Brantley', 'West', 'Wish You Were Here')
# ('Brantley', 'West', 'Allies')
# ('Magdalene', 'Herman', 'Hypnopaedia')
# ('Jahiem', 'Miles', 'Cooler Than Me')
# ('Chloe', 'Roth', 'ReprÃ\x83Â©sente')
# ('Chloe', 'Roth', 'Above The Clouds (Edited)')
# ('Braden', 'Parker', 'Shake Your Head')
# ('Chloe', 'Roth', 'Crossfire')
# ('Chloe', 'Roth', "You're The One")
# ('Adler', 'Barrera', 'Obvious Heart')
# ('Adler', 'Barrera', 'Intoxication')
# ('Anabelle', 'Simpson', 'Up Up & Away')
# ('Adler', 'Barrera', 'Fairy Tale')
# ('Anabelle', 'Simpson', 'None Shall Pass (Main)')
# ('Bronson', 'Harris', 'Whatta Man (Salt-N-Pepa Featuring En Vogue) (EP Version)')
# ('Bronson', 'Harris', 'Ghost Tigers Rise (Album Version)')
# ('Bronson', 'Harris', "Don't Wait For Daylight (Album Version)")
# ('Tegan', 'Levine', 'Hard Times (LP Version)')
# ('Tegan', 'Levine', 'Somebody To Love')
# ('Tegan', 'Levine', 'Walk Like A Woman (Album Version)')
# ('Tegan', 'Levine', 'You Belong With Me')
# ('Tegan', 'Levine', 'Festival (Of 7 Lights)')
# ('Jacob', 'Klein', 'Dynamite!')
# ('Jacob', 'Klein', 'Learn To Fly')
# ('Jacob', 'Klein', 'Buzos (En La Luna)')
# ('Jacob', 'Klein', 'Back To Life (Album Version)')
# ('Jacob', 'Klein', 'Me Quedo Contigo [Si Me Das A Elegir]')
# ('Jacob', 'Klein', "Nothin' On You [feat. Bruno Mars] (Album Version)")
# ('Jacob', 'Klein', 'Naw Meen')
# ('Jacob', 'Klein', "Don't Close The Door")
# ('Jacob', 'Klein', 'Again & Again')
# ('Jacob', 'Klein', 'Sing')
# ('Jacob', 'Klein', 'Juguete De Nadie')
# ('Jacob', 'Klein', 'Blind (Frankie Knuckles Remix)')
# ('Jacob', 'Klein', 'Kitty Kat')
# ('Jacob', 'Klein', 'Pacific Coast Highway')
# ('Jacob', 'Klein', 'Be (Intro)')
# ('Jacob', 'Klein', 'Can You Tell')
# ('Jacob', 'Klein', 'There For You')
# ('Jacob', 'Klein', 'Danger Bird (Album Version)')
# ('Jacob', 'Klein', 'You Already Know What You Are')
# ('Jacob', 'Klein', "Sleepin' On My Couch")
# ('Jacob', 'Klein', 'La Cachila')
# ('Jacob', 'Klein', 'Do You Remember')
# ('Jacob', 'Klein', "Knockin' On Heaven's Door")
# ('Jacob', 'Klein', 'Coast 2 Coast')
# ('Jacob', 'Klein', 'Who Cares Wins')
# ('Jacob', 'Klein', 'Jane Became Insane')
# ('Anabelle', 'Simpson', 'Too Drunk Too F****')
# ('Anabelle', 'Simpson', 'Divinations (Album Version)')
# ('Anabelle', 'Simpson', "Sam's Town")
# ('Stefany', 'White', 'Right Through You (LP Version)')
# ('Kaylee', 'Summers', 'You Gotta Be')
# ('Kaylee', 'Summers', 'Flat 55')
# ('Kaylee', 'Summers', 'Quem Quiser Encontrar O Amor')
# ('Kaylee', 'Summers', 'Eriatarka')
# ('Kaylee', 'Summers', 'Becoming Insane')
# ('Kaylee', 'Summers', 'Congratulations')
# ('Kaylee', 'Summers', 'Once again')
# ('Sylvie', 'Cruz', 'Pump It')
# ('Ryan', 'Smith', 'Nobody Puts Baby In The Corner')
# ('Ryan', 'Smith', 'Mango Pickle Down River (With The Wilcannia Mob)')
# ('Jayden', 'Fox', 'Eye Of The Tiger')
# ('Mohammad', 'Rodriguez', 'Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)')
# ('Mohammad', 'Rodriguez', 'Woodstock Inprovisation')
# ('Mohammad', 'Rodriguez', 'Majesty (LP Version)')
# ('Gianna', 'Jones', 'Love Shack')
# ('Gianna', 'Jones', "Frisch und g'sund")
# ('Gianna', 'Jones', 'Look At Me')
# ('Kaylee', 'Summers', 'Ya EntendÃ\x83Â\xad')
# ('Kaylee', 'Summers', "All Tomorrow's Parties")
# ('Kaylee', 'Summers', 'Psst!')
# ('Kaylee', 'Summers', "There's Your Trouble")
# ('Kaylee', 'Summers', 'Given Up (Album Version)')
# ...
# ('Lily', 'Koch', 'Planet Caravan (Remastered LP Version)')
# ('Lily', 'Koch', 'Music')
# ('Lily', 'Koch', "Don't Stop The Fight")
# ('Lily', 'Koch', 'Everlong')
# ('Lily', 'Koch', 'Quiet Please')
# ('Lily', 'Koch', 'Never Give Up')
# ('Bronson', 'Harris', 'Mr Blue Sky')
# ('Lily', 'Koch', 'Miss Sobriety (Album Version)')
# ('Lily', 'Koch', "Rockin' Rollin' Stone")
# ('Bronson', 'Harris', 'Teardrop')
# ('Lily', 'Koch', 'Liezah')
# ('Lily', 'Koch', 'Pain & Torture')
# ('Lily', 'Koch', 'Life')
# ('Lily', 'Koch', 'Que pides tu?')
# ('Lily', 'Koch', '240 Years Before Your Time')
# ('Theodore', 'Smith', 'Besame')
# ('Lily', 'Koch', 'Numb')
# ('Lily', 'Koch', "Ain't What It Used To Be")
# ('Lily', 'Koch', 'Move Away')
# ('Lily', 'Koch', 'Right Now (Produced by Ayatollah)')
# ('Lily', 'Koch', 'Second Chance (Album Version)')
# ('Lily', 'Koch', 'Laid In Earth')
# ('Lily', 'Koch', 'I Like It Like That')
# ('Lily', 'Koch', 'The Key (Album Version)')
# ('Lily', 'Koch', 'Who Can Compare')
# ('Lily', 'Koch', 'Dame La Mano Juancho')
# ('Lily', 'Koch', "I Love Playin'  With Fire")
# ('Lily', 'Koch', 'Suddenly')
# ('Lily', 'Koch', 'El Kilo')
# ('Ava', 'Robinson', 'Nevermore (1994 Digital Remaster)')
# ('Ava', 'Robinson', 'Heartbeat Radio')
# ('Lily', 'Koch', 'Greece 2000')
# ('Lily', 'Koch', 'Festival (Of 7 Lights)')
# ('Lily', 'Koch', "Don't Be Shallow")
# ('Lily', 'Koch', 'The Black Crow Knows')
# ('Lily', 'Koch', 'Video Killed The Radio Star')
# ('Lily', 'Koch', 'Pursuit Of Happiness (nightmare)')
# ('Lily', 'Koch', 'Road To Zion')
# ('Lily', 'Koch', 'Pushing Me Away (Album Version)')
# ('Lily', 'Koch', 'Killa')
# ('Lily', 'Koch', 'Lonesome Road')
# ('Lily', 'Koch', 'Hey There Mr. Brooks (feat. Feat. Shawn Mike of Alesana)')
# ('Lily', 'Koch', 'The Chariot')
# ('Lily', 'Burns', 'Twilight Time')
# ('Lily', 'Burns', "Don't Lie")
# ('Kaleb', 'Cook', 'Invalid')
# ('Kaleb', 'Cook', 'Wrong Turn')
# ('Jayden', 'Bell', "Jim Henson's Dead")
# ('Jacob', 'Klein', 'Shell Shock')
# ('Jacob', 'Klein', 'Women Lose Weight (Feat: Slick Rick)')
# ('Jacob', 'Klein', "Won't Go Home Without You")
# ('Jacob', 'Klein', 'Hey_ Soul Sister')
# ('Jacob', 'Klein', "I'm In Miami Bitch")
# ('Jacob', 'Klein', 'Sexy Bitch')
# ('Jacob', 'Klein', 'The Cure & The Cause (Dennis Ferrer Remix)')
# ('Jacob', 'Klein', 'Staring At Me')
# ('Jacob', 'Klein', 'The Second You Sleep')
# ('Jacob', 'Klein', 'Wide Eyes')
# ('Jacob', 'Klein', 'La Resistance (Medley) (LP Version)')
# ('Jacob', 'Klein', 'Restless')
# ('Jacob', 'Klein', 'Noc...')
# ('Jacob', 'Klein', 'Like You')
# ('Jacob', 'Klein', 'God Put A Smile Upon Your Face')
# ('Jacob', 'Klein', 'Playboy')
# ('Jacob', 'Klein', 'Every Time You Go')
# ('Jacob', 'Klein', 'Natural Anthem (Album)')
# ('Aiden', 'Hess', 'Taylor')
# ('Aiden', 'Hess', 'Naked As We Can')
# ('Aiden', 'Hess', 'Fantasy')
# ('Aiden', 'Hess', 'Epilogue')
# ('Aiden', 'Hess', "Groovin'")
# ('Layla', 'Griffin', "Ain't No Way (You Won't Love Me)")
# ('Layla', 'Griffin', 'Rome')
# ('Layla', 'Griffin', 'Highway Through My Home')
# ('Layla', 'Griffin', '143')
# ('Layla', 'Griffin', 'Dreams-Come-True-Girl')
# ('Layla', 'Griffin', "I Don't Feel Like Dancin'")
# ('Layla', 'Griffin', 'Right On Time (Album Version)')
# ('Ryan', 'Smith', 'Black Lines')
# ('Layla', 'Griffin', 'Uprising')
# ('Ryan', 'Smith', 'Man Makes The Zoo')
# ('Layla', 'Griffin', 'Blacks/Radio')
# ('Ryan', 'Smith', 'Love Dealer (Featuring Justin Timberlake)')
# ('Layla', 'Griffin', 'ReprÃ\x83Â©sente')
# ('Ryan', 'Smith', 'Hey_ Soul Sister')
# ('Layla', 'Griffin', 'Up And Gone')
# ('Layla', 'Griffin', 'Te Conoci')
# ('Ryan', 'Smith', 'Bottle Pop')
# ('Layla', 'Griffin', 'My Love Will Follow You')
# ('Ryan', 'Smith', 'Found Home')
# ('Layla', 'Griffin', 'My December')
# ('Ryan', 'Smith', 'The Perfect Kiss')
# ('Layla', 'Griffin', "You're Gonna Make Me Lonesome When You Go")
# ('Ryan', 'Smith', 'Shortie Like Mine')
# ('Ryan', 'Smith', 'Domination')
# ('Chloe', 'Cuevas', 'Inside My Love (Digitally Remastered 93)')
# ('Chloe', 'Cuevas', 'Structure')
# ('Chloe', 'Cuevas', 'Killing In The Name')
# ('Katherine', 'Gay', "Girl You Know It's True")
# ('Chloe', 'Cuevas', 'Waterfall (Spirit Of The Rainforest Album Version)')
# ('Chloe', 'Cuevas', 'Robot Soul (Radio Edit)')
# ('Chloe', 'Cuevas', 'Blindfold')
# ('Chloe', 'Cuevas', "I'm Yours (Album Version)")
# ('Avery', 'Watkins', 'Say Hello')
# ('Chloe', 'Cuevas', '(I Just) Died In Your Arms')
# ('Avery', 'Watkins', 'Sweet Jane')
# ('Chloe', 'Cuevas', 'Gears')
# ('Avery', 'Watkins', 'Seven Nation Army (Album Version)')
# ('Chloe', 'Cuevas', 'Fix You')
# ('Avery', 'Watkins', 'It Could Be Sweet')
# ('Chloe', 'Cuevas', 'If This Was The Last Song')
# ('Avery', 'Watkins', 'Poppiholla')
# ('Ryann', 'Smith', 'The Unforgiven III')
# ('Chloe', 'Cuevas', 'Apresurate')
# ('Avery', 'Watkins', 'There Is')
# ('Avery', 'Watkins', 'Would That Make U Love Me')
# ('Chloe', 'Cuevas', 'Screaming Infidelities')
# ('Avery', 'Watkins', 'Big Idea')
# ('Chloe', 'Cuevas', 'Bulletproof')
# ('Avery', 'Watkins', 'The Tune')
# ('Chloe', 'Cuevas', 'Trani')
# ('Avery', 'Watkins', 'Girl Money')
# ('Chloe', 'Cuevas', 'Chloe Dancer/Crown Of Thorns')
# ('Avery', 'Watkins', 'The Bachelor and the Bride')
# ('Avery', 'Watkins', 'M')
# ('Chloe', 'Cuevas', "Nothin' On You [feat. Bruno Mars] (Album Version)")
# ('Avery', 'Watkins', 'You Sent Me Flying / Cherry')
# ('Chloe', 'Cuevas', 'Faithless')
# ('Avery', 'Watkins', 'You Only Live Once')
# ('Chloe', 'Cuevas', 'Tempting Time')
# ('Avery', 'Watkins', 'Flowers In December')
# ('Chloe', 'Cuevas', 'Take It Back')
# ('Avery', 'Watkins', 'Behind Two Hills&A Swimming Pool')
# ('Chloe', 'Cuevas', 'My First Kiss (Feat. Ke$ha) [Album Version]')
# ('Avery', 'Watkins', 'Straight Outta Compton (Extended Mix) (Edit) (Explicit)')
# ('Chloe', 'Cuevas', "Goin' Home")
# ('Avery', 'Watkins', 'Sick')
# ('Chloe', 'Cuevas', 'Fix You')
# ('Chloe', 'Cuevas', 'Half Of My Heart')
# ('Chloe', 'Cuevas', 'Revelry')
# ('Chloe', 'Cuevas', 'World Coming Down')
# ('Chloe', 'Cuevas', 'Fire')
# ('Chloe', 'Cuevas', 'Shoot Me Down')
# ('Chloe', 'Cuevas', 'Juice (Know The Ledge)')
# ('Chloe', 'Cuevas', "Hymne A L'Amour (Album Version)")
# ('Chloe', 'Cuevas', "We're Only Gonna Die (Album Version)")
# ('Chloe', 'Cuevas', 'Next Hype')
# ('Chloe', 'Cuevas', 'Fireflies')
# ('Chloe', 'Cuevas', 'Hotel California')
# ('Chloe', 'Cuevas', 'Little Wing')
# ('Chloe', 'Cuevas', 'Smothered (Album Version)')
# ('Chloe', 'Cuevas', 'Try Your Best')
# ('Chloe', 'Cuevas', 'Le Courage Des Oiseaux')
# ('Chloe', 'Cuevas', 'Lips Like Morphine (Album Version)')
# ('Chloe', 'Cuevas', 'Kiedys zrozumiesz')
# ('Braden', 'Parker', "Fallin' Apart")
# ('Chloe', 'Cuevas', "Don't Cry (Original)")
# ('Chloe', 'Cuevas', 'Transparency')
# ('Chloe', 'Cuevas', 'La Suerte De Mi Vida')
# ('Chloe', 'Cuevas', 'Redwing')
# ('Chloe', 'Cuevas', 'Starfish-On-The-Toast (2008 Digital Remaster)')
# ('Chloe', 'Cuevas', 'Illusions')
# ('Mohammad', 'Rodriguez', 'Bright Lights (Remastered Version)')
# ('Mohammad', 'Rodriguez', 'Field Goal')
# ('Mohammad', 'Rodriguez', 'Nah!')
# ('Mohammad', 'Rodriguez', 'By The Way')
# ('Mohammad', 'Rodriguez', 'Keep On Running')
# ('Mohammad', 'Rodriguez', 'I Dont Wanna Wait')
# ('Mohammad', 'Rodriguez', 'Echonomix')
# ('Mohammad', 'Rodriguez', 'One By One')
# ('Matthew', 'Jones', 'Sin Miedo a Nada (con Amaia Montero)')
# ('Matthew', 'Jones', 'Bonnie Brae')
# ('Matthew', 'Jones', 'War')
# ('Matthew', 'Jones', 'Sad Lisa')
# ('Matthew', 'Jones', 'The House That Nat Built (Album Version)')
# ('Matthew', 'Jones', 'Jealous Minds Think Alike')
# ('Matthew', 'Jones', "My Mother's Eyes")
# ('Matthew', 'Jones', 'Make Her Say')
# ('Matthew', 'Jones', 'Viaje Sin Rumbo (2004 Digital Remaster)')
# ('Matthew', 'Jones', 'Dreamdancer')
# ('Matthew', 'Jones', 'The Queen of Nothing')
# ('Ryann', 'Smith', 'Riot In Cell Block Number Nine')
# ('Matthew', 'Jones', 'Sehr kosmisch')
# ('Ryann', 'Smith', 'Everything You Love (Album Version)')
# ('Ryann', 'Smith', "Someone Else's Life")
# ('Ryann', 'Smith', 'Godine prolaze')
# ('Matthew', 'Jones', 'Private Affair (Amended Album Version)')
# ('Matthew', 'Jones', 'Ginko Biloba')
# ('Matthew', 'Jones', 'Three Day Weekend')
# ('Matthew', 'Jones', 'Meen Dah Elly Nseik')
# ('Matthew', 'Jones', 'Boot On The Seat')
# ('Matthew', 'Jones', 'FaFaFa (Radio Edit)')
# ('Matthew', 'Jones', 'Human After All')
# ('Matthew', 'Jones', 'Somebody To Love')
# ('Matthew', 'Jones', 'Real Love')
# ('Matthew', 'Jones', 'Subterranean Homesick Blues (Album Version)')
# ('Matthew', 'Jones', "Can't Break Thru")
# ('Austin', 'Rosales', 'Get Me Bodied')
# ('Chloe', 'Cuevas', 'Maybe')
# ('Chloe', 'Cuevas', 'Walk To The Water')
# ('Chloe', 'Cuevas', "I CAN'T GET STARTED")
# ('Chloe', 'Cuevas', 'Breath After Breath')
# ('Chloe', 'Cuevas', 'Head Over Heels')
# ('Chloe', 'Cuevas', 'Lonely As You')
# ('Samuel', 'Gonzalez', 'One Year_ Six Months')
# ('Chloe', 'Cuevas', 'Against The Wall')
# ('Chloe', 'Cuevas', 'Knocking On Forbidden Doors')
# ('Chloe', 'Cuevas', 'Hey Hey')
# ('Chloe', 'Cuevas', 'Somebody To Love')
# ('Chloe', 'Cuevas', 'Genom tunna tyger')
# ('Chloe', 'Cuevas', 'The Little Things Give You Away [Live At Milton Keynes]')
# ('Jahiem', 'Miles', 'Devil May Care')
# ('Chloe', 'Cuevas', "Tell Me I'm A Wreck")
# ('Chloe', 'Cuevas', 'Constellations')
# ('Chloe', 'Cuevas', 'Vuelve')
# ('Chloe', 'Cuevas', 'Give Me Anything')
# ('Chloe', 'Cuevas', 'Worm Infested')
# ('Kinsley', 'Young', 'Headlights Look Like Diamonds')
# ('Chloe', 'Cuevas', 'Hands Up')
# ('Kinsley', 'Young', 'Sweet And Wild')
# ('Chloe', 'Cuevas', 'Satellite Mind')
# ('Chloe', 'Cuevas', "You're The One")
# ('Kinsley', 'Young', 'Did You Get My Message? (Live From Montalvo)')
# ('Chloe', 'Cuevas', 'N A Whitemanzeyez')
# ('Kinsley', 'Young', 'Karma Police')
# ('Ava', 'Robinson', 'Puto')
# ('Ava', 'Robinson', 'Killing Lies')
# ('Ryan', 'Smith', 'Hallelujah')
# ('Kinsley', 'Young', "Ghosts 'n' Stuff (Original Instrumental Mix)")
# ('Chloe', 'Cuevas', "You're The Voice")
# ('Ava', 'Robinson', 'Inside Of You')
# ('Ryan', 'Smith', 'Clean Up Woman (Single/LP Version)')
# ('Chloe', 'Cuevas', 'Tranen Gelachen')
# ('Kinsley', 'Young', 'The Small Print')
# ('Chloe', 'Cuevas', 'A QuÃ\x83Â© Niegas El Delirio (MalagueÃ\x83Â±a) (Live)')
# ('Kinsley', 'Young', "It's My Life (Radio Edit)")
# ('Chloe', 'Cuevas', 'Sit Down. Stand Up')
# ('Kinsley', 'Young', 'Purple Weed')
# ('Chloe', 'Cuevas', "Someone Else's Arms")
# ('Kinsley', 'Young', "The Future Ain't What It Used To Be")
# ('Chloe', 'Cuevas', 'A-Punk (Album)')
# ('Chloe', 'Cuevas', 'Time To Pretend')
# ('Kinsley', 'Young', 'Luna y Sol')
# ('Chloe', 'Cuevas', 'Touch My Horn')
# ('Kinsley', 'Young', 'Eternity')
# ('Chloe', 'Cuevas', 'Dyed in the Wool (Album Version)')
# ('Jayden', 'Fox', 'Wretchrospective (feat. Vis)')
# ('Kinsley', 'Young', 'Simple')
# ('Jayden', 'Fox', 'Riecht wie Teen Spirit (Smells Like Teen Spirit)')
# ('Chloe', 'Cuevas', 'Adrenalin')
# ('Rylan', 'George', 'Bread & Water')
# ('Kinsley', 'Young', 'VooDoo')
# ('Chloe', 'Cuevas', 'Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)')
# ('Jayden', 'Fox', "Frankie's Office")
# ('Jayden', 'Fox', 'Fireflies')
# ('Rylan', 'George', 'Summer Breeze')
# ('Kinsley', 'Young', 'Love Shack')
# ('Jayden', 'Fox', 'Alexandra')
# ('Rylan', 'George', 'Canada')
# ('Jayden', 'Fox', 'Anthem For The Underdog')
# ('Kinsley', 'Young', 'Revelry')
# ('Rylan', 'George', 'Get Ready To Bounce Recall 08')
# ('Kinsley', 'Young', 'The Good Fight')
# ('Kinsley', 'Young', 'Low Land Moan')
# ('Mohammad', 'Rodriguez', 'In')
# ('Rylan', 'George', 'Sway')
# ('Kinsley', 'Young', 'I Miss You Now')
# ('Rylan', 'George', 'Masculine Eclipse')
# ('Mohammad', 'Rodriguez', 'As If Set Afire')
# ('Kinsley', 'Young', 'Underwater World')
# ('Rylan', 'George', 'Our Last Time')
# ('Mohammad', 'Rodriguez', 'T.N.T. For The Brain (112 Bpm) (Radio Edit)')
# ('Kinsley', 'Young', 'Tattered Banners And Bloody Flags')
# ('Rylan', 'George', 'The Great Escape (Album Version) (Explicit)')
# ('Matthew', 'Jones', 'Lacreme napulitane')
# ('Mohammad', 'Rodriguez', 'Autobiography')
# ('Kinsley', 'Young', 'The Ecstasy Of Gold')
# ('Rylan', 'George', 'Kryptonite')
# ('Matthew', 'Jones', 'No Fool (For Love)')
# ('Kinsley', 'Young', 'Pray')
# ('Rylan', 'George', 'Bubble Toes')
# ('Kinsley', 'Young', 'Lotus')
# ('Matthew', 'Jones', 'You Belong With Me')
# ('Rylan', 'George', 'Candy Rain')
# ('Kinsley', 'Young', 'Firestarter')
# ('Matthew', 'Jones', 'Addicted')
# ('Rylan', 'George', 'The Evil That Men Do (1998 Digital Remaster)')
# ('Kinsley', 'Young', 'All Around Me')
# ('Rylan', 'George', 'Everyday')
# ('Kinsley', 'Young', 'Feel It')
# ('Kinsley', 'Young', 'Overload')
# ('Rylan', 'George', 'Hold You')
# ('Rylan', 'George', 'The Way She Moves')
# ('Rylan', 'George', 'I Want Your Love')
# ('Chloe', 'Cuevas', 'Corrido de Boxeo')
# ('Rylan', 'George', 'When I Grow Up')
# ('Chloe', 'Cuevas', 'Yellow')
# ('Rylan', 'George', 'She Likes (Bittersweet Love)')
# ('Chloe', 'Cuevas', 'Believe That')
# ('Rylan', 'George', 'Through The Fire And Flames (Album Version)')
# ('Chloe', 'Cuevas', 'Lucky (Album Version)')
# ('Chloe', 'Cuevas', 'Is She Weird')
# ('Rylan', 'George', 'Without Me')
# ('Chloe', 'Cuevas', 'Cry No More')
# ('Rylan', 'George', 'Lotus')
# ('Chloe', 'Cuevas', 'Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)')
# ('Rylan', 'George', 'Le Million')
# ('Chloe', 'Cuevas', 'Only Superstition')
# ('Chloe', 'Roth', 'Bedroom Suite')
# ('Rylan', 'George', 'A New Arrangement')
# ('Chloe', 'Roth', 'The Only Exception (Album Version)')
# ('Chloe', 'Cuevas', 'Sinisten tÃ\x83Â¤htien alla')
# ('Rylan', 'George', 'Knee 2')
# ('Chloe', 'Cuevas', 'SinceritÃ\x83Â© Et Jalousie')
# ('Rylan', 'George', 'Her Voice Is Beyond Her Years')
# ('Rylan', 'George', 'If You Leave Me Now')
# ('Bronson', 'Harris', 'SinceritÃ\x83Â© Et Jalousie')
# ('Rylan', 'George', 'Diamond Dave')
# ('Bronson', 'Harris', '1999')
# ('Rylan', 'George', 'King Of Pain (Live/Unplugged Version)')
# ('Bronson', 'Harris', 'Rebirthing (Album Version)')
# ('Rylan', 'George', 'Beauty and the Beast')
# ('Rylan', 'George', 'Dressed For Friend Requests (Album Version)')
# ('Rylan', 'George', "You're The One")
# ('Rylan', 'George', "Tuesday's Child")
# ('Rylan', 'George', 'All The Right Moves')
# ('Rylan', 'George', 'Wicked')
# ('Rylan', 'George', 'My Distressor 40Khz ReRub Mix')
# ('Rylan', 'George', 'Six Days At The Bottom Of The Ocean')
# ('Chloe', 'Cuevas', 'Little Bird')
# ('Chloe', 'Cuevas', 'The Horizon Has Been Defeated')
# ('Rylan', 'George', 'Everything In Its Right Place')
# ('Chloe', 'Cuevas', 'Heretics')
# ('Rylan', 'George', 'Sabbra Cadabra')
# ('Chloe', 'Cuevas', 'Catch You Baby (Steve Pitron & Max Sanna Radio Edit)')
# ('Chloe', 'Cuevas', 'Shattered')
# ('Rylan', 'George', 'As The Rhyme Goes On')
# ('Chloe', 'Cuevas', 'Settle For A Slowdown')
# ('Rylan', 'George', 'Daniel Cowman')
# ('Chloe', 'Cuevas', 'Make You Sin')
# ('Chloe', 'Cuevas', 'Roc U')
# ('Rylan', 'George', 'Sexy Bitch')
# ('Rylan', 'George', 'Sayonara-Nostalgia')
# ('Chloe', 'Cuevas', 'In The Hands Of The Gods (Featuring Biz Markie)')
# ('Chloe', 'Cuevas', "Don't Forget To Breathe")
# ('Rylan', 'George', "Now You're Gone")
# ('Chloe', 'Cuevas', 'Undo')
# ('Rylan', 'George', 'G4L')
# ('Rylan', 'George', 'Hello')
# ('Chloe', 'Cuevas', 'Tamale')
# ('Rylan', 'George', 'Another Place')
# ('Chloe', 'Cuevas', 'Straight To Hell')
# ('Chloe', 'Cuevas', 'Cry Me A River')
# ('Rylan', 'George', 'Un Camino Hasta Vos')
# ('Chloe', 'Cuevas', 'Sura (2008 Digital Remaster)')
# ('Rylan', 'George', 'Pursuit Of Happiness (nightmare)')
# ('Chloe', 'Cuevas', 'Forever')
# ('Rylan', 'George', 'Homesick [Acoustic]')
# ('Jayden', 'Bell', 'Dead And Gone [feat. Justin Timberlake] (Explicit Album Version)')
# ('Rylan', 'George', "It'll Be a Long Time (Album Version)")
# ('Chloe', 'Cuevas', 'Esta Es Para Hacerte FÃ\x83Â©liz')
# ('Jayden', 'Bell', 'Spin Spin Sugar')
# ('Rylan', 'George', 'This War Is Ours (The Guillotine II)')
# ('Chloe', 'Cuevas', 'La Vida Es Un Ratico')
# ('Rylan', 'George', 'Never Mind')
# ('Chloe', 'Cuevas', 'Possession')
# ('Rylan', 'George', "Don't Start Me Talkin'")
# ('Rylan', 'George', 'Back To Life (However Do You Want Me) (2003 Digital Remaster) (Feat. Caron Wheeler)')
# ('Chloe', 'Cuevas', 'Dog Days Are Over (Radio Edit)')
# ('Rylan', 'George', 'Heresy  (LP Version)')
# ('Chloe', 'Cuevas', 'Remedy')
# ('Chloe', 'Cuevas', 'Frozen Angel')
# ('Rylan', 'George', 'The Pretender')
# ('Rylan', 'George', 'Besos De Ceniza')
# ('Rylan', 'George', 'Rose')
# ('Rylan', 'George', 'The Haunting')
# ('Elijah', 'Davis', 'Anything You Say (Unreleased Version)')

# %%
query = """
SELECT firstName, lastName
FROM user_by_song
WHERE song = 'All Hands Against His Own'
"""
query = session.execute(query)
print(query)
for row in query:
    print(row)
# Out:
# <cassandra.cluster.ResultSet object at 0x7f9418dfb700>
# Row(firstname='Jacqueline', lastname='Lynch')

# %% [markdown]
# ### Drop the tables before closing out the sessions

# %%
## TO-DO: Drop the table before closing out the sessions

# %% [markdown]
# ### Close the session and cluster connection¶

# %%
session.shutdown()
cluster.shutdown()
